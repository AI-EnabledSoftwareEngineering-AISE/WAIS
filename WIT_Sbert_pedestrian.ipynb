# %%
from tqdm.notebook import tqdm, trange

# %%
tqdm.pandas()

# %%
import sys

# %%
import glob
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

# %%
import os

# General packages
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import plotly.express as px
from PIL import Image

from IPython.display import Image as IImage
from IPython.display import display
import warnings
warnings.filterwarnings("ignore")

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/test/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/test/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def find_gpus(nums=6):
    os.system('nvidia-smi -q -d Memory |grep -A4 GPU|grep Free >tmp_free_gpus')
    with open('tmp_free_gpus', 'r') as lines_txt:
        frees = lines_txt.readlines()
        idx_freeMemory_pair = [ (idx,int(x.split()[2]))
                              for idx,x in enumerate(frees) ]
    idx_freeMemory_pair.sort(key=lambda my_tuple:my_tuple[1],reverse=True)
    usingGPUs = [str(idx_memory_pair[0])
                    for idx_memory_pair in idx_freeMemory_pair[:nums] ]
    usingGPUs =  ','.join(usingGPUs)
    print('using GPU idx: #', usingGPUs)
    return usingGPUs

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = find_gpus(nums=2)
# Out:
# using GPU idx: # 1,0

# %%
from nltk.corpus import stopwords
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %% [markdown]
# ## get topics

# %%
from bertopic import BERTopic

# %%
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

# %%
lemmatizer = WordNetLemmatizer()

# %%
def get_topics(concept='pedestrian'):
    if concept == 'pedestrian':
        model_path = '../ped_auto_model'
    elif concept == 'aircraft':
        model_path = '../aircraft_auto_model'
    elif concept == 'car':
        model_path = '../car_auto_model'
    auto_model = BERTopic(nr_topics="auto")
    auto_model = BERTopic.load(model_path)
    similar_topics, similarity = auto_model.find_topics(concept, top_n=50)

    topics = dict()
    for t in similar_topics:
        l1 = auto_model.get_topic(t)
        el_list = []
        el_list.append(concept)
        for el in l1:
            w = lemmatizer.lemmatize(el[0], get_wordnet_pos(el[0]))
            el_list.append(w)
        topics[t]= set(el_list)
    return topics

# %% [markdown]
# # Load files

# %%
os.listdir('/raid/AISSEL/htest/datasets/wit/')
# Out:
# ['wit_v1.train.all-00007-of-00010_context_caption_en_sbert_c.tsv',
#  'wit_v1.train.all-00009-of-00010_context_caption_en_sbert_c.tsv',
#  '__MACOSX',
#  'wit_v1.train.all-1percent_sample.tsv',
#  'wit_v1.train.all-00000-of-00010_en_csim.tsv',
#  'wit_v1.train.all-00006-of-00010_context_caption_en_sbert_cpa.tsv',
#  'wit_v1.train.all-00008-of-00010_context_caption_en_sbert_cpa.tsv',
#  'aircraft_q75_en_sbert.tsv',
#  'images',
#  'wit_v1.train.all-00000-of-00010_context_caption_en_sbert_cpa.tsv',
#  'wit_v1.train.all-00001-of-00010_context_caption_en_sbert_cpa.tsv',
#  'wit_v1.train.all-00002-of-00010_context_caption_en_sbert_cpa.tsv',
#  'wit_v1.train.all-00003-of-00010_context_caption_en_sbert_cpa.tsv',
#  'wit_v1.train.all-00004-of-00010_context_caption_en_sbert_cpa.tsv',
#  'wit_v1.train.all-00005-of-00010_context_caption_en_sbert_cpa.tsv',
#  'wit_v1.train.all-00007-of-00010_context_caption_en_sbert_cpa.tsv',
#  'wit_v1.train.all-00009-of-00010_context_caption_en_sbert_cpa.tsv',
#  'wit_v1.train.all-00000-of-00010_context_caption_en_sbert_c.tsv',
#  'wit_v1.train.all-00001-of-00010_context_caption_en_sbert_c.tsv',
#  'wit_v1.train.all-00002-of-00010_context_caption_en_sbert_c.tsv',
#  'wit_v1.train.all-00003-of-00010_context_caption_en_sbert_c.tsv',
#  'wit_v1.train.all-00004-of-00010_context_caption_en_sbert_c.tsv',
#  'wit_v1.train.all-00005-of-00010_context_caption_en_sbert_c.tsv',
#  'wit_v1.train.all-00006-of-00010_context_caption_en_sbert_c.tsv',
#  'wit_v1.train.all-00008-of-00010_context_caption_en_sbert_c.tsv']

# %%
root_path = '/raid/AISSEL/htest/datasets/wit'

# %%
f_names =[el for el in os.listdir('/raid/AISSEL/htest/datasets/wit/') if el.endswith('_en_sbert_cpa.tsv')]
f_names
# Out:
# ['wit_v1.train.all-00006-of-00010_context_caption_en_sbert_cpa.tsv',
#  'wit_v1.train.all-00008-of-00010_context_caption_en_sbert_cpa.tsv',
#  'wit_v1.train.all-00000-of-00010_context_caption_en_sbert_cpa.tsv',
#  'wit_v1.train.all-00001-of-00010_context_caption_en_sbert_cpa.tsv',
#  'wit_v1.train.all-00002-of-00010_context_caption_en_sbert_cpa.tsv',
#  'wit_v1.train.all-00003-of-00010_context_caption_en_sbert_cpa.tsv',
#  'wit_v1.train.all-00004-of-00010_context_caption_en_sbert_cpa.tsv',
#  'wit_v1.train.all-00005-of-00010_context_caption_en_sbert_cpa.tsv',
#  'wit_v1.train.all-00007-of-00010_context_caption_en_sbert_cpa.tsv',
#  'wit_v1.train.all-00009-of-00010_context_caption_en_sbert_cpa.tsv']

# %%
df = pd.read_csv(f'{root_path}/{f_names[0]}', sep='\t')
df = df.drop('Unnamed: 0', 1)
df = df[df["language"]=='en']
df
# Out:
#           index language                                           page_url  \
# 0            14       en          https://en.wikipedia.org/wiki/LibreOffice
# 1            28       en               https://en.wikipedia.org/wiki/Dalian
# 2            41       en  https://en.wikipedia.org/wiki/FMW_7th_Annivers...
# 3            50       en  https://en.wikipedia.org/wiki/List_of_Bermuda_...
# 4            52       en       https://en.wikipedia.org/wiki/Parimelalhagar
# ...         ...      ...                                                ...
# 540382  3704673       en  https://en.wikipedia.org/wiki/Standard_Electri...
# 540383  3704674       en  https://en.wikipedia.org/wiki/Malaysia_Airline...
# 540384  3704675       en         https://en.wikipedia.org/wiki/Jackson_Plan
# 540385  3704677       en         https://en.wikipedia.org/wiki/Candiacervus
# 540386  3704681       en  https://en.wikipedia.org/wiki/June_2038_lunar_...
#
#                                                 image_url  \
# 0       https://upload.wikimedia.org/wikipedia/commons...
# 1       https://upload.wikimedia.org/wikipedia/commons...
# 2       https://upload.wikimedia.org/wikipedia/commons...
# 3       https://upload.wikimedia.org/wikipedia/commons...
# 4       https://upload.wikimedia.org/wikipedia/commons...
# ...                                                   ...
# 540382  https://upload.wikimedia.org/wikipedia/commons...
# 540383  https://upload.wikimedia.org/wikipedia/commons...
# 540384  https://upload.wikimedia.org/wikipedia/commons...
# 540385  https://upload.wikimedia.org/wikipedia/commons...
# 540386  https://upload.wikimedia.org/wikipedia/commons...
#
#                             page_title                 section_title  \
# 0                          LibreOffice         Included applications
# 1                               Dalian              Research centres
# 2             FMW 7th Anniversary Show                           NaN
# 3           List of Bermuda hurricanes                         1960s
# 4                       Parimelalhagar                    Early life
# ...                                ...                           ...
# 540382  Standard Electric Time Company                           NaN
# 540383    Malaysia Airlines Flight 370                      Analysis
# 540384                    Jackson Plan                Overall layout
# 540385                    Candiacervus                      Taxonomy
# 540386         June 2038 lunar eclipse  Lunar year series (354 days)
#
#                                hierarchical_section_title  \
# 0          LibreOffice / Features / Included applications
# 1                   Dalian / Education / Research centres
# 2                                FMW 7th Anniversary Show
# 3       List of Bermuda hurricanes / List of storms / ...
# 4                             Parimelalhagar / Early life
# ...                                                   ...
# 540382                     Standard Electric Time Company
# 540383  Malaysia Airlines Flight 370 / Investigation /...
# 540384  Jackson Plan / Layout and effect of the plan /...
# 540385                            Candiacervus / Taxonomy
# 540386  June 2038 lunar eclipse / Related lunar eclips...
#
#                             caption_reference_description  \
# 0                      LibreOffice Math running on Ubuntu
# 1       Dalian Institute of Chemical Physics, of the C...
# 2                                        Kawasaki Stadium
# 3       Hurricane Inga, one of the longest-lived Atlan...
# 4       A page from the Parimelalhagar's commentary on...
# ...                                                   ...
# 540382          A Standard 200177 fire alarm pull station
# 540383  A heat map indicating the probable location of...
# 540384  Map of Singapore in 1914, the layout is now mo...
# 540385          Hippopotamus creutzburgi and C. cretensis
# 540386                                                NaN
#
#                           caption_attribution_description  \
# 0       English: Screenshots of LibreOffice Math 6.4 r...
# 1                                                     NaN
# 2       English: kawasaki_fujimi Stadium 日本語: 川崎富士見球技場...
# 3       Saffir-Simpson Hurricane ScaleTDTS12345 Englis...
# 4       English: A page from Arumuka Navalar's 1861 ed...
# ...                                                   ...
# 540382  English: A Standard 200177 pull station in Har...
# 540383  English: Probability of the location where Mal...
# 540384  English: Map of the city of Singapore, ca 1914...
# 540385  English: My drawings of the two subspecies of ...
# 540386  English: May 2041 lunar eclipse chart of moon'...
#
#                              caption_alt_text_description  ...  \
# 0                                                     NaN  ...
# 1                                                     NaN  ...
# 2                                                     NaN  ...
# 3       Map showing the path and intensity of Hurrican...  ...
# 4                                                     NaN  ...
# ...                                                   ...  ...
# 540382                                                NaN  ...
# 540383                                                NaN  ...
# 540384                                                NaN  ...
# 540385                                                NaN  ...
# 540386                                                NaN  ...
#
#        296_context_score  144_context_score  12_context_score  \
# 0              -0.037750          -0.025831         -0.045994
# 1               0.070782           0.014916          0.060768
# 2               0.048340           0.031444         -0.178475
# 3              -0.104979          -0.117618         -0.052297
# 4               0.013991          -0.050420         -0.043610
# ...                  ...                ...               ...
# 540382         -0.033670          -0.089871         -0.052723
# 540383         -0.060926          -0.013728         -0.057422
# 540384          0.071714           0.023376          0.013262
# 540385          0.145484          -0.006134          0.115790
# 540386          0.091200           0.022706          0.098075
#
#         224_context_score  250_context_score  376_context_score  \
# 0               -0.067079           0.128117          -0.067173
# 1                0.137923           0.051047           0.125953
# 2                0.042817           0.119373           0.045854
# 3               -0.031839          -0.167693          -0.054938
# 4               -0.030726           0.036060          -0.098819
# ...                   ...                ...                ...
# 540382          -0.037692          -0.037566           0.038821
# 540383           0.144767          -0.017854          -0.034770
# 540384           0.339486           0.056978           0.012006
# 540385          -0.039335           0.091558           0.093865
# 540386           0.079430           0.069115           0.060533
#
#        concept_caption_score concept_context_score car_caption_score  \
# 0                  -0.040416             -0.020415         -0.032282
# 1                   0.004426              0.083636          0.018341
# 2                   0.090404             -0.012327          0.029681
# 3                   0.005365             -0.095421          0.068992
# 4                   0.025255             -0.061983         -0.008257
# ...                      ...                   ...               ...
# 540382              0.130745             -0.079322          0.099379
# 540383             -0.007270              0.046857          0.060193
# 540384              0.018857              0.090633         -0.003516
# 540385              0.052330              0.046950          0.023961
# 540386              0.121551              0.082193          0.058295
#
#        aircraft_caption_score
# 0                   -0.006119
# 1                    0.077601
# 2                    0.181104
# 3                    0.103214
# 4                    0.057020
# ...                       ...
# 540382               0.133040
# 540383               0.218703
# 540384              -0.021940
# 540385              -0.041651
# 540386               0.015714
#
# [540387 rows x 124 columns]

# %%
concept_col = ['concept_caption_score', 'car_caption_score', 'aircraft_caption_score']
new_cols = [el for el in list(df.columns) if '_score' in el]
org_cols = [el for el in list(df.columns) if not '_score' in el]

# %%
caption_score_list = [el for el in df.columns if 'caption_score' in el]
print(caption_score_list)
# Out:
# ['196_caption_score', '412_caption_score', '172_caption_score', '363_caption_score', '198_caption_score', '114_caption_score', '419_caption_score', '294_caption_score', '388_caption_score', '314_caption_score', '98_caption_score', '80_caption_score', '134_caption_score', '432_caption_score', '394_caption_score', '53_caption_score', '56_caption_score', '150_caption_score', '278_caption_score', '-1_caption_score', '43_caption_score', '265_caption_score', '345_caption_score', '378_caption_score', '11_caption_score', '331_caption_score', '202_caption_score', '169_caption_score', '327_caption_score', '309_caption_score', '68_caption_score', '216_caption_score', '40_caption_score', '99_caption_score', '426_caption_score', '344_caption_score', '47_caption_score', '8_caption_score', '416_caption_score', '112_caption_score', '137_caption_score', '441_caption_score', '192_caption_score', '20_caption_score', '296_caption_score', '144_caption_score', '12_caption_score', '224_caption_score', '250_caption_score', '376_caption_score', 'concept_caption_score', 'car_caption_score', 'aircraft_caption_score']

# %%
caption_score_list = caption_score_list[:-3]
print(caption_score_list)
# Out:
# ['196_caption_score', '412_caption_score', '172_caption_score', '363_caption_score', '198_caption_score', '114_caption_score', '419_caption_score', '294_caption_score', '388_caption_score', '314_caption_score', '98_caption_score', '80_caption_score', '134_caption_score', '432_caption_score', '394_caption_score', '53_caption_score', '56_caption_score', '150_caption_score', '278_caption_score', '-1_caption_score', '43_caption_score', '265_caption_score', '345_caption_score', '378_caption_score', '11_caption_score', '331_caption_score', '202_caption_score', '169_caption_score', '327_caption_score', '309_caption_score', '68_caption_score', '216_caption_score', '40_caption_score', '99_caption_score', '426_caption_score', '344_caption_score', '47_caption_score', '8_caption_score', '416_caption_score', '112_caption_score', '137_caption_score', '441_caption_score', '192_caption_score', '20_caption_score', '296_caption_score', '144_caption_score', '12_caption_score', '224_caption_score', '250_caption_score', '376_caption_score']

# %%
context_score_list = [el for el in df.columns if 'context_score' in el]
context_score_list = context_score_list[:-1]
print(context_score_list)
# Out:
# ['196_context_score', '412_context_score', '172_context_score', '363_context_score', '198_context_score', '114_context_score', '419_context_score', '294_context_score', '388_context_score', '314_context_score', '98_context_score', '80_context_score', '134_context_score', '432_context_score', '394_context_score', '53_context_score', '56_context_score', '150_context_score', '278_context_score', '-1_context_score', '43_context_score', '265_context_score', '345_context_score', '378_context_score', '11_context_score', '331_context_score', '202_context_score', '169_context_score', '327_context_score', '309_context_score', '68_context_score', '216_context_score', '40_context_score', '99_context_score', '426_context_score', '344_context_score', '47_context_score', '8_context_score', '416_context_score', '112_context_score', '137_context_score', '441_context_score', '192_context_score', '20_context_score', '296_context_score', '144_context_score', '12_context_score', '224_context_score', '250_context_score', '376_context_score']

# %%
# b, f, g, i, m

# %%
im_c = ['image_url', 'caption', 'context']
cap_s = ['concept_caption_score']
con_s = ['concept_context_score']
plus_col = ['car_caption_score', 'aircraft_caption_score']
col_list = im_c + cap_s + con_s + caption_score_list + context_score_list

# %%
col_list
# Out:
# ['image_url',
#  'caption',
#  'context',
#  'concept_caption_score',
#  'concept_context_score',
#  '196_caption_score',
#  '412_caption_score',
#  '172_caption_score',
#  '363_caption_score',
#  '198_caption_score',
#  '114_caption_score',
#  '419_caption_score',
#  '294_caption_score',
#  '388_caption_score',
#  '314_caption_score',
#  '98_caption_score',
#  '80_caption_score',
#  '134_caption_score',
#  '432_caption_score',
#  '394_caption_score',
#  '53_caption_score',
#  '56_caption_score',
#  '150_caption_score',
#  '278_caption_score',
#  '-1_caption_score',
#  '43_caption_score',
#  '265_caption_score',
#  '345_caption_score',
#  '378_caption_score',
#  '11_caption_score',
#  '331_caption_score',
#  '202_caption_score',
#  '169_caption_score',
#  '327_caption_score',
#  '309_caption_score',
#  '68_caption_score',
#  '216_caption_score',
#  '40_caption_score',
#  '99_caption_score',
#  '426_caption_score',
#  '344_caption_score',
#  '47_caption_score',
#  '8_caption_score',
#  '416_caption_score',
#  '112_caption_score',
#  '137_caption_score',
#  '441_caption_score',
#  '192_caption_score',
#  '20_caption_score',
#  '296_caption_score',
#  '144_caption_score',
#  '12_caption_score',
#  '224_caption_score',
#  '250_caption_score',
#  '376_caption_score',
#  '196_context_score',
#  '412_context_score',
#  '172_context_score',
#  '363_context_score',
#  '198_context_score',
#  '114_context_score',
#  '419_context_score',
#  '294_context_score',
#  '388_context_score',
#  '314_context_score',
#  '98_context_score',
#  '80_context_score',
#  '134_context_score',
#  '432_context_score',
#  '394_context_score',
#  '53_context_score',
#  '56_context_score',
#  '150_context_score',
#  '278_context_score',
#  '-1_context_score',
#  '43_context_score',
#  '265_context_score',
#  '345_context_score',
#  '378_context_score',
#  '11_context_score',
#  '331_context_score',
#  '202_context_score',
#  '169_context_score',
#  '327_context_score',
#  '309_context_score',
#  '68_context_score',
#  '216_context_score',
#  '40_context_score',
#  '99_context_score',
#  '426_context_score',
#  '344_context_score',
#  '47_context_score',
#  '8_context_score',
#  '416_context_score',
#  '112_context_score',
#  '137_context_score',
#  '441_context_score',
#  '192_context_score',
#  '20_context_score',
#  '296_context_score',
#  '144_context_score',
#  '12_context_score',
#  '224_context_score',
#  '250_context_score',
#  '376_context_score']

# %%
csim_df = pd.DataFrame()
df = df.reset_index(drop=True)
csim_df = pd.concat([csim_df, df], ignore_index=True)
csim_df
# Out:
#           index language                                           page_url  \
# 0            14       en          https://en.wikipedia.org/wiki/LibreOffice
# 1            28       en               https://en.wikipedia.org/wiki/Dalian
# 2            41       en  https://en.wikipedia.org/wiki/FMW_7th_Annivers...
# 3            50       en  https://en.wikipedia.org/wiki/List_of_Bermuda_...
# 4            52       en       https://en.wikipedia.org/wiki/Parimelalhagar
# ...         ...      ...                                                ...
# 540382  3704673       en  https://en.wikipedia.org/wiki/Standard_Electri...
# 540383  3704674       en  https://en.wikipedia.org/wiki/Malaysia_Airline...
# 540384  3704675       en         https://en.wikipedia.org/wiki/Jackson_Plan
# 540385  3704677       en         https://en.wikipedia.org/wiki/Candiacervus
# 540386  3704681       en  https://en.wikipedia.org/wiki/June_2038_lunar_...
#
#                                                 image_url  \
# 0       https://upload.wikimedia.org/wikipedia/commons...
# 1       https://upload.wikimedia.org/wikipedia/commons...
# 2       https://upload.wikimedia.org/wikipedia/commons...
# 3       https://upload.wikimedia.org/wikipedia/commons...
# 4       https://upload.wikimedia.org/wikipedia/commons...
# ...                                                   ...
# 540382  https://upload.wikimedia.org/wikipedia/commons...
# 540383  https://upload.wikimedia.org/wikipedia/commons...
# 540384  https://upload.wikimedia.org/wikipedia/commons...
# 540385  https://upload.wikimedia.org/wikipedia/commons...
# 540386  https://upload.wikimedia.org/wikipedia/commons...
#
#                             page_title                 section_title  \
# 0                          LibreOffice         Included applications
# 1                               Dalian              Research centres
# 2             FMW 7th Anniversary Show                           NaN
# 3           List of Bermuda hurricanes                         1960s
# 4                       Parimelalhagar                    Early life
# ...                                ...                           ...
# 540382  Standard Electric Time Company                           NaN
# 540383    Malaysia Airlines Flight 370                      Analysis
# 540384                    Jackson Plan                Overall layout
# 540385                    Candiacervus                      Taxonomy
# 540386         June 2038 lunar eclipse  Lunar year series (354 days)
#
#                                hierarchical_section_title  \
# 0          LibreOffice / Features / Included applications
# 1                   Dalian / Education / Research centres
# 2                                FMW 7th Anniversary Show
# 3       List of Bermuda hurricanes / List of storms / ...
# 4                             Parimelalhagar / Early life
# ...                                                   ...
# 540382                     Standard Electric Time Company
# 540383  Malaysia Airlines Flight 370 / Investigation /...
# 540384  Jackson Plan / Layout and effect of the plan /...
# 540385                            Candiacervus / Taxonomy
# 540386  June 2038 lunar eclipse / Related lunar eclips...
#
#                             caption_reference_description  \
# 0                      LibreOffice Math running on Ubuntu
# 1       Dalian Institute of Chemical Physics, of the C...
# 2                                        Kawasaki Stadium
# 3       Hurricane Inga, one of the longest-lived Atlan...
# 4       A page from the Parimelalhagar's commentary on...
# ...                                                   ...
# 540382          A Standard 200177 fire alarm pull station
# 540383  A heat map indicating the probable location of...
# 540384  Map of Singapore in 1914, the layout is now mo...
# 540385          Hippopotamus creutzburgi and C. cretensis
# 540386                                                NaN
#
#                           caption_attribution_description  \
# 0       English: Screenshots of LibreOffice Math 6.4 r...
# 1                                                     NaN
# 2       English: kawasaki_fujimi Stadium 日本語: 川崎富士見球技場...
# 3       Saffir-Simpson Hurricane ScaleTDTS12345 Englis...
# 4       English: A page from Arumuka Navalar's 1861 ed...
# ...                                                   ...
# 540382  English: A Standard 200177 pull station in Har...
# 540383  English: Probability of the location where Mal...
# 540384  English: Map of the city of Singapore, ca 1914...
# 540385  English: My drawings of the two subspecies of ...
# 540386  English: May 2041 lunar eclipse chart of moon'...
#
#                              caption_alt_text_description  ...  \
# 0                                                     NaN  ...
# 1                                                     NaN  ...
# 2                                                     NaN  ...
# 3       Map showing the path and intensity of Hurrican...  ...
# 4                                                     NaN  ...
# ...                                                   ...  ...
# 540382                                                NaN  ...
# 540383                                                NaN  ...
# 540384                                                NaN  ...
# 540385                                                NaN  ...
# 540386                                                NaN  ...
#
#        296_context_score  144_context_score  12_context_score  \
# 0              -0.037750          -0.025831         -0.045994
# 1               0.070782           0.014916          0.060768
# 2               0.048340           0.031444         -0.178475
# 3              -0.104979          -0.117618         -0.052297
# 4               0.013991          -0.050420         -0.043610
# ...                  ...                ...               ...
# 540382         -0.033670          -0.089871         -0.052723
# 540383         -0.060926          -0.013728         -0.057422
# 540384          0.071714           0.023376          0.013262
# 540385          0.145484          -0.006134          0.115790
# 540386          0.091200           0.022706          0.098075
#
#         224_context_score  250_context_score  376_context_score  \
# 0               -0.067079           0.128117          -0.067173
# 1                0.137923           0.051047           0.125953
# 2                0.042817           0.119373           0.045854
# 3               -0.031839          -0.167693          -0.054938
# 4               -0.030726           0.036060          -0.098819
# ...                   ...                ...                ...
# 540382          -0.037692          -0.037566           0.038821
# 540383           0.144767          -0.017854          -0.034770
# 540384           0.339486           0.056978           0.012006
# 540385          -0.039335           0.091558           0.093865
# 540386           0.079430           0.069115           0.060533
#
#        concept_caption_score concept_context_score car_caption_score  \
# 0                  -0.040416             -0.020415         -0.032282
# 1                   0.004426              0.083636          0.018341
# 2                   0.090404             -0.012327          0.029681
# 3                   0.005365             -0.095421          0.068992
# 4                   0.025255             -0.061983         -0.008257
# ...                      ...                   ...               ...
# 540382              0.130745             -0.079322          0.099379
# 540383             -0.007270              0.046857          0.060193
# 540384              0.018857              0.090633         -0.003516
# 540385              0.052330              0.046950          0.023961
# 540386              0.121551              0.082193          0.058295
#
#        aircraft_caption_score
# 0                   -0.006119
# 1                    0.077601
# 2                    0.181104
# 3                    0.103214
# 4                    0.057020
# ...                       ...
# 540382               0.133040
# 540383               0.218703
# 540384              -0.021940
# 540385              -0.041651
# 540386               0.015714
#
# [540387 rows x 124 columns]

# %%
csim_df = pd.DataFrame()
for idx, fn in tqdm(enumerate(f_names)):
#     if idx == 2:
#         break
    df = pd.read_csv(f'{root_path}/{fn}', sep='\t')
    df = df.drop('Unnamed: 0', 1)
    df = df[df["language"]=='en']
    df = df[col_list]
#     df_1 = df_1.sort_values(by=['196_score'], ascending=False)
    df = df.reset_index(drop=True)
    csim_df = pd.concat([csim_df, df], ignore_index=True)
# Out:
# 0it [00:00, ?it/s]

# %%
# csim_df.sort_values(by=['196_score'], ascending=False)
csim_df
# Out:
#                                                  image_url  \
# 0        https://upload.wikimedia.org/wikipedia/commons...
# 1        https://upload.wikimedia.org/wikipedia/commons...
# 2        https://upload.wikimedia.org/wikipedia/commons...
# 3        https://upload.wikimedia.org/wikipedia/commons...
# 4        https://upload.wikimedia.org/wikipedia/commons...
# ...                                                    ...
# 5411973  https://upload.wikimedia.org/wikipedia/commons...
# 5411974  https://upload.wikimedia.org/wikipedia/commons...
# 5411975  https://upload.wikimedia.org/wikipedia/commons...
# 5411976  https://upload.wikimedia.org/wikipedia/commons...
# 5411977  http://upload.wikimedia.org/wikipedia/commons/...
#
#                                                    caption  \
# 0        LibreOffice Math running on Ubuntu English: Sc...
# 1        Dalian Institute of Chemical Physics, of the C...
# 2        Kawasaki Stadium English: kawasaki_fujimi Stad...
# 3        Hurricane Inga, one of the longest-lived Atlan...
# 4        A page from the Parimelalhagar's commentary on...
# ...                                                    ...
# 5411973   English: Jia Jingde, politician of China. 中文:...
# 5411974                         Beyer in 2013 DSC_9909.jpg
# 5411975  Kannagi in Tamil Nadu. English: Idol of Kannak...
# 5411976   English: Landscape with stormy clouds and a p...
# 5411977                     Main square English: Maria Alm
#
#                                                    context  \
# 0        LibreOffice is a free and open-source office s...
# 1        Dalian is a major sub-provincial port city in ...
# 2        FMW 7th Anniversary Show was a professional wr...
# 3        The British Overseas Territory of Bermuda has ...
# 4        Parimelalhagar, also known as Vanthuvarai Peru...
# ...                                                    ...
# 5411973  This is a list of Vice Presidents of the Exami...
# 5411974  Brennen Beyer is an American football outside ...
# 5411975  Kannagi, sometimes spelled Kannaki, is a legen...
# 5411976  Don Det, is an island in the Mekong River in t...
# 5411977  Maria Alm am Steinernen Meer is a municipality...
#
#          concept_caption_score  concept_context_score  196_caption_score  \
# 0                    -0.040416              -0.020415           0.002686
# 1                     0.004426               0.083636          -0.045319
# 2                     0.090404              -0.012327          -0.049097
# 3                     0.005365              -0.095421          -0.057836
# 4                     0.025255              -0.061983           0.028717
# ...                        ...                    ...                ...
# 5411973               0.156600               0.093868          -0.021200
# 5411974               0.185849               0.191958           0.046954
# 5411975               0.065777               0.075305          -0.023543
# 5411976               0.051398               0.021199           0.041571
# 5411977               0.132863               0.067726           0.016267
#
#          412_caption_score  172_caption_score  363_caption_score  \
# 0                 0.042616           0.010594          -0.072686
# 1                -0.014597           0.050622          -0.052078
# 2                -0.018047          -0.039384          -0.064661
# 3                -0.039939          -0.033494          -0.033917
# 4                -0.008050           0.003633          -0.019985
# ...                    ...                ...                ...
# 5411973           0.070536           0.045870          -0.022279
# 5411974           0.072107           0.109573           0.070777
# 5411975          -0.038281           0.073440           0.010564
# 5411976           0.041349           0.022871          -0.075316
# 5411977           0.044567           0.107833           0.021157
#
#          198_caption_score  ...  137_context_score  441_context_score  \
# 0                -0.080525  ...          -0.026707           0.017691
# 1                 0.002163  ...           0.090900           0.139327
# 2                 0.037314  ...          -0.093685          -0.231178
# 3                -0.042589  ...          -0.134550          -0.122756
# 4                -0.025944  ...          -0.037593           0.069883
# ...                    ...  ...                ...                ...
# 5411973           0.064005  ...           0.064688          -0.003800
# 5411974           0.164449  ...           0.028834           0.043354
# 5411975           0.030676  ...           0.136019           0.181244
# 5411976          -0.023433  ...          -0.032127           0.073285
# 5411977          -0.039297  ...           0.072975           0.077708
#
#          192_context_score  20_context_score  296_context_score  \
# 0                -0.051926         -0.086811          -0.037750
# 1                 0.108564          0.032219           0.070782
# 2                -0.015962          0.008826           0.048340
# 3                -0.088162         -0.107879          -0.104979
# 4                -0.044136         -0.007787           0.013991
# ...                    ...               ...                ...
# 5411973           0.079544          0.097345           0.022783
# 5411974           0.121015          0.170634           0.032242
# 5411975           0.122867          0.101799           0.063076
# 5411976           0.013086         -0.011777           0.021279
# 5411977          -0.008408          0.007715           0.087564
#
#          144_context_score  12_context_score  224_context_score  \
# 0                -0.025831         -0.045994          -0.067079
# 1                 0.014916          0.060768           0.137923
# 2                 0.031444         -0.178475           0.042817
# 3                -0.117618         -0.052297          -0.031839
# 4                -0.050420         -0.043610          -0.030726
# ...                    ...               ...                ...
# 5411973           0.035481         -0.009618           0.142356
# 5411974           0.086187          0.108909          -0.038890
# 5411975           0.023685          0.042369           0.136377
# max         5.750273e-01      5.424188e-01       5.708867e-01
#
#        144_context_score  12_context_score  224_context_score  \
# count       5.411978e+06      5.411978e+06       5.411978e+06
# mean        7.522690e-04      1.043332e-02       1.692591e-02
# std         6.067205e-02      7.671057e-02       8.884871e-02
# min        -2.660354e-01     -3.073893e-01      -3.283010e-01
# 25%        -4.113004e-02     -4.181451e-02      -4.457409e-02
# 50%        -1.201854e-03      6.485071e-03       1.087677e-02
# 75%         4.067654e-02      5.814612e-02       7.209412e-02
# max         4.586499e-01      6.041094e-01       5.891490e-01
#
#        250_context_score  376_context_score
# count       5.411978e+06       5.411978e+06
# mean        1.978357e-02       7.244231e-03
# std         6.969397e-02       7.776987e-02
# min        -2.828747e-01      -3.845060e-01
# 25%        -2.812582e-02      -4.579195e-02
# 50%         1.813048e-02       4.907532e-03
# 75%         6.618579e-02       5.781632e-02
# max         4.600561e-01       5.546166e-01
#
# [8 rows x 102 columns]

# %%
csim_df[['concept_caption_score']].describe().round(3)
# Out:
#        concept_caption_score
# count            5411978.000
# mean                   0.087
# std                    0.070
# min                   -0.239
# 25%                    0.040
# 50%                    0.087
# 75%                    0.134
# max                    0.729

# %%
# df_p = csim_df[csim_df['concept_caption_score'] >= csim_df['concept_caption_score'].mean()]
df_p = csim_df[csim_df['concept_caption_score'] >= 0.134]
df_p = df_p.reset_index(drop=True)
df_p
# Out:
#                                                  image_url  \
# 0        https://upload.wikimedia.org/wikipedia/commons...
# 1        https://upload.wikimedia.org/wikipedia/commons...
# 2        https://upload.wikimedia.org/wikipedia/commons...
# 3        https://upload.wikimedia.org/wikipedia/commons...
# 4        https://upload.wikimedia.org/wikipedia/commons...
# ...                                                    ...
# 1355833  https://upload.wikimedia.org/wikipedia/commons...
# 1355834  https://upload.wikimedia.org/wikipedia/commons...
# 1355835  https://upload.wikimedia.org/wikipedia/commons...
# 1355836  https://upload.wikimedia.org/wikipedia/commons...
# 1355837  https://upload.wikimedia.org/wikipedia/commons...
#
#                                                    caption  \
# 0        Menachem Mendel Schneerson English: Menachem M...
# 1         English: Image cropped from a baseball card o...
# 2        The special theory of relativity, formulated i...
# 3                       English: Randy Stonehill Signature
# 4         English: United States Senator William Proxmi...
# ...                                                    ...
# 1355833  Massachusetts Bay Transportation Authority 170...
# 1355834   A map showing the path of State Highway 22 in...
# 1355835                                     English: CIPET
# 1355836   English: Jia Jingde, politician of China. 中文:...
# 1355837                         Beyer in 2013 DSC_9909.jpg
#
#                                                    context  \
# 0        1994 was a common year starting on Saturday of...
# 1        Donald Robert "Duffy" Dyer is an American form...
# 2        In relativistic physics, a velocity-addition f...
# 3        Randall Evan Stonehill is an American singer a...
# 4        Edward William Proxmire was an American politi...
# ...                                                    ...
# 1355833  The Urban Transportation Development Corporati...
# 1355834  State Highway 22 is a state highway in Oklahom...
# 1355835  Central Institute of Petrochemical Engineering...
# 1355836  This is a list of Vice Presidents of the Exami...
# 1355837  Brennen Beyer is an American football outside ...
#
#          concept_caption_score  concept_context_score  196_caption_score  \
# count            1355838.000            1355838.000        1355838.000
# mean                   0.176                  0.063              0.086
# std                    0.036                  0.066              0.070
# min                    0.134                 -0.234             -0.149
# 25%                    0.149                  0.019              0.036
# 50%                    0.167                  0.062              0.076
# 75%                    0.195                  0.105              0.125
# max                    0.729                  0.689              0.755
#
#        412_caption_score  172_caption_score  363_caption_score  \
# count        1355838.000        1355838.000        1355838.000
# mean               0.087              0.111              0.057
# std                0.059              0.065              0.053
# min               -0.126             -0.115             -0.166
# 25%                0.045              0.066              0.020
# 50%                0.081              0.104              0.054
# 75%                0.123              0.148              0.090
# max                0.610              0.615              0.510
#
#        198_caption_score  114_caption_score  419_caption_score  \
# count        1355838.000        1355838.000        1355838.000
# mean               0.093              0.103              0.114
# std                0.070              0.061              0.079
# min               -0.164             -0.126             -0.138
# 25%                0.044              0.061              0.059
# 50%                0.089              0.099              0.103
# 75%                0.137              0.140              0.158
# max                0.610              0.714              0.614
#
#        294_caption_score  ...  137_context_score  441_context_score  \
# count        1355838.000  ...        1355838.000        1355838.000
# mean               0.094  ...              0.043              0.012
# std                0.054  ...              0.084              0.077
# min               -0.122  ...             -0.291             -0.331
# 25%                0.057  ...             -0.014             -0.040
# 50%                0.088  ...              0.038              0.011
# 75%                0.124  ...              0.094              0.062
# max                0.612  ...              0.547              0.556
#
#        192_context_score  20_context_score  296_context_score  \
# count        1355838.000       1355838.000        1355838.000
# mean               0.019             0.027              0.056
# std                0.060             0.067              0.089
# min               -0.270            -0.272             -0.278
# 25%               -0.022            -0.018             -0.006
# 50%                0.019             0.025              0.049
# 75%                0.059             0.070              0.108
# max                0.536             0.515              0.561
#
#        144_context_score  12_context_score  224_context_score  \
# count        1355838.000       1355838.000        1355838.000
# mean               0.023             0.032              0.043
# std                0.059             0.079              0.094
# min               -0.254            -0.266             -0.302
# 25%               -0.018            -0.023             -0.023
# 50%                0.021             0.028              0.035
# 75%                0.061             0.081              0.100
# max                0.459             0.604              0.589
#
#        250_context_score  376_context_score
# count        1355838.000        1355838.000
# mean               0.036              0.026
# std                0.070              0.078
# min               -0.268             -0.296
# 25%               -0.012             -0.028
# 50%                0.035              0.023
# 75%                0.083              0.077
# max                0.417              0.540
#
# [8 rows x 102 columns]

# %%
df_dict = dict()
for col in caption_score_list:
    num, _ = col.split('_', 1)
    c_list = [col] + [f'{num}_context_score'] + im_c + cap_s + con_s
    df = df_p[c_list]
    
    df = df[df[col] >= 0.39]
    df = df[df['concept_caption_score'] >= 0.29]
#     df = df[df[col] > 0.55]
    df = df.sort_values(by=[col], ascending=False)
    df_dict[col] = df

# %%
df_dict[col]
# Out:
#          376_caption_score  376_context_score  \
# 985720            0.463480           0.196054
# 306610            0.463480           0.261957
# 717229            0.439399           0.357037
# 582445            0.430533           0.252759
# 308373            0.430315           0.045216
# 233344            0.429185           0.318452
# 855275            0.426821          -0.005306
# 266208            0.424288           0.357476
# 124005            0.422475           0.115039
# 885724            0.421779           0.016103
# 1070222           0.419522           0.078135
# 807541            0.415916           0.086671
# 1070222               0.303759              -0.029696
# 807541                0.319814               0.109248
# 1041441               0.312140               0.174467
# 651730                0.495109               0.143301
# 874765                0.704843               0.105616
# 918204                0.490323               0.083248
# 270750                0.424245               0.257751
# 284731                0.297306               0.090866
# 1313316               0.385699               0.136261
# 1019909               0.327121               0.122872
# 180291                0.341694               0.101828
# 1015422               0.319644               0.127677
# 1293999               0.477126               0.145152
# 785735                0.332953              -0.072905
# 85157                 0.340363               0.199341
# 1130481               0.306511              -0.147821
# 420568                0.293384               0.148550
# 696066                0.362603               0.127046
# 598690                0.362603               0.090307
# 1308956               0.335234               0.122892
# 1262123               0.459960               0.335280
# 1146317               0.348064               0.008710

# %%
col
# Out:
# '376_caption_score'

# %%
from IPython.display import display

# %%
for el in df_dict:
    t,_ = el.split('_', 1)
#     print(t)
    df_dict[el].columns = [f'{t}_caption_sim', f'{t}_context_sim', 'image_url',
                          'caption', 'context', f'ped_caption_sim', f'ped_context_sim']
    display(df_dict[el].describe().round(2))
    print('\n')
# Out:
#        196_caption_sim  196_context_sim  ped_caption_sim  ped_context_sim
# count           670.00           670.00           670.00           670.00
# mean              0.45             0.22             0.41             0.17
# std               0.06             0.17             0.09             0.14
# min               0.39            -0.14             0.29            -0.12
# 25%               0.41             0.09             0.34             0.08
# 50%               0.43             0.21             0.41             0.13
# 75%               0.47             0.31             0.48             0.23
# max               0.76             0.75             0.73             0.69
#        412_caption_sim  412_context_sim  ped_caption_sim  ped_context_sim
# count           302.00           302.00           302.00           302.00
# mean              0.43             0.17             0.48             0.17
# std               0.04             0.15             0.08             0.15
# min               0.39            -0.09             0.31            -0.08
# 25%               0.40             0.06             0.42             0.07
# 50%               0.42             0.14             0.48             0.13
# 75%               0.45             0.27             0.53             0.24
# max               0.61             0.57             0.73             0.69
#        172_caption_sim  172_context_sim  ped_caption_sim  ped_context_sim
# count           735.00           735.00           735.00           735.00
# mean              0.43             0.17             0.41             0.15
# std               0.04             0.14             0.09             0.13
# min               0.39            -0.13             0.29            -0.13
# 25%               0.40             0.08             0.33             0.06
# 50%               0.42             0.15             0.41             0.12
# 75%               0.45             0.26             0.48             0.19
# max               0.61             0.56             0.73             0.69
#        363_caption_sim  363_context_sim  ped_caption_sim  ped_context_sim
# count            19.00            19.00            19.00            19.00
# mean              0.41             0.16             0.43             0.18
# std               0.01             0.12             0.11             0.12
# min               0.39            -0.01             0.30             0.03
# 25%               0.39             0.06             0.33             0.09
# 50%               0.40             0.16             0.42             0.15
# 75%               0.42             0.26             0.54             0.23
# max               0.45             0.31             0.61             0.46
#        198_caption_sim  198_context_sim  ped_caption_sim  ped_context_sim
# count           386.00           386.00           386.00           386.00
# mean              0.43             0.19             0.40             0.15
# std               0.04             0.14             0.10             0.12
# min               0.39            -0.10             0.29            -0.07
# 25%               0.40             0.07             0.32             0.07
# 50%               0.42             0.17             0.37             0.12
# 75%               0.45             0.29             0.47             0.20
# max               0.61             0.56             0.73             0.68
#        114_caption_sim  114_context_sim  ped_caption_sim  ped_context_sim
# count           337.00           337.00           337.00           337.00
# mean              0.43             0.21             0.37             0.11
# std               0.04             0.11             0.09             0.08
# min               0.39            -0.08             0.29            -0.07
# 25%               0.40             0.12             0.30             0.06
# 50%               0.42             0.21             0.33             0.10
# 75%               0.44             0.30             0.40             0.15
# max               0.61             0.44             0.73             0.52
#        144_caption_sim  144_context_sim  ped_caption_sim  ped_context_sim
# count            11.00            11.00            11.00            11.00
# mean              0.42             0.14             0.49             0.21
# std               0.02             0.18             0.10             0.16
# min               0.39            -0.12             0.30             0.05
# 25%               0.41             0.03             0.42             0.10
# 50%               0.41             0.11             0.44             0.13
# 75%               0.43             0.14             0.58             0.28
# max               0.44             0.46             0.65             0.50
#        12_caption_sim  12_context_sim  ped_caption_sim  ped_context_sim
# count          116.00          116.00           116.00           116.00
# mean             0.44            0.16             0.44             0.13
# std              0.05            0.12             0.11             0.14
# min              0.39           -0.13             0.29            -0.06
# 25%              0.40            0.07             0.35             0.03
# 50%              0.42            0.16             0.42             0.08
# 75%              0.46            0.26             0.52             0.21
# max              0.63            0.48             0.73             0.55
#        224_caption_sim  224_context_sim  ped_caption_sim  ped_context_sim
# count           423.00           423.00           423.00           423.00
# mean              0.43             0.24             0.39             0.14
# std               0.03             0.11             0.10             0.10
# min               0.39            -0.11             0.29            -0.07
# 25%               0.40             0.17             0.31             0.08
# 50%               0.42             0.26             0.36             0.12
# 75%               0.44             0.33             0.47             0.17
# max               0.54             0.46             0.73             0.69
#        250_caption_sim  250_context_sim  ped_caption_sim  ped_context_sim
# count              0.0              0.0              0.0              0.0
# mean               NaN              NaN              NaN              NaN
# std                NaN              NaN              NaN              NaN
# min                NaN              NaN              NaN              NaN
# 25%                NaN              NaN              NaN              NaN
# 50%                NaN              NaN              NaN              NaN
# 75%                NaN              NaN              NaN              NaN
# max                NaN              NaN              NaN              NaN
#        376_caption_sim  376_context_sim  ped_caption_sim  ped_context_sim
# count            32.00            32.00            32.00            32.00
# mean              0.41             0.16             0.38             0.10
# std               0.02             0.11             0.11             0.10
# min               0.39            -0.13             0.29            -0.15
# 25%               0.40             0.11             0.31             0.08
# 50%               0.41             0.17             0.34             0.11
# 75%               0.42             0.25             0.41             0.14
# max               0.46             0.36             0.70             0.34

# %%
topics = get_topics(concept='pedestrian')

# %%
topics
# Out:
# {196: {'cross',
#   'crossing',
#   'crosswalk',
#   'pedestrian',
#   'signal',
#   'stripe',
#   'traffic'},
#  412: {'arrest',
#   'pedestrian',
#   'perp',
#   'pers',
#   'walk',
#   'walkability',
#   'walkable'},
#  172: {'car',
#   'lane',
#   'pedestrian',
#   'road',
#   'street',
#   'traffic',
#   'transportation',
#   'vehicle'},
#  363: {'assault',
#   'bystander',
#   'intervene',
#   'intervention',
#   'pedestrian',
#   'stalk',
#   'stalker',
#   'victim',
#   'witness'},
#  198: {'car',
#   'garage',
#   'park',
#   'parking',
#   'parkjockey',
#   'pedestrian',
#   'tow',
#   'vehicle'},
#  114: {'athlete',
#   'disability',
#   'paralympic',
#   'paralympics',
#   'pedestrian',
#   'sport',
#   'sportspeople',
#   'wheelchair'},
#  419: {'avenue',
#   'boulevard',
#   'intersection',
#   'manhattan',
#   'pedestrian',
#   'road',
#   'street',
#   'suffix'},
#  294: {'drive',
#   'fine',
#   'licence',
#   'offence',
#   'pedestrian',
#   'penalty',
#   'reckless',
#   'speed',
#   'ticket',
#   'traffic',
#   'violation'},
#  388: {'brownian',
#   'diffusion',
#   'distribution',
#   'markov',
#   'pedestrian',
#   'percolation',
#   'step',
#   'stochastic',
#   'walk',
#   'wiener'},
#  314: {'circle',
#   'interchange',
#   'intersection',
#   'junction',
#   'lane',
#   'pedestrian',
#   'road',
#   'roundabout',
#   'traffic'},
#  98: {'cross',
#   'direction',
#   'lane',
#   'marker',
#   'parking',
#   'pedestrian',
#   'road',
#   'sign',
#   'signage',
#   'traffic'},
#  80: {'accident',
#   'brake',
#   'collision',
#   'drive',
#   'fatality',
#   'momentum',
#   'nhtsa',
#   'pedestrian',
#   'vehicle',
#   'velocity'},
#  134: {'avenue',
#   'edmonton',
#   'expressway',
#   'freeway',
#   'gardiner',
#   'highway',
#   'lane',
#   'ontario',
#   'pedestrian',
#   'road',
#   'toronto'},
#  432: {'alice',
#   'book',
#   'fiction',
#   'novel',
#   'pedestrian',
#   'poem',
#   'poetry',
#   'pulitzer',
#   'walker'},
#  394: {'alley',
#   'boulevard',
#   'bridleway',
#   'bridleways',
#   'footpath',
#   'path',
#   'pedestrian'},
#  53: {'asphalt',
#   'cement',
#   'concrete',
#   'gravel',
#   'pave',
#   'pavement',
#   'pedestrian',
#   'pothole',
#   'road',
#   'sand'},
#  56: {'bus',
#   'pedestrian',
#   'streetcar',
#   'subway',
#   'train',
#   'tram',
#   'transit',
#   'transportation',
#   'trolley'},
#  150: {'freeway',
#   'highway',
#   'intersection',
#   'lane',
#   'pedestrian',
#   'ramp',
#   'road',
#   'traffic'},
#  278: {'deck',
#   'park',
#   'pedestrian',
#   'promenade',
#   'promenadef',
#   'promenaden',
#   'promener',
#   'walk'},
#  -1: {'american',
#   'century',
#   'example',
#   'film',
#   'her',
#   'pedestrian',
#   'public',
#   'state',
#   'street',
#   'water'},
#  43: {'black',
#   'civil',
#   'negro',
#   'pedestrian',
#   'protest',
#   'protester',
#   'race',
#   'racial',
#   'segregation',
#   'white'},
#  265: {'baby',
#   'carriage',
#   'child',
#   'diaper',
#   'harness',
#   'hatch',
#   'infant',
#   'pedestrian',
#   'stroller'},
#  345: {'barrier',
#   'bumper',
#   'guardrail',
#   'hazard',
#   'pedestrian',
#   'protect',
#   'rail',
#   'safety'},
#  378: {'architect',
#   'architecture',
#   'building',
#   'chicago',
#   'city',
#   'frederick',
#   'park',
#   'pedestrian'},
#  11: {'freeway',
#   'highway',
#   'intersection',
#   'interstate',
#   'lane',
#   'pedestrian',
#   'road',
#   'route',
#   'terminus',
#   'turnpike'},
#  331: {'byway',
#   'highway',
#   'navajo',
#   'parkway',
#   'pedestrian',
#   'road',
#   'roadway',
#   'route',
#   'scenic'},
#  202: {'bottleneck',
#   'congest',
#   'congestion',
#   'delay',
#   'downstream',
#   'pedestrian',
#   'road',
#   'speed',
#   'traffic',
#   'vehicle'},
#  169: {'apartment',
#   'condominium',
#   'home',
#   'homeless',
#   'homelessness',
#   'house',
#   'household',
#   'housing',
#   'pedestrian',
#   'shelter'},
#  327: {'bartholdi',
#   'lazarus',
#   'liberty',
#   'monument',
#   'pedestal',
#   'pedestrian',
#   'sculptor',
#   'sculpture',
#   'statue',
#   'torch'},
#  309: {'adelaide',
#   'carriageworks',
#   'close',
#   'geelong',
#   'line',
#   'melbourne',
#   'pedestrian',
#   'rail',
#   'railway',
#   'train'},
#  68: {'axle',
#   'carriage',
#   'chariot',
#   'passenger',
#   'pedestrian',
#   'vehicle',
#   'wagon',
#   'wheel'},
#  216: {'carriageway',
#   'lane',
#   'm1',
#   'm11',
#   'm25',
#   'm32',
#   'motorway',
#   'pedestrian',
#   'road',
#   'roundabout'},
#  40: {'arrest',
#   'constable',
#   'constabulary',
#   'enforcement',
#   'officer',
#   'patrol',
#   'pedestrian',
#   'police'},
#  99: {'building',
#   'concrete',
#   'construction',
#   'insulation',
#   'masonry',
#   'pedestrian',
#   'roof',
#   'structure',
#   'wall'},
#  426: {'80211p',
#   'cv2x',
#   'pedestrian',
#   'unlock',
#   'v2v',
#   'v2x',
#   'vanet',
#   'vanets',
#   'vehicle',
#   'vehicular'},
#  344: {'adriatic',
#   'censor',
#   'corniche',
#   'itinerary',
#   'pave',
#   'pedestrian',
#   'road',
#   'roman',
#   'rome'},
#  47: {'avenue',
#   'bmt',
#   'broadway',
#   'broadwayseventh',
#   'brooklyn',
#   'manhattan',
#   'pedestrian',
#   'station',
#   'subway',
#   'train'},
#  8: {'bicycle',
#   'bike',
#   'cycle',
#   'cycling',
#   'cyclist',
#   'pedestrian',
#   'rid',
#   'rider',
#   'tire'},
#  416: {'descriptor',
#   'detection',
#   'detector',
#   'keypoints',
#   'ocr',
#   'pedestrian',
#   'pixel',
#   'recognition',
#   'sift',
#   'vision'},
#  112: {'bus',
#   'congestion',
#   'freight',
#   'passenger',
#   'pedestrian',
#   'route',
#   'traffic',
#   'transit',
#   'transport',
#   'transportation'},
#  137: {'expressway',
#   'freeway',
#   'highway',
#   'lane',
#   'motorway',
#   'pedestrian',
#   'road'},
#  441: {'actor',
#   'character',
#   'drama',
#   'hamlet',
#   'novel',
#   'pedestrian',
#   'protagonist',
#   'romeo',
#   'shakespeare'},
#  192: {'ataxia',
#   'cerebellar',
#   'cerebellum',
#   'cerebral',
#   'diplegia',
#   'disorder',
#   'gait',
#   'palsy',
#   'pedestrian',
#   'symptom',
#   'syndrome'},
#  20: {'ankle', 'dance', 'dancer', 'foot', 'leg', 'pedestrian', 'toe'},
#  296: {'area',
#   'monument',
#   'park',
#   'pedestrian',
#   'playground',
#   'recreation',
#   'scenic',
#   'wilderness',
#   'yellowstone'},
#  144: {'',
#   'address',
#   'comma',
#   'image',
#   'more',
#   'pedestrian',
#   'person',
#   'separate',
#   'share',
#   'video'},
#  12: {'appalachian',
#   'footpath',
#   'hike',
#   'hiker',
#   'mountain',
#   'path',
#   'pedestrian',
#   'trail'},
#  224: {'bus',
#   'depot',
#   'fleet',
#   'goahead',
#   'pedestrian',
#   'sb',
#   'singapore',
#   'smrt',
#   'tram',
#   'transit'},
#  250: {'driver',
#   'graphic',
#   'kernel',
#   'kernelmode',
#   'kmdf',
#   'linux',
#   'pedestrian',
#   'printer',
#   'umdf',
#   'usb'},
#  376: {'bear',
#   'cartoon',
#   'charlie',
#   'disney',
#   'lucy',
#   'mickey',
#   'peanut',
#   'pedestrian',
#   'snoopy',
#   'trolley'}}

# %%
def simple_search(context, t):
    percentage = 0
    words = list(topics[t])
    for w in words:
        if w in context:
            percentage = percentage + 1
    return float(percentage/len(words))

# %%
list(topics[376])
# Out:
# ['cartoon',
#  'charlie',
#  'disney',
#  'trolley',
#  'mickey',
#  'lucy',
#  'snoopy',
#  'bear',
#  'peanut',
#  'pedestrian']

# %%
df_dict[el]['context'].tolist()[0]
# Out:
# 'The Mangapps Railway Museum is a heritage railway centre located near Burnham-on-Crouch in Essex, England. The 0.75 miles of standard gauge running line and museum are owned and operated by the Jolly family assisted by volunteers.\n'

# %%
print(el)
simple_search(df_dict[el]['context'].tolist()[0], 376)
# Out:
# 376_caption_score
# 0.0

# %%
for t in topics:
    df_key = str(t) + '_caption_score'
    df_dict[df_key]['context_gt'] = df_dict[df_key]['context'].apply(simple_search, t=t)

# %%
df_dict['412_caption_score'].describe().round(2)
# Out:
#        412_caption_sim  412_context_sim  ped_caption_sim  ped_context_sim  \
# count           302.00           302.00           302.00           302.00
# mean              0.43             0.17             0.48             0.17
# std               0.04             0.15             0.08             0.15
# min               0.39            -0.09             0.31            -0.08
# 25%               0.40             0.06             0.42             0.07
# 50%               0.42             0.14             0.48             0.13
# 75%               0.45             0.27             0.53             0.24
# max               0.61             0.57             0.73             0.69
#
#        context_gt
# count      302.00
# mean         0.11
# std          0.14
# min          0.00
# 25%          0.00
# 50%          0.00
# 75%          0.14
# max          0.57

# %%
df_dict['412_caption_score']
# Out:
#         412_caption_sim  412_context_sim  \
# 874765         0.610392         0.199226
# 479397         0.586082         0.008303
# 160058         0.573594         0.481619
# 496246         0.565820         0.190722
# 812796         0.565820         0.160237
# ...                 ...              ...
# 970576         0.391278         0.305109
# 261512         0.391050         0.137319
# 299516         0.390983         0.060743
# 221112         0.390926         0.018218
# 965150         0.390221         0.126004
#
#                                                 image_url  \
# 874765  https://upload.wikimedia.org/wikipedia/commons...
# 479397  https://upload.wikimedia.org/wikipedia/commons...
# 160058  https://upload.wikimedia.org/wikipedia/commons...
# 496246  https://upload.wikimedia.org/wikipedia/commons...
# 812796  https://upload.wikimedia.org/wikipedia/commons...
# ...                                                   ...
# 970576  https://upload.wikimedia.org/wikipedia/commons...
# 261512  https://upload.wikimedia.org/wikipedia/commons...
# 299516  http://upload.wikimedia.org/wikipedia/commons/...
# 221112  https://upload.wikimedia.org/wikipedia/commons...
# 965150  https://upload.wikimedia.org/wikipedia/commons...
#
#                                                   caption  \
# 874765         Pedestrian trail English: Pedestrian trail
# 479397   Pedestrian walk in Ferizaj English: Ferizaj City
# 160058  Prohibition of pedestrians (includes any kind ...
# 496246                       English: Pedestrian crossing
# 812796                       English: Pedestrian crossing
# ...                                                   ...
# 970576  Dalton Road entrance to Portland Walk in 2012 ...
# 261512       English: Surtees Bridge pedestrian cycleway.
# 299516  Station and the connecting pedestrian walkway ...
# 221112   English: 2016 Walking Liberty Centennial Obverse
# 965150       English: A track blockage at Mendips Raceway
#
#                                                   context  ped_caption_sim  \
# 874765  The Blue Water River Walk is a nearly one mile...         0.704843
# 479397  Ferizaj, in southeastern Kosovo, is its third-...         0.595274
# 160058  Jaywalking occurs when a pedestrian walks in o...         0.548525
# 496246  Road signs used by countries in the Americas a...         0.728629
# 812796  Road signs in Malaysia are standardised road s...         0.728629
# ...                                                   ...              ...
# 970576  Portland Walk is a shopping centre in Barrow-i...         0.310865
# 261512  The Surtees Bridge is a road bridge carrying t...         0.480469
# 299516  Utsunomiya Station is a railway station in the...         0.411879
# 221112  Although technically a circulating coin, no do...         0.389392
# 965150  Mendips Raceway is a motorsport venue in the M...         0.315098
#
#         ped_context_sim  context_gt
# 874765         0.105616    0.142857
# 479397         0.053994    0.000000
# 160058         0.483317    0.428571
# 496246         0.157267    0.000000
# 812796         0.152377    0.000000
# ...                 ...         ...
# 970576         0.180440    0.000000
# 261512         0.071229    0.000000
# 299516         0.036971    0.000000
# 221112         0.002155    0.000000
# 965150         0.030081    0.000000
#
# [302 rows x 8 columns]

# %%
pg_dict = dict()
pg_dict['a'] = [68, 112, 56, 224]
pg_dict['b'] = [309, 344, 47, -1, 53]
pg_dict['c'] = [314, 331, 419, 394]
pg_dict['d'] = [98, 196, 202, 294]
pg_dict['e'] = [172, 137, 11, 134, 150, 216]
pg_dict['f'] = [363, 40, 43]
pg_dict['g'] = [441, 376]
pg_dict['h'] = [144, 416, 327]
pg_dict['i'] = [192, 20, 114]
pg_dict['j'] = [345]
pg_dict['k'] = [8, 265]
pg_dict['l'] = [250, 80, 426]
pg_dict['m'] = [169, 99, 378]
pg_dict['n'] = [432, 388, 412]
pg_dict['o'] = [12, 278, 198, 296]

# %%
k_name = ['image_url', 'caption', 'context', 'concept2caption_sim', 
          'concept2context_sim', 'context_gt']
# k_name = ['image_url', 'caption', 'context', 'concept2caption_sim', 
#           'concept2context_sim']
for el in pg_dict:
    pg_dict[el] = [f'{i}_caption_score' for i in pg_dict[el]]
    pg_dict[el] = [df_dict[i] for i in pg_dict[el]]
    pg_dict[el] = [df_.reset_index(drop=True) for df_ in pg_dict[el]]

# %%
for el in pg_dict:
    t_df = pd.DataFrame(columns = ['topic2caption_sim', 'topic2context_sim'] + k_name)
    for df_ in pg_dict[el]:
        df_.columns = ['topic2caption_sim', 'topic2context_sim'] + k_name
        t_df = pd.concat([t_df, df_], ignore_index=True)
    pg_dict[el] = t_df

# %%
for el in pg_dict:
    print(el)
    display(pg_dict[el].describe().round(2))
# Out:
# a
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count            2046.00            2046.00              2046.00
# mean                0.44               0.23                 0.38
# std                 0.04               0.13                 0.09
# min                 0.39              -0.14                 0.29
# 25%                 0.40               0.14                 0.31
# 50%                 0.42               0.24                 0.34
# 75%                 0.45               0.33                 0.45
# max                 0.63               0.56                 0.73
#
#        concept2context_sim  context_gt
# count              2046.00     2046.00
# mean                  0.14        0.13
# std                   0.10        0.14
# min                  -0.12        0.00
# 25%                   0.08        0.00
# 50%                   0.13        0.11
# 75%                   0.17        0.20
# max                   0.69        0.78
# b
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count            2237.00            2237.00              2237.00
# mean                0.43               0.21                 0.39
# std                 0.04               0.13                 0.09
# min                 0.39              -0.14                 0.29
# 25%                 0.40               0.11                 0.31
# 50%                 0.42               0.21                 0.36
# 75%                 0.45               0.31                 0.45
# max                 0.71               0.71                 0.73
#
#        concept2context_sim  context_gt
# count              2237.00     2237.00
# mean                  0.13        0.12
# std                   0.11        0.12
# min                  -0.15        0.00
# 25%                   0.06        0.00
# 50%                   0.11        0.10
# 75%                   0.17        0.20
# max                   0.69        0.70
# c
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count            4066.00            4066.00              4066.00
# mean                0.43               0.19                 0.38
# std                 0.04               0.13                 0.08
# min                 0.39              -0.18                 0.29
# 25%                 0.40               0.09                 0.31
# 50%                 0.42               0.18                 0.36
# 75%                 0.45               0.28                 0.43
# max                 0.68               0.67                 0.73
#
#        concept2context_sim  context_gt
# count              4066.00     4066.00
# mean                  0.13        0.09
# std                   0.12        0.13
# min                  -0.15        0.00
# 25%                   0.06        0.00
# 50%                   0.11        0.00
# 75%                   0.18        0.14
# max                   0.69        1.00
# d
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count            2518.00            2518.00              2518.00
# mean                0.45               0.21                 0.40
# std                 0.05               0.16                 0.09
# min                 0.39              -0.15                 0.29
# 25%                 0.41               0.09                 0.32
# 50%                 0.44               0.19                 0.36
# 75%                 0.47               0.32                 0.46
# max                 0.76               0.75                 0.73
#
#        concept2context_sim  context_gt
# count              2518.00     2518.00
# mean                  0.16        0.17
# std                   0.13        0.19
# min                  -0.15        0.00
# 25%                   0.08        0.00
# 50%                   0.14        0.10
# 75%                   0.20        0.30
# max                   0.69        1.00
# e
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count            4975.00            4975.00              4975.00
# mean                0.43               0.20                 0.39
# std                 0.04               0.13                 0.09
# min                 0.39              -0.15                 0.29
# 25%                 0.40               0.10                 0.32
# 50%                 0.42               0.20                 0.36
# 75%                 0.45               0.29                 0.45
# max                 0.64               0.59                 0.73
#
#        concept2context_sim  context_gt
# count              4975.00     4975.00
# mean                  0.14        0.13
# std                   0.12        0.16
# min                  -0.13        0.00
# 25%                   0.07        0.00
# 50%                   0.12        0.09
# 75%                   0.19        0.20
# max                   0.69        1.00
# f
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count             888.00             888.00               888.00
# mean                0.44               0.23                 0.38
# std                 0.04               0.14                 0.10
# min                 0.39              -0.16                 0.29
# 25%                 0.41               0.11                 0.31
# 50%                 0.43               0.24                 0.33
# 75%                 0.46               0.34                 0.43
# max                 0.64               0.53                 0.73
#
#        concept2context_sim  context_gt
# count               888.00      888.00
# mean                  0.15        0.15
# std                   0.11        0.15
# min                  -0.08        0.00
# 25%                   0.08        0.00
# 50%                   0.13        0.12
# 75%                   0.21        0.25
# max                   0.69        0.75
# g
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count              46.00              46.00                46.00
# mean                0.41               0.14                 0.42
# std                 0.02               0.12                 0.14
# min                 0.39              -0.13                 0.29
# 25%                 0.40               0.05                 0.32
# 50%                 0.41               0.15                 0.36
# 75%                 0.42               0.24                 0.49
# max                 0.46               0.41                 0.73
#
#        concept2context_sim  context_gt
# count                46.00       46.00
# mean                  0.12        0.02
# std                   0.12        0.05
# min                  -0.15        0.00
# 25%                   0.08        0.00
# 50%                   0.11        0.00
# 75%                   0.15        0.00
# max                   0.69        0.22
# h
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count             282.00             282.00               282.00
# mean                0.44               0.22                 0.34
# std                 0.05               0.15                 0.08
# min                 0.39              -0.12                 0.29
# 25%                 0.41               0.10                 0.30
# 50%                 0.43               0.21                 0.31
# 75%                 0.46               0.33                 0.34
# max                 0.66               0.55                 0.70
#
#        concept2context_sim  context_gt
# count               282.00      282.00
# mean                  0.13        0.10
# std                   0.10        0.11
# min                  -0.07        0.00
# 25%                   0.07        0.00
# 50%                   0.12        0.10
# 75%                   0.18        0.20
# max                   0.50        0.50
# i
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count             310.00             310.00               310.00
# mean                0.49               0.32                 0.36
# std                 0.08               0.17                 0.09
# min                 0.39              -0.09                 0.29
# 25%                 0.41               0.17                 0.31
# 50%                 0.47               0.34                 0.33
# 75%                 0.59               0.47                 0.36
# max                 0.65               0.64                 0.73
#
#        concept2context_sim  context_gt
# count               310.00      310.00
# mean                  0.17        0.16
# std                   0.09        0.16
# min                  -0.06        0.00
# 25%                   0.11        0.00
# 50%                   0.16        0.12
# 75%                   0.21        0.25
# max                   0.50        0.62
# j
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count             240.00             240.00               240.00
# mean                0.43               0.21                 0.44
# std                 0.04               0.14                 0.10
# min                 0.39              -0.12                 0.29
# 25%                 0.40               0.11                 0.34
# 50%                 0.42               0.18                 0.44
# 75%                 0.45               0.31                 0.53
# max                 0.67               0.66                 0.73
#
#        concept2context_sim  context_gt
# count               240.00      240.00
# mean                  0.17        0.14
# std                   0.14        0.14
# min                  -0.12        0.00
# 25%                   0.08        0.00
# 50%                   0.13        0.12
# 75%                   0.23        0.25
# max                   0.69        0.75
# k
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count             237.00             237.00               237.00
# mean                0.43               0.24                 0.39
# std                 0.04               0.16                 0.11
# min                 0.39              -0.15                 0.29
# 25%                 0.41               0.11                 0.32
# 50%                 0.42               0.23                 0.35
# 75%                 0.45               0.38                 0.44
# max                 0.58               0.55                 0.73
#
#        concept2context_sim  context_gt
# count               237.00      237.00
# mean                  0.17        0.23
# std                   0.11        0.24
# min                  -0.08        0.00
# 25%                   0.10        0.00
# 50%                   0.16        0.11
# 75%                   0.23        0.33
# max                   0.68        0.89
# l
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count              61.00              61.00                61.00
# mean                0.42               0.19                 0.46
# std                 0.02               0.16                 0.14
# min                 0.39              -0.10                 0.29
# 25%                 0.41               0.07                 0.33
# 50%                 0.42               0.15                 0.42
# 75%                 0.43               0.34                 0.58
# max                 0.50               0.59                 0.73
#
#        concept2context_sim  context_gt
# count                61.00       61.00
# mean                  0.19        0.10
# std                   0.14        0.13
# min                  -0.08        0.00
# 25%                   0.07        0.00
# 50%                   0.17        0.10
# 75%                   0.25        0.20
# max                   0.50        0.60
# m
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count             893.00             893.00               893.00
# mean                0.43               0.19                 0.42
# std                 0.04               0.14                 0.10
# min                 0.39              -0.20                 0.29
# 25%                 0.40               0.09                 0.33
# 50%                 0.42               0.17                 0.42
# 75%                 0.45               0.28                 0.51
# max                 0.63               0.62                 0.73
#
#        concept2context_sim  context_gt
# count               893.00      893.00
# mean                  0.14        0.14
# std                   0.13        0.15
# min                  -0.15        0.00
# 25%                   0.06        0.00
# 50%                   0.12        0.12
# 75%                   0.19        0.25
# max                   0.69        0.75
# n
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count             353.00             353.00               353.00
# mean                0.43               0.17                 0.48
# std                 0.04               0.15                 0.09
# min                 0.39              -0.13                 0.29
# 25%                 0.40               0.05                 0.42
# 50%                 0.42               0.14                 0.48
# 75%                 0.45               0.26                 0.54
# max                 0.61               0.57                 0.73
#
#        concept2context_sim  context_gt
# count               353.00      353.00
# mean                  0.16        0.10
# std                   0.15        0.13
# min                  -0.08        0.00
# 25%                   0.07        0.00
# 50%                   0.12        0.00
# 75%                   0.23        0.14
# max                   0.69        0.57
# o
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count            2819.00            2819.00              2819.00
# mean                0.44               0.19                 0.38
# std                 0.04               0.12                 0.08
# min                 0.39              -0.14                 0.29
# 25%                 0.41               0.10                 0.31
# 50%                 0.43               0.19                 0.35
# 75%                 0.46               0.28                 0.42
# max                 0.71               0.56                 0.73
#
#        concept2context_sim  context_gt
# count              2819.00     2819.00
# mean                  0.13        0.08
# std                   0.11        0.12
# min                  -0.15        0.00
# 25%                   0.06        0.00
# 50%                   0.11        0.00
# 75%                   0.18        0.12
# max                   0.69        0.88

# %%
df__ = pd.DataFrame()
for el in pg_dict:
    df__ = pd.concat([df_, pg_dict[el]], ignore_index=True)
display(df__.describe().round(2))
# Out:
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count            3156.00            3156.00              3156.00
# mean                0.44               0.19                 0.38
# std                 0.04               0.12                 0.08
# min                 0.39              -0.14                 0.29
# 25%                 0.41               0.10                 0.31
# 50%                 0.42               0.19                 0.35
# 75%                 0.46               0.28                 0.42
# max                 0.71               0.56                 0.73
#
#        concept2context_sim  context_gt
# count              3156.00     3156.00
# mean                  0.13        0.09
# std                   0.11        0.12
# min                  -0.15        0.00
# 25%                   0.06        0.00
# 50%                   0.11        0.00
# 75%                   0.18        0.12
# max                   0.69        0.88

# %%
for el in pg_dict:
    print(el)
    display(pg_dict[el].describe().round(2))
# Out:
# a
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count            2046.00            2046.00              2046.00
# mean                0.44               0.23                 0.38
# std                 0.04               0.13                 0.09
# min                 0.39              -0.14                 0.29
# 25%                 0.40               0.14                 0.31
# 50%                 0.42               0.24                 0.34
# 75%                 0.45               0.33                 0.45
# max                 0.63               0.56                 0.73
#
#        concept2context_sim  context_gt
# count              2046.00     2046.00
# mean                  0.14        0.13
# std                   0.10        0.14
# min                  -0.12        0.00
# 25%                   0.08        0.00
# 50%                   0.13        0.11
# 75%                   0.17        0.20
# max                   0.69        0.78
# b
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count            2237.00            2237.00              2237.00
# mean                0.43               0.21                 0.39
# std                 0.04               0.13                 0.09
# min                 0.39              -0.14                 0.29
# 25%                 0.40               0.11                 0.31
# 50%                 0.42               0.21                 0.36
# 75%                 0.45               0.31                 0.45
# max                 0.71               0.71                 0.73
#
#        concept2context_sim  context_gt
# count              2237.00     2237.00
# mean                  0.13        0.12
# std                   0.11        0.12
# min                  -0.15        0.00
# 25%                   0.06        0.00
# 50%                   0.11        0.10
# 75%                   0.17        0.20
# max                   0.69        0.70
# c
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count            4066.00            4066.00              4066.00
# mean                0.43               0.19                 0.38
# std                 0.04               0.13                 0.08
# min                 0.39              -0.18                 0.29
# 25%                 0.40               0.09                 0.31
# 50%                 0.42               0.18                 0.36
# 75%                 0.45               0.28                 0.43
# max                 0.68               0.67                 0.73
#
#        concept2context_sim  context_gt
# count              4066.00     4066.00
# mean                  0.13        0.09
# std                   0.12        0.13
# min                  -0.15        0.00
# 25%                   0.06        0.00
# 50%                   0.11        0.00
# 75%                   0.18        0.14
# max                   0.69        1.00
# d
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count            2518.00            2518.00              2518.00
# mean                0.45               0.21                 0.40
# std                 0.05               0.16                 0.09
# min                 0.39              -0.15                 0.29
# 25%                 0.41               0.09                 0.32
# 50%                 0.44               0.19                 0.36
# 75%                 0.47               0.32                 0.46
# max                 0.76               0.75                 0.73
#
#        concept2context_sim  context_gt
# count              2518.00     2518.00
# mean                  0.16        0.17
# std                   0.13        0.19
# min                  -0.15        0.00
# 25%                   0.08        0.00
# 50%                   0.14        0.10
# 75%                   0.20        0.30
# max                   0.69        1.00
# e
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count            4975.00            4975.00              4975.00
# mean                0.43               0.20                 0.39
# std                 0.04               0.13                 0.09
# min                 0.39              -0.15                 0.29
# 25%                 0.40               0.10                 0.32
# 50%                 0.42               0.20                 0.36
# 75%                 0.45               0.29                 0.45
# max                 0.64               0.59                 0.73
#
#        concept2context_sim  context_gt
# count              4975.00     4975.00
# mean                  0.14        0.13
# std                   0.12        0.16
# min                  -0.13        0.00
# 25%                   0.07        0.00
# 50%                   0.12        0.09
# 75%                   0.19        0.20
# max                   0.69        1.00
# f
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count             888.00             888.00               888.00
# mean                0.44               0.23                 0.38
# std                 0.04               0.14                 0.10
# min                 0.39              -0.16                 0.29
# 25%                 0.41               0.11                 0.31
# 50%                 0.43               0.24                 0.33
# 75%                 0.46               0.34                 0.43
# max                 0.64               0.53                 0.73
#
#        concept2context_sim  context_gt
# count               888.00      888.00
# mean                  0.15        0.15
# std                   0.11        0.15
# min                  -0.08        0.00
# 25%                   0.08        0.00
# 50%                   0.13        0.12
# 75%                   0.21        0.25
# max                   0.69        0.75
# g
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count              46.00              46.00                46.00
# mean                0.41               0.14                 0.42
# std                 0.02               0.12                 0.14
# min                 0.39              -0.13                 0.29
# 25%                 0.40               0.05                 0.32
# 50%                 0.41               0.15                 0.36
# 75%                 0.42               0.24                 0.49
# max                 0.46               0.41                 0.73
#
#        concept2context_sim  context_gt
# count                46.00       46.00
# mean                  0.12        0.02
# std                   0.12        0.05
# min                  -0.15        0.00
# 25%                   0.08        0.00
# 50%                   0.11        0.00
# 75%                   0.15        0.00
# max                   0.69        0.22
# h
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count             282.00             282.00               282.00
# mean                0.44               0.22                 0.34
# std                 0.05               0.15                 0.08
# min                 0.39              -0.12                 0.29
# 25%                 0.41               0.10                 0.30
# 50%                 0.43               0.21                 0.31
# 75%                 0.46               0.33                 0.34
# max                 0.66               0.55                 0.70
#
#        concept2context_sim  context_gt
# count               282.00      282.00
# mean                  0.13        0.10
# std                   0.10        0.11
# min                  -0.07        0.00
# 25%                   0.07        0.00
# 50%                   0.12        0.10
# 75%                   0.18        0.20
# max                   0.50        0.50
# i
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count             310.00             310.00               310.00
# mean                0.49               0.32                 0.36
# std                 0.08               0.17                 0.09
# min                 0.39              -0.09                 0.29
# 25%                 0.41               0.17                 0.31
# 50%                 0.47               0.34                 0.33
# 75%                 0.59               0.47                 0.36
# max                 0.65               0.64                 0.73
#
#        concept2context_sim  context_gt
# count               310.00      310.00
# mean                  0.17        0.16
# std                   0.09        0.16
# min                  -0.06        0.00
# 25%                   0.11        0.00
# 50%                   0.16        0.12
# 75%                   0.21        0.25
# max                   0.50        0.62
# j
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count             240.00             240.00               240.00
# mean                0.43               0.21                 0.44
# std                 0.04               0.14                 0.10
# min                 0.39              -0.12                 0.29
# 25%                 0.40               0.11                 0.34
# 50%                 0.42               0.18                 0.44
# 75%                 0.45               0.31                 0.53
# max                 0.67               0.66                 0.73
#
#        concept2context_sim  context_gt
# count               240.00      240.00
# mean                  0.17        0.14
# std                   0.14        0.14
# min                  -0.12        0.00
# 25%                   0.08        0.00
# 50%                   0.13        0.12
# 75%                   0.23        0.25
# max                   0.69        0.75
# k
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count             237.00             237.00               237.00
# mean                0.43               0.24                 0.39
# std                 0.04               0.16                 0.11
# min                 0.39              -0.15                 0.29
# 25%                 0.41               0.11                 0.32
# 50%                 0.42               0.23                 0.35
# 75%                 0.45               0.38                 0.44
# max                 0.58               0.55                 0.73
#
#        concept2context_sim  context_gt
# count               237.00      237.00
# mean                  0.17        0.23
# std                   0.11        0.24
# min                  -0.08        0.00
# 25%                   0.10        0.00
# 50%                   0.16        0.11
# 75%                   0.23        0.33
# max                   0.68        0.89
# l
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count              61.00              61.00                61.00
# mean                0.42               0.19                 0.46
# std                 0.02               0.16                 0.14
# min                 0.39              -0.10                 0.29
# 25%                 0.41               0.07                 0.33
# 50%                 0.42               0.15                 0.42
# 75%                 0.43               0.34                 0.58
# max                 0.50               0.59                 0.73
#
#        concept2context_sim  context_gt
# count                61.00       61.00
# mean                  0.19        0.10
# std                   0.14        0.13
# min                  -0.08        0.00
# 25%                   0.07        0.00
# 50%                   0.17        0.10
# 75%                   0.25        0.20
# max                   0.50        0.60
# m
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count             893.00             893.00               893.00
# mean                0.43               0.19                 0.42
# std                 0.04               0.14                 0.10
# min                 0.39              -0.20                 0.29
# 25%                 0.40               0.09                 0.33
# 50%                 0.42               0.17                 0.42
# 75%                 0.45               0.28                 0.51
# max                 0.63               0.62                 0.73
#
#        concept2context_sim  context_gt
# count               893.00      893.00
# mean                  0.14        0.14
# std                   0.13        0.15
# min                  -0.15        0.00
# 25%                   0.06        0.00
# 50%                   0.12        0.12
# 75%                   0.19        0.25
# max                   0.69        0.75
# n
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count             353.00             353.00               353.00
# mean                0.43               0.17                 0.48
# std                 0.04               0.15                 0.09
# min                 0.39              -0.13                 0.29
# 25%                 0.40               0.05                 0.42
# 50%                 0.42               0.14                 0.48
# 75%                 0.45               0.26                 0.54
# max                 0.61               0.57                 0.73
#
#        concept2context_sim  context_gt
# count               353.00      353.00
# mean                  0.16        0.10
# std                   0.15        0.13
# min                  -0.08        0.00
# 25%                   0.07        0.00
# 50%                   0.12        0.00
# 75%                   0.23        0.14
# max                   0.69        0.57
# o
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count            2819.00            2819.00              2819.00
# mean                0.44               0.19                 0.38
# std                 0.04               0.12                 0.08
# min                 0.39              -0.14                 0.29
# 25%                 0.41               0.10                 0.31
# 50%                 0.43               0.19                 0.35
# 75%                 0.46               0.28                 0.42
# max                 0.71               0.56                 0.73
#
#        concept2context_sim  context_gt
# count              2819.00     2819.00
# mean                  0.13        0.08
# std                   0.11        0.12
# min                  -0.15        0.00
# 25%                   0.06        0.00
# 50%                   0.11        0.00
# 75%                   0.18        0.12
# max                   0.69        0.88

# %%
pg_dict[el]
# Out:
#       topic2caption_sim  topic2context_sim  \
# 0              0.628946           0.295938
# 1              0.591550           0.071280
# 2              0.591550           0.071280
# 3              0.591550           0.071280
# 4              0.589132           0.471493
# ...                 ...                ...
# 2814           0.390792           0.012666
# 2815           0.390645           0.119095
# 2816           0.390449           0.086269
# 2817           0.390249           0.165292
# 2818           0.390178           0.147030
#
#                                               image_url  \
# 0     https://upload.wikimedia.org/wikipedia/commons...
# 1     https://upload.wikimedia.org/wikipedia/commons...
# 2     https://upload.wikimedia.org/wikipedia/commons...
# 3     https://upload.wikimedia.org/wikipedia/commons...
# 4     https://upload.wikimedia.org/wikipedia/commons...
# ...                                                 ...
# 2814  http://upload.wikimedia.org/wikipedia/commons/...
# 2815  https://upload.wikimedia.org/wikipedia/commons...
# 2816  https://upload.wikimedia.org/wikipedia/commons...
# 2817  https://upload.wikimedia.org/wikipedia/commons...
# 2818  https://upload.wikimedia.org/wikipedia/commons...
#
#                                                 caption  \
# 0            Pedestrian trail English: Pedestrian trail
# 1                                        Walking Trail
# 2                                        Walking Trail
# 3                                        Walking Trail
# 4     Hikers awaiting southbound train English: Look...
# ...                                                 ...
# 2814  Pedestrian boulevard at night Lietuvių: Šiauli...
# 2815   English: A train crossing through Lawachara N...
# 2816  Pedestrian bridge as seen from platform, 2008 ...
# 2817  Standing Rock in Steedman English: Standing Ro...
# 2818  Madonna of the Trail monument along the Old Na...
#
#                                                 context  concept2caption_sim  \
# 0     The Blue Water River Walk is a nearly one mile...             0.704843
# 1     Bagh-e-Jinnah, formerly known as Lawrence Gard...             0.422199
# 2     Bagh-e-Jinnah, formerly known as Lawrence Gard...             0.422199
# 3     Bagh-e-Jinnah, formerly known as Lawrence Gard...             0.422199
# 4     The Appalachian Trail station is a commuter ra...             0.300308
# ...                                                 ...                  ...
# 2814  Šiauliai is the fourth largest city in Lithuan...             0.534422
# 2815  Bangladesh Railway Class 2900 is, as of 2020, ...             0.305481
# 2816  Metro Nativitas is a station on Line 2 of the ...             0.524615
# 2817  Steedman is an unincorporated community in sou...             0.309894
# 2818  The National Road was the first major improved...             0.311219
#
#       concept2context_sim  context_gt
# 0                0.105616    0.125000
# 1                0.072473    0.000000
# 2                0.072473    0.000000
# 3                0.072473    0.000000
# 4                0.143705    0.250000
# ...                   ...         ...
# 2814             0.013801    0.111111
# 2815             0.108808    0.000000
# 2816             0.145939    0.000000
# 2817             0.136679    0.000000
# 2818             0.067329    0.111111
#
# [2819 rows x 8 columns]

# %% [markdown]
# ## select image for retrain from wit

# %%
from io import BytesIO
import pillow_avif
from svglib.svglib import svg2rlg
from reportlab.graphics import renderPM
im_test = '/raid/AISSEL/htest/datasets/wit/images'

# %%
from os.path import exists
import base64
im_root_path = '/raid/AISSEL/htest/datasets/wit/images'

# %%
# def b64(link):
#     link = link.encode("utf-8")
#     im_path = f'{im_root_path}/{str(base64.b64encode(link))[2:-1]}.jpg'
#     if exists(im_path):
#         return im_path
#     return

# %%
def link_to_b64(link):
    im_root_path = '/raid/AISSEL/htest/datasets/wit/images'
    link = link.encode("utf-8")
    _, pos = str(link)[:-1].rsplit('.', 1)
    if pos == 'svg':
        return
    im_path = f'{str(base64.b64encode(link))[2:-1]}'
    if exists(f'{im_root_path}/{im_path}.jpg'):
        return f'{im_path}.jpg'
    return

# %%
def b64(fn):
    im_test = '/raid/AISSEL/htest/datasets/wit/images'
    fn = f'{im_test}/{fn}'
    base64_str = None
    if exists(fn):
        try:
            img = Image.open(fn)
            img_buffer = BytesIO()
            img.save(img_buffer, format=img.format)
            byte_data = img_buffer.getvalue()
            base64_str = str(base64.b64encode(byte_data))[2:-1]
        except:
            base64_str = None
            print(fn)

    return base64_str


def remove_special(input_string):
    final_string = ""
    for character in input_string:
        if  character == " ":
            final_string = final_string + character
        else:
            if(character.isalnum()):
                final_string = final_string + character
    return final_string


def remove_special(input_string):
    final_string = ""
    for character in input_string:
        if  character == " ":
            final_string = final_string + character
        else:
            if(character.isalnum()):
                final_string = final_string + character
    return final_string



def create_data(df, count):
#     col = ['uniq_id', 'image_id', 'caption', 'context', 'topic_id', 'labels', 'image']
    col = ['uniq_id', 'image_id', 'caption', 'labels', 'image', 'topic2caption_sim', 'concept2caption_sim']
    t_df = pd.DataFrame(columns=col)
    t_df['caption'] = df['caption'].apply(remove_special)
#     t_df['context'] = df['context'].apply(remove_special)
#     t_df['topic_id'] = df['topic_id']
    t_df['topic2caption_sim'] = df['topic2caption_sim']
    t_df['concept2caption_sim'] = df['concept2caption_sim']
    t_df['topic2context_sim'] = df['topic2context_sim']
    t_df['uniq_id'] = df.index + count
    t_df['image_id'] = df.index + count
    t_df['image'] = df['image_path'].apply(b64)
    t_df['labels'] = ' '
    t_df = t_df[t_df.image.notnull()]
    t_df = t_df.reset_index(drop=True)
    
    return t_df

# %%
def df2_df1(df1, df2):
    df = df1.merge(df2, how = 'outer' ,indicator=True).loc[lambda x : x['_merge']=='right_only']
    df = df[selected_col].reset_index(drop=True)
    return df

# %%
def df2_df1(df1, df2):
    cond = df2['image_path'].isin(df1['image_path'])
    df2.drop(df2[cond].index, inplace = True)
    return df2

# %%
def get_portion(df, p1=75, p2=15, p3=5, p4=5):
    s1 = df.sample(frac = p1/100)
    rest_part_1 = df.drop(s1.index)
    s2 = rest_part_1.sample(frac = p2/(100-p1))
    rest_part_2 = rest_part_1.drop(s2.index)
    s3 = rest_part_2.sample(frac = p3/(100 - p1 - p2))
    s4 = rest_part_2.drop(s3.index)
    return s1, s2, s3, s4

# %% [markdown]
# ### Consider All topics

# %%
missed_topics_dict = dict()
for el in pg_dict:
    missed_topics_dict[el] = pg_dict[el]
    missed_topics_dict[el]['image_path'] = missed_topics_dict[el]['image_url'].apply(link_to_b64)
    missed_topics_dict[el] = missed_topics_dict[el][missed_topics_dict[el].image_path.notnull()]
    missed_topics_dict[el] = missed_topics_dict[el].reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-273cd25f6be4> in <module>
#       2 for el in pg_dict:
#       3     missed_topics_dict[el] = pg_dict[el]
# ----> 4     missed_topics_dict[el]['image_path'] = missed_topics_dict[el]['image_url'].apply(link_to_b64)
#       5     missed_topics_dict[el] = missed_topics_dict[el][missed_topics_dict[el].image_path.notnull()]
#       6     missed_topics_dict[el] = missed_topics_dict[el].reset_index(drop=True)
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
# -> 1101                     convert=self.convert_dtype,
#    1102                 )
#    1103
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-64-80a9d3d1c8b6> in link_to_b64(link)
#       6         return
#       7     im_path = f'{str(base64.b64encode(link))[2:-1]}'
# ----> 8     if exists(f'{im_root_path}/{im_path}.jpg'):
#       9         return f'{im_path}.jpg'
#      10     return
#
# ~/.pyenv/versions/3.7.6/lib/python3.7/genericpath.py in exists(path)
#      17     """Test whether a path exists.  Returns False for broken symbolic links"""
#      18     try:
# ---> 19         os.stat(path)
#      20     except OSError:
#      21         return False
#
# KeyboardInterrupt:

# %%
missed_topics_dict[el]

# %%
# selected_col = ['caption', 'context', 'topic_id', 'image_path']
selected_col = ['image_path','topic2caption_sim', 'concept2caption_sim', 'topic2context_sim', 'context_gt', 'caption']
for el in missed_topics_dict:
    missed_topics_dict[el] = missed_topics_dict[el][selected_col]
    missed_topics_dict[el] = missed_topics_dict[el].drop_duplicates(subset=selected_col, keep=False)
    missed_topics_dict[el] = missed_topics_dict[el].reset_index(drop=True)

# %%
for el in missed_topics_dict:
#     missed_topics_dict[el] = missed_topics_dict[el][selected_col]
    missed_topics_dict[el] = missed_topics_dict[el].drop_duplicates(keep=False)
    missed_topics_dict[el] = missed_topics_dict[el].reset_index(drop=True)

# %%
missed_topics_dict['a']

# %%
for el in missed_topics_dict:
    print(el, len(missed_topics_dict[el]))

# %%
sorted_key = []
for k in sorted(missed_topics_dict, key=lambda k: len(missed_topics_dict[k])):
    print(k, len(missed_topics_dict[k]))
    sorted_key.append(k)
# Out:
# g 46
# l 58
# k 223
# j 233
# h 282
# i 282
# n 347
# f 873
# m 883
# a 2020
# b 2206
# d 2398
# o 2784
# c 3930
# e 4700

# %%
sorted_key
# Out:
# ['g', 'l', 'k', 'j', 'h', 'i', 'n', 'f', 'm', 'a', 'b', 'd', 'o', 'c', 'e']

# %%
def df2_df1(df1, df2):
    cond = df2['image_path'].isin(df1['image_path'])
    df2.drop(df2[cond].index, inplace = True)
    return df2

# %%
for idx, k in enumerate(sorted_key):
    print(sorted_key[idx:], k)
    for el in sorted_key[idx:]:
        if el == k:
            continue
        print(f'we are going to calc: {el} - {k}')
        missed_topics_dict[el] = df2_df1(missed_topics_dict[k], missed_topics_dict[el])
#     break
# Out:
# ['g', 'l', 'k', 'j', 'h', 'i', 'n', 'f', 'm', 'a', 'b', 'd', 'o', 'c', 'e'] g
# we are going to calc: l - g
# we are going to calc: k - g
# we are going to calc: j - g
# we are going to calc: h - g
# we are going to calc: i - g
# we are going to calc: n - g
# we are going to calc: f - g
# we are going to calc: m - g
# we are going to calc: a - g
# we are going to calc: b - g
# we are going to calc: d - g
# we are going to calc: o - g
# we are going to calc: c - g
# we are going to calc: e - g
# ['l', 'k', 'j', 'h', 'i', 'n', 'f', 'm', 'a', 'b', 'd', 'o', 'c', 'e'] l
# we are going to calc: k - l
# we are going to calc: j - l
# we are going to calc: h - l
# we are going to calc: i - l
# we are going to calc: n - l
# we are going to calc: f - l
# we are going to calc: m - l
# we are going to calc: a - l
# we are going to calc: b - l
# we are going to calc: d - l
# we are going to calc: o - l
# we are going to calc: c - l
# we are going to calc: e - l
# ['k', 'j', 'h', 'i', 'n', 'f', 'm', 'a', 'b', 'd', 'o', 'c', 'e'] k
# we are going to calc: j - k
# we are going to calc: h - k
# we are going to calc: i - k
# we are going to calc: n - k
# we are going to calc: f - k
# we are going to calc: m - k
# we are going to calc: a - k
# we are going to calc: b - k
# we are going to calc: d - k
# we are going to calc: o - k
# we are going to calc: c - k
# we are going to calc: e - k
# ['j', 'h', 'i', 'n', 'f', 'm', 'a', 'b', 'd', 'o', 'c', 'e'] j
# we are going to calc: h - j
# we are going to calc: i - j
# we are going to calc: n - j
# we are going to calc: f - j
# we are going to calc: m - j
# we are going to calc: a - j
# we are going to calc: b - j
# we are going to calc: d - j
# we are going to calc: o - j
# we are going to calc: c - j
# we are going to calc: e - j
# ['h', 'i', 'n', 'f', 'm', 'a', 'b', 'd', 'o', 'c', 'e'] h
# we are going to calc: i - h
# we are going to calc: n - h
# we are going to calc: f - h
# we are going to calc: m - h
# we are going to calc: a - h
# we are going to calc: b - h
# we are going to calc: d - h
# we are going to calc: o - h
# we are going to calc: c - h
# we are going to calc: e - h
# ['i', 'n', 'f', 'm', 'a', 'b', 'd', 'o', 'c', 'e'] i
# we are going to calc: n - i
# we are going to calc: f - i
# we are going to calc: m - i
# we are going to calc: a - i
# we are going to calc: b - i
# we are going to calc: d - i
# we are going to calc: o - i
# we are going to calc: c - i
# we are going to calc: e - i
# ['n', 'f', 'm', 'a', 'b', 'd', 'o', 'c', 'e'] n
# we are going to calc: f - n
# we are going to calc: m - n
# we are going to calc: a - n
# we are going to calc: b - n
# we are going to calc: d - n
# we are going to calc: o - n
# we are going to calc: c - n
# we are going to calc: e - n
# ['f', 'm', 'a', 'b', 'd', 'o', 'c', 'e'] f
# we are going to calc: m - f
# we are going to calc: a - f
# we are going to calc: b - f
# we are going to calc: d - f
# we are going to calc: o - f
# we are going to calc: c - f
# we are going to calc: e - f
# ['m', 'a', 'b', 'd', 'o', 'c', 'e'] m
# we are going to calc: a - m
# we are going to calc: b - m
# we are going to calc: d - m
# we are going to calc: o - m
# we are going to calc: c - m
# we are going to calc: e - m
# ['a', 'b', 'd', 'o', 'c', 'e'] a
# we are going to calc: b - a
# we are going to calc: d - a
# we are going to calc: o - a
# we are going to calc: c - a
# we are going to calc: e - a
# ['b', 'd', 'o', 'c', 'e'] b
# we are going to calc: d - b
# we are going to calc: o - b
# we are going to calc: c - b
# we are going to calc: e - b
# ['d', 'o', 'c', 'e'] d
# we are going to calc: o - d
# we are going to calc: c - d
# we are going to calc: e - d
# ['o', 'c', 'e'] o
# we are going to calc: c - o
# we are going to calc: e - o
# ['c', 'e'] c
# we are going to calc: e - c
# ['e'] e

# %%
sorted_key = []
for k in sorted(missed_topics_dict, key=lambda k: len(missed_topics_dict[k])):
    print(k, len(missed_topics_dict[k]))
    sorted_key.append(k)
# Out:
# g 46
# l 52
# j 176
# n 193
# k 206
# i 250
# h 266
# e 404
# m 500
# f 644
# o 888
# c 921
# d 1024
# b 1052
# a 1228

# %%
missed_topics_dict[el]
# Out:
#                                              image_path  topic2caption_sim  \
# 244   aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.438041
# 258   aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.434571
# 273   aHR0cDovL3VwbG9hZC53aWtpbWVkaWEub3JnL3dpa2lwZW...           0.432757
# 274   aHR0cDovL3VwbG9hZC53aWtpbWVkaWEub3JnL3dpa2lwZW...           0.432757
# 302   aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.426759
# ...                                                 ...                ...
# 4665  aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.392725
# 4669  aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.392393
# 4688  aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.390739
# 4689  aHR0cDovL3VwbG9hZC53aWtpbWVkaWEub3JnL3dpa2lwZW...           0.390648
# 4696  aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.390306
#
#       concept2caption_sim  topic2context_sim  context_gt  \
# 244              0.297401           0.111466       0.125
# 258              0.294126          -0.049544       0.000
# 273              0.331775           0.363471       0.125
# 274              0.331775           0.127627       0.000
# 302              0.311529           0.042451       0.000
# ...                   ...                ...         ...
# 4665             0.342140           0.358445       0.200
# 4669             0.367683           0.319098       0.000
# 4688             0.374302           0.343242       0.100
# 4689             0.291587           0.235879       0.000
# 4696             0.298474           0.213915       0.100
#
#                                                 caption
# 244   1978 Dodge Street Van 1978 Dodge Street Van dr...
# 258                                       English: lane
# 273                                         Brick Lane
# 274                                         Brick Lane
# 302                  English: Old Lane from High Street
# ...                                                 ...
# 4665   English: An emergency escape ramp on AH1 road...
# 4669  Aerial view of Wellington in 2012 showing the ...
# 4688   English: Pedestrian bridge under construction...
# 4689   English: Mechanics Hall, Main Street, Worcest...
# 4696  81st Street ramp replaced stairway in 2017 Eng...
#
# [404 rows x 6 columns]

# %%
missed_topics_with_images = dict()
count = 0
for el in missed_topics_dict:
    missed_topics_with_images[el] = create_data(missed_topics_dict[el], count)
    count = len(missed_topics_with_images[el])
# Out:
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy9mL2ZiLyVEMCU5RiVEMCVCMCVEMCVCRCVEMCVCRSVEMSU4MCVEMCVCMCVEMCVCQyVEMCVCMF8yLmpwZw==.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy9mL2ZiLyVEMCU5RiVEMCVCMCVEMCVCRCVEMCVCRSVEMSU4MCVEMCVCMCVEMCVCQyVEMCVCMF8yLmpwZw==.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvZW4vOS85Zi9TeWRuZXlQYXJhZGVQbGFxdWUuanBn.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy9mL2ZjL1dOWUNfVHJhbnNtaXR0ZXJfUGFya19zdHJlZXRfYXJ0XyUyODM0NDI5MDc2NDExJTI5LmpwZw==.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy9lL2U0LyUyODElMjlXYWl0YXJhX1RyYWluX1N0YXRpb24uanBn.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy8xLzE1L1N0cmVldF8tX3Bhbm9yYW1pb18lMjg5OSUyOS5qcGc=.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy8xLzE1L1N0cmVldF8tX3Bhbm9yYW1pb18lMjg5OSUyOS5qcGc=.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy9jL2MyL0RpYW5hX0hheWRlbl9GaWxtaVRhZGthXyUyOGNyb3BwZWQlMjkuSlBH.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy9jL2MyL0RpYW5hX0hheWRlbl9GaWxtaVRhZGthXyUyOGNyb3BwZWQlMjkuSlBH.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy8wLzBlLzIwMDgwNTE0X0Zvb3Rfb2ZfUnVzaF9mcm9tX2Fjcm9zc19DaGljYWdvX1JpdmVyLkpQRw==.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy9jL2M4L0JveV9pbl9kb29yd2F5X01WTlAuanBn.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cDovL3VwbG9hZC53aWtpbWVkaWEub3JnL3dpa2lwZWRpYS9jb21tb25zLzQvNDkvTmF0aW9uYWxfSGlnaHdheV8yMTJfJTI4SW5kaWElMjkucG5n.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy9kL2QwL05ZQ0RPVF9XMTQtNS5TVkc=.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy9kL2QwL05ZQ0RPVF9XMTQtNS5TVkc=.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy84Lzg1Lzh0aFN0cmVldFN0YXRpb24yMDE3ZC5qcGc=.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy81LzU5L0NqZF9JTUdfMDU4OS5KUEc=.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy81LzU5L0NqZF9JTUdfMDU4OS5KUEc=.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy9kL2QwL05ZQ0RPVF9XMTQtNS5TVkc=.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvZW4vMi8yOC9LZWxseV9Sb2FkLmpwZw==.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy84Lzg1Lzh0aFN0cmVldFN0YXRpb24yMDE3ZC5qcGc=.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvZW4vZS9lYy9NYWluX1N0cmVldF9PbnN0ZWRfTWljaGlnYW5fJTI4MjAxOSUyOS5KUEc=.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy
.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy9lL2U0L0FsaV9JbXJhbi1XYWxraW5nX1RyYWlsX2luX0xhd3JlbmNlX0dhcmRlbnNfSnVuZV80XzIwMDQtNC5qcGVn.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy9mL2YyL0JpZ19Db3VudHJ5X2Zvcl9hX0xvbmVfSGlrZXJfJTI4MjAyNTc1OTA0ODQlMjkuanBn.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy8zLzNlL1Jvc2hhbmFyYV9FYnJhaGltX3dhbGtpbmdfb25fdGhlX2NhdHdhbGsuanBn.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvZW4vOC84NS9Db25leV9IYWxsX3JvdW5kYWJvdXQuanBn.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy81LzU5L1BBU01PX0NhcmQuanBn.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy9lL2UxL1BlZGVzdHJpYW5fVmlld19vZl9SZXRyYWN0YWJsZV9VbWJyZWxsYXMuanBn.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvZW4vOS85ZC9QcmF0dF9TdHJlZXRfSGFydGZvcmRfMS5qcGc=.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvZW4vZS9lNy9XYWxraW5nb25jYXJzLXByZXNzLXNob3QtYXBwcm92ZWQtMjAxOS5wbmc=.jpg

# %%
missed_topics_with_images[el]
# Out:
#      uniq_id  image_id                                            caption  \
# 0        195       195                  Hiker at Wisner Park in Elmira NY
# 1        196       196           Hiker at Tompkinsville Park in Staten NY
# 2        197       197          Hiker at Garfield Square in Pottsville PA
# 3        198       198        Hiker at Fisher Veterans Park in Lebanon PA
# 4        200       200                                   Wilderness Road
# ..       ...       ...                                                ...
# 876     2961      2961   English Billy Goat C Trail approach from west...
# 877     2963      2963   English I like this photos for its alone agai...
# 878     2967      2967   English A wall of Georgia National Guardsmen ...
# 879     2970      2970   English A train crossing through Lawachara Na...
# 880     2972      2972  Standing Rock in Steedman English Standing Roc...
#
#     labels                                              image  \
# 0           /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1           /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2           /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3           /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4           /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# ..     ...                                                ...
# 876         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 877         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 878         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 879         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 880         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
#      topic2caption_sim  concept2caption_sim  topic2context_sim
# 0             0.545356             0.324049           0.270464
# 1             0.531638             0.352481           0.320010
# 2             0.530654             0.336373           0.270464
# 3             0.524322             0.375746           0.270464
# 4             0.497447             0.384842           0.393688
# ..                 ...                  ...                ...
# 876           0.392449             0.330498           0.280384
# 877           0.391950             0.315300           0.296100
# 878           0.391661             0.315743           0.120356
# 879           0.390645             0.305481           0.119095
# 880           0.390249             0.309894           0.165292
#
# [881 rows x 8 columns]

# %%
s = 0
for el in missed_topics_with_images:
    missed_topics_with_images[el] = missed_topics_with_images[el].dropna(subset=['caption'])
    missed_topics_with_images[el]['topics']  = [el] * len(missed_topics_with_images[el])
    print(el, len(missed_topics_with_images[el]))
    s = s + len(missed_topics_with_images[el])
print(s)
# Out:
# a 1226
# b 1044
# c 910
# d 1020
# e 402
# f 638
# g 45
# h 259
# i 249
# j 175
# k 202
# l 51
# m 497
# n 190
# o 881
# 7789

# %%
scol = ['topic2caption_sim', 'concept2caption_sim']
for el in missed_topics_with_images:
    print(el)
    display(missed_topics_with_images[el][scol].describe().round(2))
# Out:
# a
#        topic2caption_sim  concept2caption_sim
# count            1226.00              1226.00
# mean                0.43                 0.33
# std                 0.04                 0.04
# min                 0.39                 0.29
# 25%                 0.40                 0.30
# 50%                 0.42                 0.32
# 75%                 0.45                 0.35
# max                 0.63                 0.49
# b
#        topic2caption_sim  concept2caption_sim
# count            1044.00              1044.00
# mean                0.43                 0.34
# std                 0.03                 0.04
# min                 0.39                 0.29
# 25%                 0.40                 0.30
# 50%                 0.41                 0.32
# 75%                 0.44                 0.37
# max                 0.65                 0.51
# c
#        topic2caption_sim  concept2caption_sim
# count             910.00               910.00
# mean                0.42                 0.32
# std                 0.03                 0.03
# min                 0.39                 0.29
# 25%                 0.40                 0.30
# 50%                 0.41                 0.31
# 75%                 0.43                 0.34
# max                 0.58                 0.45
# d
#        topic2caption_sim  concept2caption_sim
# count            1020.00              1020.00
# mean                0.45                 0.34
# std                 0.05                 0.04
# min                 0.39                 0.29
# 25%                 0.41                 0.31
# 50%                 0.45                 0.33
# 75%                 0.46                 0.35
# max                 0.64                 0.49
# e
#        topic2caption_sim  concept2caption_sim
# count             402.00               402.00
# mean                0.42                 0.32
# std                 0.03                 0.03
# min                 0.39                 0.29
# 25%                 0.40                 0.30
# 50%                 0.41                 0.31
# 75%                 0.43                 0.33
# max                 0.56                 0.44
# f
#        topic2caption_sim  concept2caption_sim
# count             638.00               638.00
# mean                0.44                 0.33
# std                 0.04                 0.05
# min                 0.39                 0.29
# 25%                 0.41                 0.30
# 50%                 0.43                 0.32
# 75%                 0.46                 0.34
# max                 0.64                 0.55
# g
#        topic2caption_sim  concept2caption_sim
# count              45.00                45.00
# mean                0.41                 0.43
# std                 0.02                 0.14
# min                 0.39                 0.29
# 25%                 0.40                 0.32
# 50%                 0.41                 0.36
# 75%                 0.42                 0.49
# max                 0.46                 0.73
# h
#        topic2caption_sim  concept2caption_sim
# count             259.00               259.00
# mean                0.44                 0.33
# std                 0.04                 0.05
# min                 0.39                 0.29
# 25%                 0.41                 0.30
# 50%                 0.43                 0.31
# 75%                 0.46                 0.34
# max                 0.58                 0.60
# i
#        topic2caption_sim  concept2caption_sim
# count             249.00               249.00
# mean                0.49                 0.34
# std                 0.08                 0.05
# min                 0.39                 0.29
# 25%                 0.42                 0.30
# 50%                 0.47                 0.33
# 75%                 0.58                 0.34
# max                 0.65                 0.65
# j
#        topic2caption_sim  concept2caption_sim
# count             175.00               175.00
# mean                0.43                 0.41
# std                 0.04                 0.09
# min                 0.39                 0.29
# 25%                 0.40                 0.33
# 50%                 0.42                 0.39
# 75%                 0.44                 0.47
# max                 0.67                 0.63
# k
#        topic2caption_sim  concept2caption_sim
# count             202.00               202.00
# mean                0.43                 0.38
# std                 0.04                 0.08
# min                 0.39                 0.29
# 25%                 0.41                 0.32
# 50%                 0.42                 0.35
# 75%                 0.45                 0.40
# max                 0.58                 0.66
# l
#        topic2caption_sim  concept2caption_sim
# count              51.00                51.00
# mean                0.42                 0.44
# std                 0.02                 0.12
# min                 0.39                 0.29
# 25%                 0.40                 0.33
# 50%                 0.41                 0.39
# 75%                 0.43                 0.56
# max                 0.50                 0.65
# m
#        topic2caption_sim  concept2caption_sim
# count             497.00               497.00
# mean                0.43                 0.36
# std                 0.04                 0.06
# min                 0.39                 0.29
# 25%                 0.40                 0.31
# 50%                 0.42                 0.34
# 75%                 0.45                 0.41
# max                 0.63                 0.53
# n
#        topic2caption_sim  concept2caption_sim
# count             190.00               190.00
# mean                0.42                 0.44
# std                 0.03                 0.07
# min                 0.39                 0.29
# 25%                 0.40                 0.38
# 50%                 0.41                 0.44
# 75%                 0.43                 0.49
# max                 0.52                 0.63
# o
#        topic2caption_sim  concept2caption_sim
# count             881.00               881.00
# mean                0.42                 0.33
# std                 0.03                 0.03
# min                 0.39                 0.29
# 25%                 0.40                 0.30
# 50%                 0.42                 0.32
# 75%                 0.44                 0.34
# max                 0.66                 0.50

# %%
df_2 = pd.DataFrame()
for el in missed_topics_with_images:
    df_2 = pd.concat([df_2, missed_topics_with_images[el]], ignore_index=True)
# df_
display(df_2[scol].describe().round(2))
# Out:
#        topic2caption_sim  concept2caption_sim
# count            7789.00              7789.00
# mean                0.43                 0.34
# std                 0.04                 0.05
# min                 0.39                 0.29
# 25%                 0.40                 0.30
# 50%                 0.42                 0.32
# 75%                 0.45                 0.35
# max                 0.67                 0.73

# %% [markdown]
# ## missed one for sim

# %%
missed_ones = ['a', 'f', 'g', 'i', 'j', 'k', 'l', 'm', 'n', 'o']

# %%
for el in missed_ones:
    print(el)

    display(missed_topics_with_images[el][['topic2caption_sim', 'concept2caption_sim']].describe().round(2))
# Out:
# a
#        topic2caption_sim  concept2caption_sim
# count            1226.00              1226.00
# mean                0.43                 0.33
# std                 0.04                 0.04
# min                 0.39                 0.29
# 25%                 0.40                 0.30
# 50%                 0.42                 0.32
# 75%                 0.45                 0.35
# max                 0.63                 0.49
# f
#        topic2caption_sim  concept2caption_sim
# count             638.00               638.00
# mean                0.44                 0.33
# std                 0.04                 0.05
# min                 0.39                 0.29
# 25%                 0.41                 0.30
# 50%                 0.43                 0.32
# 75%                 0.46                 0.34
# max                 0.64                 0.55
# g
#        topic2caption_sim  concept2caption_sim
# count              45.00                45.00
# mean                0.41                 0.43
# std                 0.02                 0.14
# min                 0.39                 0.29
# 25%                 0.40                 0.32
# 50%                 0.41                 0.36
# 75%                 0.42                 0.49
# max                 0.46                 0.73
# i
#        topic2caption_sim  concept2caption_sim
# count             249.00               249.00
# mean                0.49                 0.34
# std                 0.08                 0.05
# min                 0.39                 0.29
# 25%                 0.42                 0.30
# 50%                 0.47                 0.33
# 75%                 0.58                 0.34
# max                 0.65                 0.65
# j
#        topic2caption_sim  concept2caption_sim
# count             175.00               175.00
# mean                0.43                 0.41
# std                 0.04                 0.09
# min                 0.39                 0.29
# 25%                 0.40                 0.33
# 50%                 0.42                 0.39
# 75%                 0.44                 0.47
# max                 0.67                 0.63
# k
#        topic2caption_sim  concept2caption_sim
# count             202.00               202.00
# mean                0.43                 0.38
# std                 0.04                 0.08
# min                 0.39                 0.29
# 25%                 0.41                 0.32
# 50%                 0.42                 0.35
# 75%                 0.45                 0.40
# max                 0.58                 0.66
# l
#        topic2caption_sim  concept2caption_sim
# count              51.00                51.00
# mean                0.42                 0.44
# std                 0.02                 0.12
# min                 0.39                 0.29
# 25%                 0.40                 0.33
# 50%                 0.41                 0.39
# 75%                 0.43                 0.56
# max                 0.50                 0.65
# m
#        topic2caption_sim  concept2caption_sim
# count             497.00               497.00
# mean                0.43                 0.36
# std                 0.04                 0.06
# min                 0.39                 0.29
# 25%                 0.40                 0.31
# 50%                 0.42                 0.34
# 75%                 0.45                 0.41
# max                 0.63                 0.53
# n
#        topic2caption_sim  concept2caption_sim
# count             190.00               190.00
# mean                0.42                 0.44
# std                 0.03                 0.07
# min                 0.39                 0.29
# 25%                 0.40                 0.38
# 50%                 0.41                 0.44
# 75%                 0.43                 0.49
# max                 0.52                 0.63
# o
#        topic2caption_sim  concept2caption_sim
# count             881.00               881.00
# mean                0.42                 0.33
# std                 0.03                 0.03
# min                 0.39                 0.29
# 25%                 0.40                 0.30
# 50%                 0.42                 0.32
# 75%                 0.44                 0.34
# max                 0.66                 0.50

# %%
df_l = pd.DataFrame()
for el in missed_ones:
    df_l = pd.concat([df_l, missed_topics_with_images[el]], ignore_index=True)
# df_
display(df_l[['topic2caption_sim', 'concept2caption_sim']].describe().round(2))
# Out:
#        topic2caption_sim  concept2caption_sim
# count            4154.00              4154.00
# mean                0.43                 0.35
# std                 0.04                 0.06
# min                 0.39                 0.29
# 25%                 0.40                 0.30
# 50%                 0.42                 0.32
# 75%                 0.45                 0.36
# max                 0.67                 0.73

# %% [markdown]
# ### based on cider human

# %%
missed_ones = ['f', 'g', 'h', 'j', 'l','n']

# %%
for el in missed_ones:
    print(el)

    display(missed_topics_with_images[el][['topic2caption_sim', 'concept2caption_sim']].describe().round(2))
# Out:
# f
#        topic2caption_sim  concept2caption_sim
# count             638.00               638.00
# mean                0.44                 0.33
# std                 0.04                 0.05
# min                 0.39                 0.29
# 25%                 0.41                 0.30
# 50%                 0.43                 0.32
# 75%                 0.46                 0.34
# max                 0.64                 0.55
# g
#        topic2caption_sim  concept2caption_sim
# count              45.00                45.00
# mean                0.41                 0.43
# std                 0.02                 0.14
# min                 0.39                 0.29
# 25%                 0.40                 0.32
# 50%                 0.41                 0.36
# 75%                 0.42                 0.49
# max                 0.46                 0.73
# h
#        topic2caption_sim  concept2caption_sim
# count             259.00               259.00
# mean                0.44                 0.33
# std                 0.04                 0.05
# min                 0.39                 0.29
# 25%                 0.41                 0.30
# 50%                 0.43                 0.31
# 75%                 0.46                 0.34
# max                 0.58                 0.60
# j
#        topic2caption_sim  concept2caption_sim
# count             175.00               175.00
# mean                0.43                 0.41
# std                 0.04                 0.09
# min                 0.39                 0.29
# 25%                 0.40                 0.33
# 50%                 0.42                 0.39
# 75%                 0.44                 0.47
# max                 0.67                 0.63
# l
#        topic2caption_sim  concept2caption_sim
# count              51.00                51.00
# mean                0.42                 0.44
# std                 0.02                 0.12
# min                 0.39                 0.29
# 25%                 0.40                 0.33
# 50%                 0.41                 0.39
# 75%                 0.43                 0.56
# max                 0.50                 0.65
# n
#        topic2caption_sim  concept2caption_sim
# count             190.00               190.00
# mean                0.42                 0.44
# std                 0.03                 0.07
# min                 0.39                 0.29
# 25%                 0.40                 0.38
# 50%                 0.41                 0.44
# 75%                 0.43                 0.49
# max                 0.52                 0.63

# %%
df_l = pd.DataFrame()
for el in missed_ones:
    df_l = pd.concat([df_l, missed_topics_with_images[el]], ignore_index=True)
# df_
display(df_l[['topic2caption_sim', 'concept2caption_sim']].describe().round(2))
# Out:
#        topic2caption_sim  concept2caption_sim
# count            1358.00              1358.00
# mean                0.43                 0.36
# std                 0.04                 0.08
# min                 0.39                 0.29
# 25%                 0.40                 0.30
# 50%                 0.42                 0.33
# 75%                 0.45                 0.40
# max                 0.67                 0.73

# %% [markdown]
# ### CIDEr web

# %%
missed_ones = ['e', 'f', 'g', 'h', 'j', 'm','n']

# %%
for el in missed_ones:
    print(el)

    display(missed_topics_with_images[el][['topic2caption_sim', 'concept2caption_sim']].describe().round(2))
# Out:
# e
#        topic2caption_sim  concept2caption_sim
# count             402.00               402.00
# mean                0.42                 0.32
# std                 0.03                 0.03
# min                 0.39                 0.29
# 25%                 0.40                 0.30
# 50%                 0.41                 0.31
# 75%                 0.43                 0.33
# max                 0.56                 0.44
# f
#        topic2caption_sim  concept2caption_sim
# count             638.00               638.00
# mean                0.44                 0.33
# std                 0.04                 0.05
# min                 0.39                 0.29
# 25%                 0.41                 0.30
# 50%                 0.43                 0.32
# 75%                 0.46                 0.34
# max                 0.64                 0.55
# g
#        topic2caption_sim  concept2caption_sim
# count              45.00                45.00
# mean                0.41                 0.43
# std                 0.02                 0.14
# min                 0.39                 0.29
# 25%                 0.40                 0.32
# 50%                 0.41                 0.36
# 75%                 0.42                 0.49
# max                 0.46                 0.73
# h
#        topic2caption_sim  concept2caption_sim
# count             259.00               259.00
# mean                0.44                 0.33
# std                 0.04                 0.05
# min                 0.39                 0.29
# 25%                 0.41                 0.30
# 50%                 0.43                 0.31
# 75%                 0.46                 0.34
# max                 0.58                 0.60
# j
#        topic2caption_sim  concept2caption_sim
# count             175.00               175.00
# mean                0.43                 0.41
# std                 0.04                 0.09
# min                 0.39                 0.29
# 25%                 0.40                 0.33
# 50%                 0.42                 0.39
# 75%                 0.44                 0.47
# max                 0.67                 0.63
# m
#        topic2caption_sim  concept2caption_sim
# count             497.00               497.00
# mean                0.43                 0.36
# std                 0.04                 0.06
# min                 0.39                 0.29
# 25%                 0.40                 0.31
# 50%                 0.42                 0.34
# 75%                 0.45                 0.41
# max                 0.63                 0.53
# n
#        topic2caption_sim  concept2caption_sim
# count             190.00               190.00
# mean                0.42                 0.44
# std                 0.03                 0.07
# min                 0.39                 0.29
# 25%                 0.40                 0.38
# 50%                 0.41                 0.44
# 75%                 0.43                 0.49
# max                 0.52                 0.63

# %%
df_l = pd.DataFrame()
for el in missed_ones:
    df_l = pd.concat([df_l, missed_topics_with_images[el]], ignore_index=True)
# df_
display(df_l[['topic2caption_sim', 'concept2caption_sim']].describe().round(2))
# Out:
#        topic2caption_sim  concept2caption_sim
# count            2206.00              2206.00
# mean                0.43                 0.35
# std                 0.04                 0.07
# min                 0.39                 0.29
# 25%                 0.40                 0.30
# 50%                 0.42                 0.32
# 75%                 0.45                 0.38
# max                 0.67                 0.73

# %%
def get_portion(df, p1=72, p2=16, p3=12):
    s1 = df.sample(frac = p1/100)
    rest_part_1 = df.drop(s1.index)
    s2 = rest_part_1.sample(frac = p2/(100-p1))
    s3 = rest_part_1.drop(s2.index)
    return s1, s2, s3

# %%
name_lsit = ['stage1_train', 'stage2_train', 'val']
por_dict = dict()
data_dict = dict()
for n in name_lsit:
    data_dict[n] = pd.DataFrame() 
for el in missed_ones:
    s1, s2, v = get_portion(missed_topics_with_images[el])
    
    s1 = s1.reset_index(drop=True)
    data_dict['stage1_train'] = pd.concat([data_dict['stage1_train'], s1], ignore_index=True)
    
    s2 = s2.reset_index(drop=True)
    data_dict['stage2_train'] = pd.concat([data_dict['stage2_train'], s2], ignore_index=True)
    
    v = v.reset_index(drop=True)
    data_dict['val'] = pd.concat([data_dict['val'], v], ignore_index=True)
#     data_dict[el] = por_dict

# %%
len(data_dict['stage1_train'])
# Out:
# 1587

# %%
len(data_dict['stage2_train'])
# Out:
# 353

# %%
len(data_dict['val'])
# Out:
# 266

# %%
names = ['uniq_id', 'image_id', 'caption', 'labels', 'image']

# %% [markdown]
# ## SAve Sim

# %%
! mkdir -p /raid/AISSEL/htest/datasets/ped_data/wit/missed_q50_over_avg
saved_path = '/raid/AISSEL/htest/datasets/ped_data/wit/missed_q50_over_avg'
for el in data_dict:
    name = f'caption_{el}.tsv'
    df_s = data_dict[el][names]
    df_s.to_csv(f'{saved_path}/{name}', sep="\t", index=False, header=False)

    print(name)
# Out:
# caption_stage1_train.tsv
# caption_stage2_train.tsv
# caption_val.tsv

# %% [markdown]
# ## SAve CIDEr human

# %%
! mkdir -p /raid/AISSEL/htest/datasets/ped_data/wit/missed_q50_over_avg_cider
saved_path = '/raid/AISSEL/htest/datasets/ped_data/wit/missed_q50_over_avg_cider'
for el in data_dict:
    name = f'caption_{el}.tsv'
    df_s = data_dict[el][names]
    df_s.to_csv(f'{saved_path}/{name}', sep="\t", index=False, header=False)

    print(name)
# Out:
# caption_stage1_train.tsv
# caption_stage2_train.tsv
# caption_val.tsv

# %% [markdown]
# ## SAve CIDEr web

# %%
! mkdir -p /raid/AISSEL/htest/datasets/ped_data/wit/missed_q50_over_avg_cider_web
saved_path = '/raid/AISSEL/htest/datasets/ped_data/wit/missed_q50_over_avg_cider_web'
for el in data_dict:
    name = f'caption_{el}.tsv'
    df_s = data_dict[el][names]
    df_s.to_csv(f'{saved_path}/{name}', sep="\t", index=False, header=False)

    print(name)
# Out:
# caption_stage1_train.tsv
# caption_stage2_train.tsv
# caption_val.tsv

# %%
len(data_dict['stage2_train'])
# Out:
# 611

# %% [markdown]
# ### get portion for dataset
# ```stage 1: 75%, stage 2: %15, test: %5, validation % 5```

# %%
name_lsit = ['stage1_train', 'stage2_train', 'val', 'test']
por_dict = dict()
data_dict = dict()
for n in name_lsit:
    data_dict[n] = pd.DataFrame() 
for el in missed_topics_with_images:
    s1, s2, v, t = get_portion(missed_topics_with_images[el])
    
    s1 = s1.reset_index(drop=True)
    data_dict['stage1_train'] = pd.concat([data_dict['stage1_train'], s1], ignore_index=True)
    
    s2 = s2.reset_index(drop=True)
    data_dict['stage2_train'] = pd.concat([data_dict['stage2_train'], s2], ignore_index=True)
    
    t = t.reset_index(drop=True)
    data_dict['test'] = pd.concat([data_dict['test'], t], ignore_index=True)
    
    v = v.reset_index(drop=True)
    data_dict['val'] = pd.concat([data_dict['val'], v], ignore_index=True)
#     data_dict[el] = por_dict

# %%
data_dict = dict()

# %%
def get_portion(df, p1=75, p2=15, p3=5, p4=5):
    s1 = df.sample(frac = p1/100)
    rest_part_1 = df.drop(s1.index)
    s2 = rest_part_1.sample(frac = p2/(100-p1))
    rest_part_2 = rest_part_1.drop(s2.index)
    s3 = rest_part_2.sample(frac = p3/(100 - p1 - p2))
    s4 = rest_part_2.drop(s3.index)
    return s1, s2, s3, s4

# %% [markdown]
# # Create Random Dataset

# %%
# df_p = csim_df[csim_df['concept_caption_score'] >= csim_df['concept_caption_score'].mean()]
df_p = csim_df[csim_df['concept_caption_score'] >= 0.134]
df_p = df_p.reset_index(drop=True)
df_p
# Out:
#                                                  image_url  \
# 0        https://upload.wikimedia.org/wikipedia/commons...
# 1        https://upload.wikimedia.org/wikipedia/commons...
# 2        https://upload.wikimedia.org/wikipedia/commons...
# 3        https://upload.wikimedia.org/wikipedia/commons...
# 4        https://upload.wikimedia.org/wikipedia/commons...
# ...                                                    ...
# 1355833  https://upload.wikimedia.org/wikipedia/commons...
# 1355834  https://upload.wikimedia.org/wikipedia/commons...
# 1355835  https://upload.wikimedia.org/wikipedia/commons...
# 1355836  https://upload.wikimedia.org/wikipedia/commons...
# 1355837  https://upload.wikimedia.org/wikipedia/commons...
#
#                                                    caption  \
# 0        Menachem Mendel Schneerson English: Menachem M...
# 1         English: Image cropped from a baseball card o...
# 2        The special theory of relativity, formulated i...
# 3                       English: Randy Stonehill Signature
# 4         English: United States Senator William Proxmi...
# ...                                                    ...
# 1355833  Massachusetts Bay Transportation Authority 170...
# 1355834   A map showing the path of State Highway 22 in...
# 1355835                                     English: CIPET
# 1355836   English: Jia Jingde, politician of China. 中文:...
# 1355837                         Beyer in 2013 DSC_9909.jpg
#
#                                                    context  \
# 0        1994 was a common year starting on Saturday of...
# 1        Donald Robert "Duffy" Dyer is an American form...
# 2        In relativistic physics, a velocity-addition f...
# 3        Randall Evan Stonehill is an American singer a...
# 4        Edward William Proxmire was an American politi...
# ...                                                    ...
# 1355833  The Urban Transportation Development Corporati...
# 1355834  State Highway 22 is a state highway in Oklahom...
# 1355835  Central Institute of Petrochemical Engineering...
# 1355836  This is a list of Vice Presidents of the Exami...
# 1355837  Brennen Beyer is an American football outside ...
#
#          concept_caption_score  concept_context_score  196_caption_score  \
# 0                     0.166272               0.094395           0.078204
    df = df_p[c_list]
    
    df = df[df[col] > df[col].quantile(0.75)]
    
#     df = df[df[col] >= 0.39]
#     df = df[df['concept_caption_score'] >= 0.29]

    df = df.sort_values(by=[col], ascending=False)
    df_dict[col] = df

# %%
df_dict[col]
# Out:
#          376_caption_score  376_context_score  \
# 869924            0.567895           0.407775
# 788798            0.567709           0.407775
# 841795            0.543113           0.423695
# 667637            0.537630           0.350208
# 184343            0.533986           0.539802
# ...                    ...                ...
# 97023             0.152664           0.078346
# 70261             0.152664           0.014011
# 1154967           0.152663           0.061022
# 97914             0.152663           0.023257
# 191872            0.152663           0.200746
#
#                                                  image_url  \
# 869924   https://upload.wikimedia.org/wikipedia/commons...
# 788798   https://upload.wikimedia.org/wikipedia/commons...
# 841795   https://upload.wikimedia.org/wikipedia/commons...
# 667637   https://upload.wikimedia.org/wikipedia/commons...
# 184343   https://upload.wikimedia.org/wikipedia/commons...
# ...                                                    ...
# 97023    https://upload.wikimedia.org/wikipedia/commons...
# 70261    https://upload.wikimedia.org/wikipedia/commons...
# 1154967  https://upload.wikimedia.org/wikipedia/commons...
# 97914    http://upload.wikimedia.org/wikipedia/commons/...
# 191872   http://upload.wikimedia.org/wikipedia/commons/...
#
#                                                    caption  \
# 869924    English: Recreation of Minnie Mouse's signatu...
# 788798    English: Recreation of Mickey Mouse's signatu...
# 841795    Cars 623 and 717 passing on the Red Car Troll...
# 667637   Disney villains at Disneyland's Mickey's Hallo...
# 184343   Theatrical release poster English: Poster for ...
# ...                                                    ...
# 97023                                 English: Adam Walker
# 70261                   English: Ishqi-Mari statue (front)
# 1154967  Metropolitan Police Ford F450 Jankel Guardian ...
# 97914    Entrance Deutsch: Otterzentrum English: Entran...
# 191872           Barry's bridge Deutsch: Brücke der Barry.
#
#                                                    context  \
# 869924   This is a list of characters that have appeare...
# 788798   This is a list of characters that have appeare...
# 841795   The Red Car Trolley is a 1,000 mm metre gauge ...
# 667637   Mickey's Halloween Party was an annual Hallowe...
# 184343   Trolley Troubles is a 1927 animated short subj...
# ...                                                    ...
# 97023    Adam Walker is a Scotland international rugby ...
# 70261    Ishqi-Mari or Ishgi-Mari, previously read Lamg...
# 1154967  The Jankel group of companies has been continu...
# 97914    The Hankensbüttel Otter Centre is a nature exp...
# 191872   USS Barry (DD-933) was one of eighteen Forrest...
#
#          concept_caption_score  concept_context_score
# 869924                0.189813               0.156888
# 788798                0.180582               0.156888
# 841795                0.200099               0.132485
# 667637                0.199137               0.043375
# 184343                0.172679               0.117095
# ...                        ...                    ...
# 97023                 0.305401               0.118617
# 70261                 0.242632              -0.032017
# 1154967               0.225747               0.043164
# 97914                 0.173663              -0.005479
# 191872                0.135751               0.050589
#
# [338960 rows x 7 columns]

# %%
for el in df_dict:
    t,_ = el.split('_', 1)
#     print(t)
    df_dict[el].columns = [f'{t}_caption_sim', f'{t}_context_sim', 'image_url',
                          'caption', 'context', f'ped_caption_sim', f'ped_context_sim']
    display(df_dict[el].describe().round(2))
    print('\n')
# Out:
#        196_caption_sim  196_context_sim  ped_caption_sim  ped_context_sim
# count        338960.00        338960.00        338960.00        338960.00
# mean              0
context_sim  ped_caption_sim  ped_context_sim
# count        338960.00        338960.00        338960.00        338960.00
# mean              0.22             0.12             0.19             0.07
# std               0.05             0.09             0.04             0.07
# min               0.16            -0.26             0.13            -0.23
# 25%               0.18             0.06             0.16             0.03
# 50%               0.20             0.12             0.18             0.07
# 75%               0.24             0.18             0.21             0.12
# max               0.64             0.59             0.73             0.69
#        250_caption_sim  250_context_sim  ped_caption_sim  ped_context_sim
# count        338959.00        338959.00        338959.00        338959.00
# mean              0.15             0.08             0.18             0.07
# std               0.03             0.07             0.04             0.07
# min               0.11            -0.22             0.13            -0.23
# 25%               0.12             0.03             0.15             0.02
# 50%               0.14             0.08             0.18             0.07
# 75%               0.17             0.12             0.21             0.11
# max               0.45             0.42             0.73             0.69
#        376_caption_sim  376_context_sim  ped_caption_sim  ped_context_sim
# count        338960.00        338960.00        338960.00        338960.00
# mean              0.20             0.07             0.19             0.07
# std               0.04             0.08             0.04             0.07
# min               0.15            -0.27             0.13            -0.23
# 25%               0.17             0.02             0.16             0.02
# 50%               0.19             0.07             0.18             0.07
# 75%               0.22             0.13             0.22             0.11
# max               0.57             0.54             0.73             0.69

# %%
topics = get_topics(concept='pedestrian')

# %%
pg_dict = dict()
pg_dict['a'] = [68, 112, 56, 224]
pg_dict['b'] = [309, 344, 47, -1, 53]
pg_dict['c'] = [314, 331, 419, 394]
pg_dict['d'] = [98, 196, 202, 294]
pg_dict['e'] = [172, 137, 11, 134, 150, 216]
pg_dict['f'] = [363, 40, 43]
pg_dict['g'] = [441, 376]
pg_dict['h'] = [144, 416, 327]
pg_dict['i'] = [192, 20, 114]
pg_dict['j'] = [345]
pg_dict['k'] = [8, 265]
pg_dict['l'] = [250, 80, 426]
pg_dict['m'] = [169, 99, 378]
pg_dict['n'] = [432, 388, 412]
pg_dict['o'] = [12, 278, 198, 296]

# %%
k_name = ['image_url', 'caption', 'context', 'concept2caption_sim', 
          'concept2context_sim']
# k_name = ['image_url', 'caption', 'context', 'concept2caption_sim', 
#           'concept2context_sim']
for el in pg_dict:
    pg_dict[el] = [f'{i}_caption_score' for i in pg_dict[el]]
    pg_dict[el] = [df_dict[i] for i in pg_dict[el]]
    pg_dict[el] = [df_.reset_index(drop=True) for df_ in pg_dict[el]]

# %%
for el in pg_dict:
    t_df = pd.DataFrame(columns = ['topic2caption_sim', 'topic2context_sim'] + k_name)
    for df_ in pg_dict[el]:
        df_.columns = ['topic2caption_sim', 'topic2context_sim'] + k_name
        t_df = pd.concat([t_df, df_], ignore_index=True)
    t_df = t_df.drop_duplicates()
    t_df = t_df.reset_index(drop=True)
    pg_dict[el] = t_df

# %%
for el in pg_dict:
    print(el)
    pg_dict[el].drop_duplicates(subset="image_url",
                     keep='first', inplace=True)
    display(pg_dict[el].describe().round(2))
# Out:
# a
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count          513249.00          513249.00            513249.00
# mean                0.18               0.08                 0.19
# std                 0.04               0.09                 0.04
# min                 0.12              -0.28                 0.13
# 25%                 0.15               0.02                 0.15
# 50%                 0.17               0.08                 0.18
# 75%                 0.20               0.14                 0.21
# max                 0.57               0.53                 0.73
#
#        concept2context_sim
# count            513249.00
# mean                  0.07
# std                   0.07
# min                  -0.23
# 25%                   0.03
# 50%                   0.07
# 75%                   0.11
# max                   0.69
# b
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count          695643.00          695643.00            695643.00
# mean                0.21               0.10                 0.18
# std                 0.05               0.09                 0.04
# min                 0.11              -0.27                 0.13
# 25%                 0.17               0.04                 0.15
# 50%                 0.20               0.10                 0.17
# 75%                 0.24               0.16                 0.20
# max                 0.60               0.72                 0.73
#
#        concept2context_sim
# count            695643.00
# mean                  0.07
# std                   0.07
# min                  -0.23
# 25%                   0.03
# 50%                   0.07
# 75%                   0.11
# max                   0.69
# c
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count          486016.00          486016.00            486016.00
# mean                0.21               0.10                 0.19
# std                 0.04               0.08                 0.04
# min                 0.15              -0.26                 0.13
# 25%                 0.17               0.04                 0.15
# 50%                 0.20               0.10                 0.18
# 75%                 0.23               0.15                 0.21
# max                 0.68               0.67                 0.73
#
#        concept2context_sim
# count            486016.00
# mean                  0.07
# std                   0.07
# min                  -0.23
# 25%                   0.03
# 50%                   0.07
# 75%                   0.11
# max                   0.69
# d
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count          486807.00          486807.00            486807.00
# mean                0.19               0.08                 0.19
# std                 0.06               0.08                 0.04
# min                 0.10              -0.21                 0.13
# 25%                 0.14               0.03                 0.16
# 50%                 0.18               0.08                 0.18
# 75%                 0.21               0.14                 0.21
# max                 0.73               0.64                 0.73
#
#        concept2context_sim
# count            486807.00
# mean                  0.07
# std                   0.07
# min                  -0.23
# 25%                   0.03
# 50%                   0.07
# 75%                   0.12
# max                   0.69
# e
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count          510572.00          510572.00            510572.00
# mean                0.19               0.09                 0.19
# std                 0.04               0.08                 0.04
# min                 0.14              -0.30                 0.13
# 25%                 0.17               0.03                 0.16
# 50%                 0.19               0.09                 0.18
# 75%                 0.21               0.14                 0.21
# max                 0.61               0.56                 0.73
#
#        concept2context_sim
# count            510572.00
# mean                  0.07
# std                   0.07
# min                  -0.23
# 25%                   0.03
# 50%                   0.07
# 75%                   0.11
# max                   0.69
# f
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count          517685.00          517685.00            517685.00
# mean                0.16               0.06                 0.19
# std                 0.04               0.07                 0.04
# min                 0.09              -0.25                 0.13
# 25%                 0.12               0.01                 0.16
# 50%                 0.16               0.06                 0.18
# 75%                 0.18               0.11                 0.22
# max                 0.53               0.57                 0.73
#
#        concept2context_sim
# count            517685.00
# mean                  0.07
# std                   0.07
# min                  -0.23
# 25%                   0.03
# 50%                   0.07
# 75%                   0.11
# max                   0.69
# g
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count          488750.00          488750.00            488750.00
# mean                0.18               0.06                 0.19
# std                 0.04               0.08                 0.04
# min                 0.13              -0.30                 0.13
# 25%                 0.16               0.01                 0.15
# 50%                 0.17               0.06                 0.18
# 75%                 0.20               0.11                 0.21
# max                 0.57               0.56                 0.73
#
#        concept2context_sim
# count            488750.00
# mean                  0.07
# std                   0.07
# min                  -0.23
# 25%                   0.02
# 50%                   0.07
# 75%                   0.11
# max                   0.69
# h
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count          525576.00          525576.00            525576.00
# mean                0.19               0.07                 0.19
# std                 0.05               0.08                 0.04
# min                 0.13              -0.21                 0.13
# 25%                 0.15               0.02                 0.15
# 50%                 0.18               0.06                 0.18
# 75%                 0.21               0.11                 0.21
# max                 0.53               0.57                 0.73
#
#        concept2context_sim
# count            525576.00
# mean                  0.07
# std                   0.07
# min                  -0.23
# 25%                   0.02
# 50%                   0.06
# 75%                   0.11
# max                   0.69
# i
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count          540471.00          540471.00            540471.00
# mean                0.14               0.06                 0.19
# std                 0.03               0.07                 0.04
# min                 0.09              -0.26                 0.13
# 25%                 0.12               0.02                 0.15
# 50%                 0.14               0.06                 0.18
# 75%                 0.16               0.10                 0.21
# max                 0.58               0.57                 0.73
#
#        concept2context_sim
# count            540471.00
# mean                  0.07
# std                   0.07
# min                  -0.23
# 25%                   0.02
# 50%                   0.07
# 75%                   0.11
# max                   0.69
# j
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count          274472.00          274472.00            274472.00
# mean                0.16               0.09                 0.19
# std                 0.05               0.08                 0.05
# min                 0.11              -0.22                 0.13
# 25%                 0.13               0.04                 0.16
# 50%                 0.15               0.09                 0.19
# 75%                 0.18               0.15                 0.22
# max                 0.67               0.66                 0.73
#
#        concept2context_sim
# count            274472.00
# mean                  0.08
# std                   0.07
# min                  -0.20
# 25%                   0.03
# 50%                   0.08
# 75%                   0.12
# max                   0.69
# k
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count          451090.00          451090.00            451090.00
# mean                0.14               0.08                 0.19
# std                 0.04               0.08                 0.04
# min                 0.09              -0.25                 0.13
# 25%                 0.11               0.03                 0.16
# 50%                 0.13               0.08                 0.18
# 75%                 0.16               0.13                 0.21
# max                 0.58               0.59                 0.73
#
#        concept2context_sim
# count            451090.00
# mean                  0.07
# std                   0.07
# min                  -0.23
# 25%                   0.03
# 50%                   0.07
# 75%                   0.12
# max                   0.69
# l
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count          540822.00          540822.00            540822.00
# mean                0.14               0.07                 0.19
# std                 0.03               0.07                 0.04
# min                 0.10              -0.23                 0.13
# 25%                 0.12               0.02                 0.15
# 50%                 0.14               0.07                 0.18
# 75%                 0.16               0.12                 0.21
# max                 0.49               0.59                 0.73
#
#        concept2context_sim
# count            540822.00
# mean                  0.07
# std                   0.07
# min                  -0.23
# 25%                   0.03
# 50%                   0.07
# 75%                   0.11
# max                   0.69
# m
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count          484329.00          484329.00            484329.00
# mean                0.18               0.09                 0.19
# std                 0.05               0.08                 0.04
# min                 0.12              -0.26                 0.13
# 25%                 0.15               0.03                 0.15
# 50%                 0.17               0.08                 0.18
# 75%                 0.20               0.14                 0.21
# max                 0.62               0.62                 0.73
#
#        concept2context_sim
# count            484329.00
# mean                  0.07
# std                   0.07
# min                  -0.22
# 25%                   0.03
# 50%                   0.07
# 75%                   0.11
# max                   0.69
# n
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count          549633.00          549633.00            549633.00
# mean                0.16               0.06                 0.19
# std                 0.04               0.07                 0.04
# min                 0.10              -0.25                 0.13
# 25%                 0.14               0.01                 0.16
# 50%                 0.15               0.06                 0.18
# 75%                 0.18               0.11                 0.21
# max                 0.53               0.55                 0.73
#
#        concept2context_sim
# count            549633.00
# mean                  0.07
# std                   0.07
# min                  -0.23
# 25%                   0.03
# 50%                   0.07
# 75%                   0.12
# max                   0.69
# o
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count          568776.00          568776.00            568776.00
# mean                0.19               0.10                 0.19
# std                 0.05               0.08                 0.04
# min                 0.11              -0.24                 0.13
# 25%                 0.15               0.04                 0.15
# 50%                 0.18               0.10                 0.18
# 75%                 0.23               0.15                 0.21
# max                 0.69               0.60                 0.73
#
#        concept2context_sim
# count            568776.00
# mean                  0.07
# std                   0.07
# min                  -0.23
# 25%                   0.03
# 50%                   0.07
# 75%                   0.11
# max                   0.69

# %%
pg_dict[el]
# Out:
#          topic2caption_sim  topic2context_sim  \
# 0                 0.628946           0.295938
# 1                 0.591550           0.071280
# 2                 0.591550           0.071280
# 3                 0.591550           0.071280
# 4                 0.589132           0.471493
# ...                    ...                ...
# 1354966           0.163975           0.088981
# 1354971           0.163974           0.053684
# 1354975           0.163974           0.012743
# 1354984           0.163972           0.188481
# 1354988           0.163972           0.151341
#
#                                                  image_url  \
# 0        https://upload.wikimedia.org/wikipedia/commons...
# 1        https://upload.wikimedia.org/wikipedia/commons...
# 2        https://upload.wikimedia.org/wikipedia/commons...
# 3        https://upload.wikimedia.org/wikipedia/commons...
# 4        https://upload.wikimedia.org/wikipedia/commons...
# ...                                                    ...
# 1354966  https://upload.wikimedia.org/wikipedia/commons...
# 1354971  https://upload.wikimedia.org/wikipedia/commons...
# 1354975  https://upload.wikimedia.org/wikipedia/commons...
# 1354984  https://upload.wikimedia.org/wikipedia/commons...
# 1354988  http://upload.wikimedia.org/wikipedia/commons/...
#
#                                                    caption  \
# 0               Pedestrian trail English: Pedestrian trail
# 1                                           Walking Trail
# 2                                           Walking Trail
# 3                                           Walking Trail
# 4        Hikers awaiting southbound train English: Look...
# ...                                                    ...
# 1354966   English: Rhaetina gregaria from Ladinian of I...
# 1354971  Henry Savile, who owned and bred Cremorne Men ...
# 1354975  Reconstruction of a 2nd century AD pugio Pugio...
# 1354984  German paper nativity scene, 1885 Deutsch: Pap...
# 1354988   English: View of the outer door at the Bent P...
#
#                                                    context  \
# 0        The Blue Water River Walk is a nearly one mile...
# 1        Bagh-e-Jinnah, formerly known as Lawrence Gard...
# 2        Bagh-e-Jinnah, formerly known as Lawrence Gard...
# 3        Bagh-e-Jinnah, formerly known as Lawrence Gard...
# 4        The Appalachian Trail station is a commuter ra...
# ...                                                    ...
# 1354966  Rhaetina is an extinct genus of brachiopods be...
# 1354971  Cremorne was British Thoroughbred racehorse an...
# 1354975  The pugio was a dagger used by Roman soldiers ...
# 1354984  In the Christian tradition, a nativity scene i...
# 1354988  The Bent Pyramid is an ancient Egyptian pyrami...
#
#          concept2caption_sim  concept2context_sim
# 0                   0.704843             0.105616
# 1                   0.422199             0.072473
# 2                   0.422199             0.072473
# 3                   0.422199             0.072473
# 4                   0.300308             0.143705
# ...                      ...                  ...
# 1354966             0.173961             0.030292
# 1354971             0.170176             0.018248
# 1354975             0.247398             0.092458
# 1354984             0.142268             0.075186
# 1354988             0.139151             0.000140
#
# [568776 rows x 7 columns]

# %%
df__ = pd.DataFrame()
for el in pg_dict:
    df__ = pd.concat([df_, pg_dict[el]], ignore_index=True)
    df__.drop_duplicates(subset="image_url",
                     keep='first', inplace=True)
df__.drop_duplicates(subset="image_url",
                     keep='first', inplace=True)
display(df__.describe().round(2))
# Out:
#        topic2caption_sim  topic2context_sim  concept2caption_sim  \
# count          568776.00          568776.00            568776.00
# mean                0.21               0.11                 0.19
# std                 0.06               0.09                 0.04
# min                 0.11              -0.24                 0.13
# 25%                 0.17               0.05                 0.15
# 50%                 0.20               0.10                 0.18
# 75%                 0.24               0.16                 0.21
# max                 0.67               0.59                 0.73
#
#        concept2context_sim
# count            568776.00
# mean                  0.07
# std                   0.07
# min                  -0.23
# 25%                   0.03
# 50%                   0.07
# 75%                   0.11
# max                   0.69

# %%
missed_topics_dict = dict()
for el in pg_dict:
    missed_topics_dict[el] = pg_dict[el]
    missed_topics_dict[el]['image_path'] = missed_topics_dict[el]['image_url'].apply(link_to_b64)
    missed_topics_dict[el] = missed_topics_dict[el][missed_topics_dict[el].image_path.notnull()]
    missed_topics_dict[el] = missed_topics_dict[el].reset_index(drop=True)

# %%
missed_topics_dict[el]
# Out:
#         topic2caption_sim  topic2context_sim  \
# 0                0.628946           0.295938
# 1                0.591550           0.071280
# 2                0.591550           0.071280
# 3                0.591550           0.071280
# 4                0.589132           0.471493
# ...                   ...                ...
# 551711           0.163975           0.088981
# 551712           0.163974           0.053684
# 551713           0.163974           0.012743
# 551714           0.163972           0.188481
# 551715           0.163972           0.151341
#
#                                                 image_url  \
# 0       https://upload.wikimedia.org/wikipedia/commons...
# 1       https://upload.wikimedia.org/wikipedia/commons...
# 2       https://upload.wikimedia.org/wikipedia/commons...
# 3       https://upload.wikimedia.org/wikipedia/commons...
# 4       https://upload.wikimedia.org/wikipedia/commons...
# ...                                                   ...
# 551711  https://upload.wikimedia.org/wikipedia/commons...
# 551712  https://upload.wikimedia.org/wikipedia/commons...
# 551713  https://upload.wikimedia.org/wikipedia/commons...
# 551714  https://upload.wikimedia.org/wikipedia/commons...
# 551715  http://upload.wikimedia.org/wikipedia/commons/...
#
#                                                   caption  \
# 0              Pedestrian trail English: Pedestrian trail
# 1                                          Walking Trail
# 2                                          Walking Trail
# 3                                          Walking Trail
# 4       Hikers awaiting southbound train English: Look...
# ...                                                   ...
# 551711   English: Rhaetina gregaria from Ladinian of I...
# 551712  Henry Savile, who owned and bred Cremorne Men ...
# 551713  Reconstruction of a 2nd century AD pugio Pugio...
# 551714  German paper nativity scene, 1885 Deutsch: Pap...
# 551715   English: View of the outer door at the Bent P...
#
#                                                   context  \
# 0       The Blue Water River Walk is a nearly one mile...
# 1       Bagh-e-Jinnah, formerly known as Lawrence Gard...
# 2       Bagh-e-Jinnah, formerly known as Lawrence Gard...
# 3       Bagh-e-Jinnah, formerly known as Lawrence Gard...
# 4       The Appalachian Trail station is a commuter ra...
# ...                                                   ...
# 551711  Rhaetina is an extinct genus of brachiopods be...
# 551712  Cremorne was British Thoroughbred racehorse an...
# 551713  The pugio was a dagger used by Roman soldiers ...
# 551714  In the Christian tradition, a nativity scene i...
# 551715  The Bent Pyramid is an ancient Egyptian pyrami...
#
#         concept2caption_sim  concept2context_sim  \
# 0                  0.704843             0.105616
# 1                  0.422199             0.072473
# 2                  0.422199             0.072473
# 3                  0.422199             0.072473
# 4                  0.300308             0.143705
# ...                     ...                  ...
# 551711             0.173961             0.030292
# 551712             0.170176             0.018248
# 551713             0.247398             0.092458
# 551714             0.142268             0.075186
# 551715             0.139151             0.000140
#
#                                                image_path
# 0       aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...
# 1       aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...
# 2       aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...
# 3       aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...
# 4       aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...
# ...                                                   ...
# 551711  aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...
# 551712  aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...
# 551713  aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...
# 551714  aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...
# 551715  aHR0cDovL3VwbG9hZC53aWtpbWVkaWEub3JnL3dpa2lwZW...
#
# [551716 rows x 8 columns]

# %%
selected_col = ['image_path','topic2caption_sim', 'concept2caption_sim', 'topic2context_sim', 'caption']
for el in missed_topics_dict:
    missed_topics_dict[el] = missed_topics_dict[el][selected_col]
    missed_topics_dict[el] = missed_topics_dict[el].drop_duplicates(subset=selected_col, keep=False)
    missed_topics_dict[el] = missed_topics_dict[el].reset_index(drop=True)

# %%
for el in missed_topics_dict:
#     missed_topics_dict[el] = missed_topics_dict[el][selected_col]
    missed_topics_dict[el] = missed_topics_dict[el].drop_duplicates(keep=False)
    missed_topics_dict[el] = missed_topics_dict[el].reset_index(drop=True)

# %%
missed_topics_dict['a']
# Out:
#                                                image_path  topic2caption_sim  \
# 0       aHR0cDovL3VwbG9hZC53aWtpbWVkaWEub3JnL3dpa2lwZW...           0.572484
# 1       aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.536091
# 2       aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.532109
# 3       aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.526225
# 4       aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.520849
# ...                                                   ...                ...
# 498377  aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.157879
# 498378  aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.157877
# 498379  aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.157876
# 498380  aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.157876
# 498381  aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.157874
#
#         concept2caption_sim  topic2context_sim  \
# 0                  0.208802           0.389450
# 1                  0.212263           0.355876
# 2                  0.195246           0.476177
# 3                  0.161056           0.473637
# 4                  0.194514           0.296062
# ...                     ...                ...
# 498377             0.159651           0.074182
# 498378             0.159958           0.148378
# 498379             0.182478           0.030891
# 498380             0.165309           0.119214
# 498381             0.156498          -0.057966
#
#                                                   caption
# 0                                  English: Chariot Wheel
# 1       Solid wheels on a heavy temple car, contrasted...
# 2                             English: Mitsubishi Chariot
# 3       1992–1994 Mitsubishi Chariot English: Mitsubis...
# 4              Replica of a south-pointing chariot, 2005
# ...                                                   ...
# 498377  Vyasa, at middle of the picture English: Vyasa...
# 498378  View of the J. H. Dodson Residence in San Pedr...
# 498379  Matt Ford Headshot of Matt Ford Lighting Designer
# 498380   English: Waltham Fire Station. Manned by reta...
# 498381  The gatehouse on the southwest drive English: ...
#
# [498382 rows x 5 columns]

# %%
for el in missed_topics_dict:
    print(el, len(missed_topics_dict[el]))
# Out:
# a 498382
# b 677042
# c 471389
# d 470832
# e 494671
# f 497406
# g 479709
# h 508003
# i 526649
# j 266079
# k 438599
# l 524994
# m 467491
# n 535998
# o 551716

# %%
sorted_key = []
for k in sorted(missed_topics_dict, key=lambda k: len(missed_topics_dict[k])):
    print(k, len(missed_topics_dict[k]))
    sorted_key.append(k)
# Out:
# j 266079
# k 438599
# m 467491
# d 470832
# c 471389
# g 479709
# e 494671
# f 497406
# a 498382
# h 508003
# l 524994
# i 526649
# n 535998
# o 551716
# b 677042

# %%
def df2_df1(df1, df2):
    cond = df2['image_path'].isin(df1['image_path'])
    df2.drop(df2[cond].index, inplace = True)
    return df2

# %%
for idx, k in enumerate(sorted_key):
    print(sorted_key[idx:], k)
    for el in sorted_key[idx:]:
        if el == k:
            continue
        print(f'we are going to calc: {el} - {k}')
        missed_topics_dict[el] = df2_df1(missed_topics_dict[k], missed_topics_dict[el])
#     break
# Out:
# ['j', 'k', 'm', 'd', 'c', 'g', 'e', 'f', 'a', 'h', 'l', 'i', 'n', 'o', 'b'] j
# we are going to calc: k - j
# we are going to calc: m - j
# we are going to calc: d - j
# we are going to calc: c - j
# we are going to calc: g - j
# we are going to calc: e - j
# we are going to calc: f - j
# we are going to calc: a - j
# we are going to calc: h - j
# we are going to calc: l - j
# we are going to calc: i - j
# we are going to calc: n - j
# we are going to calc: o - j
# we are going to calc: b - j
# ['k', 'm', 'd', 'c', 'g', 'e', 'f', 'a', 'h', 'l', 'i', 'n', 'o', 'b'] k
# we are going to calc: m - k
# we are going to calc: d - k
# we are going to calc: c - k
# we are going to calc: g - k
# we are going to calc: e - k
# we are going to calc: f - k
# we are going to calc: a - k
# we are going to calc: h - k
# we are going to calc: l - k
# we are going to calc: i - k
# we are going to calc: n - k
# we are going to calc: o - k
# we are going to calc: b - k
# ['m', 'd', 'c', 'g', 'e', 'f', 'a', 'h', 'l', 'i', 'n', 'o', 'b'] m
# we are going to calc: d - m
# we are going to calc: c - m
# we are going to calc: g - m
# we are going to calc: e - m
# we are going to calc: f - m
# we are going to calc: a - m
# we are going to calc: h - m
# we are going to calc: l - m
# we are going to calc: i - m
# we are going to calc: n - m
# we are going to calc: o - m
# we are going to calc: b - m
# ['d', 'c', 'g', 'e', 'f', 'a', 'h', 'l', 'i', 'n', 'o', 'b'] d
# we are going to calc: c - d
# we are going to calc: g - d
# we are going to calc: e - d
# we are going to calc: f - d
# we are going to calc: a - d
# we are going to calc: h - d
# we are going to calc: l - d
# we are going to calc: i - d
# we are going to calc: n - d
# we are going to calc: o - d
# we are going to calc: b - d
# ['c', 'g', 'e', 'f', 'a', 'h', 'l', 'i', 'n', 'o', 'b'] c
# we are going to calc: g - c
# we are going to calc: e - c
# we are going to calc: f - c
# we are going to calc: a - c
# we are going to calc: h - c
# we are going to calc: l - c
# we are going to calc: i - c
# we are going to calc: n - c
# we are going to calc: o - c
# we are going to calc: b - c
# ['g', 'e', 'f', 'a', 'h', 'l', 'i', 'n', 'o', 'b'] g
# we are going to calc: e - g
# we are going to calc: f - g
# we are going to calc: a - g
# we are going to calc: h - g
# we are going to calc: l - g
# we are going to calc: i - g
# we are going to calc: n - g
# we are going to calc: o - g
# we are going to calc: b - g
# ['e', 'f', 'a', 'h', 'l', 'i', 'n', 'o', 'b'] e
# we are going to calc: f - e
# we are going to calc: a - e
# we are going to calc: h - e
# we are going to calc: l - e
# we are going to calc: i - e
# we are going to calc: n - e
# we are going to calc: o - e
# we are going to calc: b - e
# ['f', 'a', 'h', 'l', 'i', 'n', 'o', 'b'] f
# we are going to calc: a - f
# we are going to calc: h - f
# we are going to calc: l - f
# we are going to calc: i - f
# we are going to calc: n - f
# we are going to calc: o - f
# we are going to calc: b - f
# ['a', 'h', 'l', 'i', 'n', 'o', 'b'] a
# we are going to calc: h - a
# we are going to calc: l - a
# we are going to calc: i - a
# we are going to calc: n - a
# we are going to calc: o - a
# we are going to calc: b - a
# ['h', 'l', 'i', 'n', 'o', 'b'] h
# we are going to calc: l - h
# we are going to calc: i - h
# we are going to calc: n - h
# we are going to calc: o - h
# we are going to calc: b - h
# ['l', 'i', 'n', 'o', 'b'] l
# we are going to calc: i - l
# we are going to calc: n - l
# we are going to calc: o - l
# we are going to calc: b - l
# ['i', 'n', 'o', 'b'] i
# we are going to calc: n - i
# we are going to calc: o - i
# we are going to calc: b - i
# ['n', 'o', 'b'] n
# we are going to calc: o - n
# we are going to calc: b - n
# ['o', 'b'] o
# we are going to calc: b - o
# ['b'] b

# %%
sorted_key = []
for k in sorted(missed_topics_dict, key=lambda k: len(missed_topics_dict[k])):
    print(k, len(missed_topics_dict[k]))
    sorted_key.append(k)
# Out:
# o 1825
# b 3728
# n 4904
# i 9772
# e 10146
# a 11106
# l 14489
# c 27015
# f 29601
# h 31606
# d 66386
# g 99068
# m 189160
# k 258164
# j 266079

# %%
missed_topics_dict[el]
# Out:
#                                                image_path  topic2caption_sim  \
# 16645   aHR0cDovL3VwbG9hZC53aWtpbWVkaWEub3JnL3dpa2lwZW...           0.297875
# 19605   aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.290006
# 21511   aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.285580
# 22570   aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.283370
# 23687   aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.280998
# ...                                                   ...                ...
# 676814  aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.113594
# 676841  aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.113571
# 676845  aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.113568
# 676988  aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.113454
# 677001  aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcG...           0.113444
#
#         concept2caption_sim  topic2context_sim  \
# 16645              0.144801           0.039931
# 19605              0.135893           0.235146
# 21511              0.136557           0.099045
# 22570              0.157820           0.274062
# 23687              0.136919          -0.000578
# ...                     ...                ...
# 676814             0.145010           0.086696
# 676841             0.163208           0.084670
# 676845             0.174736           0.110685
# 676988             0.143493           0.070206
# 677001             0.139832           0.004897
#
#                                                   caption
# 16645    Anchor from H.M.S. Investigator. Dropped by M...
# 19605   Newman playing for Melbourne in March 2017 Eng...
# 21511   Collingwood plays down the ground during the f...
# 22570                              Victoria in Australia
# 23687    English: Melbourne with the Yarra river looki...
# ...                                                   ...
# 676814   English: Hedyotis purpurea var montana syn Ho...
# 676841                             English: Yun Hu-myeong
# 676845                          English: Hashem Yekezareh
# 676988      English: Rudy Rupak Founder of PlanetHospital
# 677001                             English: Farah Pahlavi
#
# [3728 rows x 5 columns]

# %%
random_count = {'a': 1426, 'f': 838, 'g': 145, 'i':349, 'j': 275, 'k':302, 'l':151, 'm':797, 'n':290, 'o':1081}

# %%
for el in random_count:
    missed_topics_dict[el] = missed_topics_dict[el].sample(n =random_count[el])
    missed_topics_dict[el] = missed_topics_dict[el].reset_index(drop=True)

# %%
sorted_key = []
for k in sorted(missed_topics_dict, key=lambda k: len(missed_topics_dict[k])):
    print(k, len(missed_topics_dict[k]))
    sorted_key.append(k)
# Out:
# g 145
# l 151
# j 275
# n 290
# k 302
# i 349
# m 797
# f 838
# o 1081
# a 1426
# b 3728
# e 10146
# c 27015
# h 31606
# d 66386

# %%
missed_topics_with_images = dict()
count = 0
for el in random_count:
    missed_topics_with_images[el] = create_data(missed_topics_dict[el], count)
    count = len(missed_topics_with_images[el])
# Out:
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy8zLzNkL0EtN0VfQ29yc2Fpcl9JSV9WQS0xMi5qcGc=.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy9kL2RkL0phZmFyYWJhZGlfYnVmZmFsby5qcGc=.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy8zLzNlL0hvbmR1cmFzLlJpY2FyZG9NYWR1cm8uMDEuanBn.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy8wLzA3LzIwMjAwNjAzX2tpbWJvcmEuanBn.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy8zLzNkL0NPX0FUTC5qcGc=.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy84Lzg2LzIwMXN0X0FpcmxpZnRfU3F1YWRyb25fZW1ibGVtLmpwZw==.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy8xLzFmL1RydDF5ZW5pbG9nby5wbmc=.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy9lL2VlL0Zva2tlcl9TLklJLmpwZw==.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy83LzcwL0JhcmtpX3BhcmsuanBlZw==.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy9iL2I1L0N6ZWNob3Nsb3Zha2lhXzE5MzkuU1ZH.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy80LzQzLzE5OTMtOTRfT3BlbF9Bc3RyYV8xLjRpX1Nwb3J0aXZlJTJDX3JlYXJfbGVmdF8lMjhQb3J0dWdhbCUyOS5qcGc=.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy9jL2NhLzQ3OF9BU1dfZW1ibGVtLlBORw==.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy8wLzBkL1NjcmVlbnNob3RfNDMzMzMucG5n.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy8zLzNjLzIwMTAtMDctMTEtZ2RhbnNrLWJ5LVJhQm9lLTAzOS5KUEc=.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy82LzYwL0thcm1hdiVDMyVCNWxhZC5qcGc=.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy8yLzIyL1F1YWlkLWUtQXphbV93aXRoX0ZhdGltYV9KaW5uYWhfYW5kX011bXRhel9TaGFobmF3YXouanBn.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy82LzYxL1N0b3V0X0FpcnNlZGFuLTEuanBn.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy85LzliLyVEOSU4NiVEOSU4MiVEOCVBNyVEOCVCNCVEQiU4QyVEOCVBRSVEOCVCNy5qcGc=.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy84LzhmL1RtYXJ1cy5zaGltb2phbmFpLmZlbWFsZS4tLnRhbmlrYXdhLmpwZw==.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy9mL2Y4L0h1c2h1dWNoX0dlbmVyYWxfMTk0NC0xOTcyLnBuZw==.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy9mL2ZhL0xlbmRlX2lzX2FfQ3VwcGVkX1BsYWNlLmpwZw==.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy9kL2RmLyVDMyU5Q21taXllX2tvJUMzJUE3YWsuanBn.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy8zLzM4L1J1bWVuX1JhZGV2X29mZmljaWFsXyUyOGNyb3BwZWQlMjkuanBn.jpg
# /raid/AISSEL/htest/datasets/wit/images/aHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy
# 1067           0.128150             0.189176           0.038640
# 1068           0.128722             0.135879           0.106423
# 1069           0.129665             0.141287          -0.000303
#
# [1070 rows x 8 columns]

# %%
s = 0
for el in missed_topics_with_images:
    missed_topics_with_images[el] = missed_topics_with_images[el].dropna(subset=['caption'])
    missed_topics_with_images[el]['topics']  = [el] * len(missed_topics_with_images[el])
    print(el, len(missed_topics_with_images[el]))
    s = s + len(missed_topics_with_images[el])
print(s)
# Out:
# a 1397
# f 824
# g 140
# i 345
# j 266
# k 299
# l 147
# m 787
# n 285
# o 1070
# 5560

# %%
scol = ['topic2caption_sim', 'concept2caption_sim']
for el in missed_topics_with_images:
    print(el)
    display(missed_topics_with_images[el][scol].describe().round(2))
# Out:
# a
#        topic2caption_sim  concept2caption_sim
# count            1397.00              1397.00
# mean                0.16                 0.15
# std                 0.03                 0.02
# min                 0.12                 0.13
# 25%                 0.14                 0.14
# 50%                 0.16                 0.15
# 75%                 0.18                 0.16
# max                 0.29                 0.23
# f
#        topic2caption_sim  concept2caption_sim
# count             824.00               824.00
# mean                0.15                 0.16
# std                 0.04                 0.02
# min                 0.09                 0.13
# 25%                 0.12                 0.14
# 50%                 0.15                 0.16
# 75%                 0.18                 0.18
# max                 0.36                 0.27
# g
#        topic2caption_sim  concept2caption_sim
# count             140.00               140.00
# mean                0.18                 0.16
# std                 0.03                 0.02
# min                 0.13                 0.13
# 25%                 0.15                 0.15
# 50%                 0.17                 0.16
# 75%                 0.20                 0.17
# max                 0.28                 0.25
# i
#        topic2caption_sim  concept2caption_sim
# count             345.00               345.00
# mean                0.14                 0.15
# std                 0.03                 0.02
# min                 0.09                 0.13
# 25%                 0.12                 0.14
# 50%                 0.14                 0.15
# 75%                 0.16                 0.16
# max                 0.30                 0.22
# j
#        topic2caption_sim  concept2caption_sim
# count             266.00               266.00
# mean                0.17                 0.19
# std                 0.05                 0.05
# min                 0.11                 0.13
# 25%                 0.13                 0.16
# 50%                 0.15                 0.18
# 75%                 0.19                 0.22
# max                 0.34                 0.35
# k
#        topic2caption_sim  concept2caption_sim
# count             299.00               299.00
# mean                0.13                 0.18
# std                 0.03                 0.04
# min                 0.09                 0.13
# 25%                 0.11                 0.15
# 50%                 0.13                 0.17
# 75%                 0.15                 0.20
# max                 0.37                 0.29
# l
#        topic2caption_sim  concept2caption_sim
# count             147.00               147.00
# mean                0.14                 0.16
# std                 0.03                 0.02
# min                 0.10                 0.13
# 25%                 0.12                 0.14
# 50%                 0.13                 0.15
# 75%                 0.16                 0.16
# max                 0.25                 0.24
# m
#        topic2caption_sim  concept2caption_sim
# count             787.00               787.00
# mean                0.18                 0.17
# std                 0.04                 0.03
# min                 0.12                 0.13
# 25%                 0.15                 0.15
# 50%                 0.17                 0.16
# 75%                 0.21                 0.18
# max                 0.40                 0.32
# n
#        topic2caption_sim  concept2caption_sim
# count             285.00               285.00
# mean                0.15                 0.16
# std                 0.04                 0.02
# min                 0.10                 0.13
# 25%                 0.12                 0.14
# 50%                 0.14                 0.15
# 75%                 0.16                 0.16
# max                 0.32                 0.23
# o
#        topic2caption_sim  concept2caption_sim
# count            1070.00              1070.00
# mean                0.17                 0.15
# std                 0.04                 0.01
# min                 0.11                 0.13
# 25%                 0.14                 0.14
# 50%                 0.17                 0.15
# 75%                 0.20                 0.16
# max                 0.31                 0.23

# %%
df_2 = pd.DataFrame()
for el in missed_topics_with_images:
    df_2 = pd.concat([df_2, missed_topics_with_images[el]], ignore_index=True)
# df_
display(df_2[scol].describe().round(2))
# Out:
#        topic2caption_sim  concept2caption_sim
# count            5560.00              5560.00
# mean                0.16                 0.16
# std                 0.04                 0.03
# min                 0.09                 0.13
# 25%                 0.13                 0.14
# 50%                 0.16                 0.15
# 75%                 0.18                 0.17
# max                 0.40                 0.35

# %%
random_count_wit = {'a': 1226, 'f': 638, 'g': 45, 'i':249, 'j': 175, 'k':202, 'l':51, 'm':497, 'n':190, 'o':881}

# %%
for el in random_count_wit:
    missed_topics_with_images[el] = missed_topics_with_images[el].drop_duplicates(keep=False)
    missed_topics_with_images[el] = missed_topics_with_images[el].sample(n =random_count_wit[el])
    missed_topics_with_images[el] = missed_topics_with_images[el].reset_index(drop=True)

# %%
for el in random_count_wit:
    print(el)

    display(missed_topics_with_images[el][['topic2caption_sim', 'concept2caption_sim']].describe().round(2))
# Out:
# a
#        topic2caption_sim  concept2caption_sim
# count            1226.00              1226.00
# mean                0.16                 0.15
# std                 0.03                 0.02
# min                 0.12                 0.13
# 25%                 0.14                 0.14
# 50%                 0.16                 0.15
# 75%                 0.18                 0.16
# max                 0.29                 0.23
# f
#        topic2caption_sim  concept2caption_sim
# count             638.00               638.00
# mean                0.15                 0.16
# std                 0.04                 0.02
# min                 0.09                 0.13
# 25%                 0.12                 0.14
# 50%                 0.15                 0.16
# 75%                 0.18                 0.18
# max                 0.32                 0.25
# g
#        topic2caption_sim  concept2caption_sim
# count              45.00                45.00
# mean                0.18                 0.16
# std                 0.03                 0.02
# min                 0.13                 0.14
# 25%                 0.15                 0.15
# 50%                 0.17                 0.16
# 75%                 0.20                 0.18
# max                 0.28                 0.23
# i
#        topic2caption_sim  concept2caption_sim
# count             249.00               249.00
# mean                0.14                 0.15
# std                 0.03                 0.02
# min                 0.09                 0.13
# 25%                 0.12                 0.14
# 50%                 0.14                 0.15
# 75%                 0.16                 0.16
# max                 0.30                 0.21
# j
#        topic2caption_sim  concept2caption_sim
# count             175.00               175.00
# mean                0.17                 0.19
# std                 0.04                 0.05
# min                 0.11                 0.13
# 25%                 0.13                 0.16
# 50%                 0.15                 0.18
# 75%                 0.19                 0.22
# max                 0.33                 0.35
# k
#        topic2caption_sim  concept2caption_sim
# count             202.00               202.00
# mean                0.13                 0.18
# std                 0.04                 0.04
# min                 0.09                 0.14
# 25%                 0.11                 0.15
# 50%                 0.12                 0.17
# 75%                 0.14                 0.20
# max                 0.37                 0.29
# l
#        topic2caption_sim  concept2caption_sim
# count              51.00                51.00
# mean                0.14                 0.16
# std                 0.03                 0.02
# min                 0.10                 0.13
# 25%                 0.12                 0.14
# 50%                 0.13                 0.15
# 75%                 0.16                 0.17
# max                 0.25                 0.24
# m
#        topic2caption_sim  concept2caption_sim
# count             497.00               497.00
# mean                0.18                 0.17
# std                 0.05                 0.03
# min                 0.12                 0.13
# 25%                 0.14                 0.15
# 50%                 0.17                 0.16
# 75%                 0.21                 0.18
# max                 0.40                 0.32
# n
#        topic2caption_sim  concept2caption_sim
# count             190.00               190.00
# mean                0.15                 0.16
# std                 0.04                 0.02
# min                 0.10                 0.13
# 25%                 0.12                 0.14
# 50%                 0.14                 0.15
# 75%                 0.16                 0.16
# max                 0.31                 0.22
# o
#        topic2caption_sim  concept2caption_sim
# count             881.00               881.00
# mean                0.17                 0.15
# std                 0.04                 0.01
# min                 0.11                 0.13
# 25%                 0.14                 0.14
# 50%                 0.17                 0.14
# 75%                 0.20                 0.16
# max                 0.31                 0.23

# %%
df_l = pd.DataFrame()
for el in random_count_wit:
    df_l = pd.concat([df_l, missed_topics_with_images[el]], ignore_index=True)
# df_
display(df_l[['topic2caption_sim', 'concept2caption_sim']].describe().round(2))
# Out:
#        topic2caption_sim  concept2caption_sim
# count            4154.00              4154.00
# mean                0.16                 0.16
# std                 0.04                 0.02
# min                 0.09                 0.13
# 25%                 0.13                 0.14
# 50%                 0.16                 0.15
# 75%                 0.18                 0.17
# max                 0.40                 0.35

# %%
def get_portion(df, p1=72, p2=16, p3=12):
    s1 = df.sample(frac = p1/100)
    rest_part_1 = df.drop(s1.index)
    s2 = rest_part_1.sample(frac = p2/(100-p1))
    s3 = rest_part_1.drop(s2.index)
    return s1, s2, s3

# %%
name_lsit = ['stage1_train', 'stage2_train', 'val']
por_dict = dict()
data_dict = dict()
for n in name_lsit:
    data_dict[n] = pd.DataFrame() 
for el in random_count_wit:
    s1, s2, v = get_portion(missed_topics_with_images[el])
    
    s1 = s1.reset_index(drop=True)
    data_dict['stage1_train'] = pd.concat([data_dict['stage1_train'], s1], ignore_index=True)
    
    s2 = s2.reset_index(drop=True)
    data_dict['stage2_train'] = pd.concat([data_dict['stage2_train'], s2], ignore_index=True)
    
    v = v.reset_index(drop=True)
    data_dict['val'] = pd.concat([data_dict['val'], v], ignore_index=True)
#     data_dict[el] = por_dict

# %%
print(len(data_dict['stage1_train']))
print(len(data_dict['stage2_train']))
print(len(data_dict['val']))
# Out:
# 2990
# 664
# 500

# %%
names = ['uniq_id', 'image_id', 'caption', 'labels', 'image']

# %%
! mkdir -p /raid/AISSEL/htest/datasets/ped_data/wit/random_missed
saved_path = '/raid/AISSEL/htest/datasets/ped_data/wit/random_missed'
for el in data_dict:
    name = f'caption_{el}.tsv'
    df_s = data_dict[el][names]
    df_s.to_csv(f'{saved_path}/{name}', sep="\t", index=False, header=False)

    print(name)
# Out:
# caption_stage1_train.tsv
# caption_stage2_train.tsv
# caption_val.tsv

# %%
(31 / 88) * 100
# Out:
# 35.22727272727273

# %%
(12 / 88) * 100
# Out:
# 13.636363636363635

# %%
(14 /64) * 100
# Out:
# 21.875
