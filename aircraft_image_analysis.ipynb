# %%
import os

# General packages
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import plotly.express as px
import PIL.Image
from tqdm.notebook import tqdm, trange
import glob
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

from IPython.display import Image as IImage
from IPython.display import display
import warnings
warnings.filterwarnings("ignore")
tqdm.pandas()

# %%
import torch
import clip
from PIL import Image

import os

# %%
from sentence_transformers import SentenceTransformer, util
embedder = SentenceTransformer('all-MiniLM-L6-v2')

# %%
os.listdir('/raid/AISSEL/Hamed/datasets/av_data/fatemeh')
# Out:
# ['all',
#  'missed',
#  'df_av_test.pk',
#  'df_av_test_tags.pk',
#  'df_av_test_before_tags.pk',
#  'df_av_test_after_tags.pk',
#  'all_q50',
#  'missed_q50']

# %%
def find_gpus(nums=6):
    os.system('nvidia-smi -q -d Memory |grep -A4 GPU|grep Free >tmp_free_gpus')
    with open('tmp_free_gpus', 'r') as lines_txt:
        frees = lines_txt.readlines()
        idx_freeMemory_pair = [ (idx,int(x.split()[2]))
                              for idx,x in enumerate(frees) ]
    idx_freeMemory_pair.sort(key=lambda my_tuple:my_tuple[1],reverse=True)
    usingGPUs = [str(idx_memory_pair[0])
                    for idx_memory_pair in idx_freeMemory_pair[:nums] ]
    usingGPUs =  ','.join(usingGPUs)
    print('using GPU idx: #', usingGPUs)
    return usingGPUs

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = find_gpus(nums=2)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()
# Out:
# using GPU idx: # 1,0
# Using device: cuda

# %% [markdown]
# ## get topics

# %%
from bertopic import BERTopic
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

# %%
lemmatizer = WordNetLemmatizer()

# %%
# def get_topics(concept='pedestrian'):
#     if concept == 'pedestrian':
#         model_path = '../ped_auto_model'
#     elif concept == 'aircraft':
#         model_path = '../aircraft_auto_model'
#     elif concept == 'car':
#         model_path = '../car_auto_model'
#     auto_model = BERTopic(nr_topics="auto")
#     auto_model = BERTopic.load(model_path)
#     similar_topics, similarity = auto_model.find_topics(concept, top_n=50)

#     topics = dict()
#     for t in similar_topics:
#         l1 = auto_model.get_topic(t)
#         el_list = []
#         el_list.append(concept)
#         for el in l1:
#             w = lemmatizer.lemmatize(el[0], get_wordnet_pos(el[0]))
#             el_list.append(w)
#         topics[t]= set(el_list)
#     return topics

# %%
# auto_model = BERTopic(nr_topics="auto")
# auto_model = BERTopic.load('../aircraft_auto_model')

# %%
# av_similar_topics, av_similarity =auto_model.find_topics("aircraft", top_n=50)
# print(av_similar_topics)

# %%
topics = {63: {'aerodynamic',
  'aircraft',
  'airplane',
  'aviation',
  'fly',
  'fuselage',
  'plane',
  'wing'},
 3: {'aircraft',
  'aviation',
  'fighter',
  'flew',
  'flight',
  'fly',
  'lindbergh',
  'pilot',
  'squadron'},
 271: {'aerial',
  'aerodrome',
  'aircraft',
  'airport',
  'airspace',
  'aviation',
  'flight',
  'fly',
  'icao',
  'licensing',
  'pilot'},
 145: {'aeroflot',
  'aeroflots',
  'aerosvit',
  'aircraft',
  'airline',
  'airport',
  'boeing',
  'flight',
  'superjet',
  'volgadnepr'},
 298: {'aircraft',
  'airline',
  'aviation',
  'corporate',
  'openairplane',
  'pilot',
  'remuneration',
  'shareholders13',
  'stakeholder'},
 11: {'airbus',
  'aircraft',
  'airline',
  'airliner',
  'airport',
  'boeing',
  'flight',
  'lufthansa',
  'passenger',
  'southwest'},
 45: {'aircraft',
  'armament',
  'bomber',
  'corsair',
  'fighter',
  'fuselage',
  'navy',
  'squadron',
  'wing'},
 201: {'aerobot',
  'aerobraking',
  'aerodynamic',
  'aeronautics',
  'aircraft',
  'balloon',
  'fly',
  'glide',
  'rocket',
  'spacecraft',
  'spaceflight'},
 35: {'1900d',
  'aircraft',
  'beech',
  'beechcraft',
  'cabin',
  'cessna',
  'engine',
  'gear',
  'skyhawk',
  'wing'},
 108: {'aircraft',
  'biplane',
  'cantilever',
  'design',
  'fuselage',
  'monoplane',
  'sesquiplane',
  'strut',
  'wing'},
 58: {'737',
  '747',
  '747400',
  '747400s',
  '7478',
  'aircraft',
  'airline',
  'airliner',
  'boeing',
  'boeings',
  'freighter'},
 144: {'1943',
  '1944',
  'aircraft',
  'armament',
  'bomber',
  'raf',
  'squadron',
  'v72',
  'vengeance'},
 157: {'aerial',
  'aircraft',
  'balloon',
  'bomber',
  'camera',
  'photographic',
  'photography',
  'reconnaissance'},
 186: {'aircraft',
  'albatros',
  'armament',
  'benz',
  'biplane',
  'diii',
  'fuselage',
  'mercedes',
  'strut',
  'wing'},
 230: {'aircraft',
  'airlift',
  'airlifters',
  'cargo',
  'carry',
  'equipment',
  'helicopter',
  'payload',
  'pylon',
  'transport'},
 159: {'aircraft',
  'beaufort',
  'beauforts',
  'fuselage',
  'pilot',
  'raf',
  'spitfire',
  'squadron',
  'supermarine'},
 220: {'911',
  'aircraft',
  'airline',
  'faa',
  'flight',
  'hijack',
  'hijacker',
  'pentagon',
  'plane',
  'tower'},
 77: {'aircraft',
  'airline',
  'airport',
  'boeing',
  'calgary',
  'fleet',
  'flight',
  'toronto',
  'vancouver',
  'westjet'},
 256: {'aircraft', 'airline', 'airport', 'code', 'digit', 'flight', 'number'},
 104: {'1916',
  'aircraft',
  'argosy',
  'biplane',
  'engine',
  'fighter',
  'fit',
  'fly',
  'raf',
  'wing'},
 86: {'aircraft',
  'airline',
  'airport',
  'airway',
  'boeing',
  'fiji',
  'flight',
  'pacific',
  'qantas',
  'sydney'},
 2: {'aircraft',
  'airline',
  'cockpit',
  'crash',
  'crashed',
  'crew',
  'investigator',
  'passenger',
  'pilot',
  'wreckage'},
 34: {'administration',
  'aircraft',
  'airline',
  'airport',
  'amend',
  'aviation',
  'federal',
  'legislation',
  'tsa'},
 247: {'aircraft',
  'cockpit',
  'control',
  'display',
  'gunner',
  'instrument',
  'panel',
  'pilot'},
 23: {'aircraft',
  'amelia',
  'aviation',
  'flew',
  'flight',
  'fly',
  'pilot',
  'woman'},
 80: {'aerodynamic',
  'aircraft',
  'flight',
  'hypersonic',
  'land',
  'lift',
  'rocket',
  'shuttle',
  'spacecraft',
  'spaceplane'},
 165: {'aircraft',
  'bluebird',
  'bomber',
  'built',
  'design',
  'fuselage',
  'hampdens',
  'patent',
  'prototype',
  'raf',
  'wing'},
 32: {'aircraft',
  'boat',
  'floatplane',
  'flyingboat',
  'naval',
  'seaplane',
  'ship'},
 319: {'aeronautical',
  'aeronautics',
  'aircraft',
  'design',
  'engineer',
  'engineering',
  'hypersonic',
  'ice',
  'langley',
  'pyrodyne',
  'rodert'},
 126: {'aircraft',
  'anxiety',
  'aviophobia',
  'circadian',
  'fatigue',
  'fear',
  'flight',
  'fly',
  'phobia',
  'pilot'},
 66: {'aircraft',
  'airport',
  'airspace',
  'atc',
  'clearance',
  'controller',
  'faa',
  'flight',
  'pilot',
  'radar'},
 225: {'aerospace',
  'airbus',
  'aircraft',
  'boeing',
  'bombardier',
  'company',
  'industry',
  'merger',
  'supplier'},
 25: {'1944',
  'aircraft',
  'bomber',
  'bombing',
  'combat',
  'fighter',
  'luftwaffe',
  'pilot',
  'raf'},
 8: {'aircraft',
  'airfield',
  'airlift',
  'deployed',
  'fly',
  'mission',
  'operational',
  'raf',
  'squadron'},
 235: {'737',
  '737700',
  '737800',
  '737ng',
  '737s',
  'aircraft',
  'airline',
  'boeing',
  'boeings',
  'fuselage',
  'southwest'},
 295: {'airasia',
  'airbus',
  'aircraft',
  'airline',
  'boeing',
  'brunei',
  'kuala',
  'lumpur',
  'malaysia',
  'malaysian'},
 227: {'aircraft',
  'airline',
  'amazon',
  'ati',
  'boeing',
  'cargo',
  'cargolux',
  'charter',
  'fleet'},
 44: {'aircraft',
  'armament',
  'bomber',
  'design',
  'engine',
  'fuselage',
  'ju',
  'luftwaffe',
  'messerschmitt',
  'wing'},
 234: {'1944',
  'aircraft',
  'bomber',
  'havilland',
  'hornet',
  'mosquito',
  'raf',
  'squadron'},
 50: {'aircraft',
  'canadian',
  'dh60',
  'dhc',
  'fly',
  'fuselage',
  'havilland',
  'moth',
  'otter'},
 251: {'aircraft',
  'airliner',
  'company',
  'il214',
  'jet',
  'mig35',
  'su35s',
  'superjet',
  'tu204',
  'uac',
  'uacs'},
 31: {'aerial',
  'aircraft',
  'dji',
  'drone',
  'reconnaissance',
  'sensor',
  'uas',
  'uav',
  'uavs',
  'unmanned'},
 10: {'aircraft',
  'airfield',
  'airline',
  'airport',
  'county',
  'facility',
  'flight',
  'runway'},
 258: {'aircraft',
  'airway',
  'cabin',
  'fairchild',
  'fuselage',
  'h45',
  'h47',
  'husky',
  'monoplane',
  'rcaf'},
 72: {'1910',
  '1942',
  '1942nd',
  'aerospace4',
  'aircraft',
  'aviation',
  'aviationrelated',
  'birmingham',
  'event',
  'huntsville',
  'year'},
 93: {'aeronautical',
  'aeronautics',
  'aerospace',
  'aircraft',
  'aviation',
  'engineer',
  'engineering',
  'flight',
  'mechanical',
  'optimization'},
 118: {'aircraft',
  'airline',
  'airway',
  'bcal',
  'bcals',
  'bua',
  'flight',
  'gatwick',
  'heathrow',
  'london'},
 19: {'aircraft', 'glide', 'glider', 'kite', 'sailplane', 'soar', 'wing'},
 139: {'a37',
  'a37b',
  'aircraft',
  'cessna',
  'navy',
  'refuel',
  't33',
  't37',
  'trainer',
  'training',
  'usaf'},
 237: {'aircraft',
  'captain',
  'copilot',
  'crew',
  'duty',
  'faa',
  'officer',
  'operate',
  'operation',
  'pilot',
  'pilotincommand'}}

# %%
# topics = get_topics(concept='aircraft')
q_id = [el for el in topics]

# %%
for el in topics:
    print(el, topics[el])
# Out:
# 63 {'airplane', 'plane', 'aerodynamic', 'wing', 'aircraft', 'fly', 'fuselage', 'aviation'}
# 3 {'flight', 'flew', 'squadron', 'pilot', 'lindbergh', 'aviation', 'aircraft', 'fly', 'fighter'}
# 271 {'flight', 'airport', 'airspace', 'licensing', 'pilot', 'icao', 'aerial', 'aerodrome', 'aircraft', 'fly', 'aviation'}
# 145 {'flight', 'volgadnepr', 'airport', 'airline', 'aeroflot', 'aeroflots', 'boeing', 'aerosvit', 'aircraft', 'superjet'}
# 298 {'stakeholder', 'airline', 'corporate', 'pilot', 'remuneration', 'openairplane', 'shareholders13', 'aircraft', 'aviation'}
# 11 {'flight', 'passenger', 'airport', 'airline', 'airliner', 'southwest', 'boeing', 'lufthansa', 'aircraft', 'airbus'}
# 45 {'navy', 'armament', 'fuselage', 'squadron', 'wing', 'aircraft', 'bomber', 'corsair', 'fighter'}
# 201 {'aeronautics', 'aerobot', 'glide', 'spaceflight', 'spacecraft', 'aerodynamic', 'balloon', 'aircraft', 'fly', 'aerobraking', 'rocket'}
# ...

# %%
topics[63]
# Out:
# {'aerodynamic',
#  'aircraft',
#  'airplane',
#  'aviation',
#  'fly',
#  'fuselage',
#  'plane',
#  'wing'}

# %%
pg_t = dict()
pg_t['a'] = [31]
pg_t['b'] = [19, 32]
pg_t['c'] = [157, 230, 63, 319, 8, 201]
pg_t['d'] = [144, 45, 104, 35, 44, 165, 186]
pg_t['e'] = [8, 25, 159, 108, 50, 234]

pg_t['f'] = [235, 225, 58, 227]
pg_t['g'] = [93, 258, 139, 251]
pg_t['h'] = [145, 256, 34, 11, 77, 86, 10, 118, 295]
pg_t['k'] = [3, 271, 298]
pg_t['i'] = [247, 2, 237, 72, 23, 126, 66, 220]

# %%
for el in pg_t:
    group_words = []
    for t in pg_t[el]:
        group_words.extend(list(topics[t]))
#         break
    pg_t[el]= list(set(group_words))

# %%
print(pg_t[el])
# Out:
# ['flight', 'passenger', 'hijacker', 'instrument', 'airline', 'operate', 'wreckage', '1942nd', 'crashed', '911', 'fear', 'atc', 'crash', 'display', '1910', 'aviophobia', 'copilot', 'pentagon', 'radar', 'aircraft', 'officer', 'event', 'aviationrelated', 'clearance', 'controller', 'phobia', 'birmingham', 'crew', 'airport', 'flew', 'faa', 'fatigue', 'pilot', 'captain', 'cockpit', 'amelia', 'hijack', 'plane', 'control', 'duty', 'fly', 'huntsville', 'tower', 'pilotincommand', 'airspace', 'panel', 'woman', 'anxiety', 'gunner', 'circadian', 'investigator', '1942', 'aerospace4', 'year', 'operation', 'aviation']

# %%
for g in pg_t:
    pg_t[g] = ' '.join(pg_t[g])

# %%
pg_t[g]
# Out:
# 'flight passenger hijacker instrument airline operate wreckage 1942nd crashed 911 fear atc crash display 1910 aviophobia copilot pentagon radar aircraft officer event aviationrelated clearance controller phobia birmingham crew airport flew faa fatigue pilot captain cockpit amelia hijack plane control duty fly huntsville tower pilotincommand airspace panel woman anxiety gunner circadian investigator 1942 aerospace4 year operation aviation'

# %%
toopic_dict = dict()
for el in topics:
    toopic_dict[el] = ' '.join(topics[el])
toopic_dict[el]
# Out:
# 'crew pilotincommand faa captain operate pilot copilot aircraft duty operation officer'

# %% [markdown]
# ## Load Predictions

# %%
model, preprocess = clip.load("ViT-B/32", device=device, jit=False)

# %%
# pd.set_option('display.max_rows', None)

d_path = '/raid/AISSEL/Hamed/datasets/av_data/fatemeh'
#before
df = pd.read_pickle(f'{d_path}/df_av_test_before_tags.pk')

#after
# df = pd.read_pickle(f'{d_path}/df_av_test_after_tags.pk')

# after q50
# d_path = '/raid/AISSEL/Hamed/datasets/av_data/fatemeh/all_q50'
# df = pd.read_pickle(f'{d_path}/df_av_test_after_tags.pk')

# wit
# d_path = '/raid/AISSEL/Hamed/datasets/av_data/all'
# df = pd.read_pickle(f'{d_path}/wit_av_test_after.pk')



df
# Out:
#      uniq_id  image_id                                            caption  \
# 0          4         4                                Firefighting Drones
# 1         27        27                          DJI mavic 2 pro in flight
# 2         51        51  A small UAS is seen flying during at the US Ar...
# 3        102       102  Ruko F11 GIM2 Drone with Camera for Adults 4K ...
# 4        130       130                                     The MQ9 Reaper
# ..       ...       ...                                                ...
# 677     1931      1931  In our globalized world aviation increasingly ...
# 678     1947      1947      Lufthansa Business Class on longhaul aircraft
# 679     1969      1969  The Boeing 7478 has inherited the good looks o...
# 680     1979      1979                               911 Attacks Pentagon
# 681     1992      1992                             911 flight 93 memorial
#
#      topic_id labels                                              image  \
# ...

# %%
df['tag'].isna().sum()
# Out:
# 0

# %%
df = df[df['tag'].notna()]
df = df.reset_index(drop=True)
len(df)
# Out:
# 682

# %%
pedestrian_list = ['aircraft', 'airplane', 'plane', 'fighter', 
                 'boeing', 'superjet', 'airbus', 'bomber', 'glide', 
                 'skyhawk', 'balloon', 'helicopter', 'seaplane', 'jet',
                 'mig35', 'su35s', 'dji', 'drone', 'uas', 'uav', 'glide', 'kite']

# %%
def create_gt(tag):
    context = ""
    for el in tag:
        if tag[el]:
            context = context + " " + el
    if not context:
        context = None
    return context

# %%
df['gt'] = df.apply(lambda x: create_gt(x.tag), axis=1)
df
# Out:
#      uniq_id  image_id                                            caption  \
# 0          4         4                                Firefighting Drones
# 1         27        27                          DJI mavic 2 pro in flight
# 2         51        51  A small UAS is seen flying during at the US Ar...
# 3        102       102  Ruko F11 GIM2 Drone with Camera for Adults 4K ...
# 4        130       130                                     The MQ9 Reaper
# ..       ...       ...                                                ...
# 677     1931      1931  In our globalized world aviation increasingly ...
# 678     1947      1947      Lufthansa Business Class on longhaul aircraft
# 679     1969      1969  The Boeing 7478 has inherited the good looks o...
# 680     1979      1979                               911 Attacks Pentagon
# 681     1992      1992                             911 flight 93 memorial
#
#      topic_id labels                                              image  \
# ...

# %%
print(df['gt'].isna().sum())
df = df[df['gt'].notna()]
df = df.reset_index(drop=True)
len(df)
# Out:
# 0
# 682

# %%
dff = df.dropna()
dff
# Out:
#      uniq_id  image_id                                            caption  \
# 0          4         4                                Firefighting Drones
# 1         27        27                          DJI mavic 2 pro in flight
# 2         51        51  A small UAS is seen flying during at the US Ar...
# 3        102       102  Ruko F11 GIM2 Drone with Camera for Adults 4K ...
# 4        130       130                                     The MQ9 Reaper
# ..       ...       ...                                                ...
# 677     1931      1931  In our globalized world aviation increasingly ...
# 678     1947      1947      Lufthansa Business Class on longhaul aircraft
# 679     1969      1969  The Boeing 7478 has inherited the good looks o...
# 680     1979      1979                               911 Attacks Pentagon
# 681     1992      1992                             911 flight 93 memorial
#
#      topic_id labels                                              image  \
# ...

# %%
# pedestrian_list
def flag_search_gt(tag, t):
    context = ""
    for el in tag:
        if tag[el]:
            context = context + " " + el
        
    for w in t:
        if w in context:
            return float(1)
    return float(0)

# %%
def get_percentage(tag):
    sum_val = 0
    for el in tag:
        sum_val = sum_val + tag[el]
    return sum_val / len(tag)

# %%
df['gt_coverage'] = df.apply(lambda x: get_percentage(x.tag), axis=1)

# %%
df
# Out:
#      uniq_id  image_id                                            caption  \
# 0          4         4                                Firefighting Drones
# 1         27        27                          DJI mavic 2 pro in flight
# 2         51        51  A small UAS is seen flying during at the US Ar...
# 3        102       102  Ruko F11 GIM2 Drone with Camera for Adults 4K ...
# 4        130       130                                     The MQ9 Reaper
# ..       ...       ...                                                ...
# 677     1931      1931  In our globalized world aviation increasingly ...
# 678     1947      1947      Lufthansa Business Class on longhaul aircraft
# 679     1969      1969  The Boeing 7478 has inherited the good looks o...
# 680     1979      1979                               911 Attacks Pentagon
# 681     1992      1992                             911 flight 93 memorial
#
#      topic_id labels                                              image  \
# ...

# %%
# pd.set_option('display.max_rows', None)
ofa_cap = df[['ofa_caption']]
ofa_cap
# Out:
#                                           ofa_caption
# 0            two men are standing in front of a drone
# 1                     a small drone flying in the sky
# 2                           a drone flying in the sky
# 3    a drone next to a speaker and aepercode5664�� U�
# 4             a plane flying in the air over a desert
# ..                                                ...
# 677          a blue sign that says adding departments
# 678             a person sleeping on an airplane seat
# 679    an airplane flying in the sky above the clouds
# 680           a painting of two people in an airplane
# 681       a sign in a museum with a lizard on display
#
# [682 rows x 1 columns]

# %%
# df_test.at[1,'image']
import base64

image_64_decode = base64.b64decode(df.at[300,'image']) 
image_result = open('deer_decode.jpg', 'wb') # create a writable image and write the decoding result
image_result.write(image_64_decode)
from IPython.display import Image as IImage
IImage(filename='deer_decode.jpg')

# %%
df.at[300,'ofa_caption']
# Out:
# 'a blue and white airplane sitting on a runway'

# %%
def clip_sim(b64_img, search_query):
    image_64_decode = base64.b64decode(b64_img) 
    image_result = open('test.jpg', 'wb')
    image_result.write(image_64_decode)
    try:
        image = Image.open('test.jpg')
        image = preprocess(image).unsqueeze(0).to(device)

        with torch.no_grad():
            photos_features = model.encode_image(image)
            photos_features /= photos_features.norm(dim=-1, keepdim=True)

        with torch.no_grad():
            # Encode and normalize the search query using CLIP
            text_encoded = model.encode_text(clip.tokenize(search_query).to(device))
            text_encoded /= text_encoded.norm(dim=-1, keepdim=True)

        similarities = (photos_features @ text_encoded.T).squeeze(1)
        return similarities.detach().cpu().numpy()[0]
    except:
        return None

# %%
def get_sim(u,v):

    emb1 = embedder.encode(u)
    if isinstance(v, list):
        v = ' '.join(v)
    emb2 = embedder.encode(v)
    
    return float(util.cos_sim(emb1, emb2)[0][0])

# %%
def simple_search(context, t):
    percentage = 0
    for w in t:
        if w in context:
            percentage = percentage + 1
    return float(percentage/len(t))

# %%
df['org_top_cov'] = df.apply(lambda x: simple_search(x.caption, list(topics[x.topic_id])), axis=1)
df['ofa_top_cov'] = df.apply(lambda x: simple_search(x.ofa_caption, list(topics[x.topic_id])), axis=1)

df['gt_ped_flag'] = df.apply(lambda x: flag_search_gt(x.tag, pedestrian_list), axis=1)
df['org_top_sim'] = df.apply(lambda x: get_sim(x.caption, list(topics[x.topic_id])), axis=1)
df['ofa_top_sim'] = df.apply(lambda x: get_sim(x.ofa_caption, list(topics[x.topic_id])), axis=1)

# %%
df['ofa_con_sim'] = df.apply(lambda x: get_sim(x.ofa_caption, ['Aircraft']), axis=1)
df['org_con_sim'] = df.apply(lambda x: get_sim(x.caption, ['Aircraft']), axis=1)
# df['ofa_gt_sim'] = df.apply(lambda x: get_sim(x.ofa_caption, x.gt), axis=1)
df['ofa_gt_sim'] = df.apply(lambda x: get_sim(x.ofa_caption, create_gt(x.tag)), axis=1)
df['org_gt_sim'] = df.apply(lambda x: get_sim(x.caption, create_gt(x.tag)), axis=1)

# %%
df['CLIP_s'] = df.apply(lambda x: clip_sim(x.image, x.ofa_caption), axis=1)

# %%
df
# Out:
#      uniq_id  image_id                                            caption  \
# 0          4         4                                Firefighting Drones
# 1         27        27                          DJI mavic 2 pro in flight
# 2         51        51  A small UAS is seen flying during at the US Ar...
# 3        102       102  Ruko F11 GIM2 Drone with Camera for Adults 4K ...
# 4        130       130                                     The MQ9 Reaper
# ..       ...       ...                                                ...
# 677     1931      1931  In our globalized world aviation increasingly ...
# 678     1947      1947      Lufthansa Business Class on longhaul aircraft
# 679     1969      1969  The Boeing 7478 has inherited the good looks o...
# 680     1979      1979                               911 Attacks Pentagon
# 681     1992      1992                             911 flight 93 memorial
#
#      topic_id labels                                              image  \
# ...

# %%
df = df.dropna()
df = df.reset_index(drop=True)

# %%
df[df['topics'] == 'b']
# Out:
#     uniq_id  image_id                                            caption  \
# 14      218       218  RC soaring plane on blue sky RC remotely contr...
# 15      223       223  RC model airplane flying RC model airplane fly...
# 16      228       228  Little boy playing with handmade RC airplane t...
# 17      232       232  Little boy playing with handmade RC airplane t...
# 18      242       242  RC soaring plane on blue sky RC remotely contr...
# 19      261       261  3D rendering of a glider plane isolated on blu...
# 20      282       282  Propeller plane towing glider in sky at Harris...
# 21      286       286             Crash landed glider plane in the woods
# 22      324       324  The plane flies A passenger airplane on the sk...
# 23      331       331  Elmira New York US  July 11 2021 Sailplanes gl...
# 24      336       336  sailplane A sailplane in front of a blue sky g...
# 25      355       355  Glider being towed A glider being towed at tak...
# ...

# %%
# av_groups = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'k']
gk = df.groupby('topics')
pg_dict = dict()

# %%
bf = gk.get_group('b')
bf
# Out:
#     uniq_id  image_id                                            caption  \
# 14      218       218  RC soaring plane on blue sky RC remotely contr...
# 15      223       223  RC model airplane flying RC model airplane fly...
# 16      228       228  Little boy playing with handmade RC airplane t...
# 17      232       232  Little boy playing with handmade RC airplane t...
# 18      242       242  RC soaring plane on blue sky RC remotely contr...
# 19      261       261  3D rendering of a glider plane isolated on blu...
# 20      282       282  Propeller plane towing glider in sky at Harris...
# 21      286       286             Crash landed glider plane in the woods
# 22      324       324  The plane flies A passenger airplane on the sk...
# 23      331       331  Elmira New York US  July 11 2021 Sailplanes gl...
# 24      336       336  sailplane A sailplane in front of a blue sky g...
# 25      355       355  Glider being towed A glider being towed at tak...
# ...

# %%
bf[bf['topic2caption_sim'] >= bf['topic2caption_sim'].quantile(.25)]
# Out:
#     uniq_id  image_id                                            caption  \
# 14      218       218  RC soaring plane on blue sky RC remotely contr...
# 15      223       223  RC model airplane flying RC model airplane fly...
# 18      242       242  RC soaring plane on blue sky RC remotely contr...
# 19      261       261  3D rendering of a glider plane isolated on blu...
# 20      282       282  Propeller plane towing glider in sky at Harris...
# 21      286       286             Crash landed glider plane in the woods
# 23      331       331  Elmira New York US  July 11 2021 Sailplanes gl...
# 24      336       336  sailplane A sailplane in front of a blue sky g...
# 25      355       355  Glider being towed A glider being towed at tak...
# 26      388       388  small glider towing plane in sunset small glid...
# 27      389       389  Glider towed on a rope flying on a blue sky ba...
# 28      394       394  sailpane on an airfield sailpane on an airfiel...
# ...

# %%
gk.groups.keys()
# Out:
# dict_keys(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])

# %%
for el in gk.groups.keys():
    pg_dict[el] = gk.get_group(el)
    pg_dict[el] = pg_dict[el][pg_dict[el]['topic2caption_sim'] >= pg_dict[el]['topic2caption_sim'].quantile(.25)]
    pg_dict[el] = pg_dict[el].reset_index(drop=True)

# %%
# for el in av_groups:
#     pg_dict[el] = df[df['topics'] == el]
#     pg_dict[el] = pg_dict[el].reset_index(drop=True)

# %%
pg_dict[el]
# Out:
#     uniq_id  image_id                                            caption  \
# 0       499       499  One of many control panels in aircraft simulat...
# 1       507       507  Cartoon scene with military army car vehicle o...
# 2       508       508                         Cockpit B1900 stock photos
# 3       518       518  Many switches in an aircraft cockpit royalty f...
# 4       520       520  View of an old aircraft cockpit with two yokes...
# ..      ...       ...                                                ...
# 76     1792      1792  The various air traffic control facilities enc...
# 77     1795      1795                 Its Our Passion  Airspace Aviation
# 78     1947      1947      Lufthansa Business Class on longhaul aircraft
# 79     1979      1979                               911 Attacks Pentagon
# 80     1992      1992                             911 flight 93 memorial
#
#     topic_id labels                                              image  \
# ...

# %%
pg_dict['a'].describe().round(2)
# Out:
#        uniq_id  image_id  topic_id  topic2caption_sim  concept2caption_sim  \
# count    10.00     10.00      10.0              10.00                10.00
# mean    125.70    125.70      31.0               0.51                 0.32
# std      70.39     70.39       0.0               0.04                 0.10
# min       4.00      4.00      31.0               0.45                 0.17
# 25%      73.50     73.50      31.0               0.50                 0.29
# 50%     156.50    156.50      31.0               0.51                 0.31
# 75%     178.00    178.00      31.0               0.53                 0.35
# max     190.00    190.00      31.0               0.58                 0.49
#
#        gt_coverage  org_top_cov  ofa_top_cov  gt_ped_flag  org_top_sim  \
# count        10.00        10.00        10.00         10.0        10.00
# mean          0.49         0.03         0.09          1.0         0.48
# std           0.03         0.05         0.03          0.0         0.04
# ...

# %%
# Test
df_ = pd.DataFrame()
for el in pg_dict:
    df_ = pd.concat([df_, pg_dict[el]], ignore_index=True)
df_ = df_.reset_index(drop=True)
df_[['gt_coverage', 'gt_ped_flag', 'org_gt_sim']].describe().round(2)
# Out:
#        gt_coverage  gt_ped_flag  org_gt_sim
# count       508.00       508.00      508.00
# mean          0.55         0.96        0.50
# std           0.21         0.19        0.13
# min           0.09         0.00        0.08
# 25%           0.40         1.00        0.42
# 50%           0.56         1.00        0.50
# 75%           0.73         1.00        0.60
# max           1.00         1.00        0.90

# %%
# Test
for el in pg_dict:
    print(el)
    display(pg_dict[el][['gt_coverage', 'gt_ped_flag', 'org_gt_sim']].describe().round(2))
# Out:
# a
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        10.00         10.0       10.00
# mean          0.49          1.0        0.52
# std           0.03          0.0        0.07
# min           0.40          1.0        0.37
# 25%           0.50          1.0        0.50
# 50%           0.50          1.0        0.52
# 75%           0.50          1.0        0.54
# max           0.50          1.0        0.62
# b
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        43.00         43.0       43.00
# mean          0.66          1.0        0.51
# std           0.21          0.0        0.09
# min           0.14          1.0        0.34
# 25%           0.43          1.0        0.45
# 50%           0.71          1.0        0.53
# 75%           0.86          1.0        0.58
# max           0.86          1.0        0.69
# c
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        40.00        40.00       40.00
# mean          0.54         0.98        0.45
# ...

# %%
df_ = pd.DataFrame()
for el in pg_dict:
    df_ = pd.concat([df_, pg_dict[el]], ignore_index=True)
df_ = df_.reset_index(drop=True)

# %%
# before
df_[['gt_ped_flag', 'gt_coverage', 'org_gt_sim', 'ofa_top_sim', 'ofa_gt_sim', 'ofa_con_sim', 'CLIP_s']].describe().round(2)
# Out:
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count       508.00       508.00      508.00       508.00      508.00
# mean          0.96         0.55        0.50         0.34        0.39
# std           0.19         0.21        0.13         0.13        0.14
# min           0.00         0.09        0.08        -0.05       -0.03
# 25%           1.00         0.40        0.42         0.27        0.32
# 50%           1.00         0.56        0.50         0.33        0.39
# 75%           1.00         0.73        0.60         0.41        0.48
# max           1.00         1.00        0.90         0.69        0.84
#
#        ofa_con_sim  CLIP_s
# count       508.00  504.00
# mean          0.48    0.29
# std           0.12    0.03
# min           0.03    0.20
# 25%           0.43    0.26
# 50%           0.51    0.28
# 75%           0.55    0.31
# max           0.71    0.40

# %%
# after wit
df_[['gt_ped_flag', 'gt_coverage', 'org_gt_sim', 'ofa_top_sim', 'ofa_gt_sim', 'ofa_con_sim', 'CLIP_s']].describe().round(2)
# Out:
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count       508.00       508.00      508.00       508.00      508.00
# mean          0.96         0.55        0.50         0.39        0.44
# std           0.19         0.21        0.13         0.14        0.14
# min           0.00         0.09        0.08        -0.01        0.04
# 25%           1.00         0.40        0.42         0.30        0.34
# 50%           1.00         0.56        0.50         0.38        0.42
# 75%           1.00         0.73        0.60         0.48        0.52
# max           1.00         1.00        0.90         0.77        0.84
#
#        ofa_con_sim  CLIP_s
# count       508.00  504.00
# mean          0.46    0.29
# std           0.10    0.04
# min           0.07    0.16
# 25%           0.39    0.26
# 50%           0.46    0.29
# 75%           0.53    0.31
# max           0.74    0.40

# %%
# after q50
df_[['gt_ped_flag', 'gt_coverage', 'org_gt_sim', 'ofa_top_sim', 'ofa_gt_sim', 'ofa_con_sim', 'CLIP_s']].describe().round(2)
# Out:
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count       508.00       508.00      508.00       508.00      508.00
# mean          0.96         0.55        0.50         0.42        0.45
# std           0.19         0.21        0.13         0.15        0.15
# min           0.00         0.09        0.08        -0.03        0.04
# 25%           1.00         0.40        0.42         0.32        0.36
# 50%           1.00         0.56        0.50         0.41        0.45
# 75%           1.00         0.73        0.60         0.53        0.55
# max           1.00         1.00        0.90         0.76        0.86
#
#        ofa_con_sim  CLIP_s
# count       508.00  504.00
# mean          0.44    0.29
# std           0.10    0.04
# min           0.06    0.16
# 25%           0.38    0.27
# 50%           0.44    0.29
# 75%           0.50    0.32
# max           0.79    0.41

# %%
# before
for el in pg_dict:
    print(el)
    display(pg_dict[el][['gt_ped_flag', 'gt_coverage', 'org_gt_sim', 'ofa_top_sim', 'ofa_gt_sim', 'ofa_con_sim', 'CLIP_s']].describe().round(2))
# Out:
# a
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count         10.0        10.00       10.00        10.00       10.00
# mean           1.0         0.49        0.52         0.48        0.50
# std            0.0         0.03        0.07         0.04        0.07
# min            1.0         0.40        0.37         0.39        0.36
# 25%            1.0         0.50        0.50         0.47        0.47
# 50%            1.0         0.50        0.52         0.48        0.51
# 75%            1.0         0.50        0.54         0.50        0.53
# max            1.0         0.50        0.62         0.54        0.58
#
#        ofa_con_sim  CLIP_s
# count        10.00   10.00
# mean          0.39    0.29
# std           0.11    0.02
# min           0.21    0.27
# 25%           0.34    0.28
# 50%           0.43    0.29
# 75%           0.47    0.30
# max           0.52    0.34
# b
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# ...

# %%
#after wit
for el in pg_dict:
    print(el)
    display(pg_dict[el][['gt_ped_flag', 'gt_coverage', 'org_gt_sim', 'ofa_top_sim', 'ofa_gt_sim', 'ofa_con_sim', 'CLIP_s']].describe().round(2))
# Out:
# a
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count         10.0        10.00       10.00        10.00       10.00
# mean           1.0         0.49        0.52         0.47        0.50
# std            0.0         0.03        0.07         0.07        0.12
# min            1.0         0.40        0.37         0.33        0.32
# 25%            1.0         0.50        0.50         0.47        0.41
# 50%            1.0         0.50        0.52         0.50        0.53
# 75%            1.0         0.50        0.54         0.51        0.57
# max            1.0         0.50        0.62         0.54        0.67
#
#        ofa_con_sim  CLIP_s
# count        10.00   10.00
# mean          0.40    0.29
# std           0.06    0.03
# min           0.30    0.24
# 25%           0.38    0.28
# 50%           0.41    0.29
# 75%           0.44    0.30
# max           0.46    0.34
# b
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# ...

# %%
#after q50
for el in pg_dict:
    print(el)
    display(pg_dict[el][['gt_ped_flag', 'gt_coverage', 'org_gt_sim', 'ofa_top_sim', 'ofa_gt_sim', 'ofa_con_sim', 'CLIP_s']].describe().round(2))
# Out:
# a
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count         10.0        10.00       10.00        10.00       10.00
# mean           1.0         0.49        0.52         0.49        0.54
# std            0.0         0.03        0.07         0.12        0.13
# min            1.0         0.40        0.37         0.19        0.21
# 25%            1.0         0.50        0.50         0.48        0.49
# 50%            1.0         0.50        0.52         0.53        0.58
# 75%            1.0         0.50        0.54         0.55        0.61
# max            1.0         0.50        0.62         0.58        0.67
#
#        ofa_con_sim  CLIP_s
# count        10.00   10.00
# mean          0.42    0.29
# std           0.10    0.04
# min           0.27    0.20
# 25%           0.34    0.28
# 50%           0.42    0.29
# 75%           0.49    0.31
# max           0.55    0.34
# b
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# ...

# %% [markdown]
# # CLIP SCORE

# %%
# pd.set_option('display.max_rows', None)

d_path = '/raid/AISSEL/Hamed/datasets/av_data/fatemeh'
#before
df_b = pd.read_pickle(f'{d_path}/df_av_test_before_tags.pk')


# after q50
d_path = '/raid/AISSEL/Hamed/datasets/av_data/fatemeh/all_q50'
df_f = pd.read_pickle(f'{d_path}/df_av_test_after_tags.pk')

# wit
d_path = '/raid/AISSEL/Hamed/datasets/av_data/all'
df_w = pd.read_pickle(f'{d_path}/wit_av_test_after.pk')

#on missed
# d_path = '/raid/AISSEL/Hamed/datasets/av_data/fatemeh/missed_q50'
# df = pd.read_pickle(f'{d_path}/df_av_test_after_tags.pk')


# df

# %%
df_w
# Out:
#      uniq_id  image_id                                            caption  \
# 0          4         4                                Firefighting Drones
# 1         27        27                          DJI mavic 2 pro in flight
# 2         51        51  A small UAS is seen flying during at the US Ar...
# 3        102       102  Ruko F11 GIM2 Drone with Camera for Adults 4K ...
# 4        130       130                                     The MQ9 Reaper
# ..       ...       ...                                                ...
# 677     1931      1931  In our globalized world aviation increasingly ...
# 678     1947      1947      Lufthansa Business Class on longhaul aircraft
# 679     1969      1969  The Boeing 7478 has inherited the good looks o...
# 680     1979      1979                               911 Attacks Pentagon
# 681     1992      1992                             911 flight 93 memorial
#
#      topic_id labels                                              image  \
# ...

# %%
def drop_nan(df):
#     print(df['gt'].isna().sum())
    df = df[df['gt'].notna()]
    df = df.reset_index(drop=True)
    return df

# %%
df_b['gt'] = df_b.apply(lambda x: create_gt(x.tag), axis=1)
df_f['gt'] = df_f.apply(lambda x: create_gt(x.tag), axis=1)
df_w['gt'] = df_w.apply(lambda x: create_gt(x.tag), axis=1)
df_b = df_b[df_b['topic2caption_sim'] >= df_b['topic2caption_sim'].quantile(.25)]
df_f = df_f[df_f['topic2caption_sim'] >= df_f['topic2caption_sim'].quantile(.25)]
df_w = df_w[df_w['topic2caption_sim'] >= df_w['topic2caption_sim'].quantile(.25)]
# df_b = drop_nan(df_b)
# df_f = drop_nan(df_f)
# df_w = drop_nan(df_w)

# len(df_b)

# %%
df_b = df_b.dropna()
df_b = df_b.reset_index(drop=True)
df_f = df_f.dropna()
df_f = df_f.reset_index(drop=True)
df_w = df_w.dropna()
df_w = df_w.reset_index(drop=True)
# tmp_df

# %%
print(len(df_b))
print(len(df_f))
print(len(df_w))
# Out:
# 511
# 511
# 511

# %%
tmp_df = pd.DataFrame()
tmp_df['image'] = df_b['image'].to_list()
# tmp_df['or_caption'] = df_b['caption'].to_list()
tmp_df['bf_caption'] = df_b['ofa_caption'].to_list()
tmp_df['aw_caption'] = df_w['ofa_caption'].to_list()
tmp_df['af_caption'] = df_f['ofa_caption'].to_list()
tmp_df['topics'] = df_b['topics'].to_list()

# %%
def clip_3(row):
    image_64_decode = base64.b64decode(row['image']) 
    image_result = open('test.jpg', 'wb')
    image_result.write(image_64_decode)
    try:
        image = Image.open('test.jpg')
        image = preprocess(image).unsqueeze(0).to(device)

        with torch.no_grad():
            image_features = model.encode_image(image)

        text_snippets = [row['bf_caption'], row['aw_caption'], row['af_caption']]
        text = clip.tokenize(text_snippets).to(device)

        with torch.no_grad():
            text_features = model.encode_text(text)
        
        with torch.no_grad():
            logits_per_image, logits_per_text = model(image, text)
            probs = list(logits_per_image.softmax(dim=-1).cpu().numpy()[0])
        
        return probs[0], probs[1], probs[2] #, probs[3]
    except:
        return None

# %%
clip_scores = tmp_df.apply(clip_3, axis=1)

# %%
bf_score = []
aw_score = []
af_score = []
or_score = []
for el in clip_scores:
#     print(el)
    if el:
        bf_score.append(el[0])
        aw_score.append(el[1])
        af_score.append(el[2])
#         or_score.append(el[3])
    else:
        bf_score.append(None)
        aw_score.append(None)
        af_score.append(None)
#         or_score.append(None)

# %%
tmp_df['bf_score'] = bf_score
tmp_df['aw_score'] = aw_score
tmp_df['af_score'] = af_score
# tmp_df['or_score'] = or_score

# %%
tmp_df
# Out:
#                                                  image  \
# 0    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# ..                                                 ...
# 506  iVBORw0KGgoAAAANSUhEUgAAASIAAAEhCAIAAABUSDpPAA...
# 507  iVBORw0KGgoAAAANSUhEUgAAAhcAAAGiCAYAAABUNuQTAA...
# 508  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 509  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 510  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
#                                             bf_caption  \
# 0             two men are standing in front of a drone
# 1                      a small drone flying in the sky
# 2                            a drone flying in the sky
# 3     a drone next to a speaker and aepercode5664�� U�
# ...

# %%
tmp_df = tmp_df.dropna()
tmp_df = tmp_df.reset_index(drop=True)
tmp_df
# Out:
#                                                  image  \
# 0    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# ..                                                 ...
# 501  iVBORw0KGgoAAAANSUhEUgAAASIAAAEhCAIAAABUSDpPAA...
# 502  iVBORw0KGgoAAAANSUhEUgAAAhcAAAGiCAYAAABUNuQTAA...
# 503  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 504  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 505  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
#                                             bf_caption  \
# 0             two men are standing in front of a drone
# 1                      a small drone flying in the sky
# 2                            a drone flying in the sky
# 3     a drone next to a speaker and aepercode5664�� U�
# ...

# %%
tmp_df.describe().round(4)
# Out:
#        bf_score  aw_score  af_score
# count  506.0000  506.0000  506.0000
# mean     0.3026    0.3200    0.3774
# std      0.3296    0.3328    0.3473
# min      0.0000    0.0000    0.0000
# 25%      0.0201    0.0244    0.0436
# 50%      0.1509    0.1860    0.2863
# 75%      0.5339    0.5579    0.6710
# max      1.0000    1.0000    1.0000

# %%
gk = tmp_df.groupby('topics')
pg_dict = dict()
for el in gk.groups.keys():
    pg_dict[el] = gk.get_group(el)
    pg_dict[el] = pg_dict[el].reset_index(drop=True)
# before
for el in pg_dict:
    print(el)
    display(pg_dict[el].describe().round(2))
# Out:
# a
#        bf_score  aw_score  af_score
# count     13.00     13.00     13.00
# mean       0.37      0.36      0.27
# std        0.32      0.27      0.26
# min        0.03      0.01      0.00
# 25%        0.12      0.09      0.06
# 50%        0.33      0.42      0.29
# 75%        0.43      0.57      0.39
# max        0.99      0.80      0.93
# b
#        bf_score  aw_score  af_score
# count     56.00     56.00     56.00
# mean       0.36      0.22      0.42
# std        0.35      0.30      0.37
# min        0.00      0.00      0.00
# 25%        0.04      0.01      0.07
# 50%        0.24      0.07      0.33
# 75%        0.61      0.29      0.78
# max        1.00      0.99      1.00
# c
#        bf_score  aw_score  af_score
# count     33.00     33.00     33.00
# mean       0.36      0.27      0.38
# std        0.35      0.29      0.33
# min        0.00      0.00      0.00
# 25%        0.03      0.03      0.10
# 50%        0.14      0.17      0.31
# 75%        0.66      0.47      0.54
# ...
