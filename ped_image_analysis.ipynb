# %%
import os

# General packages
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import plotly.express as px
import PIL.Image
from tqdm.notebook import tqdm, trange
import glob
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

from IPython.display import Image as IImage
from IPython.display import display, HTML
import warnings
warnings.filterwarnings("ignore")
tqdm.pandas()

# %%
import torch
import clip
from PIL import Image
import base64

import os

# %%
from sentence_transformers import SentenceTransformer, util
embedder = SentenceTransformer('all-MiniLM-L6-v2')

# %%
def find_gpus(nums=6):
    os.system('nvidia-smi -q -d Memory |grep -A4 GPU|grep Free >tmp_free_gpus')
    with open('tmp_free_gpus', 'r') as lines_txt:
        frees = lines_txt.readlines()
        idx_freeMemory_pair = [ (idx,int(x.split()[2]))
                              for idx,x in enumerate(frees) ]
    idx_freeMemory_pair.sort(key=lambda my_tuple:my_tuple[1],reverse=True)
    usingGPUs = [str(idx_memory_pair[0])
                    for idx_memory_pair in idx_freeMemory_pair[:nums] ]
    usingGPUs =  ','.join(usingGPUs)
    print('using GPU idx: #', usingGPUs)
    return usingGPUs

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = find_gpus(nums=2)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()
# Out:
# using GPU idx: # 1,0
# Using device: cuda

# %% [markdown]
# ## get topics

# %%
from bertopic import BERTopic
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

# %%
lemmatizer = WordNetLemmatizer()

# %%
topics = {196: {'cross',
  'crossing',
  'crosswalk',
  'pedestrian',
  'signal',
  'stripe',
  'traffic'},
 412: {'arrest',
  'pedestrian',
  'perp',
  'pers',
  'walk',
  'walkability',
  'walkable'},
 172: {'car',
  'lane',
  'pedestrian',
  'road',
  'street',
  'traffic',
  'transportation',
  'vehicle'},
 363: {'assault',
  'bystander',
  'intervene',
  'intervention',
  'pedestrian',
  'stalk',
  'stalker',
  'victim',
  'witness'},
 198: {'car',
  'garage',
  'park',
  'parking',
  'parkjockey',
  'pedestrian',
  'tow',
  'vehicle'},
 114: {'athlete',
  'disability',
  'paralympic',
  'paralympics',
  'pedestrian',
  'sport',
  'sportspeople',
  'wheelchair'},
 419: {'avenue',
  'boulevard',
  'intersection',
  'manhattan',
  'pedestrian',
  'road',
  'street',
  'suffix'},
 294: {'drive',
  'fine',
  'licence',
  'offence',
  'pedestrian',
  'penalty',
  'reckless',
  'speed',
  'ticket',
  'traffic',
  'violation'},
 388: {'brownian',
  'diffusion',
  'distribution',
  'markov',
  'pedestrian',
  'percolation',
  'step',
  'stochastic',
  'walk',
  'wiener'},
 314: {'circle',
  'interchange',
  'intersection',
  'junction',
  'lane',
  'pedestrian',
  'road',
  'roundabout',
  'traffic'},
 98: {'cross',
  'direction',
  'lane',
  'marker',
  'parking',
  'pedestrian',
  'road',
  'sign',
  'signage',
  'traffic'},
 80: {'accident',
  'brake',
  'collision',
  'drive',
  'fatality',
  'momentum',
  'nhtsa',
  'pedestrian',
  'vehicle',
  'velocity'},
 134: {'avenue',
  'edmonton',
  'expressway',
  'freeway',
  'gardiner',
  'highway',
  'lane',
  'ontario',
  'pedestrian',
  'road',
  'toronto'},
 432: {'alice',
  'book',
  'fiction',
  'novel',
  'pedestrian',
  'poem',
  'poetry',
  'pulitzer',
  'walker'},
 394: {'alley',
  'boulevard',
  'bridleway',
  'bridleways',
  'footpath',
  'path',
  'pedestrian'},
 53: {'asphalt',
  'cement',
  'concrete',
  'gravel',
  'pave',
  'pavement',
  'pedestrian',
  'pothole',
  'road',
  'sand'},
 56: {'bus',
  'pedestrian',
  'streetcar',
  'subway',
  'train',
  'tram',
  'transit',
  'transportation',
  'trolley'},
 150: {'freeway',
  'highway',
  'intersection',
  'lane',
  'pedestrian',
  'ramp',
  'road',
  'traffic'},
 278: {'deck',
  'park',
  'pedestrian',
  'promenade',
  'promenadef',
  'promenaden',
  'promener',
  'walk'},
 -1: {'american',
  'century',
  'example',
  'film',
  'her',
  'pedestrian',
  'public',
  'state',
  'street',
  'water'},
 43: {'black',
  'civil',
  'negro',
  'pedestrian',
  'protest',
  'protester',
  'race',
  'racial',
  'segregation',
  'white'},
 265: {'baby',
  'carriage',
  'child',
  'diaper',
  'harness',
  'hatch',
  'infant',
  'pedestrian',
  'stroller'},
 345: {'barrier',
  'bumper',
  'guardrail',
  'hazard',
  'pedestrian',
  'protect',
  'rail',
  'safety'},
 378: {'architect',
  'architecture',
  'building',
  'chicago',
  'city',
  'frederick',
  'park',
  'pedestrian'},
 11: {'freeway',
  'highway',
  'intersection',
  'interstate',
  'lane',
  'pedestrian',
  'road',
  'route',
  'terminus',
  'turnpike'},
 331: {'byway',
  'highway',
  'navajo',
  'parkway',
  'pedestrian',
  'road',
  'roadway',
  'route',
  'scenic'},
 202: {'bottleneck',
  'congest',
  'congestion',
  'delay',
  'downstream',
  'pedestrian',
  'road',
  'speed',
  'traffic',
  'vehicle'},
 169: {'apartment',
  'condominium',
  'home',
  'homeless',
  'homelessness',
  'house',
  'household',
  'housing',
  'pedestrian',
  'shelter'},
 327: {'bartholdi',
  'lazarus',
  'liberty',
  'monument',
  'pedestal',
  'pedestrian',
  'sculptor',
  'sculpture',
  'statue',
  'torch'},
 309: {'adelaide',
  'carriageworks',
  'close',
  'geelong',
  'line',
  'melbourne',
  'pedestrian',
  'rail',
  'railway',
  'train'},
 68: {'axle',
  'carriage',
  'chariot',
  'passenger',
  'pedestrian',
  'vehicle',
  'wagon',
  'wheel'},
 216: {'carriageway',
  'lane',
  'm1',
  'm11',
  'm25',
  'm32',
  'motorway',
  'pedestrian',
  'road',
  'roundabout'},
 40: {'arrest',
  'constable',
  'constabulary',
  'enforcement',
  'officer',
  'patrol',
  'pedestrian',
  'police'},
 99: {'building',
  'concrete',
  'construction',
  'insulation',
  'masonry',
  'pedestrian',
  'roof',
  'structure',
  'wall'},
 426: {'80211p',
  'cv2x',
  'pedestrian',
  'unlock',
  'v2v',
  'v2x',
  'vanet',
  'vanets',
  'vehicle',
  'vehicular'},
 344: {'adriatic',
  'censor',
  'corniche',
  'itinerary',
  'pave',
  'pedestrian',
  'road',
  'roman',
  'rome'},
 47: {'avenue',
  'bmt',
  'broadway',
  'broadwayseventh',
  'brooklyn',
  'manhattan',
  'pedestrian',
  'station',
  'subway',
  'train'},
 8: {'bicycle',
  'bike',
  'cycle',
  'cycling',
  'cyclist',
  'pedestrian',
  'rid',
  'rider',
  'tire'},
 416: {'descriptor',
  'detection',
  'detector',
  'keypoints',
  'ocr',
  'pedestrian',
  'pixel',
  'recognition',
  'sift',
  'vision'},
 112: {'bus',
  'congestion',
  'freight',
  'passenger',
  'pedestrian',
  'route',
  'traffic',
  'transit',
  'transport',
  'transportation'},
 137: {'expressway',
  'freeway',
  'highway',
  'lane',
  'motorway',
  'pedestrian',
  'road'},
 441: {'actor',
  'character',
  'drama',
  'hamlet',
  'novel',
  'pedestrian',
  'protagonist',
  'romeo',
  'shakespeare'},
 192: {'ataxia',
  'cerebellar',
  'cerebellum',
  'cerebral',
  'diplegia',
  'disorder',
  'gait',
  'palsy',
  'pedestrian',
  'symptom',
  'syndrome'},
 20: {'ankle', 'dance', 'dancer', 'foot', 'leg', 'pedestrian', 'toe'},
 296: {'area',
  'monument',
  'park',
  'pedestrian',
  'playground',
  'recreation',
  'scenic',
  'wilderness',
  'yellowstone'},
 144: {'',
  'address',
  'comma',
  'image',
  'more',
  'pedestrian',
  'person',
  'separate',
  'share',
  'video'},
 12: {'appalachian',
  'footpath',
  'hike',
  'hiker',
  'mountain',
  'path',
  'pedestrian',
  'trail'},
 224: {'bus',
  'depot',
  'fleet',
  'goahead',
  'pedestrian',
  'sb',
  'singapore',
  'smrt',
  'tram',
  'transit'},
 250: {'driver',
  'graphic',
  'kernel',
  'kernelmode',
  'kmdf',
  'linux',
  'pedestrian',
  'printer',
  'umdf',
  'usb'},
 376: {'bear',
  'cartoon',
  'charlie',
  'disney',
  'lucy',
  'mickey',
  'peanut',
  'pedestrian',
  'snoopy',
  'trolley'}}

# %%
# topics = get_topics(concept='aircraft')
q_id = [el for el in topics]

# %%
for el in topics:
    print(el, topics[el])
# Out:
# 196 {'crosswalk', 'traffic', 'stripe', 'cross', 'crossing', 'signal', 'pedestrian'}
# 412 {'walkability', 'arrest', 'perp', 'pers', 'walk', 'pedestrian', 'walkable'}
# 172 {'street', 'traffic', 'car', 'transportation', 'vehicle', 'lane', 'pedestrian', 'road'}
# 363 {'stalk', 'intervene', 'victim', 'intervention', 'stalker', 'bystander', 'assault', 'pedestrian', 'witness'}
# 198 {'parkjockey', 'parking', 'car', 'park', 'tow', 'garage', 'pedestrian', 'vehicle'}
# 114 {'paralympics', 'sport', 'disability', 'wheelchair', 'sportspeople', 'paralympic', 'athlete', 'pedestrian'}
# 419 {'avenue', 'street', 'suffix', 'road', 'intersection', 'manhattan', 'pedestrian', 'boulevard'}
# 294 {'licence', 'speed', 'fine', 'ticket', 'violation', 'penalty', 'traffic', 'drive', 'reckless', 'offence', 'pedestrian'}
# 388 {'diffusion', 'percolation', 'distribution', 'walk', 'wiener', 'step', 'stochastic', 'markov', 'pedestrian', 'brownian'}
# 314 {'junction', 'intersection', 'roundabout', 'circle', 'traffic', 'interchange', 'lane', 'pedestrian', 'road'}
# 98 {'traffic', 'parking', 'direction', 'cross', 'marker', 'sign', 'signage', 'lane', 'pedestrian', 'road'}
# 80 {'brake', 'velocity', 'collision', 'drive', 'accident', 'nhtsa', 'fatality', 'vehicle', 'pedestrian', 'momentum'}
# 134 {'avenue', 'ontario', 'expressway', 'edmonton', 'highway', 'freeway', 'lane', 'pedestrian', 'toronto', 'gardiner', 'road'}
# 432 {'book', 'walker', 'novel', 'alice', 'fiction', 'poetry', 'pulitzer', 'poem', 'pedestrian'}
# 394 {'path', 'bridleways', 'bridleway', 'footpath', 'alley', 'pedestrian', 'boulevard'}
# 53 {'concrete', 'cement', 'pothole', 'sand', 'pave', 'asphalt', 'gravel', 'pedestrian', 'pavement', 'road'}
# 56 {'bus', 'tram', 'trolley', 'transit', 'train', 'streetcar', 'transportation', 'pedestrian', 'subway'}
# 150 {'intersection', 'ramp', 'traffic', 'highway', 'freeway', 'lane', 'pedestrian', 'road'}
# 278 {'promener', 'deck', 'promenadef', 'walk', 'park', 'promenade', 'promenaden', 'pedestrian'}
# -1 {'street', 'state', 'century', 'water', 'public', 'pedestrian', 'her', 'example', 'american', 'film'}
# 43 {'black', 'race', 'protest', 'white', 'civil', 'segregation', 'racial', 'protester', 'negro', 'pedestrian'}
# 265 {'diaper', 'child', 'stroller', 'hatch', 'carriage', 'infant', 'harness', 'baby', 'pedestrian'}
# 345 {'rail', 'protect', 'barrier', 'bumper', 'safety', 'hazard', 'pedestrian', 'guardrail'}
# 378 {'architecture', 'city', 'building', 'chicago', 'park', 'architect', 'pedestrian', 'frederick'}
# 11 {'intersection', 'interstate', 'terminus', 'highway', 'turnpike', 'freeway', 'lane', 'pedestrian', 'route', 'road'}
# 331 {'navajo', 'roadway', 'scenic', 'byway', 'parkway', 'highway', 'pedestrian', 'route', 'road'}
# 202 {'speed', 'bottleneck', 'congest', 'delay', 'congestion', 'traffic', 'downstream', 'vehicle', 'pedestrian', 'road'}
# 169 {'apartment', 'household', 'homelessness', 'shelter', 'housing', 'home', 'house', 'condominium', 'homeless', 'pedestrian'}
# 327 {'monument', 'lazarus', 'sculpture', 'bartholdi', 'liberty', 'sculptor', 'torch', 'pedestal', 'pedestrian', 'statue'}
# 309 {'melbourne', 'carriageworks', 'rail', 'railway', 'train', 'adelaide', 'geelong', 'line', 'close', 'pedestrian'}
# 68 {'passenger', 'chariot', 'wheel', 'axle', 'wagon', 'carriage', 'pedestrian', 'vehicle'}
# 216 {'m25', 'm11', 'road', 'roundabout', 'motorway', 'm1', 'm32', 'lane', 'pedestrian', 'carriageway'}
# 40 {'arrest', 'constabulary', 'constable', 'officer', 'enforcement', 'pedestrian', 'patrol', 'police'}
# 99 {'roof', 'concrete', 'construction', 'building', 'masonry', 'structure', 'insulation', 'wall', 'pedestrian'}
# 426 {'unlock', 'vanet', 'v2x', 'cv2x', 'v2v', 'vehicular', 'vehicle', 'pedestrian', '80211p', 'vanets'}
# 344 {'itinerary', 'adriatic', 'roman', 'censor', 'pave', 'corniche', 'pedestrian', 'rome', 'road'}
# 47 {'avenue', 'broadwayseventh', 'train', 'station', 'bmt', 'brooklyn', 'broadway', 'manhattan', 'pedestrian', 'subway'}
# 8 {'bike', 'rider', 'cycling', 'bicycle', 'rid', 'cycle', 'cyclist', 'pedestrian', 'tire'}
# 416 {'detector', 'sift', 'vision', 'recognition', 'pixel', 'keypoints', 'detection', 'descriptor', 'ocr', 'pedestrian'}
# 112 {'bus', 'passenger', 'freight', 'transit', 'congestion', 'traffic', 'transportation', 'pedestrian', 'route', 'transport'}
# 137 {'expressway', 'motorway', 'highway', 'freeway', 'lane', 'pedestrian', 'road'}
# 441 {'shakespeare', 'protagonist', 'novel', 'hamlet', 'romeo', 'pedestrian', 'actor', 'drama', 'character'}
# 192 {'ataxia', 'diplegia', 'symptom', 'syndrome', 'cerebellum', 'gait', 'cerebellar', 'disorder', 'pedestrian', 'cerebral', 'palsy'}
# 20 {'ankle', 'foot', 'leg', 'dancer', 'dance', 'toe', 'pedestrian'}
# 296 {'monument', 'area', 'scenic', 'playground', 'yellowstone', 'park', 'wilderness', 'pedestrian', 'recreation'}
# 144 {'', 'share', 'separate', 'comma', 'person', 'more', 'video', 'pedestrian', 'address', 'image'}
# 12 {'path', 'trail', 'appalachian', 'hike', 'hiker', 'mountain', 'footpath', 'pedestrian'}
# 224 {'bus', 'tram', 'depot', 'goahead', 'smrt', 'transit', 'sb', 'fleet', 'singapore', 'pedestrian'}
# 250 {'kmdf', 'printer', 'usb', 'driver', 'pedestrian', 'kernelmode', 'umdf', 'graphic', 'linux', 'kernel'}
# 376 {'lucy', 'trolley', 'charlie', 'bear', 'cartoon', 'disney', 'peanut', 'snoopy', 'pedestrian', 'mickey'}

# %%
topics[80]
# Out:
# {'accident',
#  'brake',
#  'collision',
#  'drive',
#  'fatality',
#  'momentum',
#  'nhtsa',
#  'pedestrian',
#  'vehicle',
#  'velocity'}

# %%
pg_t = dict()
pg_t['a'] = [68, 112, 56, 224]
pg_t['b'] = [309, 344, 47, -1, 53]
pg_t['c'] = [314, 331, 419, 394]
pg_t['d'] = [98, 196, 202, 294]
pg_t['e'] = [172, 137, 11, 134, 150, 216]
pg_t['f'] = [363, 40, 43]
pg_t['g'] = [441, 376]
pg_t['h'] = [144, 416, 327]
pg_t['i'] = [192, 20, 114]
pg_t['j'] = [345]
pg_t['k'] = [8, 265]
pg_t['l'] = [250, 80, 426]
pg_t['m'] = [169, 99, 378]
pg_t['n'] = [432, 388, 412]
pg_t['o'] = [12, 278, 198, 296]

# %%
for el in pg_t:
    group_words = []
    for t in pg_t[el]:
        group_words.extend(list(topics[t]))
#         break
    pg_t[el]= list(set(group_words))

# %%
print(pg_t[el])
# Out:
# ['area', 'mountain', 'car', 'tow', 'pedestrian', 'path', 'deck', 'hike', 'hiker', 'parkjockey', 'park', 'garage', 'promenaden', 'wilderness', 'vehicle', 'promener', 'trail', 'scenic', 'promenadef', 'playground', 'walk', 'parking', 'yellowstone', 'promenade', 'monument', 'appalachian', 'footpath', 'recreation']

# %%
for g in pg_t:
    pg_t[g] = ' '.join(pg_t[g])

# %%
pg_t[g]
# Out:
# 'area mountain car tow pedestrian path deck hike hiker parkjockey park garage promenaden wilderness vehicle promener trail scenic promenadef playground walk parking yellowstone promenade monument appalachian footpath recreation'

# %%
toopic_dict = dict()
for el in topics:
    toopic_dict[el] = ' '.join(topics[el])
toopic_dict[el]
# Out:
# 'lucy trolley charlie bear cartoon disney peanut snoopy pedestrian mickey'

# %% [markdown]
# ## Load Predictions

# %%
# pd.set_option('display.max_rows', None)

# d_path = '/raid/AISSEL/htest/datasets/ped_data/ped_ftest/all'
# before
base_path = '.'
df_b = pd.read_pickle(f'{base_path}/pd_base.pk')

# after q50_over_avg
d_path = '/raid/AISSEL/htest/datasets/ped_data/ped_ftest/missed_q50_over_avg'
df_f = pd.read_pickle(f'{d_path}/pd_mq50_over_avg.pk')


# wit
d_path = '/raid/AISSEL/htest/datasets/ped_data/wit/missed_q50_over_avg'
df_w = pd.read_pickle(f'{d_path}/ped_mq50_over_avg.pk')
# df

# random
d_path = '/raid/AISSEL/htest/datasets/ped_data/wit/random_missed'
df_r = pd.read_pickle(f'{d_path}/ped_mq50_over_avg.pk')
# df

# %%
pedestrian_list = ['people', 'someone', 'individual', 'worker', 'child', 'human', 
                   'somebody', 'man', 'boy', 'human', 'person', 'mankind', 
                   'humankind', 'guy', 'gentleman', 'someone', 'girl', 'men', 
                   'woman', 'women', 'lady', 'madam', 'pedestrian', 'kid']

# %%
def create_gt(tag):
    context = ""
    for el in tag:
        if tag[el]:
            context = context + " " + el
    if not context:
        context = None
    return context

# %%
# pedestrian_list
def flag_search_gt(tag, t):
    context = ""
    for el in tag:
        if tag[el]:
            context = context + " " + el
        
    for w in t:
        if w in context:
            return float(1)
    return float(0)

# %%
def get_percentage(tag):
    sum_val = 0
    for el in tag:
        sum_val = sum_val + tag[el]
    return sum_val / len(tag)

# %%
def get_sim(u,v):

    emb1 = embedder.encode(u)
    if isinstance(v, list):
        v = ' '.join(v)
    emb2 = embedder.encode(v)
    
    return float(util.cos_sim(emb1, emb2)[0][0])

# %%
def simple_search(context, t):
    percentage = 0
    for w in t:
        if w in context:
            percentage = percentage + 1
    return float(percentage/len(t))

# %%
def calc_sim(df):
    df = df[df['tag'].notna()]
    df = df.reset_index(drop=True)
    df = df[df['gt'].notna()]
    df = df.reset_index(drop=True)
    
    df['gt_coverage'] = df.apply(lambda x: get_percentage(x.tag), axis=1)
    df['org_top_cov'] = df.apply(lambda x: simple_search(x.caption, list(topics[x.topic_id])), axis=1)
    df['ofa_top_cov'] = df.apply(lambda x: simple_search(x.ofa_caption, list(topics[x.topic_id])), axis=1)

    df['gt_ped_flag'] = df.apply(lambda x: flag_search_gt(x.tag, pedestrian_list), axis=1)
    df['org_top_sim'] = df.apply(lambda x: get_sim(x.caption, list(topics[x.topic_id])), axis=1)
    df['ofa_top_sim'] = df.apply(lambda x: get_sim(x.ofa_caption, list(topics[x.topic_id])), axis=1)
    df['ofa_con_sim'] = df.apply(lambda x: get_sim(x.ofa_caption, ['pedestrian']), axis=1)
    df['org_con_sim'] = df.apply(lambda x: get_sim(x.caption, ['pedestrian']), axis=1)
    # df['ofa_gt_sim'] = df.apply(lambda x: get_sim(x.ofa_caption, x.gt), axis=1)
    df['ofa_gt_sim'] = df.apply(lambda x: get_sim(x.ofa_caption, create_gt(x.tag)), axis=1)
    df['org_gt_sim'] = df.apply(lambda x: get_sim(x.caption, create_gt(x.tag)), axis=1)
    df['human_con_sim'] = df.apply(lambda x: get_sim(x.h_caption, ['pedestrian']), axis=1)
    df['web_ofa_sim'] = df.apply(lambda x: get_sim(x.caption, x.ofa_caption), axis=1)
    gk = df.groupby('topics')
    pg_dict = dict()
    for el in gk.groups.keys():
        pg_dict[el] = gk.get_group(el)
        pg_dict[el] = pg_dict[el].reset_index(drop=True)
    return df, pg_dict

# %%
df_b, pg_dict_b = calc_sim(df_b)

# %%
df_f, pg_dict_f = calc_sim(df_f)

# %%
df_w, pg_dict_w = calc_sim(df_w)

# %%
df_r, pg_dict_r = calc_sim(df_r)

# %%
data = []
for el in pg_dict_b:
#     print(el)
    data.append([el, pg_dict_w[el].describe().round(2).at['mean','web_ofa_sim'], pg_dict_f[el].describe().round(2).at['mean','web_ofa_sim'], pg_dict_b[el].describe().round(2).at['mean','web_ofa_sim'], pg_dict_r[el].describe().round(2).at['mean','web_ofa_sim']])
#     print(f"{pg_dict_b[el].describe().round(2).at['mean','web_ofa_sim']}")
#     print()

# %%
df_cap2cap = pd.DataFrame(data, columns = ['Topic', 'App_1', 'App_2', 'Base', 'Random'])
df_cap2cap
# Out:
#    Topic  App_1  App_2  Base  Random
# 0      a   0.35   0.39  0.34    0.31
# 1      b   0.43   0.49  0.42    0.40
# 2      c   0.48   0.52  0.44    0.43
# 3      d   0.58   0.59  0.52    0.50
# 4      e   0.43   0.47  0.41    0.34
# 5      f   0.29   0.24  0.22    0.20
# 6      g   0.30   0.36  0.31    0.31
# 7      h   0.40   0.46  0.42    0.37
# 8      i   0.45   0.49  0.42    0.41
# 9      j   0.32   0.38  0.27    0.19
# 10     k   0.45   0.50  0.46    0.44
# 11     l   0.39   0.38  0.27    0.28
# 12     m   0.31   0.36  0.29    0.20
# 13     n   0.28   0.28  0.23    0.25
# 14     o   0.40   0.40  0.36    0.33

# %%
data = []
for el in pg_dict_b:
    data.append([el, pg_dict_w[el].describe().round(2).at['mean','ofa_con_sim'], pg_dict_f[el].describe().round(2).at['mean','ofa_con_sim'], pg_dict_b[el].describe().round(2).at['mean','ofa_con_sim'], pg_dict_r[el].describe().round(2).at['mean','ofa_con_sim']])

# %%
df_cap2con = pd.DataFrame(data, columns = ['Topic', 'App_1', 'App_2', 'Base', 'Random'])
df_cap2con
# Out:
#    Topic  App_1  App_2  Base  Random
# 0      a   0.34   0.31  0.27    0.25
# 1      b   0.39   0.38  0.30    0.29
# 2      c   0.42   0.41  0.33    0.32
# 3      d   0.51   0.46  0.40    0.38
# 4      e   0.46   0.38  0.29    0.30
# 5      f   0.29   0.21  0.19    0.25
# 6      g   0.25   0.24  0.20    0.14
# 7      h   0.38   0.38  0.34    0.29
# 8      i   0.33   0.29  0.26    0.25
# 9      j   0.34   0.33  0.26    0.22
# 10     k   0.29   0.29  0.26    0.25
# 11     l   0.49   0.39  0.27    0.26
# 12     m   0.37   0.34  0.26    0.18
# 13     n   0.32   0.32  0.26    0.24
# 14     o   0.36   0.32  0.22    0.22

# %%
data = []
for el in pg_dict_b:
    data.append([el, pg_dict_w[el].describe().round(2).at['mean','ofa_gt_sim'], pg_dict_f[el].describe().round(2).at['mean','ofa_gt_sim'], pg_dict_b[el].describe().round(2).at['mean','ofa_gt_sim'], pg_dict_r[el].describe().round(2).at['mean','ofa_gt_sim']])

# %%
df_cap2top = pd.DataFrame(data, columns = ['Topic', 'App_1', 'App_2', 'Base', 'Random'])
df_cap2top
# Out:
#    Topic  App_1  App_2  Base  Random
# 0      a   0.39   0.39  0.36    0.31
# 1      b   0.40   0.43  0.37    0.35
# 2      c   0.43   0.43  0.36    0.34
# 3      d   0.53   0.51  0.50    0.47
# 4      e   0.40   0.42  0.41    0.34
# 5      f   0.32   0.20  0.22    0.20
# 6      g   0.29   0.31  0.26    0.24
# 7      h   0.40   0.41  0.40    0.34
# 8      i   0.40   0.39  0.36    0.35
# 9      j   0.31   0.36  0.21    0.18
# 10     k   0.36   0.38  0.38    0.34
# 11     l   0.25   0.29  0.21    0.19
# 12     m   0.32   0.34  0.28    0.18
# 13     n   0.24   0.25  0.17    0.17
# 14     o   0.39   0.37  0.31    0.27

# %%
df_cap2cap.to_csv(f'ped_cap2cap.csv', index=False)
df_cap2con.to_csv(f'ped_cap2con.csv', index=False)
df_cap2top.to_csv(f'ped_cap2top.csv', index=False)

# %%
# df['gt_coverage'] = df.apply(lambda x: get_percentage(x.tag), axis=1)

# %%
# df['org_top_cov'] = df.apply(lambda x: simple_search(x.caption, list(topics[x.topic_id])), axis=1)
# df['ofa_top_cov'] = df.apply(lambda x: simple_search(x.ofa_caption, list(topics[x.topic_id])), axis=1)

# df['gt_ped_flag'] = df.apply(lambda x: flag_search_gt(x.tag, pedestrian_list), axis=1)
# df['org_top_sim'] = df.apply(lambda x: get_sim(x.caption, list(topics[x.topic_id])), axis=1)
# df['ofa_top_sim'] = df.apply(lambda x: get_sim(x.ofa_caption, list(topics[x.topic_id])), axis=1)

# %%
# df['ofa_con_sim'] = df.apply(lambda x: get_sim(x.ofa_caption, ['pedestrian']), axis=1)
# df['org_con_sim'] = df.apply(lambda x: get_sim(x.caption, ['pedestrian']), axis=1)
# # df['ofa_gt_sim'] = df.apply(lambda x: get_sim(x.ofa_caption, x.gt), axis=1)
# df['ofa_gt_sim'] = df.apply(lambda x: get_sim(x.ofa_caption, create_gt(x.tag)), axis=1)
# df['org_gt_sim'] = df.apply(lambda x: get_sim(x.caption, create_gt(x.tag)), axis=1)

# %%
# df['human_con_sim'] = df.apply(lambda x: get_sim(x.h_caption, ['pedestrian']), axis=1)
# df['web_ofa_sim'] = df.apply(lambda x: get_sim(x.caption, x.ofa_caption), axis=1)

# %%
# # av_groups = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'k']
# gk = df.groupby('topics')
# pg_dict = dict()

# %%
# for el in gk.groups.keys():
#     pg_dict[el] = gk.get_group(el)
#     pg_dict[el] = pg_dict[el].reset_index(drop=True)

# %%
pg_dict_b['a']
# Out:
#     uniq_id  image_id                                            caption  \
# 0       167       167               Car on rural road vector Stock Photo
# 1       184       184           Bus Only Lane Rendering Kuhio and Walina
# 2       187       187               Passenger boarding a bus on Bayshore
# 3       192       192               Passenger boarding a bus on Bayshore
# 4       209       209         Pedestrian Connections Congestion Strategy
# 5       213       213  Commercial Vehicle Accommodations Congestion S...
# 6       226       226  LA Metro Traffic Reduction Study Congestion Pr...
# 7       237       237  examples of universal design which include bus...
# 8       260       260                  Traffic and pedestrians in Mumbai
# 9       264       264  People cross crowded Mission Street as a bus w...
# 10      296       296  Philadelphias Greyhound bus depot at 10th and ...
# 11      348       348  vintage streetcars part of toronto heritage  o...
# 12      370       370  Bus stop with express train and passengers sto...
# 13      386       386  Tramway of the city of Tours Tramway of the ci...
# 14      390       390  mode of transport transport tram vehicle black...
# 15      406       406  Trolley passing from West Liberty Avenueonto B...
# 16      410       410              BusTrolley Accident  February 10 1978
# 17      411       411              BusTrolley Accident  February 10 1978
# 18      417       417         Streetcar at Belle Isle Avenue  March 1915
# 19      419       419  Two inbound 39Brookline streetcars approach Ca...
# 20      420       420  A family waits for the streetcarat the Capital...
# 21      422       422  Outbound streetcar passes Cape May  December 2015
# 22      423       423  A rendering of the proposed streetcar line the...
# 23      424       424  Overhead view of electric trolley buses lined ...
# 24      428       428  Wordart collection new orleans streetcar sign ...
# 25      443       443  A picture of the typical yellow tram in milan ...
# 26      444       444  Empty tram platforms and rails at night light ...
# 27      456       456                                   USA rail transit
# 28      460       460  Trams in Oslo Norway thread gracefully around ...
# 29      473       473                                 Sun Link Streetcar
# 30      488       488  Singapore MRT train and station platform with ...
# 31      491       491  Singapore MRT metro people train SINGAPORE  FE...
# 32      551       551  MRT Jakarta Jakarta Indonesia  March 23 2019 U...
# 33      576       576  SINGAPORE  NOVEMBER 08 2015 interior of MRT tr...
# 34      577       577                     Handle on a train in Singapore
# 35      590       590  SINGAPORE  June 162016 Electric train station ...
# 36      601       601  SINGAPORE  JULY 262022  Passengers in Singapor...
# 37      634       634  Dhoby Ghaut MRT Train Station Platform in Sing...
# 38      653       653  Singapore MRT station Passengers can be seen a...
# 39      659       659  Pedestrian Collision Warning lane departure wa...
# 40      699       699  JakartaIndonesiaJuly 21 2019  Mass Rapid Trans...
# 41      713       713  SINGAPORE SINGAPORE  Aug 12 2021 Downtown mrt ...
# 42      716       716  Interior of Singapore MRT Mass Rapid Transit s...
# 43      734       734  Singapore  feb 15 2017 passengers wating for a...
# 44      739       739  Singapore 27 jul 2019 passengers in singapore ...
# 45      758       758  Singapore Jun2020 Covid19 Side view of a green...
# 46      775       775  Singapore Smrt Apirl 2020 Safety marks inside ...
# 47      789       789     Light traffic on roads  Singapore stock photos
# 48      803       803  Public transportation subway MRT train crowded...
# 49      806       806  Singapore Train Station Interior This image of...
# 50      814       814  Singapore mass rapid train MRT approaching the...
#
#     topic_id labels                                              image  \
# 0         68         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1        112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2        112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3        112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4        112         /9j/7gAOQWRvYmUAZAAAAAAA/9sAQwAIBgYHBgUIBwcHCQ...
# 5        112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 6        112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 7        112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 8        112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 9        112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 10       112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 11        56         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 12        56         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 13        56         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 14        56         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 15        56         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 16        56         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 17        56         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 18        56         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 19        56         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 20        56         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 21        56         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 22        56         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 23        56         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 24        56         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 25        56         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 26        56         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 27        56         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 28        56         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 29        56         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 30       224         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 31       224         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 32       224         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 33       224         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 34       224         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 35       224         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 36       224         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 37       224         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 38       224         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 39       224         iVBORw0KGgoAAAANSUhEUgAAAfEAAAFLCAYAAADGY7VuAA...
# 40       224         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 41       224         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 42       224         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 43       224         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 44       224         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 45       224         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 46       224         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 47       224         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 48       224         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 49       224         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 50       224         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
#     topic2caption_sim  concept2caption_sim topics  \
# 0            0.376758             0.212455      a
# 1            0.392783             0.160691      a
# 2            0.438588             0.197647      a
# 3            0.438588             0.197647      a
# 4            0.612697             0.493012      a
# 5            0.437218             0.220831      a
# 6            0.552017             0.181466      a
# 7            0.402614             0.315510      a
# 8            0.453251             0.519047      a
# 9            0.488813             0.312950      a
# 10           0.490032             0.191725      a
# 11           0.599219             0.167485      a
# 12           0.459206             0.195962      a
# 13           0.486508             0.156008      a
# 14           0.442694             0.291304      a
# 15           0.486048             0.318498      a
# 16           0.505645             0.320038      a
# 17           0.505645             0.320038      a
# 18           0.542560             0.302231      a
# 19           0.547653             0.253008      a
# 20           0.429686             0.182163      a
# 21           0.492824             0.257326      a
# 22           0.511636             0.263072      a
# 23           0.521329             0.206901      a
# 24           0.477155             0.168028      a
# 25           0.472828             0.271828      a
# 26           0.444123             0.292730      a
# 27           0.511155             0.202173      a
# 28           0.457864             0.226363      a
# 29           0.598238             0.303680      a
# 30           0.442934             0.231995      a
# 31           0.523357             0.222019      a
# 32           0.385470             0.165095      a
# 33           0.473981             0.160476      a
# 34           0.469454             0.258299      a
# 35           0.454026             0.165585      a
# 36           0.486697             0.179424      a
# 37           0.391865             0.155772      a
# 38           0.524645             0.181719      a
# 39           0.416241             0.384463      a
# 40           0.409586             0.195721      a
# 41           0.476911             0.240933      a
# 42           0.523401             0.182884      a
# 43           0.508763             0.161176      a
# 44           0.505392             0.158921      a
# 45           0.509011             0.261559      a
# 46           0.441206             0.195333      a
# 47           0.415940             0.215742      a
# 48           0.411886             0.235932      a
# 49           0.407890             0.159461      a
# 50           0.427763             0.221336      a
#
#                                                   tag  ... ofa_top_cov  \
# 0   {'passenger': 0, 'wheel': 1, 'vehicle': 1, 'wa...  ...    0.000000
# 1   {'freight': 1, 'transportation': 1, 'traffic':...  ...    0.100000
# 2   {'freight': 1, 'transportation': 1, 'traffic':...  ...    0.100000
# 3   {'freight': 1, 'transportation': 1, 'traffic':...  ...    0.100000
# 4   {'freight': 1, 'transportation': 1, 'traffic':...  ...    0.100000
# 5   {'freight': 0, 'transportation': 1, 'traffic':...  ...    0.000000
# 6   {'freight': 1, 'transportation': 1, 'traffic':...  ...    0.100000
# 7   {'freight': 1, 'transportation': 1, 'traffic':...  ...    0.000000
# 8   {'freight': 1, 'transportation': 1, 'traffic':...  ...    0.200000
# 9   {'freight': 1, 'transportation': 1, 'traffic':...  ...    0.100000
# 10  {'freight': 1, 'transportation': 1, 'traffic':...  ...    0.100000
# 11  {'pedestrian': 1, 'tram': 1, 'transportation':...  ...    0.111111
# 12  {'pedestrian': 1, 'tram': 1, 'transportation':...  ...    0.111111
# 13  {'pedestrian': 1, 'tram': 1, 'transportation':...  ...    0.000000
# 14  {'pedestrian': 1, 'tram': 1, 'transportation':...  ...    0.111111
# 15  {'pedestrian': 0, 'tram': 0, 'transportation':...  ...    0.111111
# 16  {'pedestrian': 1, 'tram': 0, 'transportation':...  ...    0.111111
# 17  {'pedestrian': 1, 'tram': 1, 'transportation':...  ...    0.111111
# 18  {'pedestrian': 0, 'tram': 0, 'transportation':...  ...    0.111111
# 19  {'pedestrian': 1, 'tram': 0, 'transportation':...  ...    0.111111
# 20  {'pedestrian': 1, 'tram': 0, 'transportation':...  ...    0.111111
# 21  {'pedestrian': 1, 'tram': 0, 'transportation':...  ...    0.111111
# 22  {'pedestrian': 1, 'tram': 0, 'transportation':...  ...    0.111111
# 23  {'pedestrian': 1, 'tram': 0, 'transportation':...  ...    0.111111
# 24  {'pedestrian': 1, 'tram': 0, 'transportation':...  ...    0.000000
# 25  {'pedestrian': 0, 'tram': 1, 'transportation':...  ...    0.111111
# 26  {'pedestrian': 0, 'tram': 0, 'transportation':...  ...    0.111111
# 27  {'pedestrian': 1, 'tram': 0, 'transportation':...  ...    0.222222
# 28  {'pedestrian': 1, 'tram': 1, 'transportation':...  ...    0.111111
# 29  {'pedestrian': 1, 'tram': 0, 'transportation':...  ...    0.111111
# 30  {'pedestrian': 1, 'tram': 0, 'transportation':...  ...    0.000000
# 31  {'pedestrian': 1, 'tram': 0, 'transportation':...  ...    0.100000
# 32  {'pedestrian': 1, 'tram': 0, 'transportation':...  ...    0.000000
# 33  {'pedestrian': 0, 'tram': 0, 'transportation':...  ...    0.000000
# 34  {'pedestrian': 1, 'tram': 0, 'transportation':...  ...    0.000000
# 35  {'pedestrian': 1, 'tram': 0, 'transportation':...  ...    0.000000
# 36  {'pedestrian': 1, 'tram': 0, 'transportation':...  ...    0.000000
# 37  {'pedestrian': 1, 'tram': 0, 'transportation':...  ...    0.000000
# 38  {'tram': 0, 'goahead': 0, 'fleet': 0, 'smrt': ...  ...    0.000000
# 39  {'tram': 0, 'goahead': 0, 'fleet': 0, 'smrt': ...  ...    0.000000
# 40  {'tram': 0, 'goahead': 0, 'fleet': 0, 'smrt': ...  ...    0.000000
# 41  {'tram': 0, 'goahead': 0, 'fleet': 0, 'smrt': ...  ...    0.000000
# 42  {'tram': 0, 'goahead': 0, 'fleet': 0, 'smrt': ...  ...    0.000000
# 43  {'tram': 0, 'goahead': 0, 'fleet': 0, 'smrt': ...  ...    0.100000
# 44  {'tram': 0, 'goahead': 0, 'fleet': 0, 'smrt': ...  ...    0.000000
# 45  {'tram': 0, 'goahead': 0, 'fleet': 0, 'smrt': ...  ...    0.100000
# 46  {'tram': 0, 'goahead': 0, 'fleet': 0, 'smrt': ...  ...    0.000000
# 47  {'tram': 0, 'goahead': 0, 'fleet': 0, 'smrt': ...  ...    0.000000
# 48  {'tram': 0, 'goahead': 0, 'fleet': 0, 'smrt': ...  ...    0.000000
# 49  {'tram': 0, 'goahead': 0, 'fleet': 0, 'smrt': ...  ...    0.000000
# 50  {'tram': 0, 'goahead': 0, 'fleet': 0, 'smrt': ...  ...    0.000000
#
#    gt_ped_flag org_top_sim  ofa_top_sim  ofa_con_sim  org_con_sim  ofa_gt_sim  \
# 0          0.0    0.347474     0.174121     0.291389     0.212455    0.339229
# 1          1.0    0.369608     0.367089     0.306415     0.160691    0.465906
# 2          1.0    0.406568     0.447455     0.315319     0.197647    0.544593
# 3          1.0    0.406568     0.447455     0.315319     0.197647    0.544593
# 4          1.0    0.642390     0.346680     0.267630     0.493012    0.370596
# 5          0.0    0.467462     0.252557     0.148062     0.220831    0.254973
# 6          0.0    0.571539     0.371986     0.227163     0.181466    0.375075
# 7          1.0    0.382267     0.302053     0.224148     0.311081    0.320912
# 8          1.0    0.489579     0.445729     0.357262     0.519047    0.436709
# 9          1.0    0.493534     0.381377     0.384256     0.312950    0.370342
# 10         0.0    0.398902     0.314796     0.199376     0.163017    0.367778
# 11         1.0    0.613389     0.376379     0.268347     0.156882    0.305378
# 12         1.0    0.435664     0.407954     0.260474     0.195962    0.434075
# 13         1.0    0.547422     0.253705     0.339330     0.182111    0.203868
# 14         1.0    0.559996     0.505141     0.294234     0.263509    0.309316
# 15         0.0    0.551389     0.438164     0.325269     0.353457    0.392869
# 16         1.0    0.096184     0.379214     0.239307     0.194550    0.444713
# 17         1.0    0.096184     0.287952     0.187316     0.194550    0.291797
# 18         0.0    0.540340     0.372183     0.239868     0.297411    0.339776
# 19         1.0    0.613357     0.442149     0.368564     0.267216    0.433623
# 20         1.0    0.493510     0.308014     0.266145     0.235185    0.292440
# 21         1.0    0.491909     0.409963     0.302273     0.253275    0.398617
# 22         1.0    0.582708     0.383214     0.248205     0.260112    0.400529
# 23         1.0    0.550039     0.411579     0.223339     0.215776    0.527742
# 24         1.0    0.490782     0.256302     0.395425     0.168028    0.317709
# 25         0.0    0.504859     0.484908     0.301970     0.284333    0.303432
# 26         0.0    0.517787     0.330134     0.212782     0.271022    0.544850
# 27         1.0    0.526971     0.485396     0.226918     0.202173    0.642400
# 28         1.0    0.429297     0.342903     0.249683     0.135755    0.417392
# 29         1.0    0.619889     0.235811     0.009743     0.303680    0.187124
# 30         1.0    0.492750     0.225911     0.282016     0.231491    0.600354
# 31         1.0    0.566378     0.274319     0.204991     0.191097    0.350837
# 32         1.0    0.400133     0.150747     0.285311     0.173363    0.394117
# 33         0.0    0.520022     0.294140     0.258004     0.143269    0.689591
# 34         1.0    0.497571     0.255446     0.245454     0.214440    0.647152
# 35         1.0    0.465765     0.229600     0.292566     0.134997    0.575892
# 36         1.0    0.561991     0.241821     0.228578     0.223711    0.552585
# 37         1.0    0.390699     0.074823     0.289717     0.147229    0.264585
# 38         1.0    0.539244     0.261942     0.298944     0.189156    0.235992
# 39         1.0    0.397051     0.035427     0.209688     0.384463    0.212290
# 40         0.0    0.450239     0.200159     0.186385     0.214059    0.164913
# 41         0.0    0.533040     0.204602     0.389580     0.203686    0.138409
# 42         0.0    0.547822     0.119421     0.263942     0.142853    0.040226
# 43         1.0    0.553910     0.274319     0.204991     0.174687    0.242310
# 44         1.0    0.559445     0.238640     0.223930     0.172519    0.220903
# 45         1.0    0.523244     0.373191     0.304837     0.246581    0.424430
# 46         1.0    0.457620     0.241186     0.269991     0.186961    0.232683
# 47         1.0    0.415324     0.152766     0.333607     0.178268    0.218462
# 48         1.0    0.470777     0.238640     0.223930     0.230677    0.220903
# 49         1.0    0.419733     0.147570     0.244174     0.143472    0.102321
# 50         1.0    0.455701     0.182981     0.299641     0.226565    0.200556
#
#     org_gt_sim  human_con_sim  web_ofa_sim
# 0     0.406319       0.269255     0.505929
# 1     0.398409       0.299443     0.405279
# 2     0.446380       0.270336     0.465499
# 3     0.446380       0.270336     0.465499
# 4     0.635256       0.593294     0.172662
# 5     0.339962       0.359241     0.322450
# 6     0.567769       0.312877     0.404182
# 7     0.375126       0.317293     0.278122
# 8     0.512142       0.501388     0.524769
# 9     0.506553       0.524679     0.672055
# 10    0.504554       0.372283     0.481727
# 11    0.581695       0.323603     0.240375
# 12    0.430084       0.280603     0.580031
# 13    0.515901       0.201482     0.490784
# 14    0.651432       0.425090     0.462689
# 15    0.631521       0.423873     0.478213
# 16    0.165544       0.443639     0.091100
# 17    0.125770       0.443639     0.107429
# 18    0.624719       0.377898     0.278022
# 19    0.692986       0.227139     0.365002
# 20    0.339838       0.446704     0.399699
# 21    0.611958       0.444147     0.220635
# 22    0.603152       0.292667     0.348569
# 23    0.586638       0.244487     0.476387
# 24    0.544615       0.240155     0.442761
# 25    0.549084       0.456465     0.395600
# 26    0.400518       0.257337     0.335442
# 27    0.617105       0.329901     0.441369
# 28    0.426743       0.342658     0.320197
# 29    0.444953       0.359527     0.114902
# 30    0.457970       0.368736     0.541986
# 31    0.484920       0.246695     0.285668
# 32    0.335121       0.270256     0.255446
# 33    0.440712       0.275432     0.295915
# 34    0.416337       0.281671     0.350672
# 35    0.351381       0.377498     0.297207
# 36    0.470685       0.318278     0.355107
# 37    0.335013       0.333583     0.029910
# 38    0.535412       0.203173     0.312047
# 39    0.477145       0.398695     0.178196
# 40    0.451528       0.207121     0.248533
# 41    0.549229       0.241158     0.446032
# 42    0.648920       0.241158     0.148057
# 43    0.575153       0.203173     0.246079
# 44    0.580631       0.318278     0.348034
# 45    0.683489       0.230400     0.436035
# 46    0.539649       0.318278     0.315837
# 47    0.466835       0.379001     0.410040
# 48    0.508127       0.318278     0.408562
# 49    0.463619       0.213878     0.012911
# 50    0.479274       0.288380     0.382243
#
# [51 rows x 25 columns]

# %%
pg_dict_b['a'].describe().round(2)
# Out:
#        uniq_id  image_id  topic_id  topic2caption_sim  concept2caption_sim  \
# count    51.00     51.00     51.00              51.00                51.00
# mean    481.39    481.39    136.39               0.47                 0.24
# std     192.26    192.26     76.76               0.06                 0.08
# min     167.00    167.00     56.00               0.38                 0.16
# 25%     378.00    378.00     56.00               0.44                 0.18
# 50%     443.00    443.00    112.00               0.47                 0.22
# 75%     643.50    643.50    224.00               0.51                 0.27
# max     814.00    814.00    224.00               0.61                 0.52
#
#        gt_coverage  org_top_cov  ofa_top_cov  gt_ped_flag  org_top_sim  \
# count        51.00        51.00        51.00        51.00        51.00
# mean          0.53         0.06         0.06         0.76         0.48
# std           0.20         0.07         0.06         0.43         0.11
# min           0.20         0.00         0.00         0.00         0.10
# 25%           0.40         0.00         0.00         1.00         0.42
# 50%           0.50         0.00         0.10         1.00         0.49
# 75%           0.56         0.11         0.11         1.00         0.55
# max           1.00         0.22         0.22         1.00         0.64
#
#        ofa_top_sim  ofa_con_sim  org_con_sim  ofa_gt_sim  org_gt_sim  \
# count        51.00        51.00        51.00       51.00       51.00
# mean          0.30         0.27         0.23        0.36        0.49
# std           0.11         0.07         0.08        0.15        0.12
# min           0.04         0.01         0.13        0.04        0.13
# 25%           0.24         0.23         0.18        0.24        0.43
# 50%           0.29         0.27         0.20        0.35        0.48
# 75%           0.38         0.30         0.26        0.44        0.58
# max           0.51         0.40         0.52        0.69        0.69
#
#        human_con_sim  web_ofa_sim
# count          51.00        51.00
# mean            0.33         0.34
# std             0.09         0.14
# min             0.20         0.01
# 25%             0.26         0.27
# 50%             0.32         0.35
# 75%             0.38         0.44
# max             0.59         0.67

# %%
# Test
df_b[['gt_coverage', 'gt_ped_flag', 'org_gt_sim']].describe().round(2)
# Out:
#        gt_coverage  gt_ped_flag  org_gt_sim
# count       620.00       620.00      620.00
# mean          0.49         0.65        0.50
# std           0.23         0.48        0.14
# min           0.09         0.00        0.07
# 25%           0.33         0.00        0.41
# 50%           0.45         1.00        0.52
# 75%           0.62         1.00        0.60
# max           1.00         1.00        0.88

# %%
# Test
for el in pg_dict_b:
    print(el)
    display(pg_dict_b[el][['gt_coverage', 'gt_ped_flag', 'org_gt_sim']].describe().round(2))
# Out:
# a
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        51.00        51.00       51.00
# mean          0.53         0.76        0.49
# std           0.20         0.43        0.12
# min           0.20         0.00        0.13
# 25%           0.40         1.00        0.43
# 50%           0.50         1.00        0.48
# 75%           0.56         1.00        0.58
# max           1.00         1.00        0.69
# b
#        gt_coverage  gt_ped_flag  org_gt_sim
# count       103.00       103.00      103.00
# mean          0.40         0.82        0.49
# std           0.16         0.39        0.12
# min           0.10         0.00        0.14
# 25%           0.30         1.00        0.41
# 50%           0.40         1.00        0.51
# 75%           0.50         1.00        0.58
# max           0.70         1.00        0.77
# c
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        57.00        57.00       57.00
# mean          0.43         0.63        0.49
# std           0.18         0.49        0.09
# min           0.11         0.00        0.25
# 25%           0.29         0.00        0.44
# 50%           0.44         1.00        0.49
# 75%           0.56         1.00        0.55
# max           0.78         1.00        0.65
# d
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        62.00        62.00       62.00
# mean          0.45         0.16        0.59
# std           0.13         0.37        0.11
# min           0.10         0.00        0.29
# 25%           0.40         0.00        0.55
# 50%           0.41         0.00        0.61
# 75%           0.50         0.00        0.66
# max           0.71         1.00        0.77
# e
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        46.00        46.00       46.00
# mean          0.50         0.59        0.54
# std           0.24         0.50        0.13
# min           0.09         0.00        0.33
# 25%           0.36         0.00        0.45
# 50%           0.45         1.00        0.55
# 75%           0.60         1.00        0.61
# max           1.00         1.00        0.83
# f
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        16.00        16.00       16.00
# mean          0.67         0.62        0.50
# std           0.33         0.50        0.11
# min           0.12         0.00        0.30
# 25%           0.38         0.00        0.46
# 50%           0.72         1.00        0.50
# 75%           1.00         1.00        0.57
# max           1.00         1.00        0.65
# g
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        25.00        25.00       25.00
# mean          0.24         0.56        0.45
# std           0.11         0.51        0.17
# min           0.10         0.00        0.13
# 25%           0.20         0.00        0.38
# 50%           0.20         1.00        0.50
# 75%           0.30         1.00        0.59
# max           0.56         1.00        0.69
# h
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        28.00         28.0       28.00
# mean          0.27          1.0        0.49
# std           0.12          0.0        0.12
# min           0.20          1.0        0.25
# 25%           0.20          1.0        0.42
# 50%           0.20          1.0        0.46
# 75%           0.30          1.0        0.55
# max           0.70          1.0        0.74
# i
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        70.00        70.00       70.00
# mean          0.58         0.67        0.54
# std           0.23         0.47        0.16
# min           0.12         0.00        0.17
# 25%           0.38         0.00        0.42
# 50%           0.55         1.00        0.61
# 75%           0.86         1.00        0.65
# max           1.00         1.00        0.78
# j
#        gt_coverage  gt_ped_flag  org_gt_sim
# count         7.00         7.00        7.00
# mean          0.93         0.43        0.66
# std           0.07         0.53        0.07
# min           0.88         0.00        0.56
# 25%           0.88         0.00        0.62
# 50%           0.88         0.00        0.66
# 75%           1.00         1.00        0.69
# max           1.00         1.00        0.79
# k
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        41.00        41.00       41.00
# mean          0.83         0.98        0.50
# std           0.12         0.16        0.12
# min           0.44         0.00        0.11
# 25%           0.78         1.00        0.43
# 50%           0.78         1.00        0.52
# 75%           0.89         1.00        0.58
# max           1.00         1.00        0.77
# l
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        11.00        11.00       11.00
# mean          0.44         0.64        0.34
# std           0.27         0.50        0.14
# min           0.10         0.00        0.18
# 25%           0.20         0.00        0.26
# 50%           0.50         1.00        0.28
# 75%           0.60         1.00        0.39
# max           0.80         1.00        0.68
# m
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        25.00        25.00       25.00
# mean          0.63         0.68        0.50
# std           0.18         0.48        0.12
# min           0.11         0.00        0.19
# 25%           0.60         0.00        0.46
# 50%           0.62         1.00        0.52
# 75%           0.75         1.00        0.56
# max           0.88         1.00        0.74
# n
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        29.00        29.00       29.00
# mean          0.34         0.66        0.26
# std           0.24         0.48        0.13
# min           0.11         0.00        0.07
# 25%           0.11         0.00        0.13
# 50%           0.30         1.00        0.24
# 75%           0.57         1.00        0.40
# max           0.71         1.00        0.49
# o
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        49.00        49.00       49.00
# mean          0.54         0.51        0.51
# std           0.15         0.51        0.14
# min           0.12         0.00        0.24
# 25%           0.50         0.00        0.42
# 50%           0.50         1.00        0.51
# 75%           0.62         1.00        0.59
# max           0.88         1.00        0.88

# %% [markdown]
# # Random

# %%
df[['gt_ped_flag', 'gt_coverage', 'org_top_sim', 'ofa_top_sim', 'ofa_gt_sim', 'ofa_con_sim', 'web_ofa_sim']].describe().round(2)
# Out:
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count       620.00       620.00       620.00       620.00      620.00
# mean          0.65         0.49         0.46         0.26        0.32
# std           0.48         0.23         0.13         0.16        0.18
# min           0.00         0.09         0.08        -0.09       -0.10
# 25%           0.00         0.33         0.39         0.15        0.18
# 50%           1.00         0.45         0.47         0.25        0.33
# 75%           1.00         0.62         0.55         0.38        0.45
# max           1.00         1.00         0.86         0.74        0.84
#
#        ofa_con_sim  web_ofa_sim
# count       620.00       620.00
# mean          0.27         0.37
# std           0.12         0.19
# min          -0.06        -0.08
# 25%           0.20         0.23
# 50%           0.27         0.37
# 75%           0.34         0.50
# max           0.68         0.87

# %%
# random
for el in pg_dict:
    print(el)
    display(pg_dict[el][['gt_ped_flag', 'gt_coverage', 'org_top_sim', 'ofa_top_sim', 'ofa_gt_sim', 'ofa_con_sim', 'web_ofa_sim']].describe().round(2))
# Out:
# a
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        51.00        51.00        51.00        51.00       51.00
# mean          0.76         0.53         0.48         0.28        0.31
# std           0.43         0.20         0.10         0.13        0.15
# min           0.00         0.20         0.09        -0.05        0.07
# 25%           1.00         0.40         0.44         0.19        0.18
# 50%           1.00         0.50         0.49         0.28        0.31
# 75%           1.00         0.56         0.54         0.37        0.42
# max           1.00         1.00         0.61         0.62        0.61
#
#        ofa_con_sim  web_ofa_sim
# count        51.00        51.00
# mean          0.25         0.31
# std           0.08         0.13
# min           0.07         0.07
# 25%           0.20         0.21
# 50%           0.23         0.29
# 75%           0.28         0.40
# max           0.52         0.58
# b
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count       103.00       103.00       103.00       103.00      103.00
# mean          0.82         0.40         0.41         0.24        0.35
# std           0.39         0.16         0.11         0.10        0.13
# min           0.00         0.10         0.08         0.02        0.08
# 25%           1.00         0.30         0.33         0.18        0.24
# 50%           1.00         0.40         0.40         0.22        0.35
# 75%           1.00         0.50         0.49         0.30        0.45
# max           1.00         0.70         0.69         0.49        0.66
#
#        ofa_con_sim  web_ofa_sim
# count       103.00       103.00
# mean          0.29         0.40
# std           0.10         0.15
# min           0.09         0.02
# 25%           0.22         0.29
# 50%           0.29         0.41
# 75%           0.35         0.50
# max           0.68         0.75
# c
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        57.00        57.00        57.00        57.00       57.00
# mean          0.63         0.43         0.43         0.28        0.34
# std           0.49         0.18         0.06         0.11        0.14
# min           0.00         0.11         0.31         0.01        0.03
# 25%           0.00         0.29         0.39         0.22        0.24
# 50%           1.00         0.44         0.42         0.27        0.36
# 75%           1.00         0.56         0.47         0.35        0.43
# max           1.00         0.78         0.58         0.51        0.61
#
#        ofa_con_sim  web_ofa_sim
# count        57.00        57.00
# mean          0.32         0.43
# std           0.12         0.17
# min           0.06         0.01
# 25%           0.26         0.33
# 50%           0.32         0.43
# 75%           0.37         0.54
# max           0.61         0.86
# d
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        62.00        62.00        62.00        62.00       62.00
# mean          0.16         0.45         0.63         0.45        0.47
# std           0.37         0.13         0.10         0.21        0.20
# min           0.00         0.10         0.37        -0.05       -0.06
# 25%           0.00         0.40         0.61         0.31        0.30
# 50%           0.00         0.41         0.64         0.50        0.55
# 75%           0.00         0.50         0.68         0.62        0.61
# max           1.00         0.71         0.86         0.74        0.84
#
#        ofa_con_sim  web_ofa_sim
# count        62.00        62.00
# mean          0.38         0.50
# std           0.14         0.19
# min           0.06         0.07
# 25%           0.28         0.37
# 50%           0.36         0.49
# 75%           0.48         0.63
# max           0.62         0.87
# e
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        46.00        46.00        46.00        46.00       46.00
# mean          0.59         0.50         0.53         0.27        0.34
# std           0.50         0.24         0.09         0.14        0.15
# min           0.00         0.09         0.36        -0.05        0.03
# 25%           0.00         0.36         0.46         0.16        0.24
# 50%           1.00         0.45         0.52         0.30        0.38
# 75%           1.00         0.60         0.58         0.38        0.45
# max           1.00         1.00         0.80         0.56        0.55
#
#        ofa_con_sim  web_ofa_sim
# count        46.00        46.00
# mean          0.30         0.34
# std           0.09         0.13
# min           0.12         0.12
# 25%           0.25         0.23
# 50%           0.32         0.34
# 75%           0.33         0.45
# max           0.56         0.66
# f
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        16.00        16.00        16.00        16.00       16.00
# mean          0.62         0.67         0.49         0.18        0.20
# std           0.50         0.33         0.09         0.20        0.17
# min           0.00         0.12         0.31        -0.09       -0.10
# 25%           0.00         0.38         0.45         0.02        0.10
# 50%           1.00         0.72         0.51         0.16        0.15
# 75%           1.00         1.00         0.55         0.29        0.31
# max           1.00         1.00         0.62         0.49        0.49
#
#        ofa_con_sim  web_ofa_sim
# count        16.00        16.00
# mean          0.25         0.20
# std           0.09         0.20
# min           0.05        -0.04
# 25%           0.23         0.03
# 50%           0.28         0.22
# 75%           0.30         0.29
# max           0.37         0.72
# g
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        25.00        25.00        25.00        25.00       25.00
# mean          0.56         0.24         0.36         0.20        0.24
# std           0.51         0.11         0.17         0.14        0.17
# min           0.00         0.10         0.11        -0.02       -0.04
# 25%           0.00         0.20         0.16         0.12        0.11
# 50%           1.00         0.20         0.42         0.17        0.19
# 75%           1.00         0.30         0.47         0.30        0.37
# max           1.00         0.56         0.60         0.45        0.54
#
#        ofa_con_sim  web_ofa_sim
# count        25.00        25.00
# mean          0.14         0.31
# std           0.11         0.17
# min          -0.06         0.06
# 25%           0.07         0.19
# 50%           0.12         0.34
# 75%           0.19         0.46
# max           0.40         0.61
# h
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count         28.0        28.00        28.00        28.00       28.00
# mean           1.0         0.27         0.40         0.23        0.34
# std            0.0         0.12         0.07         0.12        0.13
# min            1.0         0.20         0.29         0.04        0.12
# 25%            1.0         0.20         0.35         0.16        0.25
# 50%            1.0         0.20         0.40         0.20        0.31
# 75%            1.0         0.30         0.44         0.29        0.42
# max            1.0         0.70         0.54         0.47        0.60
#
#        ofa_con_sim  web_ofa_sim
# count        28.00        28.00
# mean          0.29         0.37
# std           0.08         0.15
# min           0.14         0.06
# 25%           0.26         0.25
# 50%           0.28         0.41
# 75%           0.35         0.47
# max           0.44         0.68
# i
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        70.00        70.00        70.00        70.00       70.00
# mean          0.67         0.58         0.48         0.28        0.35
# std           0.47         0.23         0.12         0.16        0.22
# min           0.00         0.12         0.19        -0.08       -0.06
# 25%           0.00         0.38         0.45         0.13        0.15
# 50%           1.00         0.55         0.49         0.34        0.39
# 75%           1.00         0.86         0.55         0.39        0.58
# max           1.00         1.00         0.74         0.58        0.65
#
#        ofa_con_sim  web_ofa_sim
# count        70.00        70.00
# mean          0.25         0.41
# std           0.11         0.20
# min           0.05         0.03
# 25%           0.16         0.24
# 50%           0.27         0.46
# 75%           0.34         0.58
# max           0.43         0.75
# j
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count         7.00         7.00         7.00         7.00        7.00
# mean          0.43         0.93         0.69         0.19        0.18
# std           0.53         0.07         0.08         0.13        0.14
# min           0.00         0.88         0.61         0.02        0.00
# 25%           0.00         0.88         0.64         0.08        0.06
# 50%           0.00         0.88         0.67         0.24        0.18
# 75%           1.00         1.00         0.74         0.27        0.29
# max           1.00         1.00         0.80         0.36        0.35
#
#        ofa_con_sim  web_ofa_sim
# count         7.00         7.00
# mean          0.22         0.19
# std           0.09         0.11
# min           0.10         0.05
# 25%           0.15         0.10
# 50%           0.22         0.22
# 75%           0.28         0.27
# max           0.33         0.34
# k
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        41.00        41.00        41.00        41.00       41.00
# mean          0.98         0.83         0.51         0.35        0.34
# std           0.16         0.12         0.07         0.17        0.18
# min           0.00         0.44         0.29         0.00       -0.03
# 25%           1.00         0.78         0.49         0.30        0.25
# 50%           1.00         0.78         0.51         0.39        0.37
# 75%           1.00         0.89         0.54         0.52        0.49
# max           1.00         1.00         0.68         0.57        0.66
#
#        ofa_con_sim  web_ofa_sim
# count        41.00        41.00
# mean          0.25         0.44
# std           0.06         0.17
# min           0.14         0.10
# 25%           0.21         0.35
# 50%           0.25         0.46
# 75%           0.28         0.54
# max           0.43         0.84
# l
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        11.00        11.00        11.00        11.00       11.00
# mean          0.64         0.44         0.31         0.11        0.19
# std           0.50         0.27         0.12         0.09        0.12
# min           0.00         0.10         0.12        -0.03        0.04
# 25%           0.00         0.20         0.24         0.05        0.13
# 50%           1.00         0.50         0.28         0.12        0.15
# 75%           1.00         0.60         0.37         0.16        0.20
# max           1.00         0.80         0.51         0.26        0.44
#
#        ofa_con_sim  web_ofa_sim
# count        11.00        11.00
# mean          0.26         0.28
# std           0.13         0.18
# min           0.03         0.00
# 25%           0.19         0.17
# 50%           0.27         0.27
# 75%           0.35         0.37
# max           0.44         0.65
# m
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        25.00        25.00        25.00        25.00       25.00
# mean          0.68         0.63         0.46         0.16        0.18
# std           0.48         0.18         0.08         0.11        0.14
# min           0.00         0.11         0.26        -0.08       -0.06
# 25%           0.00         0.60         0.42         0.10        0.08
# 50%           1.00         0.62         0.47         0.17        0.16
# 75%           1.00         0.75         0.50         0.25        0.32
# max           1.00         0.88         0.62         0.29        0.46
#
#        ofa_con_sim  web_ofa_sim
# count        25.00        25.00
# mean          0.18         0.20
# std           0.09         0.13
# min           0.06        -0.03
# 25%           0.10         0.14
# 50%           0.16         0.20
# 75%           0.23         0.25
# max           0.42         0.50
# n
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        29.00        29.00        29.00        29.00       29.00
# mean          0.66         0.34         0.27         0.12        0.17
# std           0.48         0.24         0.06         0.10        0.14
# min           0.00         0.11         0.17        -0.03       -0.09
# 25%           0.00         0.11         0.23         0.03        0.06
# 50%           1.00         0.30         0.27         0.10        0.15
# 75%           1.00         0.57         0.30         0.19        0.32
# max           1.00         0.71         0.45         0.36        0.42
#
#        ofa_con_sim  web_ofa_sim
# count        29.00        29.00
# mean          0.24         0.25
# std           0.14         0.17
# min          -0.03        -0.01
# 25%           0.15         0.10
# 50%           0.23         0.21
# 75%           0.33         0.33
# max           0.58         0.65
# o
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        49.00        49.00        49.00        49.00       49.00
# mean          0.51         0.54         0.48         0.20        0.27
# std           0.51         0.15         0.11         0.14        0.17
# min           0.00         0.12         0.27        -0.07       -0.05
# 25%           0.00         0.50         0.40         0.11        0.13
# 50%           1.00         0.50         0.48         0.18        0.25
# 75%           1.00         0.62         0.55         0.31        0.40
# max           1.00         0.88         0.80         0.44        0.65
#
#        ofa_con_sim  web_ofa_sim
# count        49.00        49.00
# mean          0.22         0.33
# std           0.10         0.21
# min           0.03        -0.08
# 25%           0.14         0.17
# 50%           0.21         0.29
# 75%           0.27         0.44
# max           0.58         0.80

# %%
for el in pg_dict:
    print(el)
    print(f"{pg_dict[el].describe().round(2).at['mean','web_ofa_sim']}")
    print()
# Out:
# a
# 0.31
#
# b
# 0.4
#
# c
# 0.43
#
# d
# 0.5
#
# e
# 0.34
#
# f
# 0.2
#
# g
# 0.31
#
# h
# 0.37
#
# i
# 0.41
#
# j
# 0.19
#
# k
# 0.44
#
# l
# 0.28
#
# m
# 0.2
#
# n
# 0.25
#
# o
# 0.33

# %%
for el in pg_dict:
    print(el)
    print(f"{pg_dict[el].describe().round(2).at['mean','ofa_con_sim']}")
    print()
# Out:
# a
# 0.25
#
# b
# 0.29
#
# c
# 0.32
#
# d
# 0.38
#
# e
# 0.3
#
# f
# 0.25
#
# g
# 0.14
#
# h
# 0.29
#
# i
# 0.25
#
# j
# 0.22
#
# k
# 0.25
#
# l
# 0.26
#
# m
# 0.18
#
# n
# 0.24
#
# o
# 0.22

# %%
for el in pg_dict:
    print(el)
    print(f"{pg_dict[el].describe().round(2).at['mean','ofa_gt_sim']}")
    print()
# Out:
# a
# 0.31
#
# b
# 0.35
#
# c
# 0.34
#
# d
# 0.47
#
# e
# 0.34
#
# f
# 0.2
#
# g
# 0.24
#
# h
# 0.34
#
# i
# 0.35
#
# j
# 0.18
#
# k
# 0.34
#
# l
# 0.19
#
# m
# 0.18
#
# n
# 0.17
#
# o
# 0.27

# %% [markdown]
# # base

# %% [markdown]
# ### keep all

# %%
df[['gt_ped_flag', 'gt_coverage', 'org_top_sim', 'ofa_top_sim', 'ofa_gt_sim', 'ofa_con_sim', 'web_ofa_sim']].describe().round(2)
# Out:
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count       620.00       620.00       620.00       620.00      620.00
# mean          0.65         0.49         0.46         0.29        0.35
# std           0.48         0.23         0.13         0.15        0.18
# min           0.00         0.09         0.08        -0.12       -0.08
# 25%           0.00         0.33         0.39         0.18        0.22
# 50%           1.00         0.45         0.47         0.28        0.36
# 75%           1.00         0.62         0.55         0.40        0.48
# max           1.00         1.00         0.86         0.75        0.79
#
#        ofa_con_sim  web_ofa_sim
# count       620.00       620.00
# mean          0.29         0.40
# std           0.11         0.18
# min          -0.04        -0.06
# 25%           0.21         0.27
# 50%           0.28         0.39
# 75%           0.36         0.53
# max           0.63         0.85

# %%
# before
for el in pg_dict:
    print(el)
    display(pg_dict[el][['gt_ped_flag', 'gt_coverage', 'org_top_sim', 'ofa_top_sim', 'ofa_gt_sim', 'ofa_con_sim', 'web_ofa_sim']].describe().round(2))
# Out:
# a
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        51.00        51.00        51.00        51.00       51.00
# mean          0.76         0.53         0.48         0.30        0.36
# std           0.43         0.20         0.10         0.13        0.15
# min           0.00         0.20         0.09         0.04        0.04
# 25%           1.00         0.40         0.44         0.21        0.24
# 50%           1.00         0.50         0.49         0.31        0.35
# 75%           1.00         0.56         0.54         0.41        0.44
# max           1.00         1.00         0.61         0.52        0.69
#
#        ofa_con_sim  web_ofa_sim
# count        51.00        51.00
# mean          0.27         0.34
# std           0.07         0.14
# min           0.01         0.01
# 25%           0.23         0.27
# 50%           0.27         0.35
# 75%           0.30         0.44
# max           0.40         0.67
# b
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count       103.00       103.00       103.00       103.00      103.00
# mean          0.82         0.40         0.41         0.25        0.37
# std           0.39         0.16         0.11         0.11        0.15
# min           0.00         0.10         0.08        -0.06        0.02
# 25%           1.00         0.30         0.33         0.18        0.26
# 50%           1.00         0.40         0.40         0.26        0.37
# 75%           1.00         0.50         0.49         0.33        0.46
# max           1.00         0.70         0.69         0.54        0.76
#
#        ofa_con_sim  web_ofa_sim
# count       103.00       103.00
# mean          0.30         0.42
# std           0.09         0.16
# min           0.07         0.07
# 25%           0.24         0.32
# 50%           0.30         0.42
# 75%           0.37         0.52
# max           0.61         0.84
# c
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        57.00        57.00        57.00        57.00       57.00
# mean          0.63         0.43         0.43         0.29        0.36
# std           0.49         0.18         0.06         0.10        0.12
# min           0.00         0.11         0.31         0.08        0.06
# 25%           0.00         0.29         0.39         0.24        0.31
# 50%           1.00         0.44         0.42         0.30        0.37
# 75%           1.00         0.56         0.47         0.36        0.43
# max           1.00         0.78         0.58         0.49        0.66
#
#        ofa_con_sim  web_ofa_sim
# count        57.00        57.00
# mean          0.33         0.44
# std           0.11         0.18
# min           0.06         0.05
# 25%           0.27         0.33
# 50%           0.32         0.45
# 75%           0.39         0.53
# max           0.63         0.85
# d
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        62.00        62.00        62.00        62.00       62.00
# mean          0.16         0.45         0.63         0.48        0.50
# std           0.37         0.13         0.10         0.16        0.17
# min           0.00         0.10         0.37         0.09        0.09
# 25%           0.00         0.40         0.61         0.36        0.36
# 50%           0.00         0.41         0.64         0.51        0.55
# 75%           0.00         0.50         0.68         0.61        0.61
# max           1.00         0.71         0.86         0.75        0.78
#
#        ofa_con_sim  web_ofa_sim
# count        62.00        62.00
# mean          0.40         0.52
# std           0.10         0.15
# min           0.18         0.15
# 25%           0.33         0.44
# 50%           0.39         0.53
# 75%           0.45         0.61
# max           0.63         0.82
# e
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        46.00        46.00        46.00        46.00       46.00
# mean          0.59         0.50         0.53         0.35        0.41
# std           0.50         0.24         0.09         0.12        0.12
# min           0.00         0.09         0.36        -0.01        0.03
# 25%           0.00         0.36         0.46         0.29        0.34
# 50%           1.00         0.45         0.52         0.38        0.43
# 75%           1.00         0.60         0.58         0.44        0.50
# max           1.00         1.00         0.80         0.58        0.60
#
#        ofa_con_sim  web_ofa_sim
# count        46.00        46.00
# mean          0.29         0.41
# std           0.09         0.13
# min           0.08         0.15
# 25%           0.23         0.28
# 50%           0.30         0.42
# 75%           0.33         0.52
# max           0.48         0.64
# f
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        16.00        16.00        16.00        16.00       16.00
# mean          0.62         0.67         0.49         0.22        0.22
# std           0.50         0.33         0.09         0.13        0.14
# min           0.00         0.12         0.31         0.04        0.05
# 25%           0.00         0.38         0.45         0.12        0.11
# 50%           1.00         0.72         0.51         0.20        0.21
# 75%           1.00         1.00         0.55         0.28        0.26
# max           1.00         1.00         0.62         0.46        0.47
#
#        ofa_con_sim  web_ofa_sim
# count        16.00        16.00
# mean          0.19         0.22
# std           0.08         0.13
# min           0.04        -0.06
# 25%           0.16         0.15
# 50%           0.18         0.25
# 75%           0.26         0.28
# max           0.31         0.46
# g
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        25.00        25.00        25.00        25.00       25.00
# mean          0.56         0.24         0.36         0.21        0.26
# std           0.51         0.11         0.17         0.15        0.18
# min           0.00         0.10         0.11         0.03       -0.02
# 25%           0.00         0.20         0.16         0.11        0.14
# 50%           1.00         0.20         0.42         0.17        0.25
# 75%           1.00         0.30         0.47         0.28        0.34
# max           1.00         0.56         0.60         0.61        0.73
#
#        ofa_con_sim  web_ofa_sim
# count        25.00        25.00
# mean          0.20         0.31
# std           0.12         0.18
# min          -0.04         0.05
# 25%           0.11         0.19
# 50%           0.21         0.29
# 75%           0.25         0.42
# max           0.53         0.74
# h
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count         28.0        28.00        28.00        28.00       28.00
# mean           1.0         0.27         0.40         0.23        0.40
# std            0.0         0.12         0.07         0.11        0.15
# min            1.0         0.20         0.29         0.11        0.11
# 25%            1.0         0.20         0.35         0.14        0.26
# 50%            1.0         0.20         0.40         0.21        0.40
# 75%            1.0         0.30         0.44         0.30        0.51
# max            1.0         0.70         0.54         0.45        0.62
#
#        ofa_con_sim  web_ofa_sim
# count        28.00        28.00
# mean          0.34         0.42
# std           0.10         0.14
# min           0.12         0.19
# 25%           0.27         0.32
# 50%           0.35         0.39
# 75%           0.42         0.49
# max           0.54         0.65
# i
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        70.00        70.00        70.00        70.00       70.00
# mean          0.67         0.58         0.48         0.29        0.36
# std           0.47         0.23         0.12         0.16        0.22
# min           0.00         0.12         0.19        -0.01       -0.01
# 25%           0.00         0.38         0.45         0.17        0.17
# 50%           1.00         0.55         0.49         0.32        0.35
# 75%           1.00         0.86         0.55         0.43        0.56
# max           1.00         1.00         0.74         0.54        0.79
#
#        ofa_con_sim  web_ofa_sim
# count        70.00        70.00
# mean          0.26         0.42
# std           0.13         0.20
# min           0.06         0.05
# 25%           0.14         0.30
# 50%           0.28         0.40
# 75%           0.36         0.58
# max           0.56         0.78
# j
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count         7.00         7.00         7.00         7.00        7.00
# mean          0.43         0.93         0.69         0.24        0.21
# std           0.53         0.07         0.08         0.14        0.15
# min           0.00         0.88         0.61         0.02       -0.03
# 25%           0.00         0.88         0.64         0.14        0.10
# 50%           0.00         0.88         0.67         0.26        0.26
# 75%           1.00         1.00         0.74         0.34        0.34
# max           1.00         1.00         0.80         0.43        0.36
#
#        ofa_con_sim  web_ofa_sim
# count         7.00         7.00
# mean          0.26         0.27
# std           0.08         0.13
# min           0.19         0.10
# 25%           0.21         0.18
# 50%           0.24         0.31
# 75%           0.29         0.32
# max           0.41         0.49
# k
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        41.00        41.00        41.00        41.00       41.00
# mean          0.98         0.83         0.51         0.39        0.38
# std           0.16         0.12         0.07         0.17        0.18
# min           0.00         0.44         0.29        -0.05       -0.05
# 25%           1.00         0.78         0.49         0.34        0.28
# 50%           1.00         0.78         0.51         0.42        0.40
# 75%           1.00         0.89         0.54         0.53        0.52
# max           1.00         1.00         0.68         0.61        0.66
#
#        ofa_con_sim  web_ofa_sim
# count        41.00        41.00
# mean          0.26         0.46
# std           0.08         0.17
# min           0.09         0.09
# 25%           0.21         0.34
# 50%           0.26         0.48
# 75%           0.32         0.57
# max           0.44         0.75
# l
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        11.00        11.00        11.00        11.00       11.00
# mean          0.64         0.44         0.31         0.15        0.21
# std           0.50         0.27         0.12         0.11        0.12
# min           0.00         0.10         0.12        -0.02        0.07
# 25%           0.00         0.20         0.24         0.06        0.12
# 50%           1.00         0.50         0.28         0.18        0.23
# 75%           1.00         0.60         0.37         0.24        0.27
# max           1.00         0.80         0.51         0.29        0.47
#
#        ofa_con_sim  web_ofa_sim
# count        11.00        11.00
# mean          0.27         0.27
# std           0.15         0.19
# min          -0.00         0.01
# 25%           0.23         0.16
# 50%           0.26         0.28
# 75%           0.37         0.34
# max           0.50         0.65
# m
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        25.00        25.00        25.00        25.00       25.00
# mean          0.68         0.63         0.46         0.25        0.28
# std           0.48         0.18         0.08         0.15        0.19
# min           0.00         0.11         0.26        -0.04       -0.02
# 25%           0.00         0.60         0.42         0.18        0.14
# 50%           1.00         0.62         0.47         0.24        0.27
# 75%           1.00         0.75         0.50         0.34        0.42
# max           1.00         0.88         0.62         0.58        0.75
#
#        ofa_con_sim  web_ofa_sim
# count        25.00        25.00
# mean          0.26         0.29
# std           0.11         0.18
# min          -0.02        -0.01
# 25%           0.21         0.14
# 50%           0.25         0.30
# 75%           0.31         0.36
# max           0.44         0.70
# n
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        29.00        29.00        29.00        29.00       29.00
# mean          0.66         0.34         0.27         0.14        0.17
# std           0.48         0.24         0.06         0.11        0.13
# min           0.00         0.11         0.17        -0.12       -0.08
# 25%           0.00         0.11         0.23         0.07        0.08
# 50%           1.00         0.30         0.27         0.12        0.18
# 75%           1.00         0.57         0.30         0.21        0.24
# max           1.00         0.71         0.45         0.34        0.48
#
#        ofa_con_sim  web_ofa_sim
# count        29.00        29.00
# mean          0.26         0.23
# std           0.12         0.15
# min           0.01        -0.02
# 25%           0.18         0.13
# 50%           0.25         0.21
# 75%           0.35         0.32
# max           0.48         0.53
# o
#        gt_ped_flag  gt_coverage  org_top_sim  ofa_top_sim  ofa_gt_sim  \
# count        49.00        49.00        49.00        49.00       49.00
# mean          0.51         0.54         0.48         0.25        0.31
# std           0.51         0.15         0.11         0.12        0.16
# min           0.00         0.12         0.27        -0.00        0.06
# 25%           0.00         0.50         0.40         0.17        0.18
# 50%           1.00         0.50         0.48         0.22        0.28
# 75%           1.00         0.62         0.55         0.34        0.40
# max           1.00         0.88         0.80         0.50        0.77
#
#        ofa_con_sim  web_ofa_sim
# count        49.00        49.00
# mean          0.22         0.36
# std           0.11         0.22
# min          -0.01        -0.00
# 25%           0.16         0.19
# 50%           0.22         0.31
# 75%           0.29         0.54
# max           0.59         0.79

# %%
for el in pg_dict:
    print(el)
    print(f"{pg_dict[el].describe().round(2).at['mean','web_ofa_sim']}")
    print()
# Out:
# a
# 0.34
#
# b
# 0.42
#
# c
# 0.44
#
# d
# 0.52
#
# e
# 0.41
#
# f
# 0.22
#
# g
# 0.31
#
# h
# 0.42
#
# i
# 0.42
#
# j
# 0.27
#
# k
# 0.46
#
# l
# 0.27
#
# m
# 0.29
#
# n
# 0.23
#
# o
# 0.36

# %%
for el in pg_dict:
    print(el)
    print(f"{pg_dict[el].describe().round(2).at['mean','ofa_con_sim']}")
    print()
# Out:
# a
# 0.27
#
# b
# 0.3
#
# c
# 0.33
#
# d
# 0.4
#
# e
# 0.29
#
# f
# 0.19
#
# g
# 0.2
#
# h
# 0.34
#
# i
# 0.26
#
# j
# 0.26
#
# k
# 0.26
#
# l
# 0.27
#
# m
# 0.26
#
# n
# 0.26
#
# o
# 0.22

# %%
for el in pg_dict:
    print(el)
    print(f"{pg_dict[el].describe().round(2).at['mean','ofa_gt_sim']}")
    print()
# Out:
# a
# 0.36
#
# b
# 0.37
#
# c
# 0.36
#
# d
# 0.5
#
# e
# 0.41
#
# f
# 0.22
#
# g
# 0.26
#
# h
# 0.4
#
# i
# 0.36
#
# j
# 0.21
#
# k
# 0.38
#
# l
# 0.21
#
# m
# 0.28
#
# n
# 0.17
#
# o
# 0.31

# %% [markdown]
# # After Fatemeh

# %% [markdown]
# ### keep all

# %%
df[['gt_ped_flag', 'gt_coverage', 'org_gt_sim', 'ofa_top_sim', 'ofa_gt_sim', 'ofa_con_sim', 'web_ofa_sim']].describe().round(2)
# Out:
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count       620.00       620.00      620.00       620.00      620.00
# mean          0.65         0.49        0.50         0.34        0.40
# std           0.48         0.23        0.14         0.16        0.17
# min           0.00         0.09        0.07        -0.09       -0.09
# 25%           0.00         0.33        0.41         0.23        0.27
# 50%           1.00         0.45        0.52         0.35        0.41
# 75%           1.00         0.62        0.60         0.43        0.54
# max           1.00         1.00        0.88         0.79        0.81
#
#        ofa_con_sim  web_ofa_sim
# count       620.00       620.00
# mean          0.35         0.45
# std           0.15         0.20
# min          -0.07        -0.04
# 25%           0.24         0.31
# 50%           0.32         0.47
# 75%           0.45         0.59
# max           0.76         0.94

# %%
#after
for el in pg_dict:
    print(el)
    display(pg_dict[el][['gt_ped_flag', 'gt_coverage', 'org_gt_sim', 'ofa_top_sim', 'ofa_gt_sim', 'ofa_con_sim', 'web_ofa_sim']].describe().round(2))
# Out:
# a
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        51.00        51.00       51.00        51.00       51.00
# mean          0.76         0.53        0.49         0.33        0.39
# std           0.43         0.20        0.12         0.13        0.16
# min           0.00         0.20        0.13        -0.00        0.07
# 25%           1.00         0.40        0.43         0.22        0.26
# 50%           1.00         0.50        0.48         0.35        0.41
# 75%           1.00         0.56        0.58         0.45        0.50
# max           1.00         1.00        0.69         0.55        0.73
#
#        ofa_con_sim  web_ofa_sim
# count        51.00        51.00
# mean          0.31         0.39
# std           0.12         0.16
# min           0.14         0.19
# 25%           0.23         0.26
# 50%           0.29         0.38
# 75%           0.36         0.49
# max           0.63         0.79
# b
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count       103.00       103.00      103.00       103.00      103.00
# mean          0.82         0.40        0.49         0.31        0.43
# std           0.39         0.16        0.12         0.10        0.15
# min           0.00         0.10        0.14         0.03        0.07
# 25%           1.00         0.30        0.41         0.24        0.31
# 50%           1.00         0.40        0.51         0.30        0.46
# 75%           1.00         0.50        0.58         0.37        0.55
# max           1.00         0.70        0.77         0.58        0.80
#
#        ofa_con_sim  web_ofa_sim
# count       103.00       103.00
# mean          0.38         0.49
# std           0.15         0.17
# min           0.08         0.09
# 25%           0.26         0.37
# 50%           0.33         0.49
# 75%           0.49         0.61
# max           0.76         0.87
# c
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        57.00        57.00       57.00        57.00       57.00
# mean          0.63         0.43        0.49         0.36        0.43
# std           0.49         0.18        0.09         0.11        0.14
# min           0.00         0.11        0.25         0.02        0.03
# 25%           0.00         0.29        0.44         0.29        0.36
# 50%           1.00         0.44        0.49         0.38        0.46
# 75%           1.00         0.56        0.55         0.43        0.50
# max           1.00         0.78        0.65         0.61        0.66
#
#        ofa_con_sim  web_ofa_sim
# count        57.00        57.00
# mean          0.41         0.52
# std           0.15         0.17
# min           0.08         0.08
# 25%           0.29         0.42
# 50%           0.38         0.53
# 75%           0.54         0.58
# max           0.69         0.92
# d
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        62.00        62.00       62.00        62.00       62.00
# mean          0.16         0.45        0.59         0.53        0.51
# std           0.37         0.13        0.11         0.18        0.18
# min           0.00         0.10        0.29         0.08        0.08
# 25%           0.00         0.40        0.55         0.43        0.39
# 50%           0.00         0.41        0.61         0.58        0.56
# 75%           0.00         0.50        0.66         0.65        0.64
# max           1.00         0.71        0.77         0.79        0.81
#
#        ofa_con_sim  web_ofa_sim
# count        62.00        62.00
# mean          0.46         0.59
# std           0.15         0.17
# min           0.19         0.01
# 25%           0.31         0.50
# 50%           0.50         0.61
# 75%           0.57         0.73
# max           0.71         0.91
# e
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        46.00        46.00       46.00        46.00       46.00
# mean          0.59         0.50        0.54         0.38        0.42
# std           0.50         0.24        0.13         0.11        0.13
# min           0.00         0.09        0.33         0.07        0.04
# 25%           0.00         0.36        0.45         0.34        0.37
# 50%           1.00         0.45        0.55         0.39        0.43
# 75%           1.00         0.60        0.61         0.47        0.48
# max           1.00         1.00        0.83         0.58        0.66
#
#        ofa_con_sim  web_ofa_sim
# count        46.00        46.00
# mean          0.38         0.47
# std           0.15         0.16
# min           0.08         0.15
# 25%           0.27         0.37
# 50%           0.34         0.53
# 75%           0.49         0.57
# max           0.71         0.83
# f
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        16.00        16.00       16.00        16.00       16.00
# mean          0.62         0.67        0.50         0.20        0.20
# std           0.50         0.33        0.11         0.16        0.16
# min           0.00         0.12        0.30        -0.09       -0.09
# 25%           0.00         0.38        0.46         0.09        0.08
# 50%           1.00         0.72        0.50         0.23        0.19
# 75%           1.00         1.00        0.57         0.27        0.32
# max           1.00         1.00        0.65         0.44        0.44
#
#        ofa_con_sim  web_ofa_sim
# count        16.00        16.00
# mean          0.21         0.24
# std           0.11         0.15
# min          -0.01         0.00
# 25%           0.19         0.12
# 50%           0.23         0.26
# 75%           0.28         0.35
# max           0.34         0.52
# g
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        25.00        25.00       25.00        25.00       25.00
# mean          0.56         0.24        0.45         0.24        0.31
# std           0.51         0.11        0.17         0.15        0.17
# min           0.00         0.10        0.13        -0.08       -0.04
# 25%           0.00         0.20        0.38         0.15        0.20
# 50%           1.00         0.20        0.50         0.20        0.33
# 75%           1.00         0.30        0.59         0.34        0.45
# max           1.00         0.56        0.69         0.53        0.56
#
#        ofa_con_sim  web_ofa_sim
# count        25.00        25.00
# mean          0.24         0.36
# std           0.13         0.17
# min           0.09         0.06
# 25%           0.15         0.25
# 50%           0.23         0.37
# 75%           0.29         0.47
# max           0.53         0.76
# h
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count         28.0        28.00       28.00        28.00       28.00
# mean           1.0         0.27        0.49         0.27        0.41
# std            0.0         0.12        0.12         0.09        0.17
# min            1.0         0.20        0.25         0.06        0.08
# 25%            1.0         0.20        0.42         0.22        0.29
# 50%            1.0         0.20        0.46         0.28        0.40
# 75%            1.0         0.30        0.55         0.32        0.59
# max            1.0         0.70        0.74         0.41        0.63
#
#        ofa_con_sim  web_ofa_sim
# count        28.00        28.00
# mean          0.38         0.46
# std           0.14         0.15
# min           0.12         0.15
# 25%           0.29         0.35
# 50%           0.34         0.48
# 75%           0.48         0.57
# max           0.62         0.74
# i
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        70.00        70.00       70.00        70.00       70.00
# mean          0.67         0.58        0.54         0.32        0.39
# std           0.47         0.23        0.16         0.15        0.20
# min           0.00         0.12        0.17        -0.04       -0.02
# 25%           0.00         0.38        0.42         0.21        0.23
# 50%           1.00         0.55        0.61         0.37        0.44
# 75%           1.00         0.86        0.65         0.43        0.59
# max           1.00         1.00        0.78         0.60        0.68
#
#        ofa_con_sim  web_ofa_sim
# count        70.00        70.00
# mean          0.29         0.49
# std           0.13         0.24
# min          -0.01        -0.03
# 25%           0.20         0.32
# 50%           0.32         0.50
# 75%           0.41         0.69
# max           0.48         0.94
# j
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count         7.00         7.00        7.00         7.00        7.00
# mean          0.43         0.93        0.66         0.38        0.36
# std           0.53         0.07        0.07         0.07        0.09
# min           0.00         0.88        0.56         0.30        0.27
# 25%           0.00         0.88        0.62         0.32        0.30
# 50%           0.00         0.88        0.66         0.36        0.33
# 75%           1.00         1.00        0.69         0.40        0.38
# max           1.00         1.00        0.79         0.52        0.53
#
#        ofa_con_sim  web_ofa_sim
# count         7.00         7.00
# mean          0.33         0.38
# std           0.11         0.04
# min           0.23         0.31
# 25%           0.26         0.36
# 50%           0.29         0.37
# 75%           0.34         0.41
# max           0.56         0.43
# k
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        41.00        41.00       41.00        41.00       41.00
# mean          0.98         0.83        0.50         0.40        0.38
# std           0.16         0.12        0.12         0.12        0.14
# min           0.00         0.44        0.11         0.05        0.02
# 25%           1.00         0.78        0.43         0.37        0.32
# 50%           1.00         0.78        0.52         0.40        0.39
# 75%           1.00         0.89        0.58         0.46        0.45
# max           1.00         1.00        0.77         0.62        0.62
#
#        ofa_con_sim  web_ofa_sim
# count        41.00        41.00
# mean          0.29         0.50
# std           0.10         0.15
# min           0.07         0.04
# 25%           0.23         0.43
# 50%           0.27         0.51
# 75%           0.37         0.59
# max           0.56         0.80
# l
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        11.00        11.00       11.00        11.00       11.00
# mean          0.64         0.44        0.34         0.24        0.29
# std           0.50         0.27        0.14         0.14        0.16
# min           0.00         0.10        0.18         0.06        0.10
# 25%           0.00         0.20        0.26         0.12        0.15
# 50%           1.00         0.50        0.28         0.21        0.29
# 75%           1.00         0.60        0.39         0.35        0.37
# max           1.00         0.80        0.68         0.44        0.62
#
#        ofa_con_sim  web_ofa_sim
# count        11.00        11.00
# mean          0.39         0.38
# std           0.19         0.18
# min           0.08         0.09
# 25%           0.30         0.24
# 50%           0.38         0.44
# 75%           0.54         0.52
# max           0.63         0.55
# m
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        25.00        25.00       25.00        25.00       25.00
# mean          0.68         0.63        0.50         0.31        0.34
# std           0.48         0.18        0.12         0.14        0.18
# min           0.00         0.11        0.19        -0.01        0.02
# 25%           0.00         0.60        0.46         0.24        0.21
# 50%           1.00         0.62        0.52         0.31        0.34
# 75%           1.00         0.75        0.56         0.40        0.47
# max           1.00         0.88        0.74         0.57        0.72
#
#        ofa_con_sim  web_ofa_sim
# count        25.00        25.00
# mean          0.34         0.36
# std           0.17         0.22
# min           0.09        -0.04
# 25%           0.20         0.19
# 50%           0.34         0.32
# 75%           0.48         0.54
# max           0.66         0.76
# n
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        29.00        29.00       29.00        29.00       29.00
# mean          0.66         0.34        0.26         0.18        0.25
# std           0.48         0.24        0.13         0.13        0.18
# min           0.00         0.11        0.07        -0.03       -0.05
# 25%           0.00         0.11        0.13         0.09        0.14
# 50%           1.00         0.30        0.24         0.15        0.24
# 75%           1.00         0.57        0.40         0.29        0.33
# max           1.00         0.71        0.49         0.44        0.70
#
#        ofa_con_sim  web_ofa_sim
# count        29.00        29.00
# mean          0.32         0.28
# std           0.17         0.17
# min          -0.05         0.03
# 25%           0.22         0.16
# 50%           0.29         0.24
# 75%           0.38         0.39
# max           0.70         0.64
# o
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        49.00        49.00       49.00        49.00       49.00
# mean          0.51         0.54        0.51         0.31        0.37
# std           0.51         0.15        0.14         0.15        0.17
# min           0.00         0.12        0.24        -0.07        0.01
# 25%           0.00         0.50        0.42         0.21        0.25
# 50%           1.00         0.50        0.51         0.30        0.39
# 75%           1.00         0.62        0.59         0.39        0.50
# max           1.00         0.88        0.88         0.58        0.71
#
#        ofa_con_sim  web_ofa_sim
# count        49.00        49.00
# mean          0.32         0.40
# std           0.17         0.24
# min          -0.07        -0.02
# 25%           0.21         0.19
# 50%           0.31         0.35
# 75%           0.42         0.57
# max           0.69         0.92

# %%
for el in pg_dict:
    print(el)
    print(f"{pg_dict[el].describe().round(2).at['mean','web_ofa_sim']}")
    print()
# Out:
# a
# 0.39
#
# b
# 0.49
#
# c
# 0.52
#
# d
# 0.59
#
# e
# 0.47
#
# f
# 0.24
#
# g
# 0.36
#
# h
# 0.46
#
# i
# 0.49
#
# j
# 0.38
#
# k
# 0.5
#
# l
# 0.38
#
# m
# 0.36
#
# n
# 0.28
#
# o
# 0.4

# %%
for el in pg_dict:
    print(el)
    print(f"{pg_dict[el].describe().round(2).at['mean','ofa_con_sim']}")
    print()
# Out:
# a
# 0.31
#
# b
# 0.38
#
# c
# 0.41
#
# d
# 0.46
#
# e
# 0.38
#
# f
# 0.21
#
# g
# 0.24
#
# h
# 0.38
#
# i
# 0.29
#
# j
# 0.33
#
# k
# 0.29
#
# l
# 0.39
#
# m
# 0.34
#
# n
# 0.32
#
# o
# 0.32

# %%
for el in pg_dict:
    print(el)
    print(f"{pg_dict[el].describe().round(2).at['mean','ofa_gt_sim']}")
    print()
# Out:
# a
# 0.39
#
# b
# 0.43
#
# c
# 0.43
#
# d
# 0.51
#
# e
# 0.42
#
# f
# 0.2
#
# g
# 0.31
#
# h
# 0.41
#
# i
# 0.39
#
# j
# 0.36
#
# k
# 0.38
#
# l
# 0.29
#
# m
# 0.34
#
# n
# 0.25
#
# o
# 0.37

# %% [markdown]
# # Wit

# %%
df[['gt_ped_flag', 'gt_coverage', 'org_gt_sim', 'ofa_top_sim', 'ofa_gt_sim', 'ofa_con_sim', 'web_ofa_sim']].describe().round(2)
# Out:
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count       620.00       620.00      620.00       620.00      620.00
# mean          0.65         0.49        0.50         0.34        0.39
# std           0.48         0.23        0.14         0.16        0.17
# min           0.00         0.09        0.07        -0.10       -0.05
# 25%           0.00         0.33        0.41         0.23        0.26
# 50%           1.00         0.45        0.52         0.34        0.39
# 75%           1.00         0.62        0.60         0.43        0.53
# max           1.00         1.00        0.88         0.76        0.84
#
#        ofa_con_sim  web_ofa_sim
# count       620.00       620.00
# mean          0.38         0.42
# std           0.16         0.18
# min          -0.01        -0.05
# 25%           0.27         0.29
# 50%           0.35         0.42
# 75%           0.52         0.56
# max           0.71         0.94

# %%
#after
for el in pg_dict:
    print(el)
    display(pg_dict[el][['gt_ped_flag', 'gt_coverage', 'org_gt_sim', 'ofa_top_sim', 'ofa_gt_sim', 'ofa_con_sim', 'web_ofa_sim']].describe().round(2))
# Out:
# a
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        51.00        51.00       51.00        51.00       51.00
# mean          0.76         0.53        0.49         0.36        0.39
# std           0.43         0.20        0.12         0.12        0.15
# min           0.00         0.20        0.13         0.11        0.11
# 25%           1.00         0.40        0.43         0.28        0.25
# 50%           1.00         0.50        0.48         0.36        0.38
# 75%           1.00         0.56        0.58         0.44        0.47
# max           1.00         1.00        0.69         0.65        0.73
#
#        ofa_con_sim  web_ofa_sim
# count        51.00        51.00
# mean          0.34         0.35
# std           0.13         0.13
# min           0.16         0.13
# 25%           0.25         0.26
# 50%           0.31         0.33
# 75%           0.38         0.44
# max           0.61         0.61
# b
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count       103.00       103.00      103.00       103.00      103.00
# mean          0.82         0.40        0.49         0.28        0.40
# std           0.39         0.16        0.12         0.10        0.13
# min           0.00         0.10        0.14         0.01        0.10
# 25%           1.00         0.30        0.41         0.24        0.31
# 50%           1.00         0.40        0.51         0.29        0.41
# 75%           1.00         0.50        0.58         0.34        0.50
# max           1.00         0.70        0.77         0.55        0.67
#
#        ofa_con_sim  web_ofa_sim
# count       103.00       103.00
# mean          0.39         0.43
# std           0.13         0.14
# min          -0.00         0.08
# 25%           0.29         0.33
# 50%           0.36         0.41
# 75%           0.51         0.54
# max           0.70         0.80
# c
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        57.00        57.00       57.00        57.00       57.00
# mean          0.63         0.43        0.49         0.36        0.43
# std           0.49         0.18        0.09         0.12        0.15
# min           0.00         0.11        0.25        -0.05       -0.05
# 25%           0.00         0.29        0.44         0.29        0.34
# 50%           1.00         0.44        0.49         0.38        0.46
# 75%           1.00         0.56        0.55         0.45        0.55
# max           1.00         0.78        0.65         0.52        0.69
#
#        ofa_con_sim  web_ofa_sim
# count        57.00        57.00
# mean          0.42         0.48
# std           0.16         0.17
# min           0.08         0.10
# 25%           0.31         0.37
# 50%           0.40         0.47
# 75%           0.55         0.60
# max           0.71         0.87
# d
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        62.00        62.00       62.00        62.00       62.00
# mean          0.16         0.45        0.59         0.56        0.53
# std           0.37         0.13        0.11         0.16        0.16
# min           0.00         0.10        0.29         0.17        0.17
# 25%           0.00         0.40        0.55         0.44        0.43
# 50%           0.00         0.41        0.61         0.60        0.56
# 75%           0.00         0.50        0.66         0.72        0.66
# max           1.00         0.71        0.77         0.76        0.84
#
#        ofa_con_sim  web_ofa_sim
# count        62.00        62.00
# mean          0.51         0.58
# std           0.14         0.16
# min           0.21         0.21
# 25%           0.37         0.45
# 50%           0.54         0.59
# 75%           0.64         0.68
# max           0.68         0.94
# e
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        46.00        46.00       46.00        46.00       46.00
# mean          0.59         0.50        0.54         0.38        0.40
# std           0.50         0.24        0.13         0.11        0.12
# min           0.00         0.09        0.33         0.04        0.10
# 25%           0.00         0.36        0.45         0.36        0.32
# 50%           1.00         0.45        0.55         0.40        0.40
# 75%           1.00         0.60        0.61         0.45        0.49
# max           1.00         1.00        0.83         0.53        0.64
#
#        ofa_con_sim  web_ofa_sim
# count        46.00        46.00
# mean          0.46         0.43
# std           0.11         0.11
# min           0.22         0.17
# 25%           0.37         0.37
# 50%           0.51         0.42
# 75%           0.54         0.51
# max           0.60         0.61
# f
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        16.00        16.00       16.00        16.00       16.00
# mean          0.62         0.67        0.50         0.31        0.32
# std           0.50         0.33        0.11         0.17        0.18
# min           0.00         0.12        0.30         0.03        0.05
# 25%           0.00         0.38        0.46         0.20        0.19
# 50%           1.00         0.72        0.50         0.36        0.34
# 75%           1.00         1.00        0.57         0.45        0.47
# max           1.00         1.00        0.65         0.52        0.57
#
#        ofa_con_sim  web_ofa_sim
# count        16.00        16.00
# mean          0.29         0.29
# std           0.13         0.21
# min           0.09        -0.05
# 25%           0.24         0.17
# 50%           0.31         0.32
# 75%           0.34         0.40
# max           0.65         0.72
# g
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        25.00        25.00       25.00        25.00       25.00
# mean          0.56         0.24        0.45         0.22        0.29
# std           0.51         0.11        0.17         0.13        0.19
# min           0.00         0.10        0.13         0.01       -0.01
# 25%           0.00         0.20        0.38         0.14        0.14
# 50%           1.00         0.20        0.50         0.19        0.24
# 75%           1.00         0.30        0.59         0.31        0.43
# max           1.00         0.56        0.69         0.53        0.62
#
#        ofa_con_sim  web_ofa_sim
# count        25.00        25.00
# mean          0.25         0.30
# std           0.18         0.18
# min          -0.01        -0.00
# 25%           0.12         0.19
# 50%           0.22         0.31
# 75%           0.28         0.37
# max           0.62         0.76
# h
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count         28.0        28.00       28.00        28.00       28.00
# mean           1.0         0.27        0.49         0.25        0.40
# std            0.0         0.12        0.12         0.10        0.15
# min            1.0         0.20        0.25         0.07        0.15
# 25%            1.0         0.20        0.42         0.18        0.30
# 50%            1.0         0.20        0.46         0.24        0.39
# 75%            1.0         0.30        0.55         0.32        0.54
# max            1.0         0.70        0.74         0.41        0.65
#
#        ofa_con_sim  web_ofa_sim
# count        28.00        28.00
# mean          0.38         0.40
# std           0.13         0.17
# min           0.14         0.06
# 25%           0.30         0.29
# 50%           0.34         0.37
# 75%           0.43         0.50
# max           0.67         0.72
# i
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        70.00        70.00       70.00        70.00       70.00
# mean          0.67         0.58        0.54         0.33        0.40
# std           0.47         0.23        0.16         0.16        0.22
# min           0.00         0.12        0.17        -0.10       -0.04
# 25%           0.00         0.38        0.42         0.21        0.23
# 50%           1.00         0.55        0.61         0.36        0.36
# 75%           1.00         0.86        0.65         0.43        0.62
# max           1.00         1.00        0.78         0.69        0.75
#
#        ofa_con_sim  web_ofa_sim
# count        70.00        70.00
# mean          0.33         0.45
# std           0.15         0.21
# min           0.03        -0.03
# 25%           0.22         0.29
# 50%           0.33         0.50
# 75%           0.43         0.61
# max           0.69         0.81
# j
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count         7.00         7.00        7.00         7.00        7.00
# mean          0.43         0.93        0.66         0.31        0.31
# std           0.53         0.07        0.07         0.09        0.09
# min           0.00         0.88        0.56         0.17        0.15
# 25%           0.00         0.88        0.62         0.26        0.28
# 50%           0.00         0.88        0.66         0.35        0.34
# 75%           1.00         1.00        0.69         0.37        0.36
# max           1.00         1.00        0.79         0.41        0.39
#
#        ofa_con_sim  web_ofa_sim
# count         7.00         7.00
# mean          0.34         0.32
# std           0.12         0.09
# min           0.19         0.17
# 25%           0.29         0.26
# 50%           0.30         0.35
# 75%           0.37         0.38
# max           0.57         0.42
# k
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        41.00        41.00       41.00        41.00       41.00
# mean          0.98         0.83        0.50         0.38        0.36
# std           0.16         0.12        0.12         0.16        0.17
# min           0.00         0.44        0.11        -0.04       -0.04
# 25%           1.00         0.78        0.43         0.35        0.32
# 50%           1.00         0.78        0.52         0.41        0.38
# 75%           1.00         0.89        0.58         0.49        0.48
# max           1.00         1.00        0.77         0.60        0.64
#
#        ofa_con_sim  web_ofa_sim
# count        41.00        41.00
# mean          0.29         0.45
# std           0.09         0.15
# min           0.13         0.10
# 25%           0.23         0.32
# 50%           0.27         0.49
# 75%           0.33         0.56
# max           0.61         0.75
# l
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        11.00        11.00       11.00        11.00       11.00
# mean          0.64         0.44        0.34         0.21        0.25
# std           0.50         0.27        0.14         0.09        0.15
# min           0.00         0.10        0.18         0.05        0.11
# 25%           0.00         0.20        0.26         0.17        0.13
# 50%           1.00         0.50        0.28         0.21        0.20
# 75%           1.00         0.60        0.39         0.25        0.30
# max           1.00         0.80        0.68         0.40        0.54
#
#        ofa_con_sim  web_ofa_sim
# count        11.00        11.00
# mean          0.49         0.39
# std           0.16         0.21
# min           0.21         0.04
# 25%           0.39         0.26
# 50%           0.49         0.39
# 75%           0.60         0.49
# max           0.71         0.76
# m
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        25.00        25.00       25.00        25.00       25.00
# mean          0.68         0.63        0.50         0.31        0.32
# std           0.48         0.18        0.12         0.15        0.19
# min           0.00         0.11        0.19        -0.04       -0.03
# 25%           0.00         0.60        0.46         0.18        0.16
# 50%           1.00         0.62        0.52         0.32        0.32
# 75%           1.00         0.75        0.56         0.40        0.44
# max           1.00         0.88        0.74         0.58        0.70
#
#        ofa_con_sim  web_ofa_sim
# count        25.00        25.00
# mean          0.37         0.31
# std           0.16         0.18
# min           0.10        -0.04
# 25%           0.26         0.23
# 50%           0.30         0.30
# 75%           0.54         0.43
# max           0.61         0.67
# n
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        29.00        29.00       29.00        29.00       29.00
# mean          0.66         0.34        0.26         0.19        0.24
# std           0.48         0.24        0.13         0.13        0.17
# min           0.00         0.11        0.07        -0.05       -0.04
# 25%           0.00         0.11        0.13         0.10        0.12
# 50%           1.00         0.30        0.24         0.17        0.22
# 75%           1.00         0.57        0.40         0.29        0.38
# max           1.00         0.71        0.49         0.46        0.66
#
#        ofa_con_sim  web_ofa_sim
# count        29.00        29.00
# mean          0.32         0.28
# std           0.18         0.17
# min          -0.01        -0.00
# 25%           0.19         0.15
# 50%           0.28         0.27
# 75%           0.49         0.38
# max           0.66         0.62
# o
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count        49.00        49.00       49.00        49.00       49.00
# mean          0.51         0.54        0.51         0.31        0.39
# std           0.51         0.15        0.14         0.14        0.17
# min           0.00         0.12        0.24         0.04        0.08
# 25%           0.00         0.50        0.42         0.21        0.22
# 50%           1.00         0.50        0.51         0.32        0.39
# 75%           1.00         0.62        0.59         0.41        0.51
# max           1.00         0.88        0.88         0.66        0.69
#
#        ofa_con_sim  web_ofa_sim
# count        49.00        49.00
# mean          0.36         0.40
# std           0.17         0.20
# min          -0.00         0.00
# 25%           0.22         0.25
# 50%           0.33         0.36
# 75%           0.50         0.60
# max           0.67         0.79

# %%
for el in pg_dict:
    print(el)
    print(f"{pg_dict[el].describe().round(2).at['mean','web_ofa_sim']}")
    print()
# Out:
# a
# 0.35
#
# b
# 0.43
#
# c
# 0.48
#
# d
# 0.58
#
# e
# 0.43
#
# f
# 0.29
#
# g
# 0.3
#
# h
# 0.4
#
# i
# 0.45
#
# j
# 0.32
#
# k
# 0.45
#
# l
# 0.39
#
# m
# 0.31
#
# n
# 0.28
#
# o
# 0.4

# %%
for el in pg_dict:
    print(el)
    print(f"{pg_dict[el].describe().round(2).at['mean','ofa_con_sim']}")
    print()
# Out:
# a
# 0.34
#
# b
# 0.39
#
# c
# 0.42
#
# d
# 0.51
#
# e
# 0.46
#
# f
# 0.29
#
# g
# 0.25
#
# h
# 0.38
#
# i
# 0.33
#
# j
# 0.34
#
# k
# 0.29
#
# l
# 0.49
#
# m
# 0.37
#
# n
# 0.32
#
# o
# 0.36

# %%
for el in pg_dict:
    print(el)
    print(f"{pg_dict[el].describe().round(2).at['mean','ofa_gt_sim']}")
    print()
# Out:
# a
# 0.39
#
# b
# 0.4
#
# c
# 0.43
#
# d
# 0.53
#
# e
# 0.4
#
# f
# 0.32
#
# g
# 0.29
#
# h
# 0.4
#
# i
# 0.4
#
# j
# 0.31
#
# k
# 0.36
#
# l
# 0.25
#
# m
# 0.32
#
# n
# 0.24
#
# o
# 0.39

# %% [markdown]
# # CLIP

# %%
model, preprocess = clip.load("ViT-B/32", device=device, jit=False)

# %%
d_path = '.'
#before
df_b = pd.read_pickle(f'{d_path}/pd_base.pk')


# after fat
d_path = '/raid/AISSEL/htest/datasets/ped_data/ped_ftest/missed_q50_over_avg'
df_f = pd.read_pickle(f'{d_path}/pd_mq50_over_avg.pk')

# wit
d_path = '/raid/AISSEL/htest/datasets/ped_data/wit/missed_q50_over_avg'
df_w = pd.read_pickle(f'{d_path}/ped_mq50_over_avg.pk')

# random
d_path = '/raid/AISSEL/htest/datasets/ped_data/wit/random_missed'
df_r = pd.read_pickle(f'{d_path}/ped_mq50_over_avg.pk')

# %%
df_b = df_b.dropna()
df_b = df_b.reset_index(drop=True)
df_f = df_f.dropna()
df_f = df_f.reset_index(drop=True)
df_w = df_w.dropna()
df_w = df_w.reset_index(drop=True)

df_r = df_r.dropna()
df_r = df_r.reset_index(drop=True)

# %%
df_b
# Out:
#      uniq_id  image_id                                            caption  \
# 0        167       167               Car on rural road vector Stock Photo
# 1        184       184           Bus Only Lane Rendering Kuhio and Walina
# 2        187       187               Passenger boarding a bus on Bayshore
# 3        192       192               Passenger boarding a bus on Bayshore
# 4        209       209         Pedestrian Connections Congestion Strategy
# ..       ...       ...                                                ...
# 615     1228      1228          Westown Commons picnic shelter front view
# 616     1241      1241                        Humboldt Alexander Von Park
# 617     1259      1259  photo of trees and the fenceline at Mason Hill...
# 618     1296      1296                                Hogback Ridge Park
# 619     1306      1306          Playground and park unveiled in Jamaica 4
#
#      topic_id labels                                              image  \
# 0          68         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4         112         /9j/7gAOQWRvYmUAZAAAAAAA/9sAQwAIBgYHBgUIBwcHCQ...
# ..        ...    ...                                                ...
# 615       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 616       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 617       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 618       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 619       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
#      topic2caption_sim  concept2caption_sim topics  \
# 0             0.376758             0.212455      a
# 1             0.392783             0.160691      a
# 2             0.438588             0.197647      a
# 3             0.438588             0.197647      a
# 4             0.612697             0.493012      a
# ..                 ...                  ...    ...
# 615           0.395052             0.217862      o
# 616           0.415312             0.211162      o
# 617           0.446961             0.234170      o
# 618           0.579372             0.235827      o
# 619           0.499459             0.164558      o
#
#                                                    tag  \
# 0    {'passenger': 0, 'wheel': 1, 'vehicle': 1, 'wa...
# 1    {'freight': 1, 'transportation': 1, 'traffic':...
# 2    {'freight': 1, 'transportation': 1, 'traffic':...
# 3    {'freight': 1, 'transportation': 1, 'traffic':...
# 4    {'freight': 1, 'transportation': 1, 'traffic':...
# ..                                                 ...
# 615  {'scenic': 0, 'recreation': 1, 'wilderness': 0...
# 616  {'scenic': 1, 'recreation': 1, 'wilderness': 0...
# 617  {'scenic': 1, 'recreation': 1, 'wilderness': 0...
# 618  {'scenic': 1, 'recreation': 1, 'wilderness': 0...
# 619  {'scenic': 0, 'recreation': 1, 'wilderness': 0...
#
#                                                     gt  \
# 0                                        wheel vehicle
# 1     freight transportation traffic transport tran...
# 2     freight transportation traffic transport tran...
# 3     freight transportation traffic transport tran...
# 4     freight transportation traffic transport cong...
# ..                                                 ...
# 615                               recreation park area
# 616             scenic recreation park area pedestrian
# 617                        scenic recreation park area
# 618                        scenic recreation park area
# 619         recreation park area pedestrian playground
#
#                                              h_caption  \
# 0                        A parked car in a remote area
# 1    Two individuals ride bikes on the bus-only rou...
# 2    A bus stopped in the bus stop when a passenger...
# 3    A bus stopped in the bus stop when a passenger...
# 4     A pedestrian with wheelchair waiting in the road
# ..                                                 ...
# 615                                     Shed in a park
# 616                               A bridge over a lake
# 617                                             A park
# 618                            Fallen leaves with food
# 619                             People in a playground
#
#                                            ofa_caption
# 0              a silhouette of a car parked in a field
# 1      a street with a bus and a white car on the road
# 2           a person is getting on a bus at a bus stop
# 3           a person is getting on a bus at a bus stop
# 4    a woman and a child in a wheelchair waiting fo...
# ..                                                 ...
# 615              a gazebo with picnic tables in a park
# 616         a bridge over a river with a body of water
# 617                  a tree in a field next to a fence
# 618      a person holding a camera on a pile of leaves
# 619        a woman wearing a face mask at a playground
#
# [620 rows x 13 columns]

# %%
print(len(df_b))
print(len(df_f))
print(len(df_w))
print(len(df_r))
# Out:
# 620
# 620
# 620
# 620

# %%
tmp_df = pd.DataFrame()
tmp_df['image'] = df_b['image'].to_list()
# tmp_df['or_caption'] = df_b['caption'].to_list()
tmp_df['bf_caption'] = df_b['ofa_caption'].to_list()
tmp_df['aw_caption'] = df_w['ofa_caption'].to_list()
tmp_df['af_caption'] = df_f['ofa_caption'].to_list()
# tmp_df['hu_caption'] = df_b['h_caption'].to_list()
tmp_df['topics'] = df_b['topics'].to_list()

tmp_df['ar_caption'] = df_f['ofa_caption'].to_list()

# %%
tmp_df
# Out:
#                                                  image  \
# 0    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4    /9j/7gAOQWRvYmUAZAAAAAAA/9sAQwAIBgYHBgUIBwcHCQ...
# ..                                                 ...
# 615  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 616  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 617  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 618  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 619  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
#                                             bf_caption  \
# 0              a silhouette of a car parked in a field
# 1      a street with a bus and a white car on the road
# 2           a person is getting on a bus at a bus stop
# 3           a person is getting on a bus at a bus stop
# 4    a woman and a child in a wheelchair waiting fo...
# ..                                                 ...
# 615              a gazebo with picnic tables in a park
# 616         a bridge over a river with a body of water
# 617                  a tree in a field next to a fence
# 618      a person holding a camera on a pile of leaves
# 619        a woman wearing a face mask at a playground
#
#                                             aw_caption  \
# 0                 A car parked on the side of the road
# 1    English A pedestrian and cyclists crossing the...
# 2         English A woman boarding a bus at a bus stop
# 3         English A woman boarding a bus at a bus stop
# 4    English A woman in a wheelchair waiting for a ...
# ..                                                 ...
# 615               English A picnic shelter in the park
# 616  English A pedestrian bridge over the river in ...
# 617   English A view from the parking lot of the house
# 618  English woman holding a camera on the ground w...
# 619  English A woman wearing a face mask stands in ...
#
#                                             af_caption topics  \
# 0              a silhouette of a car parked in a field      a
# 1    pedestrians and cars on a pedestrian crossing ...      a
# 2            a woman is getting on a bus at a bus stop      a
# 3            a woman is getting on a bus at a bus stop      a
# 4    a woman in a wheelchair crossing the street in...      a
# ..                                                 ...    ...
# 615  a pavilion with picnic tables and benches in a...      o
# 616                   pedestrian bridge over the river      o
# 617                     a tree in a field with a fence      o
# 618  a woman holding a camera in her hand with autu...      o
# 619  a woman wearing a face mask stands in front of...      o
#
#                                             ar_caption
# 0              a silhouette of a car parked in a field
# 1    pedestrians and cars on a pedestrian crossing ...
# 2            a woman is getting on a bus at a bus stop
# 3            a woman is getting on a bus at a bus stop
# 4    a woman in a wheelchair crossing the street in...
# ..                                                 ...
# 615  a pavilion with picnic tables and benches in a...
# 616                   pedestrian bridge over the river
# 617                     a tree in a field with a fence
# 618  a woman holding a camera in her hand with autu...
# 619  a woman wearing a face mask stands in front of...
#
# [620 rows x 6 columns]

# %%
def clip_3(row):
    image_64_decode = base64.b64decode(row['image']) 
    image_result = open('test.jpg', 'wb')
    image_result.write(image_64_decode)
    try:
        image = Image.open('test.jpg')
        image = preprocess(image).unsqueeze(0).to(device)

        with torch.no_grad():
            image_features = model.encode_image(image)

#         text_snippets = [row['bf_caption'], row['aw_caption'], row['af_caption']]
        text_snippets = [row['bf_caption'], row['aw_caption'], row['af_caption'], row['ar_caption']]
        text = clip.tokenize(text_snippets).to(device)

        with torch.no_grad():
            text_features = model.encode_text(text)
        
        with torch.no_grad():
            logits_per_image, logits_per_text = model(image, text)
            probs = list(logits_per_image.softmax(dim=-1).cpu().numpy()[0])
        
        return probs[0], probs[1], probs[2] , probs[3]
    except:
        return None

# %%
clip_scores = tmp_df.apply(clip_3, axis=1)

# %%
bf_score = []
aw_score = []
af_score = []
ar_score = []
for el in clip_scores:
#     print(el)
    if el:
        bf_score.append(el[0])
        aw_score.append(el[1])
        af_score.append(el[2])
        ar_score.append(el[3])
    else:
        bf_score.append(None)
        aw_score.append(None)
        af_score.append(None)
        ar_score.append(None)

# %%
tmp_df['bf_score'] = bf_score
tmp_df['aw_score'] = aw_score
tmp_df['af_score'] = af_score
tmp_df['ar_score'] = ar_score

# %%
tmp_df
# Out:
#                                                  image  \
# 0    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4    /9j/7gAOQWRvYmUAZAAAAAAA/9sAQwAIBgYHBgUIBwcHCQ...
# ..                                                 ...
# 615  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 616  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 617  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 618  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 619  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
#                                             bf_caption  \
# 0              a silhouette of a car parked in a field
# 1      a street with a bus and a white car on the road
# 2           a person is getting on a bus at a bus stop
# 3           a person is getting on a bus at a bus stop
# 4    a woman and a child in a wheelchair waiting fo...
# ..                                                 ...
# 615              a gazebo with picnic tables in a park
# 616         a bridge over a river with a body of water
# 617                  a tree in a field next to a fence
# 618      a person holding a camera on a pile of leaves
# 619        a woman wearing a face mask at a playground
#
#                                             aw_caption  \
# 0                 A car parked on the side of the road
# 1    English A pedestrian and cyclists crossing the...
# 2         English A woman boarding a bus at a bus stop
# 3         English A woman boarding a bus at a bus stop
# 4    English A woman in a wheelchair waiting for a ...
# ..                                                 ...
# 615               English A picnic shelter in the park
# 616  English A pedestrian bridge over the river in ...
# 617   English A view from the parking lot of the house
# 618  English woman holding a camera on the ground w...
# 619  English A woman wearing a face mask stands in ...
#
#                                             af_caption topics  \
# 0              a silhouette of a car parked in a field      a
# 1    pedestrians and cars on a pedestrian crossing ...      a
# 2            a woman is getting on a bus at a bus stop      a
# 3            a woman is getting on a bus at a bus stop      a
# 4    a woman in a wheelchair crossing the street in...      a
# ..                                                 ...    ...
# 615  a pavilion with picnic tables and benches in a...      o
# 616                   pedestrian bridge over the river      o
# 617                     a tree in a field with a fence      o
# 618  a woman holding a camera in her hand with autu...      o
# 619  a woman wearing a face mask stands in front of...      o
#
#                                             ar_caption  bf_score  aw_score  \
# 0              a silhouette of a car parked in a field  0.333252  0.000018
# 1    pedestrians and cars on a pedestrian crossing ...  0.630371  0.109558
# 2            a woman is getting on a bus at a bus stop  0.089478  0.029510
# 3            a woman is getting on a bus at a bus stop  0.089478  0.029510
# 4    a woman in a wheelchair crossing the street in...  0.093323  0.002230
# ..                                                 ...       ...       ...
# 615  a pavilion with picnic tables and benches in a...  0.795898  0.025589
# 616                   pedestrian bridge over the river  0.070740  0.211060
# 617                     a tree in a field with a fence  0.150879  0.410156
# 618  a woman holding a camera in her hand with autu...  0.018616  0.351318
# 619  a woman wearing a face mask stands in front of...  0.285889  0.024216
#
#      af_score  ar_score
# 0    0.333252  0.333252
# 1    0.130127  0.130127
# 2    0.440430  0.440430
# 3    0.440430  0.440430
# 4    0.452148  0.452148
# ..        ...       ...
# 615  0.089294  0.089294
# 616  0.359131  0.359131
# 617  0.219482  0.219482
# 618  0.314941  0.314941
# 619  0.344971  0.344971
#
# [620 rows x 10 columns]

# %%
tmp_df = tmp_df.dropna()
tmp_df = tmp_df.reset_index(drop=True)
tmp_df
# Out:
#                                                  image  \
# 0    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4    /9j/7gAOQWRvYmUAZAAAAAAA/9sAQwAIBgYHBgUIBwcHCQ...
# ..                                                 ...
# 614  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 615  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 616  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 617  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 618  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
#                                             bf_caption  \
# 0              a silhouette of a car parked in a field
# 1      a street with a bus and a white car on the road
# 2           a person is getting on a bus at a bus stop
# 3           a person is getting on a bus at a bus stop
# 4    a woman and a child in a wheelchair waiting fo...
# ..                                                 ...
# 614              a gazebo with picnic tables in a park
# 615         a bridge over a river with a body of water
# 616                  a tree in a field next to a fence
# 617      a person holding a camera on a pile of leaves
# 618        a woman wearing a face mask at a playground
#
#                                             aw_caption  \
# 0                 A car parked on the side of the road
# 1    English A pedestrian and cyclists crossing the...
# 2         English A woman boarding a bus at a bus stop
# 3         English A woman boarding a bus at a bus stop
# 4    English A woman in a wheelchair waiting for a ...
# ..                                                 ...
# 614               English A picnic shelter in the park
# 615  English A pedestrian bridge over the river in ...
# 616   English A view from the parking lot of the house
# 617  English woman holding a camera on the ground w...
# 618  English A woman wearing a face mask stands in ...
#
#                                             af_caption topics  \
# 0              a silhouette of a car parked in a field      a
# 1    pedestrians and cars on a pedestrian crossing ...      a
# 2            a woman is getting on a bus at a bus stop      a
# 3            a woman is getting on a bus at a bus stop      a
# 4    a woman in a wheelchair crossing the street in...      a
# ..                                                 ...    ...
# 614  a pavilion with picnic tables and benches in a...      o
# 615                   pedestrian bridge over the river      o
# 616                     a tree in a field with a fence      o
# 617  a woman holding a camera in her hand with autu...      o
# 618  a woman wearing a face mask stands in front of...      o
#
#                                             ar_caption  bf_score  aw_score  \
# 0              a silhouette of a car parked in a field  0.333252  0.000018
# 1    pedestrians and cars on a pedestrian crossing ...  0.630371  0.109558
# 2            a woman is getting on a bus at a bus stop  0.089478  0.029510
# 3            a woman is getting on a bus at a bus stop  0.089478  0.029510
# 4    a woman in a wheelchair crossing the street in...  0.093323  0.002230
# ..                                                 ...       ...       ...
# 614  a pavilion with picnic tables and benches in a...  0.795898  0.025589
# 615                   pedestrian bridge over the river  0.070740  0.211060
# 616                     a tree in a field with a fence  0.150879  0.410156
# 617  a woman holding a camera in her hand with autu...  0.018616  0.351318
# 618  a woman wearing a face mask stands in front of...  0.285889  0.024216
#
#      af_score  ar_score
# 0    0.333252  0.333252
# 1    0.130127  0.130127
# 2    0.440430  0.440430
# 3    0.440430  0.440430
# 4    0.452148  0.452148
# ..        ...       ...
# 614  0.089294  0.089294
# 615  0.359131  0.359131
# 616  0.219482  0.219482
# 617  0.314941  0.314941
# 618  0.344971  0.344971
#
# [619 rows x 10 columns]

# %%
tmp_df.describe().round(2)
# Out:
#        bf_score  aw_score  af_score  ar_score
# count    619.00    619.00    619.00    619.00
# mean       0.32      0.16      0.26      0.26
# std        0.31      0.25      0.17      0.17
# min        0.00      0.00      0.00      0.00
# 25%        0.05      0.00      0.10      0.10
# 50%        0.23      0.04      0.27      0.27
# 75%        0.52      0.20      0.42      0.42
# max        1.00      1.00      0.50      0.50

# %%
gk = tmp_df.groupby('topics')
pg_dict = dict()
for el in gk.groups.keys():
    pg_dict[el] = gk.get_group(el)
    pg_dict[el] = pg_dict[el].reset_index(drop=True)
# # before
# for el in pg_dict:
#     print(el)
#     print(f"{pg_dict[el].describe().round(2).at['mean','aw_score']}, {pg_dict[el].describe().round(2).at['mean','af_score']}, {pg_dict[el].describe().round(2).at['mean','bf_score']}")
#     print()

# %%
data = []
for el in pg_dict:
    data.append([el, pg_dict[el].describe().round(2).at['mean','aw_score'], pg_dict[el].describe().round(2).at['mean','af_score'], pg_dict[el].describe().round(2).at['mean','bf_score'], pg_dict[el].describe().round(2).at['mean','ar_score']])

# %%
df_clip = pd.DataFrame(data, columns = ['Topic', 'App_1', 'App_2', 'Base', 'random'])
df_clip
# Out:
#    Topic  App_1  App_2  Base  random
# 0      a   0.13   0.27  0.34    0.27
# 1      b   0.12   0.27  0.35    0.27
# 2      c   0.18   0.27  0.28    0.27
# 3      d   0.22   0.26  0.26    0.26
# 4      e   0.09   0.24  0.42    0.24
# 5      f   0.12   0.33  0.22    0.33
# 6      g   0.14   0.27  0.32    0.27
# 7      h   0.18   0.23  0.35    0.23
# 8      i   0.26   0.20  0.34    0.20
# 9      j   0.01   0.25  0.49    0.25
# 10     k   0.21   0.28  0.23    0.28
# 11     l   0.16   0.29  0.25    0.29
# 12     m   0.04   0.29  0.38    0.29
# 13     n   0.19   0.28  0.25    0.28
# 14     o   0.11   0.27  0.35    0.27

# %%
df_clip.to_csv(f'ped_clip.csv', index=False)

# %%
gk = tmp_df.groupby('topics')
pg_dict = dict()
for el in gk.groups.keys():
    pg_dict[el] = gk.get_group(el)
    pg_dict[el] = pg_dict[el].reset_index(drop=True)
# before
for el in pg_dict:
    print(el)
    display(pg_dict[el].describe().round(2))
# Out:
# a
#        bf_score  aw_score  af_score
# count     51.00     51.00     51.00
# mean       0.40      0.16      0.44
# std        0.36      0.26      0.34
# min        0.00      0.00      0.01
# 25%        0.06      0.00      0.11
# 50%        0.32      0.05      0.40
# 75%        0.81      0.17      0.75
# max        0.99      0.98      0.98
# b
#        bf_score  aw_score  af_score
# count    103.00    103.00    103.00
# mean       0.42      0.14      0.44
# std        0.31      0.22      0.33
# min        0.00      0.00      0.00
# 25%        0.16      0.00      0.12
# 50%        0.37      0.03      0.40
# 75%        0.65      0.20      0.75
# max        1.00      1.00      1.00
# c
#        bf_score  aw_score  af_score
# count     57.00     57.00     57.00
# mean       0.35      0.22      0.43
# std        0.29      0.26      0.31
# min        0.00      0.00      0.01
# 25%        0.08      0.01      0.19
# 50%        0.25      0.11      0.38
# 75%        0.62      0.33      0.66
# max        0.99      0.97      0.98
# d
#        bf_score  aw_score  af_score
# count     61.00     61.00     61.00
# mean       0.31      0.25      0.44
# std        0.31      0.31      0.35
# min        0.00      0.00      0.00
# 25%        0.03      0.01      0.10
# 50%        0.22      0.09      0.35
# 75%        0.55      0.45      0.72
# max        1.00      0.98      1.00
# e
#        bf_score  aw_score  af_score
# count     46.00     46.00     46.00
# mean       0.50      0.10      0.40
# std        0.35      0.23      0.36
# min        0.00      0.00      0.00
# 25%        0.18      0.00      0.09
# 50%        0.46      0.01      0.31
# 75%        0.85      0.06      0.71
# max        1.00      0.92      1.00
# f
#        bf_score  aw_score  af_score
# count     16.00     16.00     16.00
# mean       0.29      0.15      0.56
# std        0.28      0.24      0.34
# min        0.01      0.00      0.00
# 25%        0.05      0.01      0.31
# 50%        0.27      0.03      0.54
# 75%        0.45      0.17      0.95
# max        0.97      0.73      0.98
# g
#        bf_score  aw_score  af_score
# count     25.00     25.00     25.00
# mean       0.39      0.16      0.44
# std        0.33      0.30      0.35
# min        0.01      0.00      0.00
# 25%        0.08      0.00      0.04
# 50%        0.28      0.01      0.50
# 75%        0.58      0.16      0.75
# max        0.99      0.98      0.96
# h
#        bf_score  aw_score  af_score
# count     28.00     28.00     28.00
# mean       0.41      0.21      0.38
# std        0.33      0.28      0.33
# min        0.00      0.00      0.00
# 25%        0.14      0.00      0.07
# 50%        0.30      0.07      0.32
# 75%        0.66      0.35      0.69
# max        1.00      1.00      0.98
# i
#        bf_score  aw_score  af_score
# count     70.00     70.00     70.00
# mean       0.39      0.29      0.31
# std        0.33      0.30      0.32
# min        0.00      0.00      0.00
# 25%        0.07      0.05      0.06
# 50%        0.32      0.19      0.19
# 75%        0.71      0.44      0.53
# max        1.00      0.95      0.99
# j
#        bf_score  aw_score  af_score
# count      7.00      7.00      7.00
# mean       0.54      0.01      0.45
# std        0.45      0.01      0.45
# min        0.02      0.00      0.00
# 25%        0.09      0.00      0.09
# 50%        0.81      0.00      0.19
# 75%        0.89      0.00      0.91
# max        1.00      0.04      0.98
# k
#        bf_score  aw_score  af_score
# count     41.00     41.00     41.00
# mean       0.29      0.25      0.45
# std        0.27      0.27      0.33
# min        0.00      0.00      0.00
# 25%        0.04      0.05      0.20
# 50%        0.28      0.17      0.37
# 75%        0.48      0.32      0.79
# max        1.00      1.00      0.99
# l
#        bf_score  aw_score  af_score
# count     11.00     11.00     11.00
# mean       0.30      0.18      0.52
# std        0.32      0.32      0.40
# min        0.00      0.00      0.00
# 25%        0.05      0.01      0.14
# 50%        0.17      0.02      0.58
# 75%        0.51      0.17      0.88
# max        0.99      1.00      0.95
# m
#        bf_score  aw_score  af_score
# count     25.00     25.00     25.00
# mean       0.47      0.06      0.47
# std        0.35      0.13      0.32
# min        0.00      0.00      0.00
# 25%        0.16      0.00      0.25
# 50%        0.37      0.01      0.50
# 75%        0.75      0.04      0.73
# max        1.00      0.55      0.99
# n
#        bf_score  aw_score  af_score
# count     29.00     29.00     29.00
# mean       0.31      0.22      0.47
# std        0.30      0.30      0.35
# min        0.00      0.00      0.00
# 25%        0.04      0.01      0.16
# 50%        0.14      0.08      0.37
# 75%        0.53      0.18      0.85
# max        0.89      0.95      0.99
# o
#        bf_score  aw_score  af_score
# count     49.00     49.00     49.00
# mean       0.43      0.13      0.43
# std        0.31      0.22      0.29
# min        0.00      0.00      0.00
# 25%        0.12      0.00      0.27
# 50%        0.42      0.03      0.39
# 75%        0.63      0.19      0.57
# max        1.00      0.98      1.00
