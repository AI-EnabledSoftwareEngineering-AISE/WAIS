# %%
import os

# General packages
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import plotly.express as px
import PIL.Image
from tqdm.notebook import tqdm, trange
import glob
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

from IPython.display import Image as IImage
from IPython.display import display
import warnings
warnings.filterwarnings("ignore")
tqdm.pandas()

# %%
import torch
import clip
from PIL import Image

import os

# %%
from sentence_transformers import SentenceTransformer, util
embedder = SentenceTransformer('all-MiniLM-L6-v2')

# %%
os.listdir('/raid/AISSEL/Hamed/datasets/ped_data/ped_fatemeh/all')
# Out:
# ['caption_stage1_train_all_topics_ped.tsv',
#  'caption_stage2_train_all_topics_ped.tsv',
#  'caption_val_all_topics_ped.tsv',
#  'caption_test_all_topics_ped.tsv',
#  'checkpoint1_best.pt',
#  'checkpoint2_best.pt',
#  'test_prediction_trained_on_all.pk',
#  'test_after_trained_on_all_ped.pk',
#  'test_before_trained_on_all_ped.pk']

# %%
def find_gpus(nums=6):
    os.system('nvidia-smi -q -d Memory |grep -A4 GPU|grep Free >tmp_free_gpus')
    with open('tmp_free_gpus', 'r') as lines_txt:
        frees = lines_txt.readlines()
        idx_freeMemory_pair = [ (idx,int(x.split()[2]))
                              for idx,x in enumerate(frees) ]
    idx_freeMemory_pair.sort(key=lambda my_tuple:my_tuple[1],reverse=True)
    usingGPUs = [str(idx_memory_pair[0])
                    for idx_memory_pair in idx_freeMemory_pair[:nums] ]
    usingGPUs =  ','.join(usingGPUs)
    print('using GPU idx: #', usingGPUs)
    return usingGPUs

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = find_gpus(nums=2)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print()
# Out:
# using GPU idx: # 1,0
# Using device: cuda

# %% [markdown]
# ## get topics

# %%
from bertopic import BERTopic
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

# %%
lemmatizer = WordNetLemmatizer()

# %%
# def get_topics(concept='pedestrian'):
#     if concept == 'pedestrian':
#         model_path = '../ped_auto_model'
#     elif concept == 'aircraft':
#         model_path = '../aircraft_auto_model'
#     elif concept == 'car':
#         model_path = '../car_auto_model'
#     auto_model = BERTopic(nr_topics="auto")
#     auto_model = BERTopic.load(model_path)
#     similar_topics, similarity = auto_model.find_topics(concept, top_n=50)

#     topics = dict()
#     for t in similar_topics:
#         l1 = auto_model.get_topic(t)
#         el_list = []
#         el_list.append(concept)
#         for el in l1:
#             w = lemmatizer.lemmatize(el[0], get_wordnet_pos(el[0]))
#             el_list.append(w)
#         topics[t]= set(el_list)
#     return topics

# %%
# auto_model = BERTopic(nr_topics="auto")
# auto_model = BERTopic.load('../aircraft_auto_model')

# %%
# av_similar_topics, av_similarity =auto_model.find_topics("aircraft", top_n=50)
# print(av_similar_topics)

# %%
topics = {196: {'cross',
  'crossing',
  'crosswalk',
  'pedestrian',
  'signal',
  'stripe',
  'traffic'},
 412: {'arrest',
  'pedestrian',
  'perp',
  'pers',
  'walk',
  'walkability',
  'walkable'},
 172: {'car',
  'lane',
  'pedestrian',
  'road',
  'street',
  'traffic',
  'transportation',
  'vehicle'},
 363: {'assault',
  'bystander',
  'intervene',
  'intervention',
  'pedestrian',
  'stalk',
  'stalker',
  'victim',
  'witness'},
 198: {'car',
  'garage',
  'park',
  'parking',
  'parkjockey',
  'pedestrian',
  'tow',
  'vehicle'},
 114: {'athlete',
  'disability',
  'paralympic',
  'paralympics',
  'pedestrian',
  'sport',
  'sportspeople',
  'wheelchair'},
 419: {'avenue',
  'boulevard',
  'intersection',
  'manhattan',
  'pedestrian',
  'road',
  'street',
  'suffix'},
 294: {'drive',
  'fine',
  'licence',
  'offence',
  'pedestrian',
  'penalty',
  'reckless',
  'speed',
  'ticket',
  'traffic',
  'violation'},
 388: {'brownian',
  'diffusion',
  'distribution',
  'markov',
  'pedestrian',
  'percolation',
  'step',
  'stochastic',
  'walk',
  'wiener'},
 314: {'circle',
  'interchange',
  'intersection',
  'junction',
  'lane',
  'pedestrian',
  'road',
  'roundabout',
  'traffic'},
 98: {'cross',
  'direction',
  'lane',
  'marker',
  'parking',
  'pedestrian',
  'road',
  'sign',
  'signage',
  'traffic'},
 80: {'accident',
  'brake',
  'collision',
  'drive',
  'fatality',
  'momentum',
  'nhtsa',
  'pedestrian',
  'vehicle',
  'velocity'},
 134: {'avenue',
  'edmonton',
  'expressway',
  'freeway',
  'gardiner',
  'highway',
  'lane',
  'ontario',
  'pedestrian',
  'road',
  'toronto'},
 432: {'alice',
  'book',
  'fiction',
  'novel',
  'pedestrian',
  'poem',
  'poetry',
  'pulitzer',
  'walker'},
 394: {'alley',
  'boulevard',
  'bridleway',
  'bridleways',
  'footpath',
  'path',
  'pedestrian'},
 53: {'asphalt',
  'cement',
  'concrete',
  'gravel',
  'pave',
  'pavement',
  'pedestrian',
  'pothole',
  'road',
  'sand'},
 56: {'bus',
  'pedestrian',
  'streetcar',
  'subway',
  'train',
  'tram',
  'transit',
  'transportation',
  'trolley'},
 150: {'freeway',
  'highway',
  'intersection',
  'lane',
  'pedestrian',
  'ramp',
  'road',
  'traffic'},
 278: {'deck',
  'park',
  'pedestrian',
  'promenade',
  'promenadef',
  'promenaden',
  'promener',
  'walk'},
 -1: {'american',
  'century',
  'example',
  'film',
  'her',
  'pedestrian',
  'public',
  'state',
  'street',
  'water'},
 43: {'black',
  'civil',
  'negro',
  'pedestrian',
  'protest',
  'protester',
  'race',
  'racial',
  'segregation',
  'white'},
 265: {'baby',
  'carriage',
  'child',
  'diaper',
  'harness',
  'hatch',
  'infant',
  'pedestrian',
  'stroller'},
 345: {'barrier',
  'bumper',
  'guardrail',
  'hazard',
  'pedestrian',
  'protect',
  'rail',
  'safety'},
 378: {'architect',
  'architecture',
  'building',
  'chicago',
  'city',
  'frederick',
  'park',
  'pedestrian'},
 11: {'freeway',
  'highway',
  'intersection',
  'interstate',
  'lane',
  'pedestrian',
  'road',
  'route',
  'terminus',
  'turnpike'},
 331: {'byway',
  'highway',
  'navajo',
  'parkway',
  'pedestrian',
  'road',
  'roadway',
  'route',
  'scenic'},
 202: {'bottleneck',
  'congest',
  'congestion',
  'delay',
  'downstream',
  'pedestrian',
  'road',
  'speed',
  'traffic',
  'vehicle'},
 169: {'apartment',
  'condominium',
  'home',
  'homeless',
  'homelessness',
  'house',
  'household',
  'housing',
  'pedestrian',
  'shelter'},
 327: {'bartholdi',
  'lazarus',
  'liberty',
  'monument',
  'pedestal',
  'pedestrian',
  'sculptor',
  'sculpture',
  'statue',
  'torch'},
 309: {'adelaide',
  'carriageworks',
  'close',
  'geelong',
  'line',
  'melbourne',
  'pedestrian',
  'rail',
  'railway',
  'train'},
 68: {'axle',
  'carriage',
  'chariot',
  'passenger',
  'pedestrian',
  'vehicle',
  'wagon',
  'wheel'},
 216: {'carriageway',
  'lane',
  'm1',
  'm11',
  'm25',
  'm32',
  'motorway',
  'pedestrian',
  'road',
  'roundabout'},
 40: {'arrest',
  'constable',
  'constabulary',
  'enforcement',
  'officer',
  'patrol',
  'pedestrian',
  'police'},
 99: {'building',
  'concrete',
  'construction',
  'insulation',
  'masonry',
  'pedestrian',
  'roof',
  'structure',
  'wall'},
 426: {'80211p',
  'cv2x',
  'pedestrian',
  'unlock',
  'v2v',
  'v2x',
  'vanet',
  'vanets',
  'vehicle',
  'vehicular'},
 344: {'adriatic',
  'censor',
  'corniche',
  'itinerary',
  'pave',
  'pedestrian',
  'road',
  'roman',
  'rome'},
 47: {'avenue',
  'bmt',
  'broadway',
  'broadwayseventh',
  'brooklyn',
  'manhattan',
  'pedestrian',
  'station',
  'subway',
  'train'},
 8: {'bicycle',
  'bike',
  'cycle',
  'cycling',
  'cyclist',
  'pedestrian',
  'rid',
  'rider',
  'tire'},
 416: {'descriptor',
  'detection',
  'detector',
  'keypoints',
  'ocr',
  'pedestrian',
  'pixel',
  'recognition',
  'sift',
  'vision'},
 112: {'bus',
  'congestion',
  'freight',
  'passenger',
  'pedestrian',
  'route',
  'traffic',
  'transit',
  'transport',
  'transportation'},
 137: {'expressway',
  'freeway',
  'highway',
  'lane',
  'motorway',
  'pedestrian',
  'road'},
 441: {'actor',
  'character',
  'drama',
  'hamlet',
  'novel',
  'pedestrian',
  'protagonist',
  'romeo',
  'shakespeare'},
 192: {'ataxia',
  'cerebellar',
  'cerebellum',
  'cerebral',
  'diplegia',
  'disorder',
  'gait',
  'palsy',
  'pedestrian',
  'symptom',
  'syndrome'},
 20: {'ankle', 'dance', 'dancer', 'foot', 'leg', 'pedestrian', 'toe'},
 296: {'area',
  'monument',
  'park',
  'pedestrian',
  'playground',
  'recreation',
  'scenic',
  'wilderness',
  'yellowstone'},
 144: {'',
  'address',
  'comma',
  'image',
  'more',
  'pedestrian',
  'person',
  'separate',
  'share',
  'video'},
 12: {'appalachian',
  'footpath',
  'hike',
  'hiker',
  'mountain',
  'path',
  'pedestrian',
  'trail'},
 224: {'bus',
  'depot',
  'fleet',
  'goahead',
  'pedestrian',
  'sb',
  'singapore',
  'smrt',
  'tram',
  'transit'},
 250: {'driver',
  'graphic',
  'kernel',
  'kernelmode',
  'kmdf',
  'linux',
  'pedestrian',
  'printer',
  'umdf',
  'usb'},
 376: {'bear',
  'cartoon',
  'charlie',
  'disney',
  'lucy',
  'mickey',
  'peanut',
  'pedestrian',
  'snoopy',
  'trolley'}}

# %%
# topics = get_topics(concept='aircraft')
q_id = [el for el in topics]

# %%
for el in topics:
    print(el, topics[el])
# Out:
# 196 {'cross', 'crossing', 'signal', 'traffic', 'crosswalk', 'stripe', 'pedestrian'}
# 412 {'arrest', 'walkable', 'perp', 'walk', 'pers', 'walkability', 'pedestrian'}
# 172 {'car', 'lane', 'traffic', 'transportation', 'street', 'vehicle', 'road', 'pedestrian'}
# 363 {'stalk', 'intervene', 'victim', 'bystander', 'assault', 'witness', 'intervention', 'stalker', 'pedestrian'}
# 198 {'garage', 'car', 'park', 'parking', 'vehicle', 'parkjockey', 'tow', 'pedestrian'}
# 114 {'paralympic', 'sport', 'athlete', 'wheelchair', 'disability', 'paralympics', 'sportspeople', 'pedestrian'}
# 419 {'avenue', 'road', 'street', 'intersection', 'manhattan', 'boulevard', 'suffix', 'pedestrian'}
# 294 {'violation', 'drive', 'traffic', 'licence', 'speed', 'ticket', 'fine', 'reckless', 'offence', 'penalty', 'pedestrian'}
# 388 {'step', 'percolation', 'brownian', 'stochastic', 'wiener', 'diffusion', 'distribution', 'walk', 'markov', 'pedestrian'}
# 314 {'interchange', 'junction', 'roundabout', 'circle', 'lane', 'traffic', 'intersection', 'road', 'pedestrian'}
# 98 {'sign', 'cross', 'lane', 'traffic', 'marker', 'parking', 'road', 'signage', 'direction', 'pedestrian'}
# 80 {'brake', 'nhtsa', 'accident', 'drive', 'collision', 'velocity', 'fatality', 'vehicle', 'momentum', 'pedestrian'}
# 134 {'avenue', 'freeway', 'ontario', 'toronto', 'highway', 'lane', 'pedestrian', 'edmonton', 'gardiner', 'road', 'expressway'}
# 432 {'walker', 'fiction', 'pulitzer', 'poem', 'poetry', 'book', 'alice', 'novel', 'pedestrian'}
# 394 {'alley', 'bridleway', 'pedestrian', 'footpath', 'boulevard', 'path', 'bridleways'}
# 53 {'gravel', 'pave', 'sand', 'pavement', 'cement', 'pothole', 'asphalt', 'road', 'concrete', 'pedestrian'}
# 56 {'streetcar', 'trolley', 'bus', 'transportation', 'tram', 'subway', 'transit', 'train', 'pedestrian'}
# 150 {'freeway', 'highway', 'lane', 'traffic', 'intersection', 'road', 'ramp', 'pedestrian'}
# 278 {'promenadef', 'deck', 'park', 'promenade', 'promenaden', 'promener', 'walk', 'pedestrian'}
# -1 {'example', 'film', 'american', 'state', 'street', 'her', 'water', 'public', 'century', 'pedestrian'}
# 43 {'negro', 'race', 'black', 'civil', 'white', 'racial', 'protest', 'protester', 'segregation', 'pedestrian'}
# 265 {'carriage', 'child', 'hatch', 'baby', 'harness', 'infant', 'stroller', 'diaper', 'pedestrian'}
# 345 {'rail', 'protect', 'safety', 'guardrail', 'bumper', 'hazard', 'barrier', 'pedestrian'}
# 378 {'architecture', 'building', 'park', 'pedestrian', 'frederick', 'chicago', 'architect', 'city'}
# 11 {'freeway', 'terminus', 'highway', 'lane', 'interstate', 'intersection', 'route', 'turnpike', 'road', 'pedestrian'}
# 331 {'navajo', 'highway', 'byway', 'parkway', 'route', 'scenic', 'road', 'roadway', 'pedestrian'}
# 202 {'road', 'delay', 'traffic', 'congestion', 'bottleneck', 'speed', 'vehicle', 'downstream', 'congest', 'pedestrian'}
# 169 {'home', 'household', 'shelter', 'pedestrian', 'condominium', 'apartment', 'homeless', 'homelessness', 'house', 'housing'}
# 327 {'liberty', 'sculpture', 'bartholdi', 'pedestal', 'torch', 'statue', 'lazarus', 'monument', 'sculptor', 'pedestrian'}
# 309 {'geelong', 'line', 'carriageworks', 'rail', 'adelaide', 'close', 'railway', 'melbourne', 'train', 'pedestrian'}
# 68 {'carriage', 'wheel', 'chariot', 'wagon', 'passenger', 'vehicle', 'axle', 'pedestrian'}
# 216 {'motorway', 'roundabout', 'lane', 'm32', 'm1', 'm25', 'm11', 'road', 'carriageway', 'pedestrian'}
# 40 {'arrest', 'officer', 'enforcement', 'police', 'constable', 'patrol', 'constabulary', 'pedestrian'}
# 99 {'roof', 'concrete', 'building', 'structure', 'insulation', 'wall', 'masonry', 'construction', 'pedestrian'}
# 426 {'v2x', 'vanets', 'vanet', 'vehicular', 'cv2x', 'v2v', 'unlock', 'vehicle', '80211p', 'pedestrian'}
# 344 {'corniche', 'adriatic', 'pave', 'censor', 'rome', 'roman', 'road', 'itinerary', 'pedestrian'}
# 47 {'broadway', 'avenue', 'bmt', 'broadwayseventh', 'brooklyn', 'subway', 'manhattan', 'station', 'train', 'pedestrian'}
# 8 {'tire', 'cyclist', 'cycling', 'bicycle', 'bike', 'rider', 'cycle', 'rid', 'pedestrian'}
# 416 {'ocr', 'vision', 'descriptor', 'detector', 'pixel', 'recognition', 'keypoints', 'sift', 'detection', 'pedestrian'}
# 112 {'bus', 'traffic', 'transportation', 'congestion', 'freight', 'passenger', 'route', 'transit', 'transport', 'pedestrian'}
# 137 {'motorway', 'freeway', 'highway', 'lane', 'pedestrian', 'road', 'expressway'}
# 441 {'drama', 'protagonist', 'hamlet', 'romeo', 'actor', 'shakespeare', 'novel', 'character', 'pedestrian'}
# 192 {'cerebellum', 'diplegia', 'gait', 'syndrome', 'symptom', 'disorder', 'palsy', 'cerebellar', 'ataxia', 'cerebral', 'pedestrian'}
# 20 {'dancer', 'toe', 'leg', 'ankle', 'foot', 'dance', 'pedestrian'}
# 296 {'wilderness', 'park', 'yellowstone', 'recreation', 'scenic', 'area', 'playground', 'monument', 'pedestrian'}
# 144 {'', 'address', 'separate', 'share', 'video', 'more', 'person', 'comma', 'image', 'pedestrian'}
# 12 {'appalachian', 'mountain', 'trail', 'hike', 'footpath', 'path', 'hiker', 'pedestrian'}
# 224 {'smrt', 'sb', 'fleet', 'bus', 'depot', 'goahead', 'transit', 'tram', 'singapore', 'pedestrian'}
# 250 {'usb', 'kernelmode', 'graphic', 'kernel', 'printer', 'pedestrian', 'driver', 'linux', 'umdf', 'kmdf'}
# 376 {'peanut', 'trolley', 'charlie', 'snoopy', 'mickey', 'cartoon', 'bear', 'lucy', 'disney', 'pedestrian'}

# %%
topics[80]
# Out:
# {'accident',
#  'brake',
#  'collision',
#  'drive',
#  'fatality',
#  'momentum',
#  'nhtsa',
#  'pedestrian',
#  'vehicle',
#  'velocity'}

# %%
pg_t = dict()
pg_t['a'] = [68, 112, 56, 224]
pg_t['b'] = [309, 344, 47, -1, 53]
pg_t['c'] = [314, 331, 419, 394]
pg_t['d'] = [98, 196, 202, 294]
pg_t['e'] = [172, 137, 11, 134, 150, 216]
pg_t['f'] = [363, 40, 43]
pg_t['g'] = [441, 376]
pg_t['h'] = [144, 416, 327]
pg_t['i'] = [192, 20, 114]
pg_t['j'] = [345]
pg_t['k'] = [8, 265]
pg_t['l'] = [250, 80, 426]
pg_t['m'] = [169, 99, 378]
pg_t['n'] = [432, 388, 412]
pg_t['o'] = [12, 278, 198, 296]

# %%
for el in pg_t:
    group_words = []
    for t in pg_t[el]:
        group_words.extend(list(topics[t]))
#         break
    pg_t[el]= list(set(group_words))

# %%
print(pg_t[el])
# Out:
# ['garage', 'appalachian', 'mountain', 'wilderness', 'park', 'yellowstone', 'walk', 'footpath', 'recreation', 'car', 'promenadef', 'trail', 'promenaden', 'parkjockey', 'playground', 'tow', 'monument', 'hiker', 'pedestrian', 'promenade', 'hike', 'vehicle', 'deck', 'promener', 'parking', 'scenic', 'area', 'path']

# %%
for g in pg_t:
    pg_t[g] = ' '.join(pg_t[g])

# %%
pg_t[g]
# Out:
# 'garage appalachian mountain wilderness park yellowstone walk footpath recreation car promenadef trail promenaden parkjockey playground tow monument hiker pedestrian promenade hike vehicle deck promener parking scenic area path'

# %%
toopic_dict = dict()
for el in topics:
    toopic_dict[el] = ' '.join(topics[el])
toopic_dict[el]
# Out:
# 'peanut trolley charlie snoopy mickey cartoon bear lucy disney pedestrian'

# %% [markdown]
# ## Load Predictions

# %%
model, preprocess = clip.load("ViT-B/32", device=device, jit=False)

# %%
# pd.set_option('display.max_rows', None)

d_path = '/raid/AISSEL/Hamed/datasets/ped_data/ped_fatemeh/all'
# before
df = pd.read_pickle(f'{d_path}/test_before_trained_on_all_ped.pk')

#after
# df = pd.read_pickle(f'{d_path}/test_after_trained_on_all_ped.pk')

# wit
# d_path = '/raid/AISSEL/Hamed/datasets/ped_data/wit/all_topics'
# df = pd.read_pickle(f'{d_path}/wit_ped_test_after.pk')
df
# Out:
#      uniq_id  image_id                                            caption  \
# 0        167       167               Car on rural road vector Stock Photo
# 1        184       184           Bus Only Lane Rendering Kuhio and Walina
# 2        187       187               Passenger boarding a bus on Bayshore
# 3        192       192               Passenger boarding a bus on Bayshore
# 4        209       209         Pedestrian Connections Congestion Strategy
# ..       ...       ...                                                ...
# 644     1228      1228          Westown Commons picnic shelter front view
# 645     1241      1241                        Humboldt Alexander Von Park
# 646     1259      1259  photo of trees and the fenceline at Mason Hill...
# 647     1296      1296                                Hogback Ridge Park
# 648     1306      1306          Playground and park unveiled in Jamaica 4
#
#      topic_id labels                                              image  \
# 0          68         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4         112         /9j/7gAOQWRvYmUAZAAAAAAA/9sAQwAIBgYHBgUIBwcHCQ...
# ..        ...    ...                                                ...
# 644       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 645       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 646       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 647       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 648       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
#      topic2caption_sim  concept2caption_sim topics  \
# 0             0.376758             0.212455      a
# 1             0.392783             0.160691      a
# 2             0.438588             0.197647      a
# 3             0.438588             0.197647      a
# 4             0.612697             0.493012      a
# ..                 ...                  ...    ...
# 644           0.395052             0.217862      o
# 645           0.415312             0.211162      o
# 646           0.446961             0.234170      o
# 647           0.579372             0.235827      o
# 648           0.499459             0.164558      o
#
#                                                    tag  \
# 0    {'passenger': 0, 'wheel': 1, 'vehicle': 1, 'wa...
# 1    {'freight': 1, 'transportation': 1, 'traffic':...
# 2    {'freight': 1, 'transportation': 1, 'traffic':...
# 3    {'freight': 1, 'transportation': 1, 'traffic':...
# 4    {'freight': 1, 'transportation': 1, 'traffic':...
# ..                                                 ...
# 644  {'scenic': 0, 'recreation': 1, 'wilderness': 0...
# 645  {'scenic': 1, 'recreation': 1, 'wilderness': 0...
# 646  {'scenic': 1, 'recreation': 1, 'wilderness': 0...
# 647  {'scenic': 1, 'recreation': 1, 'wilderness': 0...
# 648  {'scenic': 0, 'recreation': 1, 'wilderness': 0...
#
#                                            ofa_caption  \
# 0              a silhouette of a car parked in a field
# 1      a street with a bus and a white car on the road
# 2           a person is getting on a bus at a bus stop
# 3           a person is getting on a bus at a bus stop
# 4    a woman and a child in a wheelchair waiting fo...
# ..                                                 ...
# 644              a gazebo with picnic tables in a park
# 645         a bridge over a river with a body of water
# 646                  a tree in a field next to a fence
# 647      a person holding a camera on a pile of leaves
# 648        a woman wearing a face mask at a playground
#
#                                                     gt
# 0                                        wheel vehicle
# 1     freight transportation traffic transport tran...
# 2     freight transportation traffic transport tran...
# 3     freight transportation traffic transport tran...
# 4     freight transportation traffic transport cong...
# ..                                                 ...
# 644                               recreation park area
# 645             scenic recreation park area pedestrian
# 646                        scenic recreation park area
# 647                        scenic recreation park area
# 648         recreation park area pedestrian playground
#
# [649 rows x 12 columns]

# %%
df['tag'].isna().sum()
# Out:
# 0

# %%
df = df[df['tag'].notna()]
df = df.reset_index(drop=True)
len(df)
# Out:
# 649

# %%
pedestrian_list = ['people', 'someone', 'individual', 'worker', 'child', 'human', 
                   'somebody', 'man', 'boy', 'human', 'person', 'mankind', 
                   'humankind', 'guy', 'gentleman', 'someone', 'girl', 'men', 
                   'woman', 'women', 'lady', 'madam', 'pedestrian', 'kid']

# %%
def create_gt(tag):
    context = ""
    for el in tag:
        if tag[el]:
            context = context + " " + el
    if not context:
        context = None
    return context

# %%
df['gt'] = df.apply(lambda x: create_gt(x.tag), axis=1)
df
# Out:
#      uniq_id  image_id                                            caption  \
# 0        167       167               Car on rural road vector Stock Photo
# 1        184       184           Bus Only Lane Rendering Kuhio and Walina
# 2        187       187               Passenger boarding a bus on Bayshore
# 3        192       192               Passenger boarding a bus on Bayshore
# 4        209       209         Pedestrian Connections Congestion Strategy
# ..       ...       ...                                                ...
# 644     1228      1228          Westown Commons picnic shelter front view
# 645     1241      1241                        Humboldt Alexander Von Park
# 646     1259      1259  photo of trees and the fenceline at Mason Hill...
# 647     1296      1296                                Hogback Ridge Park
# 648     1306      1306          Playground and park unveiled in Jamaica 4
#
#      topic_id labels                                              image  \
# 0          68         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4         112         /9j/7gAOQWRvYmUAZAAAAAAA/9sAQwAIBgYHBgUIBwcHCQ...
# ..        ...    ...                                                ...
# 644       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 645       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 646       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 647       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 648       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
#      topic2caption_sim  concept2caption_sim topics  \
# 0             0.376758             0.212455      a
# 1             0.392783             0.160691      a
# 2             0.438588             0.197647      a
# 3             0.438588             0.197647      a
# 4             0.612697             0.493012      a
# ..                 ...                  ...    ...
# 644           0.395052             0.217862      o
# 645           0.415312             0.211162      o
# 646           0.446961             0.234170      o
# 647           0.579372             0.235827      o
# 648           0.499459             0.164558      o
#
#                                                    tag  \
# 0    {'passenger': 0, 'wheel': 1, 'vehicle': 1, 'wa...
# 1    {'freight': 1, 'transportation': 1, 'traffic':...
# 2    {'freight': 1, 'transportation': 1, 'traffic':...
# 3    {'freight': 1, 'transportation': 1, 'traffic':...
# 4    {'freight': 1, 'transportation': 1, 'traffic':...
# ..                                                 ...
# 644  {'scenic': 0, 'recreation': 1, 'wilderness': 0...
# 645  {'scenic': 1, 'recreation': 1, 'wilderness': 0...
# 646  {'scenic': 1, 'recreation': 1, 'wilderness': 0...
# 647  {'scenic': 1, 'recreation': 1, 'wilderness': 0...
# 648  {'scenic': 0, 'recreation': 1, 'wilderness': 0...
#
#                                            ofa_caption  \
# 0              a silhouette of a car parked in a field
# 1      a street with a bus and a white car on the road
# 2           a person is getting on a bus at a bus stop
# 3           a person is getting on a bus at a bus stop
# 4    a woman and a child in a wheelchair waiting fo...
# ..                                                 ...
# 644              a gazebo with picnic tables in a park
# 645         a bridge over a river with a body of water
# 646                  a tree in a field next to a fence
# 647      a person holding a camera on a pile of leaves
# 648        a woman wearing a face mask at a playground
#
#                                                     gt
# 0                                        wheel vehicle
# 1     freight transportation traffic transport tran...
# 2     freight transportation traffic transport tran...
# 3     freight transportation traffic transport tran...
# 4     freight transportation traffic transport cong...
# ..                                                 ...
# 644                               recreation park area
# 645             scenic recreation park area pedestrian
# 646                        scenic recreation park area
# 647                        scenic recreation park area
# 648         recreation park area pedestrian playground
#
# [649 rows x 12 columns]

# %%
print(df['gt'].isna().sum())
df = df[df['gt'].notna()]
df = df.reset_index(drop=True)
len(df)
# Out:
# 26
# 623

# %%
dff = df.dropna()
dff
# Out:
#      uniq_id  image_id                                            caption  \
# 0        167       167               Car on rural road vector Stock Photo
# 1        184       184           Bus Only Lane Rendering Kuhio and Walina
# 2        187       187               Passenger boarding a bus on Bayshore
# 3        192       192               Passenger boarding a bus on Bayshore
# 4        209       209         Pedestrian Connections Congestion Strategy
# ..       ...       ...                                                ...
# 618     1228      1228          Westown Commons picnic shelter front view
# 619     1241      1241                        Humboldt Alexander Von Park
# 620     1259      1259  photo of trees and the fenceline at Mason Hill...
# 621     1296      1296                                Hogback Ridge Park
# 622     1306      1306          Playground and park unveiled in Jamaica 4
#
#      topic_id labels                                              image  \
# 0          68         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4         112         /9j/7gAOQWRvYmUAZAAAAAAA/9sAQwAIBgYHBgUIBwcHCQ...
# ..        ...    ...                                                ...
# 618       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 619       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 620       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 621       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 622       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
#      topic2caption_sim  concept2caption_sim topics  \
# 0             0.376758             0.212455      a
# 1             0.392783             0.160691      a
# 2             0.438588             0.197647      a
# 3             0.438588             0.197647      a
# 4             0.612697             0.493012      a
# ..                 ...                  ...    ...
# 618           0.395052             0.217862      o
# 619           0.415312             0.211162      o
# 620           0.446961             0.234170      o
# 621           0.579372             0.235827      o
# 622           0.499459             0.164558      o
#
#                                                    tag  \
# 0    {'passenger': 0, 'wheel': 1, 'vehicle': 1, 'wa...
# 1    {'freight': 1, 'transportation': 1, 'traffic':...
# 2    {'freight': 1, 'transportation': 1, 'traffic':...
# 3    {'freight': 1, 'transportation': 1, 'traffic':...
# 4    {'freight': 1, 'transportation': 1, 'traffic':...
# ..                                                 ...
# 618  {'scenic': 0, 'recreation': 1, 'wilderness': 0...
# 619  {'scenic': 1, 'recreation': 1, 'wilderness': 0...
# 620  {'scenic': 1, 'recreation': 1, 'wilderness': 0...
# 621  {'scenic': 1, 'recreation': 1, 'wilderness': 0...
# 622  {'scenic': 0, 'recreation': 1, 'wilderness': 0...
#
#                                            ofa_caption  \
# 0              a silhouette of a car parked in a field
# 1      a street with a bus and a white car on the road
# 2           a person is getting on a bus at a bus stop
# 3           a person is getting on a bus at a bus stop
# 4    a woman and a child in a wheelchair waiting fo...
# ..                                                 ...
# 618              a gazebo with picnic tables in a park
# 619         a bridge over a river with a body of water
# 620                  a tree in a field next to a fence
# 621      a person holding a camera on a pile of leaves
# 622        a woman wearing a face mask at a playground
#
#                                                     gt
# 0                                        wheel vehicle
# 1     freight transportation traffic transport tran...
# 2     freight transportation traffic transport tran...
# 3     freight transportation traffic transport tran...
# 4     freight transportation traffic transport cong...
# ..                                                 ...
# 618                               recreation park area
# 619             scenic recreation park area pedestrian
# 620                        scenic recreation park area
# 621                        scenic recreation park area
# 622         recreation park area pedestrian playground
#
# [623 rows x 12 columns]

# %%
# pedestrian_list
def flag_search_gt(tag, t):
    context = ""
    for el in tag:
        if tag[el]:
            context = context + " " + el
        
    for w in t:
        if w in context:
            return float(1)
    return float(0)

# %%
def get_percentage(tag):
    sum_val = 0
    for el in tag:
        sum_val = sum_val + tag[el]
    return sum_val / len(tag)

# %%
df['gt_coverage'] = df.apply(lambda x: get_percentage(x.tag), axis=1)

# %%
df
# Out:
#      uniq_id  image_id                                            caption  \
# 0        167       167               Car on rural road vector Stock Photo
# 1        184       184           Bus Only Lane Rendering Kuhio and Walina
# 2        187       187               Passenger boarding a bus on Bayshore
# 3        192       192               Passenger boarding a bus on Bayshore
# 4        209       209         Pedestrian Connections Congestion Strategy
# ..       ...       ...                                                ...
# 618     1228      1228          Westown Commons picnic shelter front view
# 619     1241      1241                        Humboldt Alexander Von Park
# 620     1259      1259  photo of trees and the fenceline at Mason Hill...
# 621     1296      1296                                Hogback Ridge Park
# 622     1306      1306          Playground and park unveiled in Jamaica 4
#
#      topic_id labels                                              image  \
# 0          68         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4         112         /9j/7gAOQWRvYmUAZAAAAAAA/9sAQwAIBgYHBgUIBwcHCQ...
# ..        ...    ...                                                ...
# 618       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 619       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 620       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 621       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 622       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
#      topic2caption_sim  concept2caption_sim topics  \
# 0             0.376758             0.212455      a
# 1             0.392783             0.160691      a
# 2             0.438588             0.197647      a
# 3             0.438588             0.197647      a
# 4             0.612697             0.493012      a
# ..                 ...                  ...    ...
# 618           0.395052             0.217862      o
# 619           0.415312             0.211162      o
# 620           0.446961             0.234170      o
# 621           0.579372             0.235827      o
# 622           0.499459             0.164558      o
#
#                                                    tag  \
# 0    {'passenger': 0, 'wheel': 1, 'vehicle': 1, 'wa...
# 1    {'freight': 1, 'transportation': 1, 'traffic':...
# 2    {'freight': 1, 'transportation': 1, 'traffic':...
# 3    {'freight': 1, 'transportation': 1, 'traffic':...
# 4    {'freight': 1, 'transportation': 1, 'traffic':...
# ..                                                 ...
# 618  {'scenic': 0, 'recreation': 1, 'wilderness': 0...
# 619  {'scenic': 1, 'recreation': 1, 'wilderness': 0...
# 620  {'scenic': 1, 'recreation': 1, 'wilderness': 0...
# 621  {'scenic': 1, 'recreation': 1, 'wilderness': 0...
# 622  {'scenic': 0, 'recreation': 1, 'wilderness': 0...
#
#                                            ofa_caption  \
# 0              a silhouette of a car parked in a field
# 1      a street with a bus and a white car on the road
# 2           a person is getting on a bus at a bus stop
# 3           a person is getting on a bus at a bus stop
# 4    a woman and a child in a wheelchair waiting fo...
# ..                                                 ...
# 618              a gazebo with picnic tables in a park
# 619         a bridge over a river with a body of water
# 620                  a tree in a field next to a fence
# 621      a person holding a camera on a pile of leaves
# 622        a woman wearing a face mask at a playground
#
#                                                     gt  gt_coverage
# 0                                        wheel vehicle     0.250000
# 1     freight transportation traffic transport tran...     0.800000
# 2     freight transportation traffic transport tran...     0.800000
# 3     freight transportation traffic transport tran...     0.800000
# 4     freight transportation traffic transport cong...     0.900000
# ..                                                 ...          ...
# 618                               recreation park area     0.333333
# 619             scenic recreation park area pedestrian     0.555556
# 620                        scenic recreation park area     0.444444
# 621                        scenic recreation park area     0.444444
# 622         recreation park area pedestrian playground     0.555556
#
# [623 rows x 13 columns]

# %%
# pd.set_option('display.max_rows', None)
ofa_cap = df[['ofa_caption']]
ofa_cap
# Out:
#                                            ofa_caption
# 0              a silhouette of a car parked in a field
# 1      a street with a bus and a white car on the road
# 2           a person is getting on a bus at a bus stop
# 3           a person is getting on a bus at a bus stop
# 4    a woman and a child in a wheelchair waiting fo...
# ..                                                 ...
# 618              a gazebo with picnic tables in a park
# 619         a bridge over a river with a body of water
# 620                  a tree in a field next to a fence
# 621      a person holding a camera on a pile of leaves
# 622        a woman wearing a face mask at a playground
#
# [623 rows x 1 columns]

# %%
# df_test.at[1,'image']
import base64

image_64_decode = base64.b64decode(df.at[300,'image']) 
image_result = open('deer_decode.jpg', 'wb') # create a writable image and write the decoding result
image_result.write(image_64_decode)
from IPython.display import Image as IImage
IImage(filename='deer_decode.jpg')

# %%
df.at[300,'ofa_caption']
# Out:
# 'an empty highway with a street with cars on it'

# %%
def clip_sim(b64_img, search_query):
    image_64_decode = base64.b64decode(b64_img) 
    image_result = open('test.jpg', 'wb')
    image_result.write(image_64_decode)
    try:
        image = Image.open('test.jpg')
        image = preprocess(image).unsqueeze(0).to(device)

        with torch.no_grad():
            photos_features = model.encode_image(image)
            photos_features /= photos_features.norm(dim=-1, keepdim=True)

        with torch.no_grad():
            # Encode and normalize the search query using CLIP
            text_encoded = model.encode_text(clip.tokenize(search_query).to(device))
            text_encoded /= text_encoded.norm(dim=-1, keepdim=True)

        similarities = (photos_features @ text_encoded.T).squeeze(1)
        return similarities.detach().cpu().numpy()[0]
    except:
        return None

# %%
def get_sim(u,v):

    emb1 = embedder.encode(u)
    if isinstance(v, list):
        v = ' '.join(v)
    emb2 = embedder.encode(v)
    
    return float(util.cos_sim(emb1, emb2)[0][0])

# %%
def simple_search(context, t):
    percentage = 0
    for w in t:
        if w in context:
            percentage = percentage + 1
    return float(percentage/len(t))

# %%
df['org_top_cov'] = df.apply(lambda x: simple_search(x.caption, list(topics[x.topic_id])), axis=1)
df['ofa_top_cov'] = df.apply(lambda x: simple_search(x.ofa_caption, list(topics[x.topic_id])), axis=1)

df['gt_ped_flag'] = df.apply(lambda x: flag_search_gt(x.tag, pedestrian_list), axis=1)
df['org_top_sim'] = df.apply(lambda x: get_sim(x.caption, list(topics[x.topic_id])), axis=1)
df['ofa_top_sim'] = df.apply(lambda x: get_sim(x.ofa_caption, list(topics[x.topic_id])), axis=1)

# %%
df['ofa_con_sim'] = df.apply(lambda x: get_sim(x.ofa_caption, ['pedestrian']), axis=1)
df['org_con_sim'] = df.apply(lambda x: get_sim(x.caption, ['pedestrian']), axis=1)
# df['ofa_gt_sim'] = df.apply(lambda x: get_sim(x.ofa_caption, x.gt), axis=1)
df['ofa_gt_sim'] = df.apply(lambda x: get_sim(x.ofa_caption, create_gt(x.tag)), axis=1)
df['org_gt_sim'] = df.apply(lambda x: get_sim(x.caption, create_gt(x.tag)), axis=1)

# %%
df['CLIP_s'] = df.apply(lambda x: clip_sim(x.image, x.ofa_caption), axis=1)

# %%
df
# Out:
#      uniq_id  image_id                                            caption  \
# 0        167       167               Car on rural road vector Stock Photo
# 1        184       184           Bus Only Lane Rendering Kuhio and Walina
# 2        187       187               Passenger boarding a bus on Bayshore
# 3        192       192               Passenger boarding a bus on Bayshore
# 4        209       209         Pedestrian Connections Congestion Strategy
# ..       ...       ...                                                ...
# 618     1228      1228          Westown Commons picnic shelter front view
# 619     1241      1241                        Humboldt Alexander Von Park
# 620     1259      1259  photo of trees and the fenceline at Mason Hill...
# 621     1296      1296                                Hogback Ridge Park
# 622     1306      1306          Playground and park unveiled in Jamaica 4
#
#      topic_id labels                                              image  \
# 0          68         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4         112         /9j/7gAOQWRvYmUAZAAAAAAA/9sAQwAIBgYHBgUIBwcHCQ...
# ..        ...    ...                                                ...
# 618       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 619       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 620       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 621       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 622       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
#      topic2caption_sim  concept2caption_sim topics  \
# 0             0.376758             0.212455      a
# 1             0.392783             0.160691      a
# 2             0.438588             0.197647      a
# 3             0.438588             0.197647      a
# 4             0.612697             0.493012      a
# ..                 ...                  ...    ...
# 618           0.395052             0.217862      o
# 619           0.415312             0.211162      o
# 620           0.446961             0.234170      o
# 621           0.579372             0.235827      o
# 622           0.499459             0.164558      o
#
#                                                    tag  ... gt_coverage  \
# 0    {'passenger': 0, 'wheel': 1, 'vehicle': 1, 'wa...  ...    0.250000
# 1    {'freight': 1, 'transportation': 1, 'traffic':...  ...    0.800000
# 2    {'freight': 1, 'transportation': 1, 'traffic':...  ...    0.800000
# 3    {'freight': 1, 'transportation': 1, 'traffic':...  ...    0.800000
# 4    {'freight': 1, 'transportation': 1, 'traffic':...  ...    0.900000
# ..                                                 ...  ...         ...
# 618  {'scenic': 0, 'recreation': 1, 'wilderness': 0...  ...    0.333333
# 619  {'scenic': 1, 'recreation': 1, 'wilderness': 0...  ...    0.555556
# 620  {'scenic': 1, 'recreation': 1, 'wilderness': 0...  ...    0.444444
# 621  {'scenic': 1, 'recreation': 1, 'wilderness': 0...  ...    0.444444
# 622  {'scenic': 0, 'recreation': 1, 'wilderness': 0...  ...    0.555556
#
#     org_top_cov  ofa_top_cov  gt_ped_flag  org_top_sim  ofa_top_sim  \
# 0      0.000000     0.000000          0.0     0.359901     0.184061
# 1      0.000000     0.100000          1.0     0.386788     0.412878
# 2      0.100000     0.100000          1.0     0.441203     0.517497
# 3      0.100000     0.100000          1.0     0.441203     0.517497
# 4      0.000000     0.100000          1.0     0.652822     0.392628
# ..          ...          ...          ...          ...          ...
# 618    0.000000     0.111111          0.0     0.378377     0.372350
# 619    0.000000     0.000000          1.0     0.347500     0.054662
# 620    0.000000     0.000000          0.0     0.441244     0.207250
# 621    0.000000     0.000000          0.0     0.543530     0.151606
# 622    0.111111     0.111111          1.0     0.465626     0.275794
#
#      ofa_con_sim  org_con_sim  ofa_gt_sim  org_gt_sim
# 0       0.291389     0.212455    0.339229    0.406319
# 1       0.306415     0.160691    0.465906    0.398409
# 2       0.315319     0.197647    0.544593    0.446380
# 3       0.315319     0.197647    0.544593    0.446380
# 4       0.267630     0.493012    0.370596    0.635256
# ..           ...          ...         ...         ...
# 618     0.157326     0.201472    0.416476    0.429998
# 619     0.150574     0.206693    0.169459    0.380411
# 620     0.215570     0.234170    0.283402    0.522400
# 621     0.269154     0.235827    0.156436    0.575687
# 622     0.248916     0.164558    0.370815    0.554346
#
# [623 rows x 22 columns]

# %%
# av_groups = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'k']
gk = df.groupby('topics')
pg_dict = dict()

# %%
df[df['topics'] == 'k']
# Out:
#      uniq_id  image_id                                            caption  \
# 468       96        96  Young stylish woman cyclist in black clothes c...
# 469       98        98  A group of cyclists with bikes and wearing lyc...
# 470      150       150  Row of bollards separating a cycle lane from cars
# 471      160       160  Man and woman riding bicycles with green lands...
# 472      191       191                   Laws that cyclists ought to know
# 473      200       200         Bikes parked in Amsterdam near a bike path
# 474      223       223                                 Discerning Cyclist
# 475      231       231  Riding a bicycle on a sidewalk can be dangerou...
# 476      250       250                Ride a bicycle concept illustration
# 477      273       273                 Cycling accidents with pedestrians
# 478      278       278  Mother pushing baby stroller on lined pedestri...
# 479      297       297  Young mother walking and pushing a stroller in...
# 480      301       301    Young mother walking with baby carriage in park
# 481      309       309  Woman walking with baby carriage in autumn Out...
# 482      327       327                             Mother with a stroller
# 483      340       340  Mother with baby in stroller and dog walking o...
# 484      344       344         Mother with baby in a stroller in the city
# 485      350       350  Mother running with child in stroller in the city
# 486      353       353  Mother with son in baby carriage crossing stre...
# 487      367       367  mother pushing a stroller in the street  baby ...
# 488      371       371  afternoon walk  baby stroller stock pictures r...
# 489      438       438             baby buggy baby carriage baby stroller
# 490      449       449  Young businesswoman with baby boy in stroller ...
# 491      455       455                  Father running with baby stroller
# 492      463       463  Free Beautiful Mother On Walking With Baby In ...
# 493      467       467  Young Girl With Her Daughter Walking The Stree...
# 494      472       472  Young Girl With Her Daughter Walking The Stree...
# 495      490       490  Baby carriage vector illustration Girls baby p...
# 496      495       495  Two happy mothers walking with the baby prams ...
# 497      520       520  Young working mother and formal office outfit ...
# 498      552       552  Preiser 28037 HO Scale Individual Figure  Pede...
# 499      584       584                  Baby Buggy Baby Stroller Stroller
# 500      592       592  Mother with Baby in Stroller royalty free illu...
# 501      594       594  Father and mother with a baby in a stroller an...
# 502      640       640  Young parents walk roll a stroller with baby c...
# 503      647       647  Pushing a baby stroller in an autumn park Stoc...
# 504      655       655  Happy young mother walking with baby stroller ...
# 505      685       685       Mother with baby carriage and kid background
# 506      713       713             Baby Buggy Baby Carriage Baby Stroller
# 507      722       722  Woman wearing a protective mask sits with a ba...
# 508      726       726  Melania TrumpTrump pushes a baby carriage with...
#
#      topic_id labels                                              image  \
# 468         8         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 469         8         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 470         8         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 471         8         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 472         8         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 473         8         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 474         8         iVBORw0KGgoAAAANSUhEUgAAAu0AAAGQCAMAAAAtNK7XAA...
# 475         8         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 476         8         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 477         8         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 478       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 479       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 480       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 481       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 482       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 483       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 484       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 485       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 486       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 487       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 488       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 489       265         iVBORw0KGgoAAAANSUhEUgAAAfQAAAH0CAYAAADL1t+KAA...
# 490       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 491       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 492       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 493       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 494       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 495       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 496       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 497       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 498       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 499       265         iVBORw0KGgoAAAANSUhEUgAAAVQAAAFUCAYAAAB7ksS1AA...
# 500       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 501       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 502       265         UklGRtCpAABXRUJQVlA4IMSpAADQewGdASrgAQ4BPmUoj0...
# 503       265         UklGRlhXAABXRUJQVlA4IExXAADwQQGdASrgAQwBPm0wk0...
# 504       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 505       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 506       265         iVBORw0KGgoAAAANSUhEUgAAAVQAAAFUCAYAAAB7ksS1AA...
# 507       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 508       265         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
#      topic2caption_sim  concept2caption_sim topics  \
# 468           0.358875             0.330161      k
# 469           0.327767             0.199751      k
# 470           0.292522             0.216508      k
# 471           0.360575             0.247716      k
# 472           0.341095             0.296031      k
# 473           0.376473             0.245213      k
# 474           0.487333             0.411786      k
# 475           0.395086             0.406180      k
# 476           0.360138             0.244874      k
# 477           0.426162             0.576595      k
# 478           0.608725             0.366239      k
# 479           0.565878             0.241546      k
# 480           0.550996             0.242466      k
# 481           0.486132             0.368934      k
# 482           0.485505             0.297802      k
# 483           0.468636             0.235162      k
# 484           0.514650             0.325738      k
# 485           0.457849             0.255579      k
# 486           0.489963             0.290098      k
# 487           0.477716             0.268416      k
# 488           0.464708             0.247929      k
# 489           0.659672             0.248147      k
# 490           0.477167             0.325274      k
# 491           0.476632             0.218014      k
# 492           0.476864             0.321595      k
# 493           0.493289             0.283359      k
# 494           0.493289             0.283359      k
# 495           0.547081             0.225755      k
# 496           0.495568             0.223118      k
# 497           0.493890             0.280489      k
# 498           0.497226             0.512290      k
# 499           0.493561             0.283101      k
# 500           0.483125             0.184396      k
# 501           0.478843             0.260985      k
# 502           0.468479             0.281333      k
# 503           0.513750             0.246831      k
# 504           0.466061             0.303660      k
# 505           0.538015             0.216913      k
# 506           0.606497             0.281234      k
# 507           0.464005             0.283779      k
# 508           0.485830             0.207656      k
#
#                                                    tag  ... gt_coverage  \
# 468  {'cycle': 1, 'bicycle': 1, 'rider': 1, 'bike':...  ...    1.000000
# 469  {'cycle': 1, 'bicycle': 1, 'rider': 1, 'bike':...  ...    1.000000
# 470  {'cycle': 1, 'bicycle': 1, 'rider': 0, 'bike':...  ...    0.444444
# 471  {'cycle': 1, 'bicycle': 1, 'rider': 1, 'bike':...  ...    1.000000
# 472  {'cycle': 1, 'bicycle': 1, 'rider': 1, 'bike':...  ...    1.000000
# 473  {'cycle': 1, 'bicycle': 1, 'rider': 0, 'bike':...  ...    0.777778
# 474  {'cycle': 1, 'bicycle': 1, 'rider': 1, 'bike':...  ...    0.888889
# 475  {'cycle': 1, 'bicycle': 1, 'rider': 1, 'bike':...  ...    1.000000
# 476  {'cycle': 1, 'bicycle': 1, 'rider': 1, 'bike':...  ...    1.000000
# 477  {'cycle': 1, 'bicycle': 1, 'rider': 1, 'bike':...  ...    1.000000
# 478  {'cycle': 1, 'bicycle': 1, 'rider': 1, 'bike':...  ...    1.000000
# 479  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.777778
# 480  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.777778
# 481  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.777778
# 482  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.777778
# 483  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.777778
# 484  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.777778
# 485  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.777778
# 486  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.777778
# 487  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.777778
# 488  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.777778
# 489  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.666667
# 490  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.777778
# 491  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.777778
# 492  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.777778
# 493  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.777778
# 494  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.666667
# 495  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.777778
# 496  {'diaper': 1, 'harness': 1, 'baby': 1, 'hatch'...  ...    1.000000
# 497  {'diaper': 1, 'harness': 1, 'baby': 1, 'hatch'...  ...    1.000000
# 498  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.777778
# 499  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.666667
# 500  {'diaper': 0, 'harness': 1, 'baby': 1, 'hatch'...  ...    0.888889
# 501  {'diaper': 0, 'harness': 1, 'baby': 1, 'hatch'...  ...    0.888889
# 502  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.777778
# 503  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.777778
# 504  {'diaper': 0, 'harness': 1, 'baby': 1, 'hatch'...  ...    0.888889
# 505  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.777778
# 506  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.777778
# 507  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.777778
# 508  {'diaper': 0, 'harness': 0, 'baby': 1, 'hatch'...  ...    0.777778
#
#     org_top_cov  ofa_top_cov  gt_ped_flag  org_top_sim  ofa_top_sim  \
# 468    0.777778     0.222222          1.0     0.419324     0.481298
# 469    0.222222     0.222222          1.0     0.342832     0.367025
# 470    0.111111     0.000000          0.0     0.303290     0.226265
# 471    0.333333     0.222222          1.0     0.390950     0.371766
# 472    0.111111     0.111111          1.0     0.426926     0.337707
# 473    0.111111     0.111111          1.0     0.378760     0.313702
# 474    0.000000     0.222222          1.0     0.589668     0.350220
# 475    0.444444     0.222222          1.0     0.452212     0.268090
# 476    0.222222     0.222222          1.0     0.390447     0.338610
# 477    0.111111     0.222222          1.0     0.560312     0.460235
# 478    0.444444     0.111111          1.0     0.579874     0.342734
# 479    0.333333     0.111111          1.0     0.503607     0.334608
# 480    0.222222     0.222222          1.0     0.551079     0.453517
# 481    0.222222     0.333333          1.0     0.497181     0.572494
# 482    0.111111     0.222222          1.0     0.498434     0.339993
# 483    0.222222     0.222222          1.0     0.470523     0.411359
# 484    0.222222     0.111111          1.0     0.526926     0.373338
# 485    0.222222     0.000000          1.0     0.469594     0.133092
# 486    0.222222     0.222222          1.0     0.497410     0.542756
# 487    0.222222     0.111111          1.0     0.500126     0.363262
# 488    0.222222     0.222222          1.0     0.466321     0.494062
# 489    0.333333     0.000000          1.0     0.657438     0.100923
# 490    0.222222     0.222222          1.0     0.483417     0.500264
# 491    0.222222     0.111111          1.0     0.484106     0.348162
# 492    0.000000     0.111111          1.0     0.459002     0.423671
# 493    0.000000     0.222222          1.0     0.508134     0.556437
# 494    0.000000     0.222222          1.0     0.508134     0.504674
# 495    0.333333     0.000000          1.0     0.555152     0.069164
pg_dict[el]
# Out:
#     uniq_id  image_id                                            caption  \
# 0       623       623               best walking trails   greenbelt park
# 1       628       628          best walking trails   wild hyacinth trail
# 2       637       637                           Great American RailTrail
# 3       661       661  park trail path peaceful shade outdoor trees l...
# 4       682       682                    Joppenbergh Mountain Loop Trail
# 5       699       699           nature forest path hiking bridge walkway
# 6       716       716  a long pedestrian walkway amidst trees against...
# 7       740       740                Wildwood All Purpose WalkBike Trail
# 8       744       744                        Middlegrounds WalkBike Path
# 9       757       757  Evening Sidewalk  pedestrian walkway stock pic...
# 10      760       760  Walking man vector icon People walk sign illus...
# 11      764       764  forest pedestrian bridge on a path used to hik...
# 12      778       778                                  Hiking in Nesbyen
# 13      822       822                                        Fruit Trail
# 14      830       830       Hardangervidda fourday hike Best in the West
# 15      837       837                              Hike to Prest Aurland
# 16      852       852          Coastal path  hike VettreVollenSlemmestad
# 17      859       859                             Hiking route Stokkvola
# 18      868       868                  Mountain hike with personal guide
# 19      909       909                                Uganda hiking trail
# 20      951       951                                     Promenade Park
# 21      958       958  Macedonia street in city center of Skopje Pede...
# 22      968       968  Riverside pedestrian promenade of central phno...
# 23      973       973  Pedestrian promenade along Como lake in Varenn...
# 24      977       977                Before photo of the North Promenade
# 25      988       988                                   Waterfront Walks
# 26     1013      1013                  Promenade Park Kids Water Feature
# 27     1057      1057                  State Street pedestrian promenade
# 28     1060      1060                      A rendering of a park walkway
# 29     1077      1077  tow truck 02 VECTOR EPS10  set of tow truck an...
# 30     1084      1084  No parking tow away zone sign set Tow away zon...
# 31     1092      1092                          Parking garage rate signs
# 32     1094      1094                                       parking sign
# 33     1096      1096                           Parking Sign in Old Town
# 34     1102      1102                      Cars parked on street in city
# 35     1121      1121  Used 2021 Kia Sorento S w 3rd Row Remote Start...
# 36     1123      1123                           guys towing bad park job
# 37     1126      1126                                        parked cars
# 38     1145      1145                                    Parking garages
# 39     1146      1146                                    Parking tickets
# 40     1170      1170  Children and guardians enjoying the playground...
# 41     1172      1172                              Peace Park Playground
# 42     1175      1175  Crosscut saw work on Soldier Lakes Trail 4013 ...
# 43     1214      1214                           Matanuska Peak Trailhead
# 44     1228      1228          Westown Commons picnic shelter front view
# 45     1241      1241                        Humboldt Alexander Von Park
# 46     1259      1259  photo of trees and the fenceline at Mason Hill...
# 47     1296      1296                                Hogback Ridge Park
# 48     1306      1306          Playground and park unveiled in Jamaica 4
#
#     topic_id labels                                              image  \
# 0         12         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1         12         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2         12         iVBORw0KGgoAAAANSUhEUgAAAQEAAADKCAYAAACltPU+AA...
# 3         12         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4         12         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 5         12         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 6         12         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 7         12         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 8         12         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 9         12         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 10        12         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 11        12         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 12        12         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 13        12         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 14        12         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 15        12         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 16        12         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 17        12         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 18        12         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 19        12         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 20       278         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 21       278         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 22       278         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 23       278         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 24       278         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 25       278         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 26       278         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 27       278         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 28       278         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 29       198         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 30       198         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 31       198         UklGRq5yAABXRUJQVlA4IKJyAAAQTwKdASq8AtMBPm0wlE...
# 32       198         iVBORw0KGgoAAAANSUhEUgAABLAAAAMgCAYAAAAz4JsCAA...
# 33       198         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 34       198         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 35       198         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 36       198         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 37       198         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 38       198         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 39       198         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 40       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 41       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 42       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 43       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 44       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 45       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 46       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 47       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 48       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
#     topic2caption_sim  concept2caption_sim topics  \
# 0            0.454872             0.232587      o
# 1            0.520891             0.203545      o
# 2            0.440600             0.247155      o
# 3            0.344498             0.190819      o
# 4            0.458614             0.183405      o
# 5            0.397415             0.260743      o
# 6            0.349519             0.525547      o
# 7            0.518146             0.246602      o
# 8            0.385482             0.303328      o
# 9            0.348947             0.499094      o
# 10           0.366952             0.476942      o
# 11           0.434385             0.443421      o
# 12           0.344231             0.166816      o
# 13           0.361557             0.275719      o
# 14           0.411762             0.186001      o
# 15           0.382127             0.205837      o
# 16           0.411352             0.237549      o
# 17           0.446834             0.223715      o
# 18           0.651963             0.205433      o
# 19           0.467730             0.170227      o
# 20           0.786056             0.355492      o
# 21           0.440024             0.288900      o
# 22           0.560961             0.348909      o
# 23           0.414396             0.290038      o
# 24           0.586877             0.268937      o
# 25           0.440539             0.357029      o
# 26           0.573104             0.221547      o
# 27           0.764886             0.611949      o
# 28           0.472902             0.366341      o
# 29           0.410121             0.201768      o
# 30           0.469492             0.240293      o
# 31           0.587108             0.234403      o
# 32           0.554434             0.447087      o
# 33           0.488979             0.334550      o
# 34           0.489807             0.320258      o
# 35           0.398495             0.370932      o
# 36           0.524552             0.210832      o
# 37           0.589196             0.431392      o
# 38           0.721260             0.341730      o
# 39           0.538829             0.355412      o
# 40           0.496056             0.164625      o
# 41           0.584267             0.251159      o
# 42           0.380725             0.168271      o
# 43           0.406962             0.203358      o
# 44           0.395052             0.217862      o
# 45           0.415312             0.211162      o
# 46           0.446961             0.234170      o
# 47           0.579372             0.235827      o
# 48           0.499459             0.164558      o
#
#                                                   tag  ... gt_coverage  \
# 0   {'hike': 1, 'footpath': 1, 'mountain': 0, 'pat...  ...    0.500000
# 1   {'hike': 1, 'footpath': 1, 'mountain': 0, 'pat...  ...    0.500000
# 2   {'hike': 1, 'footpath': 1, 'mountain': 0, 'pat...  ...    0.500000
# 3   {'hike': 1, 'footpath': 1, 'mountain': 0, 'pat...  ...    0.500000
# 4   {'hike': 1, 'footpath': 1, 'mountain': 1, 'pat...  ...    0.625000
# 5   {'hike': 1, 'footpath': 1, 'mountain': 0, 'pat...  ...    0.500000
# 6   {'hike': 1, 'footpath': 1, 'mountain': 0, 'pat...  ...    0.500000
# 7   {'hike': 1, 'footpath': 1, 'mountain': 0, 'pat...  ...    0.625000
# 8   {'hike': 1, 'footpath': 1, 'mountain': 0, 'pat...  ...    0.375000
# 9   {'hike': 1, 'footpath': 1, 'mountain': 0, 'pat...  ...    0.375000
# 10  {'hike': 0, 'footpath': 0, 'mountain': 0, 'pat...  ...    0.125000
# 11  {'hike': 1, 'footpath': 1, 'mountain': 0, 'pat...  ...    0.500000
# 12  {'hike': 1, 'footpath': 1, 'mountain': 1, 'pat...  ...    0.875000
# 13  {'hike': 1, 'footpath': 1, 'mountain': 1, 'pat...  ...    0.875000
# 14  {'hike': 1, 'footpath': 0, 'mountain': 1, 'pat...  ...    0.375000
# 15  {'hike': 1, 'footpath': 1, 'mountain': 1, 'pat...  ...    0.875000
# 16  {'hike': 1, 'footpath': 0, 'mountain': 1, 'pat...  ...    0.750000
# 17  {'hike': 1, 'footpath': 1, 'mountain': 1, 'pat...  ...    0.750000
# 18  {'hike': 1, 'footpath': 0, 'mountain': 1, 'pat...  ...    0.625000
# 19  {'hike': 1, 'footpath': 1, 'mountain': 0, 'pat...  ...    0.625000
# 20  {'walk': 1, 'park': 1, 'promenade': 1, 'deck':...  ...    0.625000
# 21  {'walk': 1, 'park': 0, 'promenade': 1, 'deck':...  ...    0.375000
# 22  {'walk': 1, 'park': 1, 'promenade': 1, 'deck':...  ...    0.500000
# 23  {'walk': 1, 'park': 1, 'promenade': 1, 'deck':...  ...    0.500000
# 24  {'walk': 1, 'park': 1, 'promenade': 1, 'deck':...  ...    0.500000
# 25  {'walk': 1, 'park': 1, 'promenade': 1, 'deck':...  ...    0.500000
# 26  {'walk': 1, 'park': 1, 'promenade': 1, 'deck':...  ...    0.500000
# 27  {'walk': 1, 'park': 1, 'promenade': 1, 'deck':...  ...    0.500000
# 28  {'walk': 1, 'park': 1, 'promenade': 1, 'deck':...  ...    0.625000
# 29  {'parking': 0, 'vehicle': 1, 'parkjockey': 0, ...  ...    0.375000
# 30  {'parking': 1, 'vehicle': 1, 'parkjockey': 0, ...  ...    0.625000
# 31  {'parking': 1, 'vehicle': 1, 'parkjockey': 0, ...  ...    0.625000
# 32  {'parking': 1, 'vehicle': 0, 'parkjockey': 0, ...  ...    0.250000
# 33  {'parking': 1, 'vehicle': 1, 'parkjockey': 0, ...  ...    0.625000
# 34  {'parking': 1, 'vehicle': 1, 'parkjockey': 0, ...  ...    0.625000
# 35  {'parking': 0, 'vehicle': 1, 'parkjockey': 0, ...  ...    0.250000
# 36  {'parking': 1, 'vehicle': 1, 'parkjockey': 0, ...  ...    0.500000
# 37  {'parking': 1, 'vehicle': 1, 'parkjockey': 0, ...  ...    0.625000
# 38  {'parking': 1, 'vehicle': 1, 'parkjockey': 0, ...  ...    0.625000
# 39  {'parking': 1, 'vehicle': 0, 'parkjockey': 0, ...  ...    0.375000
# 40  {'scenic': 1, 'recreation': 1, 'wilderness': 0...  ...    0.666667
# 41  {'scenic': 1, 'recreation': 1, 'wilderness': 0...  ...    0.555556
# 42  {'scenic': 1, 'recreation': 0, 'wilderness': 1...  ...    0.555556
# 43  {'scenic': 1, 'recreation': 1, 'wilderness': 1...  ...    0.666667
# 44  {'scenic': 0, 'recreation': 1, 'wilderness': 0...  ...    0.333333
# 45  {'scenic': 1, 'recreation': 1, 'wilderness': 0...  ...    0.555556
# 46  {'scenic': 1, 'recreation': 1, 'wilderness': 0...  ...    0.444444
# 47  {'scenic': 1, 'recreation': 1, 'wilderness': 0...  ...    0.444444
# 48  {'scenic': 0, 'recreation': 1, 'wilderness': 0...  ...    0.555556
#
#    org_top_cov  ofa_top_cov  gt_ped_flag  org_top_sim  ofa_top_sim  \
# 0     0.125000     0.000000          0.0     0.397946     0.254206
# count        52.00        52.00        52.00       52.00       52.00
# mean          0.31         0.27         0.23        0.36        0.49
# std           0.12         0.07         0.08        0.15        0.12
# min           0.06         0.01         0.13        0.04        0.13
# 25%           0.23         0.23         0.18        0.24        0.43
# 50%           0.31         0.27         0.21        0.35        0.48
# 75%           0.39         0.30         0.25        0.43        0.58
# max           0.53         0.40         0.52        0.69        0.69

# %%
# Test
df[['gt_coverage', 'gt_ped_flag', 'org_gt_sim']].describe().round(2)
# Out:
#        gt_coverage  gt_ped_flag  org_gt_sim
# count       623.00       623.00      623.00
# mean          0.49         0.65        0.50
# std           0.23         0.48        0.14
# min           0.09         0.00        0.07
# 25%           0.33         0.00        0.41
# 50%           0.45         1.00        0.52
# 75%           0.62         1.00        0.60
# max           1.00         1.00        0.88

# %%
# Test
for el in pg_dict:
    print(el)
    display(pg_dict[el][['gt_coverage', 'gt_ped_flag', 'org_gt_sim']].describe().round(2))
# Out:
# a
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        52.00        52.00       52.00
# mean          0.53         0.77        0.49
# std           0.20         0.43        0.12
# min           0.20         0.00        0.13
# 25%           0.40         1.00        0.43
# 50%           0.50         1.00        0.48
# 75%           0.58         1.00        0.58
# max           1.00         1.00        0.69
# b
#        gt_coverage  gt_ped_flag  org_gt_sim
# count       103.00       103.00      103.00
# mean          0.40         0.82        0.49
# std           0.16         0.39        0.12
# min           0.10         0.00        0.14
# 25%           0.30         1.00        0.41
# 50%           0.40         1.00        0.51
# 75%           0.50         1.00        0.58
# max           0.70         1.00        0.77
# c
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        57.00        57.00       57.00
# mean          0.43         0.63        0.49
# std           0.18         0.49        0.09
# min           0.11         0.00        0.25
# 25%           0.29         0.00        0.44
# 50%           0.44         1.00        0.49
# 75%           0.56         1.00        0.55
# max           0.78         1.00        0.65
# d
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        62.00        62.00       62.00
# mean          0.45         0.16        0.59
# std           0.13         0.37        0.11
# min           0.10         0.00        0.29
# 25%           0.40         0.00        0.55
# 50%           0.41         0.00        0.61
# 75%           0.50         0.00        0.66
# max           0.71         1.00        0.77
# e
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        46.00        46.00       46.00
# mean          0.50         0.59        0.54
# std           0.24         0.50        0.13
# min           0.09         0.00        0.33
# 25%           0.36         0.00        0.45
# 50%           0.45         1.00        0.55
# 75%           0.60         1.00        0.61
# max           1.00         1.00        0.83
# f
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        16.00        16.00       16.00
# mean          0.67         0.62        0.50
# std           0.33         0.50        0.11
# min           0.12         0.00        0.30
# 25%           0.38         0.00        0.46
# 50%           0.72         1.00        0.50
# 75%           1.00         1.00        0.57
# max           1.00         1.00        0.65
# g
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        25.00        25.00       25.00
# mean          0.24         0.56        0.45
# std           0.11         0.51        0.17
# min           0.10         0.00        0.13
# 25%           0.20         0.00        0.38
# 50%           0.20         1.00        0.50
# 75%           0.30         1.00        0.59
# max           0.56         1.00        0.69
# h
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        28.00         28.0       28.00
# mean          0.27          1.0        0.49
# std           0.12          0.0        0.12
# min           0.20          1.0        0.25
# 25%           0.20          1.0        0.42
# 50%           0.20          1.0        0.46
# 75%           0.30          1.0        0.55
# max           0.70          1.0        0.74
# i
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        72.00        72.00       72.00
# mean          0.59         0.67        0.54
# std           0.23         0.47        0.15
# min           0.12         0.00        0.17
# 25%           0.38         0.00        0.42
# 50%           0.55         1.00        0.60
# 75%           0.86         1.00        0.65
# max           1.00         1.00        0.78
# j
#        gt_coverage  gt_ped_flag  org_gt_sim
# count         7.00         7.00        7.00
# mean          0.93         0.43        0.66
# std           0.07         0.53        0.07
# min           0.88         0.00        0.56
# 25%           0.88         0.00        0.62
# 50%           0.88         0.00        0.66
# 75%           1.00         1.00        0.69
# max           1.00         1.00        0.79
# k
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        41.00        41.00       41.00
# mean          0.83         0.98        0.50
# std           0.12         0.16        0.12
# min           0.44         0.00        0.11
# 25%           0.78         1.00        0.43
# 50%           0.78         1.00        0.52
# 75%           0.89         1.00        0.58
# max           1.00         1.00        0.77
# l
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        11.00        11.00       11.00
# mean          0.44         0.64        0.34
# std           0.27         0.50        0.14
# min           0.10         0.00        0.18
# 25%           0.20         0.00        0.26
# 50%           0.50         1.00        0.28
# 75%           0.60         1.00        0.39
# max           0.80         1.00        0.68
# m
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        25.00        25.00       25.00
# mean          0.63         0.68        0.50
# std           0.18         0.48        0.12
# min           0.11         0.00        0.19
# 25%           0.60         0.00        0.46
# 50%           0.62         1.00        0.52
# 75%           0.75         1.00        0.56
# max           0.88         1.00        0.74
# n
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        29.00        29.00       29.00
# mean          0.34         0.66        0.26
# std           0.24         0.48        0.13
# min           0.11         0.00        0.07
# 25%           0.11         0.00        0.13
# 50%           0.30         1.00        0.24
# 75%           0.57         1.00        0.40
# max           0.71         1.00        0.49
# o
#        gt_coverage  gt_ped_flag  org_gt_sim
# count        49.00        49.00       49.00
# mean          0.54         0.51        0.51
# std           0.15         0.51        0.14
# min           0.12         0.00        0.24
# 25%           0.50         0.00        0.42
# 50%           0.50         1.00        0.51
# 75%           0.62         1.00        0.59
# max           0.88         1.00        0.88

# %%
# before
df[['gt_ped_flag', 'gt_coverage', 'org_gt_sim', 'ofa_top_sim', 'ofa_gt_sim', 'ofa_con_sim', 'CLIP_s']].describe().round(4)
# Out:
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count     623.0000     623.0000    623.0000     623.0000    623.0000
# mean        0.6549       0.4929      0.4997       0.2953      0.3539
# std         0.4758       0.2326      0.1433       0.1525      0.1764
# min         0.0000       0.0909      0.0683      -0.1070     -0.0814
# 25%         0.0000       0.3333      0.4135       0.1833      0.2223
# 50%         1.0000       0.4545      0.5222       0.2846      0.3574
# 75%         1.0000       0.6250      0.5962       0.4036      0.4807
# max         1.0000       1.0000      0.8761       0.7568      0.7906
#
#        ofa_con_sim    CLIP_s
# count     623.0000  622.0000
# mean        0.2869    0.2923
# std         0.1126    0.0336
# min        -0.0426    0.1606
# 25%         0.2134    0.2722
# 50%         0.2841    0.2917
# 75%         0.3592    0.3147
# max         0.6272    0.4033

# %%
# after wit
df[['gt_ped_flag', 'gt_coverage', 'org_gt_sim', 'ofa_top_sim', 'ofa_gt_sim', 'ofa_con_sim', 'CLIP_s']].describe().round(4)
# Out:
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count     623.0000     623.0000    623.0000     623.0000    623.0000
# mean        0.6549       0.4929      0.4997       0.3230      0.3712
# std         0.4758       0.2326      0.1433       0.1600      0.1699
# min         0.0000       0.0909      0.0683      -0.1333     -0.0840
# 25%         0.0000       0.3333      0.4135       0.2122      0.2489
# 50%         1.0000       0.4545      0.5222       0.3237      0.3806
# 75%         1.0000       0.6250      0.5962       0.4298      0.4914
# max         1.0000       1.0000      0.8761       0.7680      0.8427
#
#        ofa_con_sim    CLIP_s
# count     623.0000  622.0000
# mean        0.3171    0.2864
# std         0.1407    0.0367
# min        -0.0568    0.1353
# 25%         0.2254    0.2640
# 50%         0.3020    0.2897
# 75%         0.3844    0.3088
# max         0.6698    0.3967

# %%
# after
df[['gt_ped_flag', 'gt_coverage', 'org_gt_sim', 'ofa_top_sim', 'ofa_gt_sim', 'ofa_con_sim', 'CLIP_s']].describe().round(4)
# Out:
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count     623.0000     623.0000    623.0000     623.0000    623.0000
# mean        0.6549       0.4929      0.4997       0.4244      0.4584
# std         0.4758       0.2326      0.1433       0.1676      0.1808
# min         0.0000       0.0909      0.0683      -0.1238     -0.0869
# 25%         0.0000       0.3333      0.4135       0.3182      0.3363
# 50%         1.0000       0.4545      0.5222       0.4331      0.4872
# 75%         1.0000       0.6250      0.5962       0.5258      0.5895
# max         1.0000       1.0000      0.8761       0.8514      0.8832
#
#        ofa_con_sim    CLIP_s
# count     623.0000  622.0000
# mean        0.4053    0.2970
# std         0.1858    0.0398
# min        -0.0097    0.1597
# 25%         0.2475    0.2721
# 50%         0.4138    0.2982
# 75%         0.5600    0.3229
# max         0.7630    0.4072

# %%
# before
for el in pg_dict:
    print(el)
    display(pg_dict[el][['gt_ped_flag', 'gt_coverage', 'org_gt_sim', 'ofa_top_sim', 'ofa_gt_sim', 'ofa_con_sim', 'CLIP_s']].describe().round(4))
# Out:
# a
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count      52.0000      52.0000     52.0000      52.0000     52.0000
# mean        0.7692       0.5319      0.4886       0.3055      0.3587
# std         0.4254       0.1956      0.1173       0.1171      0.1465
# min         0.0000       0.2000      0.1258       0.0645      0.0402
# 25%         1.0000       0.4000      0.4292       0.2318      0.2407
# 50%         1.0000       0.5000      0.4821       0.3059      0.3483
# 75%         1.0000       0.5833      0.5765       0.3919      0.4347
# max         1.0000       1.0000      0.6930       0.5262      0.6896
#
#        ofa_con_sim   CLIP_s
# count      52.0000  52.0000
# mean        0.2673   0.2850
# std         0.0669   0.0316
# min         0.0097   0.2209
# 25%         0.2262   0.2579
# 50%         0.2669   0.2845
# 75%         0.3029   0.3129
# max         0.3954   0.3425
# b
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
#
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count       16.000      16.0000     16.0000      16.0000     16.0000
# mean         0.625       0.6656      0.5006       0.2156      0.2207
# std          0.500       0.3341      0.1052       0.1299      0.1390
# min          0.000       0.1250      0.3005       0.0508      0.0529
# 25%          0.000       0.3833      0.4555       0.1103      0.1070
# 50%          1.000       0.7153      0.5029       0.2075      0.2114
# 75%          1.000       1.0000      0.5658       0.2697      0.2636
# max          1.000       1.0000      0.6500       0.4639      0.4737
#
#        ofa_con_sim   CLIP_s
# count      16.0000  16.0000
# mean        0.1899   0.2776
# std         0.0771   0.0382
# min         0.0421   0.2046
# 25%         0.1605   0.2524
# 50%         0.1836   0.2872
# 75%         0.2565   0.2990
# max         0.3059   0.3569
# g
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count      25.0000      25.0000     25.0000      25.0000     25.0000
# mean        0.5600       0.2391      0.4525       0.2103      0.2616
# std         0.5066       0.1077      0.1747       0.1360      0.1844
# min         0.0000       0.1000      0.1280       0.0229     -0.0169
# 25%         0.0000       0.2000      0.3817       0.1229      0.1351
# 50%         1.0000       0.2000      0.4998       0.1720      0.2469
# 75%         1.0000       0.3000      0.5931       0.2611      0.3394
# max         1.0000       0.5556      0.6873       0.5544      0.7287
#
#        ofa_con_sim   CLIP_s
# count      25.0000  25.0000
# mean        0.1989   0.2927
# std         0.1172   0.0222
# min        -0.0426   0.2561
# 25%         0.1098   0.2744
# 50%         0.2099   0.2932
# 75%         0.2469   0.3096
# max         0.5313   0.3352
# h
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count         28.0      28.0000     28.0000      28.0000     28.0000
# mean           1.0       0.2714      0.4853       0.2385      0.3959
# std            0.0       0.1182      0.1192       0.1104      0.1510
# min            1.0       0.2000      0.2482       0.1041      0.1099
# 25%            1.0       0.2000      0.4161       0.1476      0.2605
# 50%            1.0       0.2000      0.4601       0.2164      0.4018
# 75%            1.0       0.3000      0.5478       0.2920      0.5060
# max            1.0       0.7000      0.7383       0.4701      0.6167
#
#        ofa_con_sim   CLIP_s
# count      28.0000  28.0000
# mean        0.3427   0.3023
# std         0.0979   0.0321
# min         0.1157   0.2283
# 25%         0.2719   0.2825
# 50%         0.3516   0.2980
# 75%         0.4203   0.3102
# max         0.5374   0.3843
# i
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count      72.0000      72.0000     72.0000      72.0000     72.0000
# mean        0.6667       0.5866      0.5408       0.3098      0.3555
# std         0.4747       0.2297      0.1532       0.1721      0.2184
# min         0.0000       0.1250      0.1724      -0.0092     -0.0090
# 25%         0.0000       0.3750      0.4241       0.1797      0.1711
# 50%         1.0000       0.5455      0.5956       0.3175      0.3326
# 75%         1.0000       0.8571      0.6514       0.4654      0.5555
# max         1.0000       1.0000      0.7780       0.6159      0.7906
#
#        ofa_con_sim   CLIP_s
# count      72.0000  72.0000
# mean        0.2639   0.3009
# std         0.1267   0.0339
# min         0.0583   0.2255
# 25%         0.1438   0.2749
# 50%         0.2794   0.3007
# 75%         0.3678   0.3277
# max         0.5581   0.3633
# j
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
#
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count      49.0000      49.0000     49.0000      49.0000     49.0000
# mean        0.5102       0.5363      0.5123       0.2412      0.3114
# std         0.5051       0.1535      0.1373       0.1160      0.1565
# min         0.0000       0.1250      0.2380      -0.0153      0.0596
# 25%         0.0000       0.5000      0.4246       0.1561      0.1822
# 50%         1.0000       0.5000      0.5099       0.2487      0.2846
# 75%         1.0000       0.6250      0.5939       0.3337      0.4023
# max         1.0000       0.8750      0.8761       0.4748      0.7687
#
#        ofa_con_sim   CLIP_s
# count      49.0000  49.0000
# mean        0.2248   0.2915
# std         0.1080   0.0352
# min        -0.0129   0.2009
# 25%         0.1561   0.2698
# 50%         0.2156   0.2930
# 75%         0.2903   0.3125
# max         0.5856   0.3662

# %%
#after wit
for el in pg_dict:
    print(el)
    display(pg_dict[el][['gt_ped_flag', 'gt_coverage', 'org_gt_sim', 'ofa_top_sim', 'ofa_gt_sim', 'ofa_con_sim', 'CLIP_s']].describe().round(4))
# Out:
# a
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count      52.0000      52.0000     52.0000      52.0000     52.0000
# mean        0.7692       0.5319      0.4886       0.3526      0.3799
# std         0.4254       0.1956      0.1173       0.1174      0.1315
# min         0.0000       0.2000      0.1258       0.0348      0.1133
# 25%         1.0000       0.4000      0.4292       0.2724      0.2802
# 50%         1.0000       0.5000      0.4821       0.3328      0.3657
# 75%         1.0000       0.5833      0.5765       0.4347      0.4728
# max         1.0000       1.0000      0.6930       0.6680      0.6398
#
#        ofa_con_sim   CLIP_s
# count      52.0000  52.0000
# mean        0.2984   0.2827
# std         0.0943   0.0277
# min         0.1628   0.1840
# 25%         0.2445   0.2697
# 50%         0.2835   0.2863
# 75%         0.3321   0.2992
# max         0.6408   0.3389
# b
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count     103.0000     103.0000    103.0000     103.0000    103.0000
# mean        0.8155       0.3951      0.4909       0.2849      0.3752
# std         0.3898       0.1570      0.1250       0.1036      0.1256
# min         0.0000       0.1000      0.1430      -0.1333     -0.0810
# 25%         1.0000       0.3000      0.4145       0.2348      0.3067
# 50%         1.0000       0.4000      0.5131       0.2758      0.3806
# 75%         1.0000       0.5000      0.5775       0.3404      0.4539
# max         1.0000       0.7000      0.7675       0.5196      0.6521
#
#        ofa_con_sim    CLIP_s
# count     103.0000  103.0000
# mean        0.3158    0.2842
# std         0.1190    0.0371
# min         0.0213    0.1770
# 25%         0.2335    0.2614
# 50%         0.3040    0.2874
# 75%         0.3699    0.3033
# max         0.6219    0.3921
# c
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count      57.0000      57.0000     57.0000      57.0000     57.0000
# mean        0.6316       0.4282      0.4873       0.3742      0.4247
# std         0.4867       0.1815      0.0920       0.1207      0.1267
# min         0.0000       0.1111      0.2546       0.0756      0.1298
# 25%         0.0000       0.2857      0.4402       0.2949      0.3383
# 50%         1.0000       0.4444      0.4945       0.3665      0.4228
# 75%         1.0000       0.5556      0.5527       0.4578      0.4938
# max         1.0000       0.7778      0.6511       0.6075      0.6954
#
#        ofa_con_sim   CLIP_s
# count      57.0000  57.0000
# mean        0.3638   0.2929
# std         0.1235   0.0385
# min         0.0682   0.2120
# 25%         0.2855   0.2666
# 50%         0.3349   0.2908
# 75%         0.4238   0.3196
# max         0.6698   0.3967
# d
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count         28.0      28.0000     28.0000      28.0000     28.0000
# mean           1.0       0.2714      0.4853       0.2410      0.3785
# std            0.0       0.1182      0.1192       0.1120      0.1385
# min            1.0       0.2000      0.2482       0.0944      0.1302
# 25%            1.0       0.2000      0.4161       0.1678      0.2831
# 50%            1.0       0.2000      0.4601       0.2060      0.3793
# 75%            1.0       0.3000      0.5478       0.2957      0.4712
# max            1.0       0.7000      0.7383       0.4882      0.6274
#
#        ofa_con_sim   CLIP_s
# count      28.0000  28.0000
# mean        0.3324   0.2915
# std         0.1111   0.0254
# min         0.1390   0.2539
# 25%         0.2530   0.2681
# 50%         0.3187   0.2909
# 75%         0.4084   0.3041
# max         0.6358   0.3718
# i
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count      72.0000      72.0000     72.0000      72.0000     72.0000
# mean        0.6667       0.5866      0.5408       0.3327      0.3785
# std         0.4747       0.2297      0.1532       0.1509      0.1949
# min         0.0000       0.1250      0.1724      -0.0224     -0.0253
# 25%         0.0000       0.3750      0.4241       0.2060      0.2238
# 50%         1.0000       0.5455      0.5956       0.3962      0.3607
# 75%         1.0000       0.8571      0.6514       0.4465      0.5817
# max         1.0000       1.0000      0.7780       0.6400      0.7568
#
#        ofa_con_sim   CLIP_s
# count      72.0000  72.0000
# mean        0.2922   0.2988
# std         0.1288   0.0368
# min         0.0203   0.1957
# 25%         0.2167   0.2744
# 50%         0.2897   0.3026
# 75%         0.3836   0.3243
# max         0.6592   0.3748
# j
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count       7.0000       7.0000      7.0000       7.0000      7.0000
# mean        0.4286       0.9286      0.6603       0.3636      0.3562
# std         0.5345       0.0668      0.0722       0.1073      0.1025
# min         0.0000       0.8750      0.5609       0.1459      0.1564
# 25%         0.0000       0.8750      0.6187       0.3476      0.3372
# 50%         0.0000       0.8750      0.6570       0.3794      0.3848
# 75%         1.0000       1.0000      0.6901       0.4277      0.3946
# max         1.0000       1.0000      0.7865       0.4689      0.4885
#
#        ofa_con_sim  CLIP_s
# count       7.0000  7.0000
# mean        0.2908  0.2750
# std         0.0525  0.0132
# min         0.2170  0.2600
# 25%         0.2614  0.2661
# 50%         0.2766  0.2722
# 75%         0.3237  0.2821
# max         0.3715  0.2966
# k
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count      41.0000      41.0000     41.0000      41.0000     41.0000
# mean        0.9756       0.8266      0.5034       0.3774      0.3796
# std         0.1562       0.1218      0.1213       0.1211      0.1490
# min         0.0000       0.4444      0.1137       0.0466     -0.0314
# 25%         1.0000       0.7778      0.4298       0.3318      0.3438
# 50%         1.0000       0.7778      0.5188       0.3749      0.3932
# 75%         1.0000       0.8889      0.5753       0.4807      0.4851
# max         1.0000       1.0000      0.7668       0.5511      0.6213
#
#        ofa_con_sim   CLIP_s
# count      41.0000  41.0000
# mean        0.2931   0.3065
# std         0.1204   0.0311
# min         0.0176   0.1954
# 25%         0.2140   0.2869
# 50%         0.2676   0.3130
# 75%         0.3563   0.3291
# max         0.6698   0.3584
# l
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count      11.0000      11.0000     11.0000      11.0000     11.0000
# mean        0.6364       0.4364      0.3399       0.1579      0.2317
# std         0.5045       0.2656      0.1411       0.0955      0.1423
# min         0.0000       0.1000      0.1751      -0.0298      0.0362
# 25%         0.0000       0.2000      0.2554       0.0989      0.1494
# 50%         1.0000       0.5000      0.2789       0.1884      0.2357
# 75%         1.0000       0.6000      0.3880       0.1970      0.2506
# max         1.0000       0.8000      0.6784       0.3428      0.5412
#
#        ofa_con_sim   CLIP_s
# count      11.0000  11.0000
# mean        0.2999   0.2619
# std         0.1681   0.0325
# min         0.0184   0.2262
# 25%         0.2416   0.2319
# 50%         0.3239   0.2617
# 75%         0.3648   0.2806
# max         0.5632   0.3206
# m
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count      25.0000      25.0000     25.0000      25.0000     25.0000
# mean        0.6800       0.6306      0.4993       0.2288      0.2504
# std         0.4761       0.1768      0.1236       0.1458      0.1738
# min         0.0000       0.1111      0.1858      -0.0532     -0.0356
# 25%         0.0000       0.6000      0.4618       0.1386      0.1378
# 50%         1.0000       0.6250      0.5239       0.2021      0.2311
# 75%         1.0000       0.7500      0.5576       0.3564      0.3740
# max         1.0000       0.8750      0.7359       0.5021      0.6052
#
#        ofa_con_sim   CLIP_s
# count      25.0000  25.0000
# mean        0.2783   0.2622
# std         0.1744   0.0407
# min         0.0468   0.1802
# 25%         0.1393   0.2421
# 50%         0.2474   0.2612
# 75%         0.3056   0.2908
# max         0.6215   0.3359
# n
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count      29.0000      29.0000     29.0000      29.0000     29.0000
# mean        0.6552       0.3364      0.2580       0.1499      0.2053
# std         0.4837       0.2391      0.1340       0.1243      0.1368
# min         0.0000       0.1111      0.0683      -0.0551     -0.0156
# 25%         0.0000       0.1111      0.1311       0.0553      0.1016
# 50%         1.0000       0.3000      0.2426       0.1212      0.1813
# 75%         1.0000       0.5714      0.3957       0.2394      0.3162
# max         1.0000       0.7143      0.4939       0.3962      0.4805
#
#        ofa_con_sim   CLIP_s
# count      29.0000  29.0000
# mean        0.2783   0.2651
# std         0.1676   0.0505
# min        -0.0058   0.1353
# 25%         0.1649   0.2404
# 50%         0.2391   0.2786
# 75%         0.4013   0.3005
# max         0.5799   0.3303
# o
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count      49.0000      49.0000     49.0000      49.0000     49.0000
# mean        0.5102       0.5363      0.5123       0.2669      0.3518
# std         0.5051       0.1535      0.1373       0.1384      0.1841
# min         0.0000       0.1250      0.2380      -0.0581     -0.0080
# 25%         0.0000       0.5000      0.4246       0.1934      0.1955
# 50%         1.0000       0.5000      0.5099       0.2705      0.3845
# 75%         1.0000       0.6250      0.5939       0.3702      0.4906
# max         1.0000       0.8750      0.8761       0.5995      0.7047
#
#        ofa_con_sim   CLIP_s
# count      49.0000  49.0000
# mean        0.2697   0.2871
# std         0.1300   0.0357
# min         0.0166   0.2159
# 25%         0.1958   0.2559
# 50%         0.2485   0.2893
# 75%         0.3384   0.3076
# max         0.6698   0.3784

# %%
#after
for el in pg_dict:
    print(el)
    display(pg_dict[el][['gt_ped_flag', 'gt_coverage', 'org_gt_sim', 'ofa_top_sim', 'ofa_gt_sim', 'ofa_con_sim', 'CLIP_s']].describe().round(4))
# Out:
# a
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count      46.0000      46.0000     46.0000      46.0000     46.0000
# mean        0.5870       0.4983      0.5413       0.5062      0.5330
# std         0.4978       0.2433      0.1308       0.1497      0.1789
# min         0.0000       0.0909      0.3295       0.0505      0.0048
# 25%         0.0000       0.3636      0.4531       0.4164      0.4103
# 50%         1.0000       0.4545      0.5498       0.5138      0.5246
# 75%         1.0000       0.6000      0.6130       0.5786      0.6270
# max         1.0000       1.0000      0.8276       0.8514      0.8790
#
#        ofa_con_sim   CLIP_s
# count      46.0000  46.0000
# mean        0.5113   0.2837
# std         0.1420   0.0377
# min         0.0940   0.2035
# 25%         0.4027   0.2571
# 50%         0.5274   0.2806
# 75%         0.6215   0.3131
# max         0.7064   0.3623
# f
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count       16.000      16.0000     16.0000      16.0000     16.0000
# mean         0.625       0.6656      0.5006       0.4036      0.3897
# std          0.500       0.3341      0.1052       0.1507      0.1614
# min          0.000       0.1250      0.3005       0.0486      0.0902
# 25%          0.000       0.3833      0.4555       0.3396      0.3049
# 50%          1.000       0.7153      0.5029       0.4169      0.4274
# 75%          1.000       1.0000      0.5658       0.4624      0.4838
# max          1.000       1.0000      0.6500       0.6656      0.6097
#
#        ofa_con_sim   CLIP_s
# count      16.0000  16.0000
# mean        0.2848   0.3188
# std         0.1303   0.0396
# min         0.1193   0.2487
# 25%         0.2041   0.2950
# 50%         0.2530   0.3176
# 75%         0.3106   0.3419
# max         0.6047   0.3831
# g
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count      25.0000      25.0000     25.0000      25.0000     25.0000
# mean        0.5600       0.2391      0.4525       0.2771      0.3403
# std         0.5066       0.1077      0.1747       0.1368      0.1962
# min         0.0000       0.1000      0.1280       0.0459      0.0283
# 25%         0.0000       0.2000      0.3817       0.1770      0.1498
# 50%         1.0000       0.2000      0.4998       0.2837      0.3772
# 75%         1.0000       0.3000      0.5931       0.4187      0.5037
# max         1.0000       0.5556      0.6873       0.4601      0.6667
#
#        ofa_con_sim   CLIP_s
# count      25.0000  25.0000
# mean        0.1990   0.2915
# std         0.1753   0.0326
# min        -0.0036   0.2061
# 25%         0.0605   0.2771
# 50%         0.1478   0.2969
# 75%         0.2576   0.3154
# max         0.6667   0.3562
# h
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count         28.0      28.0000     28.0000      28.0000     28.0000
# mean           1.0       0.2714      0.4853       0.3269      0.4702
# std            0.0       0.1182      0.1192       0.0916      0.1436
# min            1.0       0.2000      0.2482       0.0943      0.1715
# 25%            1.0       0.2000      0.4161       0.2730      0.3578
# 50%            1.0       0.2000      0.4601       0.2975      0.4943
# 75%            1.0       0.3000      0.5478       0.3992      0.5863
# max            1.0       0.7000      0.7383       0.5471      0.7227
#
#        ofa_con_sim   CLIP_s
# count      28.0000  28.0000
# mean        0.4510   0.3032
# std         0.1592   0.0288
# min         0.0850   0.2390
# 25%         0.3145   0.2898
# 50%         0.5102   0.3042
# 75%         0.5659   0.3195
# max         0.6647   0.3706
# i
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count      72.0000      72.0000     72.0000      72.0000     72.0000
# mean        0.6667       0.5866      0.5408       0.4197      0.4652
# std         0.4747       0.2297      0.1532       0.1555      0.1755
# min         0.0000       0.1250      0.1724       0.0139      0.0749
# 25%         0.0000       0.3750      0.4241       0.3433      0.3386
# 50%         1.0000       0.5455      0.5956       0.4415      0.5220
# 75%         1.0000       0.8571      0.6514       0.5173      0.5957
# max         1.0000       1.0000      0.7780       0.7011      0.7506
#
#        ofa_con_sim   CLIP_s
# count      72.0000  72.0000
# mean        0.3078   0.3045
# std         0.1629   0.0369
# min        -0.0071   0.1937
# 25%         0.1883   0.2748
# 50%         0.2885   0.3068
# 75%         0.4138   0.3268
# max         0.7064   0.4036
# j
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
#
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count      29.0000      29.0000     29.0000      29.0000     29.0000
# mean        0.6552       0.3364      0.2580       0.2209      0.2488
# std         0.4837       0.2391      0.1340       0.1549      0.1697
# min         0.0000       0.1111      0.0683      -0.1238     -0.0869
# 25%         0.0000       0.1111      0.1311       0.1277      0.1369
# 50%         1.0000       0.3000      0.2426       0.2057      0.2292
# 75%         1.0000       0.5714      0.3957       0.2641      0.3657
# max         1.0000       0.7143      0.4939       0.5653      0.5433
#
#        ofa_con_sim   CLIP_s
# count      29.0000  29.0000
# mean        0.3289   0.2852
# std         0.1789   0.0431
# min         0.0863   0.1709
# 25%         0.2071   0.2708
# 50%         0.2506   0.2920
# 75%         0.4564   0.3103
# max         0.7568   0.3547
# o
#        gt_ped_flag  gt_coverage  org_gt_sim  ofa_top_sim  ofa_gt_sim  \
# count      49.0000      49.0000     49.0000      49.0000     49.0000
# mean        0.5102       0.5363      0.5123       0.4038      0.4266
# std         0.5051       0.1535      0.1373       0.1533      0.1766
# min         0.0000       0.1250      0.2380      -0.0325      0.0200
# 25%         0.0000       0.5000      0.4246       0.3217      0.3011
# 50%         1.0000       0.5000      0.5099       0.3786      0.4229
# 75%         1.0000       0.6250      0.5939       0.5099      0.5543
# max         1.0000       0.8750      0.8761       0.6950      0.7990
#
#        ofa_con_sim   CLIP_s
# count      49.0000  49.0000
# mean        0.4366   0.2883
# std         0.1955   0.0461
# min        -0.0097   0.2068
# 25%         0.2523   0.2612
# 50%         0.4581   0.2871
# 75%         0.5826   0.3210
# max         0.7064   0.3838

# %% [markdown]
# # CLIP list score

# %%
d_path = '/raid/AISSEL/Hamed/datasets/ped_data/ped_fatemeh/all'
# before
df_b = pd.read_pickle(f'{d_path}/test_before_trained_on_all_ped.pk')

#after
df_f = pd.read_pickle(f'{d_path}/test_after_trained_on_all_ped.pk')

# wit
d_path = '/raid/AISSEL/Hamed/datasets/ped_data/wit/all_topics'
df_w = pd.read_pickle(f'{d_path}/wit_ped_test_after.pk')
# df

# %%
def drop_nan(df):
#     print(df['gt'].isna().sum())
    df = df[df['gt'].notna()]
    df = df.reset_index(drop=True)
    return df

# %%
df_b['gt'] = df.apply(lambda x: create_gt(x.tag), axis=1)
df_f['gt'] = df.apply(lambda x: create_gt(x.tag), axis=1)
df_w['gt'] = df.apply(lambda x: create_gt(x.tag), axis=1)
# df_b = drop_nan(df_b)
# df_f = drop_nan(df_f)
# df_w = drop_nan(df_w)

# len(df_b)

# %%
df_b = df_b.dropna()
df_b = df_b.reset_index(drop=True)
df_f = df_f.dropna()
df_f = df_f.reset_index(drop=True)
df_w = df_w.dropna()
df_w = df_w.reset_index(drop=True)

# %%
print(len(df_b))
print(len(df_f))
print(len(df_w))
# Out:
# 623
# 623
# 623

# %%
tmp_df = pd.DataFrame()

# %%
tmp_df['image'] = df_b['image'].to_list()

# %%
tmp_df['bf_caption'] = df_b['ofa_caption'].to_list()
tmp_df['aw_caption'] = df_w['ofa_caption'].to_list()
tmp_df['af_caption'] = df_f['ofa_caption'].to_list()
tmp_df['topics'] = df_b['topics'].to_list()

# %%
tmp_df
# Out:
#                                                  image  \
# 0    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4    /9j/7gAOQWRvYmUAZAAAAAAA/9sAQwAIBgYHBgUIBwcHCQ...
# ..                                                 ...
# 618  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 619  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 620  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 621  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 622  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
#                                             bf_caption  \
# 0              a silhouette of a car parked in a field
# 1      a street with a bus and a white car on the road
# 2           a person is getting on a bus at a bus stop
# 3           a person is getting on a bus at a bus stop
# 4    a woman and a child in a wheelchair waiting fo...
# ..                                                 ...
# 618           a woman sitting on the top of a mountain
# 619    a man and woman standing on a trail in a forest
# 620                    a woman walking a dog in a park
# 621      a statue of a woman standing on a city street
# 622    a view of a river with a city in the background
#
#                                             aw_caption  \
# 0    A car parked on the side of the road with the ...
# 1                A bike lane in the middle of the city
# 2    A bus driver at the bus stop in the city of sa...
# 3    A bus driver at the bus stop in the city of sa...
# 4    English woman with a child in a wheelchair wai...
# ..                                                 ...
# 618                 English picnic shelter in the park
# 619  English view of the pedestrian bridge over the...
# 620              English view from the top of the hill
# 621  English woman holding a camera on the ground w...
# 622  English woman wearing a face mask in front of ...
#
#                                             af_caption topics
# 0    illustrated silhouette of a car on a hill at n...      a
# 1                          Pedestrian and bicycle lane      a
# 2                Pedestrian getting on bus at bus stop      a
# 3                Pedestrian getting on bus at bus stop      a
# 4    Pedestrians waiting to cross the street at a b...      a
# ..                                                 ...    ...
# 618     hiker woman sitting on the top of the mountain      o
# 619            A man and a woman walking in the forest      o
# 620  Pedestrians and their dogs walk along the pede...      o
# 621  A pedestrian promenade in the center of the ci...      o
# 622  pedestrian promenade along the river in singap...      o
#
# [623 rows x 5 columns]

# %%
def clip_3(row):
    image_64_decode = base64.b64decode(row['image']) 
    image_result = open('test.jpg', 'wb')
    image_result.write(image_64_decode)
    try:
        image = Image.open('test.jpg')
        image = preprocess(image).unsqueeze(0).to(device)

        with torch.no_grad():
            image_features = model.encode_image(image)

        text_snippets = [row['bf_caption'], row['aw_caption'], row['af_caption']]
        text = clip.tokenize(text_snippets).to(device)

        with torch.no_grad():
            text_features = model.encode_text(text)
        
        with torch.no_grad():
            logits_per_image, logits_per_text = model(image, text)
            probs = list(logits_per_image.softmax(dim=-1).cpu().numpy()[0])
        
        return probs[0], probs[1], probs[2]
    except:
        return None

# %%
for index, row in tmp_df.iterrows():
    print(clip_3(row))
    break
# Out:
# (0.263, 4.87e-05, 0.7373)

# %%
clip_scores = tmp_df.apply(clip_3, axis=1)

# %%
bf_score = []
aw_score = []
af_score = []
for el in clip_scores:
#     print(el)
    if el:
        bf_score.append(el[0])
        aw_score.append(el[1])
        af_score.append(el[2])
    else:
        bf_score.append(None)
        aw_score.append(None)
        af_score.append(None)

# %%
tmp_df['bf_score'] = bf_score
tmp_df['aw_score'] = aw_score
tmp_df['af_score'] = af_score

# %%
tmp_df
# Out:
#                                                  image  \
# 0    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4    /9j/7gAOQWRvYmUAZAAAAAAA/9sAQwAIBgYHBgUIBwcHCQ...
# ..                                                 ...
# 618  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 619  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 620  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 621  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 622  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
#                                             bf_caption  \
# 0              a silhouette of a car parked in a field
# 1      a street with a bus and a white car on the road
# 2           a person is getting on a bus at a bus stop
# 3           a person is getting on a bus at a bus stop
# 4    a woman and a child in a wheelchair waiting fo...
# ..                                                 ...
# 618           a woman sitting on the top of a mountain
# 619    a man and woman standing on a trail in a forest
# 620                    a woman walking a dog in a park
# 621      a statue of a woman standing on a city street
# 622    a view of a river with a city in the background
#
#                                             aw_caption  \
# 0    A car parked on the side of the road with the ...
# 1                A bike lane in the middle of the city
# 2    A bus driver at the bus stop in the city of sa...
# 3    A bus driver at the bus stop in the city of sa...
# 4    English woman with a child in a wheelchair wai...
# ..                                                 ...
# 618                 English picnic shelter in the park
# 619  English view of the pedestrian bridge over the...
# 620              English view from the top of the hill
# 621  English woman holding a camera on the ground w...
# 622  English woman wearing a face mask in front of ...
#
#                                             af_caption topics  bf_score  \
# 0    illustrated silhouette of a car on a hill at n...      a  0.262939
# 1                          Pedestrian and bicycle lane      a  0.044037
# 2                Pedestrian getting on bus at bus stop      a  0.040619
# 3                Pedestrian getting on bus at bus stop      a  0.040619
# 4    Pedestrians waiting to cross the street at a b...      a  0.964355
# ..                                                 ...    ...       ...
# 618     hiker woman sitting on the top of the mountain      o  0.841797
# 619            A man and a woman walking in the forest      o  0.604004
# 620  Pedestrians and their dogs walk along the pede...      o  0.000095
# 621  A pedestrian promenade in the center of the ci...      o  0.001926
# 622  pedestrian promenade along the river in singap...      o  0.189575
#
#          aw_score  af_score
# 0    4.869699e-05  0.737305
# 1    8.489990e-02  0.871094
# 2    2.163086e-01  0.743164
# 3    2.163086e-01  0.743164
# 4    1.608276e-02  0.019409
# ..            ...       ...
# 618  1.788139e-07  0.158203
# 619  1.132488e-06  0.395996
# 620  8.344650e-07  1.000000
# 621  2.384186e-07  0.998047
# 622  0.000000e+00  0.810547
#
# [623 rows x 8 columns]

# %%
tmp_df = tmp_df.dropna()
tmp_df = tmp_df.reset_index(drop=True)
tmp_df
# Out:
#                                                  image  \
# 0    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3    /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4    /9j/7gAOQWRvYmUAZAAAAAAA/9sAQwAIBgYHBgUIBwcHCQ...
# ..                                                 ...
# 616  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 617  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 618  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 619  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 620  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
#                                             bf_caption  \
# 0              a silhouette of a car parked in a field
# 1      a street with a bus and a white car on the road
# 2           a person is getting on a bus at a bus stop
# 3           a person is getting on a bus at a bus stop
# 4    a woman and a child in a wheelchair waiting fo...
# ..                                                 ...
# 616           a woman sitting on the top of a mountain
# 617    a man and woman standing on a trail in a forest
# 618                    a woman walking a dog in a park
# 619      a statue of a woman standing on a city street
# 620    a view of a river with a city in the background
#
#                                             aw_caption  \
# 0    A car parked on the side of the road with the ...
# 1                A bike lane in the middle of the city
# 2    A bus driver at the bus stop in the city of sa...
# 3    A bus driver at the bus stop in the city of sa...
# 4    English woman with a child in a wheelchair wai...
# ..                                                 ...
# 616                 English picnic shelter in the park
# 617  English view of the pedestrian bridge over the...
# 618              English view from the top of the hill
# 619  English woman holding a camera on the ground w...
# 620  English woman wearing a face mask in front of ...
#
#                                             af_caption topics  bf_score  \
# 0    illustrated silhouette of a car on a hill at n...      a  0.262939
# 1                          Pedestrian and bicycle lane      a  0.044037
# 2                Pedestrian getting on bus at bus stop      a  0.040619
# 3                Pedestrian getting on bus at bus stop      a  0.040619
# 4    Pedestrians waiting to cross the street at a b...      a  0.964355
# ..                                                 ...    ...       ...
# 616     hiker woman sitting on the top of the mountain      o  0.841797
# 617            A man and a woman walking in the forest      o  0.604004
# 618  Pedestrians and their dogs walk along the pede...      o  0.000095
# 619  A pedestrian promenade in the center of the ci...      o  0.001926
# 620  pedestrian promenade along the river in singap...      o  0.189575
#
#          aw_score  af_score
# 0    4.869699e-05  0.737305
# 1    8.489990e-02  0.871094
# 2    2.163086e-01  0.743164
# 3    2.163086e-01  0.743164
# 4    1.608276e-02  0.019409
# ..            ...       ...
# 616  1.788139e-07  0.158203
# 617  1.132488e-06  0.395996
# 618  8.344650e-07  1.000000
# 619  2.384186e-07  0.998047
# 620  0.000000e+00  0.810547
#
# [621 rows x 8 columns]

# %%
tmp_df[['bf_score', 'aw_score', 'af_score']].describe().round(4)
# Out:
#        bf_score  aw_score  af_score
# count  621.0000  621.0000  621.0000
# mean     0.4395    0.0367    0.5238
# std      0.3731    0.1421    0.3755
# min      0.0000    0.0000    0.0000
# 25%      0.0518    0.0000    0.1260
# 50%      0.3894    0.0000    0.5312
# 75%      0.8164    0.0015    0.9209
# max      1.0000    0.9937    1.0000

# %%
gk = tmp_df.groupby('topics')
pg_dict = dict()
for el in gk.groups.keys():
    pg_dict[el] = gk.get_group(el)
    pg_dict[el] = pg_dict[el].reset_index(drop=True)
# before
for el in pg_dict:
    print(el)
    display(pg_dict[el][['bf_score', 'aw_score', 'af_score']].describe().round(2))
# Out:
# a
#        bf_score  aw_score  af_score
# count     53.00     53.00     53.00
# mean       0.38      0.19      0.43
# std        0.37      0.31      0.36
# min        0.00      0.00      0.00
# 25%        0.04      0.00      0.07
# 50%        0.24      0.04      0.37
# 75%        0.74      0.22      0.81
# max        0.99      0.99      0.98
# b
#        bf_score  aw_score  af_score
# count    105.00    105.00    105.00
# mean       0.47      0.05      0.48
# std        0.35      0.17      0.35
# min        0.00      0.00      0.00
# 25%        0.12      0.00      0.13
# 50%        0.46      0.00      0.45
# 75%        0.81      0.00      0.85
# max        1.00      0.92      1.00
# c
#        bf_score  aw_score  af_score
# count     59.00     59.00     59.00
# mean       0.43      0.01      0.56
# std        0.34      0.04      0.34
# min        0.00      0.00      0.00
# 25%        0.11      0.00      0.34
# 50%        0.35      0.00      0.62
# 75%        0.66      0.00      0.88
# max        1.00      0.31      1.00
# d
#        bf_score  aw_score  af_score
# count     62.00     62.00     62.00
# mean       0.37      0.04      0.59
# std        0.38      0.13      0.39
# min        0.00      0.00      0.00
# 25%        0.02      0.00      0.20
# 50%        0.20      0.00      0.75
# 75%        0.71      0.01      0.98
# max        1.00      0.89      1.00
# e
#        bf_score  aw_score  af_score
# count     48.00     48.00     48.00
# mean       0.52      0.01      0.47
# std        0.41      0.03      0.42
# min        0.00      0.00      0.00
# 25%        0.03      0.00      0.08
# 50%        0.68      0.00      0.32
# 75%        0.91      0.00      0.96
# max        1.00      0.20      1.00
# f
#        bf_score  aw_score  af_score
# count     17.00      17.0     17.00
# mean       0.25       0.0      0.75
# std        0.31       0.0      0.31
# min        0.00       0.0      0.02
# 25%        0.01       0.0      0.55
# 50%        0.07       0.0      0.93
# 75%        0.45       0.0      0.99
# max        0.98       0.0      1.00
# g
#        bf_score  aw_score  af_score
# count     26.00     26.00     26.00
# mean       0.53      0.01      0.46
# std        0.32      0.05      0.32
# min        0.00      0.00      0.00
# 25%        0.29      0.00      0.20
# 50%        0.57      0.00      0.42
# 75%        0.79      0.00      0.71
# max        1.00      0.23      1.00
# h
#        bf_score  aw_score  af_score
# count     33.00     33.00     33.00
# mean       0.46      0.01      0.53
# std        0.35      0.04      0.35
# min        0.00      0.00      0.00
# 25%        0.10      0.00      0.28
# 50%        0.44      0.00      0.55
# 75%        0.73      0.00      0.90
# max        1.00      0.23      1.00
# i
#        bf_score  aw_score  af_score
# count     75.00     75.00     75.00
# mean       0.51      0.03      0.46
# std        0.38      0.12      0.37
# min        0.00      0.00      0.00
# 25%        0.12      0.00      0.12
# 50%        0.58      0.00      0.37
# 75%        0.87      0.00      0.86
# max        1.00      0.73      1.00
# j
#        bf_score  aw_score  af_score
# count      7.00       7.0      7.00
# mean       0.72       0.0      0.28
# std        0.42       0.0      0.42
# min        0.06       0.0      0.00
# 25%        0.53       0.0      0.01
# 50%        0.93       0.0      0.07
# 75%        0.99       0.0      0.47
# max        1.00       0.0      0.94
# k
#        bf_score  aw_score  af_score
# count     41.00     41.00     41.00
# mean       0.34      0.00      0.66
# std        0.37      0.01      0.38
# min        0.00      0.00      0.00
# 25%        0.01      0.00      0.29
# 50%        0.14      0.00      0.86
# 75%        0.71      0.00      0.99
# max        0.99      0.06      1.00
# l
#        bf_score  aw_score  af_score
# count     11.00     11.00     11.00
# mean       0.43      0.00      0.57
# std        0.40      0.01      0.40
# min        0.00      0.00      0.00
# 25%        0.07      0.00      0.23
# 50%        0.29      0.00      0.71
# 75%        0.76      0.00      0.93
# max        1.00      0.02      1.00
# m
#        bf_score  aw_score  af_score
# count     25.00     25.00     25.00
# mean       0.49      0.00      0.51
# std        0.42      0.00      0.42
# min        0.00      0.00      0.00
# 25%        0.07      0.00      0.02
# 50%        0.41      0.00      0.59
# 75%        0.98      0.00      0.93
# max        1.00      0.02      1.00
# n
#        bf_score  aw_score  af_score
# count     36.00     36.00     36.00
# mean       0.29      0.00      0.71
# std        0.34      0.00      0.34
# min        0.00      0.00      0.00
# 25%        0.03      0.00      0.41
# 50%        0.12      0.00      0.88
# 75%        0.59      0.00      0.97
# max        1.00      0.01      1.00
# o
#        bf_score  aw_score  af_score
# count     23.00     23.00     23.00
# mean       0.53      0.04      0.43
# std        0.40      0.19      0.40
# min        0.00      0.00      0.00
# 25%        0.11      0.00      0.03
# 50%        0.63      0.00      0.36
# 75%        0.93      0.00      0.85
# max        0.99      0.93      1.00

# %%
43 + 38 + 19
# Out:
# 100
