# %%
import sys
sys.path.append("/home/test/PycharmProjects")
from pycocotools.coco import COCO
from pycocoevalcap.eval import COCOEvalCap
import pandas as pd
import json

# %%
annotation_file = './example/captions_val2014.json'
results_file = './example/captions_val2014_fakecap_results.json'

# create coco object and coco_result object
# coco = COCO(annotation_file)

# %%
# create coco_eval object by taking coco and coco_result
# coco_result = coco.loadRes(results_file)

# %%
! ls ./example/
# Out:
# captions_val2014_fakecap_results.json  coco_eval_example.py
# captions_val2014.json

# %%
with open(annotation_file, 'r') as f:
    jdata = json.load(f)

# %%
for el in jdata:
    print(el)
# Out:
# info
# images
# licenses
# type
# annotations

# %%
d_path = '.'
bf = f'{d_path}/test_before_trained_on_all_ped.pk'
af_wit = f'{d_path}/wit_ped_test_after.pk'
af_fat = f'{d_path}/test_after_trained_on_all_ped.pk'

# %%
# df_wp = pd.read_pickle(bf)
# df_wp = pd.read_pickle(af_wit)
df_wp = pd.read_pickle(af_fat)
df_wp
# Out:
#      uniq_id  image_id                                            caption  \
# 0        167       167               Car on rural road vector Stock Photo
# 1        184       184           Bus Only Lane Rendering Kuhio and Walina
# 2        187       187               Passenger boarding a bus on Bayshore
# 3        192       192               Passenger boarding a bus on Bayshore
# 4        209       209         Pedestrian Connections Congestion Strategy
# ..       ...       ...                                                ...
# 644     1228      1228          Westown Commons picnic shelter front view
# 645     1241      1241                        Humboldt Alexander Von Park
# 646     1259      1259  photo of trees and the fenceline at Mason Hill...
# 647     1296      1296                                Hogback Ridge Park
# 648     1306      1306          Playground and park unveiled in Jamaica 4
#
#      topic_id labels                                              image  \
# 0          68         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4         112         /9j/7gAOQWRvYmUAZAAAAAAA/9sAQwAIBgYHBgUIBwcHCQ...
# ..        ...    ...                                                ...
# 644       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 645       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 646       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 647       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 648       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
#      topic2caption_sim  concept2caption_sim topics  \
# 0             0.376758             0.212455      a
# 1             0.392783             0.160691      a
# 2             0.438588             0.197647      a
# 3             0.438588             0.197647      a
# 4             0.612697             0.493012      a
# ..                 ...                  ...    ...
# 644           0.395052             0.217862      o
# 645           0.415312             0.211162      o
# 646           0.446961             0.234170      o
# 647           0.579372             0.235827      o
# 648           0.499459             0.164558      o
#
#                                                    tag  \
# 0    {'passenger': 0, 'wheel': 1, 'vehicle': 1, 'wa...
# 1    {'freight': 1, 'transportation': 1, 'traffic':...
# 2    {'freight': 1, 'transportation': 1, 'traffic':...
# 3    {'freight': 1, 'transportation': 1, 'traffic':...
# 4    {'freight': 1, 'transportation': 1, 'traffic':...
# ..                                                 ...
# 644  {'scenic': 0, 'recreation': 1, 'wilderness': 0...
# 645  {'scenic': 1, 'recreation': 1, 'wilderness': 0...
# 646  {'scenic': 1, 'recreation': 1, 'wilderness': 0...
# 647  {'scenic': 1, 'recreation': 1, 'wilderness': 0...
# 648  {'scenic': 0, 'recreation': 1, 'wilderness': 0...
#
#                                            ofa_caption  \
# 0    illustrated silhouette of a car on a hill at n...
# 1                          Pedestrian and bicycle lane
# 2                Pedestrian getting on bus at bus stop
# 3                Pedestrian getting on bus at bus stop
# 4    Pedestrians waiting to cross the street at a b...
# ..                                                 ...
# 644  A blue and white gazebo in a park with picnic ...
# 645                 Pedestrian walkway along the river
# 646                                   Pedestrian fence
# 647  A woman in a red and white plaid dress holding...
# 648  A woman wearing a face mask stands in front of...
#
#                                                     gt
# 0                                        wheel vehicle
# 1     freight transportation traffic transport tran...
# 2     freight transportation traffic transport tran...
# 3     freight transportation traffic transport tran...
# 4     freight transportation traffic transport cong...
# ..                                                 ...
# 644                               recreation park area
# 645             scenic recreation park area pedestrian
# 646                        scenic recreation park area
# 647                        scenic recreation park area
# 648         recreation park area pedestrian playground
#
# [649 rows x 12 columns]

# %%
def create_gt(tag):
    context = []
    for el in tag:
        if tag[el]:
            context.append(el)
    if not context:
        context = None
    return context

# %%
def create_con_gt(tag):
    context = ""
    for el in tag:
        if tag[el]:
            context = context + " " + el
    if not context:
        context = None
    return context

# %%
df_wp['gt'] = df_wp.apply(lambda x: create_gt(x.tag), axis=1)
df_wp['con_gt'] = df_wp.apply(lambda x: create_con_gt(x.tag), axis=1)
df_wp
# Out:
#      uniq_id  image_id                                            caption  \
# 0        167       167               Car on rural road vector Stock Photo
# 1        184       184           Bus Only Lane Rendering Kuhio and Walina
# 2        187       187               Passenger boarding a bus on Bayshore
# 3        192       192               Passenger boarding a bus on Bayshore
# 4        209       209         Pedestrian Connections Congestion Strategy
# ..       ...       ...                                                ...
# 644     1228      1228          Westown Commons picnic shelter front view
# 645     1241      1241                        Humboldt Alexander Von Park
# 646     1259      1259  photo of trees and the fenceline at Mason Hill...
# 647     1296      1296                                Hogback Ridge Park
# 648     1306      1306          Playground and park unveiled in Jamaica 4
#
#      topic_id labels                                              image  \
# 0          68         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3         112         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4         112         /9j/7gAOQWRvYmUAZAAAAAAA/9sAQwAIBgYHBgUIBwcHCQ...
# ..        ...    ...                                                ...
# 644       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 645       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 646       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 647       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 648       296         /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
#      topic2caption_sim  concept2caption_sim topics  \
# 0             0.376758             0.212455      a
# 1             0.392783             0.160691      a
# 2             0.438588             0.197647      a
# 3             0.438588             0.197647      a
# 4             0.612697             0.493012      a
# ..                 ...                  ...    ...
# 644           0.395052             0.217862      o
# 645           0.415312             0.211162      o
# 646           0.446961             0.234170      o
# 647           0.579372             0.235827      o
# 648           0.499459             0.164558      o
#
#                                                    tag  \
# 0    {'passenger': 0, 'wheel': 1, 'vehicle': 1, 'wa...
# 1    {'freight': 1, 'transportation': 1, 'traffic':...
# 2    {'freight': 1, 'transportation': 1, 'traffic':...
# 3    {'freight': 1, 'transportation': 1, 'traffic':...
# 4    {'freight': 1, 'transportation': 1, 'traffic':...
# ..                                                 ...
# 644  {'scenic': 0, 'recreation': 1, 'wilderness': 0...
# 645  {'scenic': 1, 'recreation': 1, 'wilderness': 0...
# 646  {'scenic': 1, 'recreation': 1, 'wilderness': 0...
# 647  {'scenic': 1, 'recreation': 1, 'wilderness': 0...
# 648  {'scenic': 0, 'recreation': 1, 'wilderness': 0...
#
#                                            ofa_caption  \
# 0    illustrated silhouette of a car on a hill at n...
# 1                          Pedestrian and bicycle lane
# 2                Pedestrian getting on bus at bus stop
# 3                Pedestrian getting on bus at bus stop
# 4    Pedestrians waiting to cross the street at a b...
# ..                                                 ...
# 644  A blue and white gazebo in a park with picnic ...
# 645                 Pedestrian walkway along the river
# 646                                   Pedestrian fence
# 647  A woman in a red and white plaid dress holding...
# 648  A woman wearing a face mask stands in front of...
#
#                                                     gt  \
# 0                                     [wheel, vehicle]
# 1    [freight, transportation, traffic, transport, ...
# 2    [freight, transportation, traffic, transport, ...
# 3    [freight, transportation, traffic, transport, ...
# 4    [freight, transportation, traffic, transport, ...
# ..                                                 ...
# 644                           [recreation, park, area]
# 645       [scenic, recreation, park, area, pedestrian]
# 646                   [scenic, recreation, park, area]
# 647                   [scenic, recreation, park, area]
# 648   [recreation, park, area, pedestrian, playground]
#
#                                                 con_gt
# 0                                        wheel vehicle
# 1     freight transportation traffic transport tran...
# 2     freight transportation traffic transport tran...
# 3     freight transportation traffic transport tran...
# 4     freight transportation traffic transport cong...
# ..                                                 ...
# 644                               recreation park area
# 645             scenic recreation park area pedestrian
# 646                        scenic recreation park area
# 647                        scenic recreation park area
# 648         recreation park area pedestrian playground
#
# [649 rows x 13 columns]

# %%
print(df_wp['gt'].isna().sum())
df_wp = df_wp[df_wp['gt'].notna()]
df_wp = df_wp.reset_index(drop=True)
len(df_wp)
# Out:
# 26
# 623

# %%
import numpy as np

# %%
def id2imdf(_df):
    _df = _df[['uniq_id']]
    _df['license'] = 1
    _df['url'] = 'http://farm9.staticflickr.com'
    _df['file_name'] = 'test.jpg'
    _df['width'] = 640
    _df['height'] = 360
    _df['date_captured'] = '2013-11-14 11:18:45'
    _df.columns = _df.columns.str.replace('uniq_id', 'id')
    return _df

# %%
def concat_gt2anno(_df):
    image_id = []
    caption = []
    for index, row in _df.iterrows():
        image_id.append(row['image_id'])
        caption.append(row['con_gt'])
    
    df_ = pd.DataFrame()
    df_['image_id'] = image_id
    df_['id'] = np.arange(len(caption))
    df_['caption'] = caption
    return df_

# %%
def gt2anno(_df):
    image_id = []
    caption = []
    for index, row in _df.iterrows():
#         print(row['image_id'], row['gt'])
        for el in row['gt']:
            image_id.append(row['image_id'])
            caption.append(el)
#         break
    df_ = pd.DataFrame()
    df_['image_id'] = image_id
    df_['id'] = np.arange(len(caption))
    df_['caption'] = caption
    return df_

# %%
def org_2anno(_df):
    image_id = []
#     caption = []
    for index, row in _df.iterrows():
        image_id.append(row['image_id'])
#         caption.append('pedestrian')
    
    df_ = pd.DataFrame()
    df_['image_id'] = image_id
    df_['id'] = np.arange(len(image_id))
    df_['caption'] = _df['caption'].to_list()
    return df_

# %%
gk = df_wp.groupby('topics')
pg_dict = dict()
for el in gk.groups.keys():
    pg_dict[el] = dict()
    pg_dict[el]['data'] = gk.get_group(el)
    pg_dict[el]['data'] = pg_dict[el]['data'][pg_dict[el]['data']['topic2caption_sim'] >= pg_dict[el]['data']['topic2caption_sim'].quantile(.25)]
    pg_dict[el]['data'] = pg_dict[el]['data'].reset_index(drop=True)
    temp = pg_dict[el]['data'][['image_id', 'ofa_caption']]
    temp.columns = temp.columns.str.replace('ofa_caption', 'caption')
    pg_dict[el]['results'] = temp
    pg_dict[el]['images'] = id2imdf(pg_dict[el]['data'])
    pg_dict[el]['split_annotations'] = gt2anno(pg_dict[el]['data'])
    pg_dict[el]['con_annotations'] = concat_gt2anno(pg_dict[el]['data'])
    pg_dict[el]['org_annotations'] = org_2anno(pg_dict[el]['data'])
# Out:
# /tmp/ipykernel_13084/2853690035.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['license'] = 1
# /tmp/ipykernel_13084/2853690035.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['url'] = 'http://farm9.staticflickr.com'
# /tmp/ipykernel_13084/2853690035.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['file_name'] = 'test.jpg'
# /tmp/ipykernel_13084/2853690035.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['width'] = 640
# /tmp/ipykernel_13084/2853690035.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['height'] = 360
# /tmp/ipykernel_13084/2853690035.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['date_captured'] = '2013-11-14 11:18:45'
# /tmp/ipykernel_13084/2853690035.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['license'] = 1
# /tmp/ipykernel_13084/2853690035.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['url'] = 'http://farm9.staticflickr.com'
# /tmp/ipykernel_13084/2853690035.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['file_name'] = 'test.jpg'
# /tmp/ipykernel_13084/2853690035.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['width'] = 640
# /tmp/ipykernel_13084/2853690035.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['height'] = 360
# /tmp/ipykernel_13084/2853690035.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['date_captured'] = '2013-11-14 11:18:45'
# /tmp/ipykernel_13084/2853690035.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['license'] = 1
# /tmp/ipykernel_13084/2853690035.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['url'] = 'http://farm9.staticflickr.com'
# /tmp/ipykernel_13084/2853690035.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['file_name'] = 'test.jpg'
# /tmp/ipykernel_13084/2853690035.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['width'] = 640
# /tmp/ipykernel_13084/2853690035.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['height'] = 360
# /tmp/ipykernel_13084/2853690035.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['date_captured'] = '2013-11-14 11:18:45'
# /tmp/ipykernel_13084/2853690035.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['license'] = 1
# /tmp/ipykernel_13084/2853690035.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['url'] = 'http://farm9.staticflickr.com'
# /tmp/ipykernel_13084/2853690035.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['file_name'] = 'test.jpg'
# /tmp/ipykernel_13084/2853690035.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['width'] = 640
# /tmp/ipykernel_13084/2853690035.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['height'] = 360
# /tmp/ipykernel_13084/2853690035.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['date_captured'] = '2013-11-14 11:18:45'
# /tmp/ipykernel_13084/2853690035.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['license'] = 1
# /tmp/ipykernel_13084/2853690035.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['url'] = 'http://farm9.staticflickr.com'
# /tmp/ipykernel_13084/2853690035.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['file_name'] = 'test.jpg'
# /tmp/ipykernel_13084/2853690035.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['width'] = 640
# /tmp/ipykernel_13084/2853690035.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['height'] = 360
# /tmp/ipykernel_13084/2853690035.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['date_captured'] = '2013-11-14 11:18:45'
# /tmp/ipykernel_13084/2853690035.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['license'] = 1
# /tmp/ipykernel_13084/2853690035.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['url'] = 'http://farm9.staticflickr.com'
# /tmp/ipykernel_13084/2853690035.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['file_name'] = 'test.jpg'
# /tmp/ipykernel_13084/2853690035.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['width'] = 640
# /tmp/ipykernel_13084/2853690035.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['height'] = 360
# /tmp/ipykernel_13084/2853690035.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['date_captured'] = '2013-11-14 11:18:45'
# /tmp/ipykernel_13084/2853690035.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['license'] = 1
# /tmp/ipykernel_13084/2853690035.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['url'] = 'http://farm9.staticflickr.com'
# /tmp/ipykernel_13084/2853690035.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['file_name'] = 'test.jpg'
# /tmp/ipykernel_13084/2853690035.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['width'] = 640
# /tmp/ipykernel_13084/2853690035.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['height'] = 360
# /tmp/ipykernel_13084/2853690035.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['date_captured'] = '2013-11-14 11:18:45'
# /tmp/ipykernel_13084/2853690035.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['license'] = 1
# /tmp/ipykernel_13084/2853690035.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['url'] = 'http://farm9.staticflickr.com'
# /tmp/ipykernel_13084/2853690035.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['file_name'] = 'test.jpg'
# /tmp/ipykernel_13084/2853690035.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['width'] = 640
# /tmp/ipykernel_13084/2853690035.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['height'] = 360
# /tmp/ipykernel_13084/2853690035.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['date_captured'] = '2013-11-14 11:18:45'
# /tmp/ipykernel_13084/2853690035.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['license'] = 1
# /tmp/ipykernel_13084/2853690035.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['url'] = 'http://farm9.staticflickr.com'
# /tmp/ipykernel_13084/2853690035.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['file_name'] = 'test.jpg'
# /tmp/ipykernel_13084/2853690035.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['width'] = 640
# /tmp/ipykernel_13084/2853690035.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['height'] = 360
# /tmp/ipykernel_13084/2853690035.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['date_captured'] = '2013-11-14 11:18:45'
# /tmp/ipykernel_13084/2853690035.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['license'] = 1
# /tmp/ipykernel_13084/2853690035.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['url'] = 'http://farm9.staticflickr.com'
# /tmp/ipykernel_13084/2853690035.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['file_name'] = 'test.jpg'
# /tmp/ipykernel_13084/2853690035.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['width'] = 640
# /tmp/ipykernel_13084/2853690035.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['height'] = 360
# /tmp/ipykernel_13084/2853690035.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['date_captured'] = '2013-11-14 11:18:45'
# /tmp/ipykernel_13084/2853690035.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['license'] = 1
# /tmp/ipykernel_13084/2853690035.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['url'] = 'http://farm9.staticflickr.com'
# /tmp/ipykernel_13084/2853690035.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['file_name'] = 'test.jpg'
# /tmp/ipykernel_13084/2853690035.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['width'] = 640
# /tmp/ipykernel_13084/2853690035.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['height'] = 360
# /tmp/ipykernel_13084/2853690035.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['date_captured'] = '2013-11-14 11:18:45'
# /tmp/ipykernel_13084/2853690035.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['license'] = 1
# /tmp/ipykernel_13084/2853690035.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['url'] = 'http://farm9.staticflickr.com'
# /tmp/ipykernel_13084/2853690035.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['file_name'] = 'test.jpg'
# /tmp/ipykernel_13084/2853690035.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['width'] = 640
# /tmp/ipykernel_13084/2853690035.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['height'] = 360
# /tmp/ipykernel_13084/2853690035.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['date_captured'] = '2013-11-14 11:18:45'
# /tmp/ipykernel_13084/2853690035.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['license'] = 1
# /tmp/ipykernel_13084/2853690035.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['url'] = 'http://farm9.staticflickr.com'
# /tmp/ipykernel_13084/2853690035.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['file_name'] = 'test.jpg'
# /tmp/ipykernel_13084/2853690035.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['width'] = 640
# /tmp/ipykernel_13084/2853690035.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['height'] = 360
# /tmp/ipykernel_13084/2853690035.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['date_captured'] = '2013-11-14 11:18:45'
# /tmp/ipykernel_13084/2853690035.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['license'] = 1
# /tmp/ipykernel_13084/2853690035.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['url'] = 'http://farm9.staticflickr.com'
# /tmp/ipykernel_13084/2853690035.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['file_name'] = 'test.jpg'
# /tmp/ipykernel_13084/2853690035.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['width'] = 640
# /tmp/ipykernel_13084/2853690035.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['height'] = 360
# /tmp/ipykernel_13084/2853690035.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['date_captured'] = '2013-11-14 11:18:45'
# /tmp/ipykernel_13084/2853690035.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['license'] = 1
# /tmp/ipykernel_13084/2853690035.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['url'] = 'http://farm9.staticflickr.com'
# /tmp/ipykernel_13084/2853690035.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['file_name'] = 'test.jpg'
# /tmp/ipykernel_13084/2853690035.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['width'] = 640
# /tmp/ipykernel_13084/2853690035.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['height'] = 360
# /tmp/ipykernel_13084/2853690035.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df['date_captured'] = '2013-11-14 11:18:45'

# %%
pg_dict[el]['org_annotations']
# Out:
#     image_id  id                                            caption
# 0        623   0               best walking trails   greenbelt park
# 1        628   1          best walking trails   wild hyacinth trail
# 2        637   2                           Great American RailTrail
# 3        682   3                    Joppenbergh Mountain Loop Trail
# 4        740   4                Wildwood All Purpose WalkBike Trail
# 5        764   5  forest pedestrian bridge on a path used to hik...
# 6        830   6       Hardangervidda fourday hike Best in the West
# 7        852   7          Coastal path  hike VettreVollenSlemmestad
# 8        859   8                             Hiking route Stokkvola
# 9        868   9                  Mountain hike with personal guide
# 10       909  10                                Uganda hiking trail
# 11       951  11                                     Promenade Park
# 12       958  12  Macedonia street in city center of Skopje Pede...
# 13       968  13  Riverside pedestrian promenade of central phno...
# 14       973  14  Pedestrian promenade along Como lake in Varenn...
# 15       977  15                Before photo of the North Promenade
# 16       988  16                                   Waterfront Walks
# 17      1013  17                  Promenade Park Kids Water Feature
# 18      1057  18                  State Street pedestrian promenade
# 19      1060  19                      A rendering of a park walkway
# 20      1077  20  tow truck 02 VECTOR EPS10  set of tow truck an...
# 21      1084  21  No parking tow away zone sign set Tow away zon...
# 22      1092  22                          Parking garage rate signs
# 23      1094  23                                       parking sign
# 24      1096  24                           Parking Sign in Old Town
# 25      1102  25                      Cars parked on street in city
# 26      1123  26                           guys towing bad park job
# 27      1126  27                                        parked cars
# 28      1145  28                                    Parking garages
# 29      1146  29                                    Parking tickets
# 30      1170  30  Children and guardians enjoying the playground...
# 31      1172  31                              Peace Park Playground
# 32      1214  32                           Matanuska Peak Trailhead
# 33      1241  33                        Humboldt Alexander Von Park
# 34      1259  34  photo of trees and the fenceline at Mason Hill...
# 35      1296  35                                Hogback Ridge Park
# 36      1306  36          Playground and park unveiled in Jamaica 4

# %%
def crate_json(t='split_annotations'):
    t_data = dict()
    t_data['info'] = jdata['info']
    t_data['images'] = pg_dict[el]['images'].to_dict('records')
    t_data['type'] = jdata['type']
    t_data['licenses'] = jdata['licenses']
    t_data['annotations'] = pg_dict[el][t].to_dict('records')
    return t_data

# %%
file_dict = dict()
for el in gk.groups.keys():
    file_dict[el] = dict()
#     print(el)
    
    s_data = crate_json(t='split_annotations')
    c_data = crate_json(t='con_annotations')  
    o_data = crate_json(t='org_annotations')  
    res = pg_dict[el]['results'].to_dict('records')
    
    file_dict[el]['results'] = f"data/{el}_results.json"
    with open(file_dict[el]['results'], "w") as final:
        json.dump(res, final)
    
    file_dict[el]['sval'] = f"data/{el}_sval.json"
    with open(file_dict[el]['sval'], "w") as final:
        json.dump(s_data, final)
    
    file_dict[el]['cval'] = f"data/{el}_cval.json"
    with open(file_dict[el]['cval'], "w") as final:
        json.dump(c_data, final)
    
    file_dict[el]['oval'] = f"data/{el}_oval.json"
    with open(file_dict[el]['oval'], "w") as final:
        json.dump(o_data, final)

# %% [markdown]
# # Load data

# %%
def calc_metrics(topic='a', anno='s'):
    if anno == 's':
        annotation_file = file_dict[topic]['sval']
    elif anno == 'c':
        annotation_file = file_dict[topic]['cval']
    else:
        annotation_file = file_dict[topic]['oval']
        
    results_file = file_dict[topic]['results']
    coco = COCO(annotation_file)
    coco_result = coco.loadRes(results_file)
    coco_eval = COCOEvalCap(coco, coco_result)
    coco_eval.params['image_id'] = coco_result.getImgIds()
    coco_eval.evaluate()
    return coco_eval.eval

# %%
split_res_dict = dict()
con_res_dict = dict()
org_res_dict = dict()
for el in gk.groups.keys():
#     split_res_dict[el] = calc_metrics(topic=el, anno='s')
#     con_res_dict[el] = calc_metrics(topic=el, anno='c')
    org_res_dict[el] = calc_metrics(topic=el, anno='o')
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 565 tokens at 12544.56 tokens per second.
# PTBTokenizer tokenized 452 tokens at 8571.56 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 414, 'reflen': 527, 'guess': [414, 375, 336, 297], 'correct': [95, 22, 7, 3]}
# ratio: 0.7855787476265929
# Bleu_1: 0.175
# Bleu_2: 0.088
# Bleu_3: 0.050
# Bleu_4: 0.031
# computing METEOR score...
# METEOR: 0.083
# computing Rouge score...
# ROUGE_L: 0.139
# computing CIDEr score...
# CIDEr: 0.204
# computing SPICE score...
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.nustaq.serialization.FSTClazzInfo (file:/home/barzamini/PycharmProjects/pycocoevalcap/spice/lib/fst-2.47.jar) to field java.lang.String.value
# WARNING: Please consider reporting this to the maintainers of org.nustaq.serialization.FSTClazzInfo
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Parsing reference captions
# Parsing test captions
# Initiating Stanford parsing pipeline
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - TokenizerAnnotator: No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ...
# done [0.3 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [0.6 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [0.4 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.4 sec].
# Threads( StanfordCoreNLP ) [1.77 seconds]
# Warning: Nashorn engine is planned to be removed from a future JDK release
# SPICE evaluation took: 4.423 s
# SPICE: 0.082
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 1138 tokens at 21900.21 tokens per second.
# PTBTokenizer tokenized 754 tokens at 14401.66 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 678, 'reflen': 1062, 'guess': [678, 601, 524, 447], 'correct': [258, 89, 37, 20]}
# ratio: 0.638418079095444
# Bleu_1: 0.216
# Bleu_2: 0.135
# Bleu_3: 0.090
# Bleu_4: 0.066
# computing METEOR score...
# METEOR: 0.120
# computing Rouge score...
# ROUGE_L: 0.247
# computing CIDEr score...
# CIDEr: 0.582
# computing SPICE score...
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.nustaq.serialization.FSTClazzInfo (file:/home/barzamini/PycharmProjects/pycocoevalcap/spice/lib/fst-2.47.jar) to field java.lang.String.value
# WARNING: Please consider reporting this to the maintainers of org.nustaq.serialization.FSTClazzInfo
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Parsing reference captions
# Parsing test captions
# Initiating Stanford parsing pipeline
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - TokenizerAnnotator: No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ...
# done [0.3 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [0.6 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [0.4 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.4 sec].
# Threads( StanfordCoreNLP ) [1.402 seconds]
# Warning: Nashorn engine is planned to be removed from a future JDK release
# SPICE evaluation took: 4.604 s
# SPICE: 0.129
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 655 tokens at 14265.02 tokens per second.
# PTBTokenizer tokenized 450 tokens at 9975.71 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 408, 'reflen': 613, 'guess': [408, 365, 322, 280], 'correct': [148, 46, 13, 4]}
# ratio: 0.6655791190853743
# Bleu_1: 0.219
# Bleu_2: 0.129
# Bleu_3: 0.074
# Bleu_4: 0.043
# computing METEOR score...
# METEOR: 0.122
# computing Rouge score...
# ROUGE_L: 0.236
# computing CIDEr score...
# CIDEr: 0.414
# computing SPICE score...
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.nustaq.serialization.FSTClazzInfo (file:/home/barzamini/PycharmProjects/pycocoevalcap/spice/lib/fst-2.47.jar) to field java.lang.String.value
# WARNING: Please consider reporting this to the maintainers of org.nustaq.serialization.FSTClazzInfo
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Parsing reference captions
# Parsing test captions
# Initiating Stanford parsing pipeline
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - TokenizerAnnotator: No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ...
# done [0.3 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [0.6 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [0.4 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.4 sec].
# Threads( StanfordCoreNLP ) [0.886 seconds]
# Warning: Nashorn engine is planned to be removed from a future JDK release
# SPICE evaluation took: 4.096 s
# SPICE: 0.149
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 681 tokens at 14703.39 tokens per second.
# PTBTokenizer tokenized 380 tokens at 8340.42 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 335, 'reflen': 636, 'guess': [335, 290, 245, 203], 'correct': [175, 82, 41, 24]}
# ratio: 0.5267295597475995
# Bleu_1: 0.213
# Bleu_2: 0.156
# Bleu_3: 0.119
# Bleu_4: 0.095
# computing METEOR score...
# METEOR: 0.158
# computing Rouge score...
# ROUGE_L: 0.401
# computing CIDEr score...
# CIDEr: 1.628
# computing SPICE score...
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.nustaq.serialization.FSTClazzInfo (file:/home/barzamini/PycharmProjects/pycocoevalcap/spice/lib/fst-2.47.jar) to field java.lang.String.value
# WARNING: Please consider reporting this to the maintainers of org.nustaq.serialization.FSTClazzInfo
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Parsing reference captions
# Parsing test captions
# Initiating Stanford parsing pipeline
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - TokenizerAnnotator: No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ...
# done [0.3 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [0.6 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [0.4 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.4 sec].
# Threads( StanfordCoreNLP ) [0.725 seconds]
# Warning: Nashorn engine is planned to be removed from a future JDK release
# SPICE evaluation took: 3.811 s
# SPICE: 0.322
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 690 tokens at 15256.15 tokens per second.
# PTBTokenizer tokenized 381 tokens at 8301.02 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 348, 'reflen': 657, 'guess': [348, 314, 280, 246], 'correct': [250, 175, 150, 129]}
# ratio: 0.5296803652959975
# Bleu_1: 0.296
# Bleu_2: 0.260
# Bleu_3: 0.246
# Bleu_4: 0.238
# computing METEOR score...
# METEOR: 0.227
# computing Rouge score...
# ROUGE_L: 0.492
# computing CIDEr score...
# CIDEr: 2.008
# computing SPICE score...
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.nustaq.serialization.FSTClazzInfo (file:/home/barzamini/PycharmProjects/pycocoevalcap/spice/lib/fst-2.47.jar) to field java.lang.String.value
# WARNING: Please consider reporting this to the maintainers of org.nustaq.serialization.FSTClazzInfo
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Parsing reference captions
# Parsing test captions
# Initiating Stanford parsing pipeline
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - TokenizerAnnotator: No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ...
# done [0.3 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [0.6 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [0.4 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.4 sec].
# Threads( StanfordCoreNLP ) [0.808 seconds]
# Warning: Nashorn engine is planned to be removed from a future JDK release
# SPICE evaluation took: 3.997 s
# SPICE: 0.284
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 129 tokens at 2593.15 tokens per second.
# PTBTokenizer tokenized 150 tokens at 3393.55 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 139, 'reflen': 118, 'guess': [139, 127, 115, 103], 'correct': [40, 22, 12, 7]}
# ratio: 1.1779661016849325
# Bleu_1: 0.288
# Bleu_2: 0.223
# Bleu_3: 0.173
# Bleu_4: 0.137
# computing METEOR score...
# METEOR: 0.141
# computing Rouge score...
# ROUGE_L: 0.266
# computing CIDEr score...
# CIDEr: 1.150
# computing SPICE score...
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.nustaq.serialization.FSTClazzInfo (file:/home/barzamini/PycharmProjects/pycocoevalcap/spice/lib/fst-2.47.jar) to field java.lang.String.value
# WARNING: Please consider reporting this to the maintainers of org.nustaq.serialization.FSTClazzInfo
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Parsing reference captions
# Parsing test captions
# Initiating Stanford parsing pipeline
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - TokenizerAnnotator: No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ...
# done [0.3 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [0.6 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [0.4 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.4 sec].
# Threads( StanfordCoreNLP ) [0.441 seconds]
# Warning: Nashorn engine is planned to be removed from a future JDK release
# SPICE evaluation took: 3.530 s
# SPICE: 0.097
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 260 tokens at 5895.15 tokens per second.
# PTBTokenizer tokenized 213 tokens at 4734.52 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 195, 'reflen': 242, 'guess': [195, 176, 157, 138], 'correct': [29, 5, 0, 0]}
# ratio: 0.8057851239636125
# Bleu_1: 0.117
# Bleu_2: 0.051
# Bleu_3: 0.000
# Bleu_4: 0.000
# computing METEOR score...
# METEOR: 0.048
# computing Rouge score...
# ROUGE_L: 0.118
# computing CIDEr score...
# CIDEr: 0.199
# computing SPICE score...
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.nustaq.serialization.FSTClazzInfo (file:/home/barzamini/PycharmProjects/pycocoevalcap/spice/lib/fst-2.47.jar) to field java.lang.String.value
# WARNING: Please consider reporting this to the maintainers of org.nustaq.serialization.FSTClazzInfo
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Parsing reference captions
# Parsing test captions
# Initiating Stanford parsing pipeline
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - TokenizerAnnotator: No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ...
# done [0.3 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [0.6 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [0.4 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.4 sec].
# Threads( StanfordCoreNLP ) [0.760 seconds]
# Warning: Nashorn engine is planned to be removed from a future JDK release
# SPICE evaluation took: 3.895 s
# SPICE: 0.054
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 340 tokens at 7005.07 tokens per second.
# PTBTokenizer tokenized 269 tokens at 5923.91 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 249, 'reflen': 320, 'guess': [249, 228, 207, 186], 'correct': [77, 21, 6, 2]}
# ratio: 0.7781249999975683
# Bleu_1: 0.233
# Bleu_2: 0.127
# Bleu_3: 0.071
# Bleu_4: 0.041
# computing METEOR score...
# METEOR: 0.104
# computing Rouge score...
# ROUGE_L: 0.193
# computing CIDEr score...
# CIDEr: 0.291
# computing SPICE score...
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.nustaq.serialization.FSTClazzInfo (file:/home/barzamini/PycharmProjects/pycocoevalcap/spice/lib/fst-2.47.jar) to field java.lang.String.value
# WARNING: Please consider reporting this to the maintainers of org.nustaq.serialization.FSTClazzInfo
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Parsing reference captions
# Parsing test captions
# Initiating Stanford parsing pipeline
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - TokenizerAnnotator: No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ...
# done [0.3 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [0.6 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [0.4 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.4 sec].
# Threads( StanfordCoreNLP ) [0.754 seconds]
# Warning: Nashorn engine is planned to be removed from a future JDK release
# SPICE evaluation took: 3.892 s
# SPICE: 0.109
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 728 tokens at 15600.97 tokens per second.
# Sep 01, 2022 4:45:08 AM edu.stanford.nlp.process.PTBLexer next
# WARNING: Untokenizable:  (U+F0A7, decimal: 61607)
# PTBTokenizer tokenized 538 tokens at 7005.89 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 485, 'reflen': 675, 'guess': [485, 431, 377, 323], 'correct': [243, 143, 100, 74]}
# ratio: 0.7185185185174541
# Bleu_1: 0.339
# Bleu_2: 0.276
# Bleu_3: 0.239
# Bleu_4: 0.214
# computing METEOR score...
# METEOR: 0.180
# computing Rouge score...
# ROUGE_L: 0.380
# computing CIDEr score...
# CIDEr: 2.128
# computing SPICE score...
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.nustaq.serialization.FSTClazzInfo (file:/home/barzamini/PycharmProjects/pycocoevalcap/spice/lib/fst-2.47.jar) to field java.lang.String.value
# WARNING: Please consider reporting this to the maintainers of org.nustaq.serialization.FSTClazzInfo
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Parsing reference captions
# Parsing test captions
# Initiating Stanford parsing pipeline
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - TokenizerAnnotator: No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ...
# done [0.3 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [0.6 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [0.4 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.4 sec].
# Threads( StanfordCoreNLP ) [0.973 seconds]
# Warning: Nashorn engine is planned to be removed from a future JDK release
# SPICE evaluation took: 4.191 s
# SPICE: 0.323
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 46 tokens at 978.34 tokens per second.
# PTBTokenizer tokenized 30 tokens at 695.86 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 26, 'reflen': 42, 'guess': [26, 21, 16, 11], 'correct': [12, 2, 0, 0]}
# ratio: 0.6190476190328799
# Bleu_1: 0.249
# Bleu_2: 0.113
# Bleu_3: 0.000
# Bleu_4: 0.000
# computing METEOR score...
# METEOR: 0.142
# computing Rouge score...
# ROUGE_L: 0.360
# computing CIDEr score...
# CIDEr: 0.257
# computing SPICE score...
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.nustaq.serialization.FSTClazzInfo (file:/home/barzamini/PycharmProjects/pycocoevalcap/spice/lib/fst-2.47.jar) to field java.lang.String.value
# WARNING: Please consider reporting this to the maintainers of org.nustaq.serialization.FSTClazzInfo
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Parsing reference captions
# Parsing test captions
# Initiating Stanford parsing pipeline
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - TokenizerAnnotator: No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ...
# done [0.3 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [0.6 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [0.4 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.4 sec].
# Threads( StanfordCoreNLP ) [0.217 seconds]
# Warning: Nashorn engine is planned to be removed from a future JDK release
# SPICE evaluation took: 3.237 s
# SPICE: 0.000
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 488 tokens at 10922.82 tokens per second.
# PTBTokenizer tokenized 354 tokens at 7900.86 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 324, 'reflen': 458, 'guess': [324, 293, 262, 231], 'correct': [156, 68, 30, 14]}
# ratio: 0.7074235807844816
# Bleu_1: 0.318
# Bleu_2: 0.221
# Bleu_3: 0.155
# Bleu_4: 0.110
# computing METEOR score...
# METEOR: 0.184
# computing Rouge score...
# ROUGE_L: 0.395
# computing CIDEr score...
# CIDEr: 1.101
# computing SPICE score...
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.nustaq.serialization.FSTClazzInfo (file:/home/barzamini/PycharmProjects/pycocoevalcap/spice/lib/fst-2.47.jar) to field java.lang.String.value
# WARNING: Please consider reporting this to the maintainers of org.nustaq.serialization.FSTClazzInfo
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Parsing reference captions
# Parsing test captions
# Initiating Stanford parsing pipeline
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - TokenizerAnnotator: No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ...
# done [0.3 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [0.6 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [0.4 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.4 sec].
# Threads( StanfordCoreNLP ) [0.917 seconds]
# Warning: Nashorn engine is planned to be removed from a future JDK release
# SPICE evaluation took: 4.188 s
# SPICE: 0.247
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 176 tokens at 3965.62 tokens per second.
# PTBTokenizer tokenized 97 tokens at 2232.50 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 90, 'reflen': 169, 'guess': [90, 82, 74, 66], 'correct': [22, 5, 3, 2]}
# ratio: 0.5325443786950738
# Bleu_1: 0.102
# Bleu_2: 0.051
# Bleu_3: 0.035
# Bleu_4: 0.027
# computing METEOR score...
# METEOR: 0.061
# computing Rouge score...
# ROUGE_L: 0.195
# computing CIDEr score...
# CIDEr: 0.640
# computing SPICE score...
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.nustaq.serialization.FSTClazzInfo (file:/home/barzamini/PycharmProjects/pycocoevalcap/spice/lib/fst-2.47.jar) to field java.lang.String.value
# WARNING: Please consider reporting this to the maintainers of org.nustaq.serialization.FSTClazzInfo
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Parsing reference captions
# Initiating Stanford parsing pipeline
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - TokenizerAnnotator: No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ...
# done [0.3 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [0.7 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [0.4 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.4 sec].
# Threads( StanfordCoreNLP ) [5.94 seconds]
# Error: Could not cache item to /home/barzamini/PycharmProjects/pycocoevalcap/spice/cache with key:
# "new york ny march 06 pedestrians walk along a manhattan street on march 6 2018 in new york city a new report by the governors highway safety association estimates the number of pedestrian deaths last year was 6000 nationwide a 33year high the report highlights a number of factors for the continued increase including distracted drivers using mobile devices and a larger number of cars on the road due to an improved economy despite an accident yesterday that took the lives of two small children in brooklyn new york city has been seeing a steady decline of pedestrian deaths since mayor bill de blasios vision zero initiative photo by spencer plattgetty images"
# Caption may be too long
# Parsing test captions
# Threads( StanfordCoreNLP ) [0.402 seconds]
# Warning: Nashorn engine is planned to be removed from a future JDK release
# SPICE evaluation took: 8.545 s
# SPICE: 0.203
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 250 tokens at 5248.17 tokens per second.
# PTBTokenizer tokenized 208 tokens at 4109.19 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 190, 'reflen': 232, 'guess': [190, 171, 152, 133], 'correct': [35, 5, 0, 0]}
# ratio: 0.8189655172378493
# Bleu_1: 0.148
# Bleu_2: 0.059
# Bleu_3: 0.000
# Bleu_4: 0.000
# computing METEOR score...
# METEOR: 0.061
# computing Rouge score...
# ROUGE_L: 0.189
# computing CIDEr score...
# CIDEr: 0.449
# computing SPICE score...
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.nustaq.serialization.FSTClazzInfo (file:/home/barzamini/PycharmProjects/pycocoevalcap/spice/lib/fst-2.47.jar) to field java.lang.String.value
# WARNING: Please consider reporting this to the maintainers of org.nustaq.serialization.FSTClazzInfo
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Parsing reference captions
# Parsing test captions
# Initiating Stanford parsing pipeline
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - TokenizerAnnotator: No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ...
# done [0.3 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [0.6 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [0.4 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.4 sec].
# Threads( StanfordCoreNLP ) [0.629 seconds]
# Warning: Nashorn engine is planned to be removed from a future JDK release
# SPICE evaluation took: 3.796 s
# SPICE: 0.080
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 318 tokens at 7006.48 tokens per second.
# PTBTokenizer tokenized 268 tokens at 6134.77 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 247, 'reflen': 297, 'guess': [247, 225, 203, 182], 'correct': [38, 5, 2, 0]}
# ratio: 0.8316498316470315
# Bleu_1: 0.126
# Bleu_2: 0.048
# Bleu_3: 0.026
# Bleu_4: 0.000
# computing METEOR score...
# METEOR: 0.044
# computing Rouge score...
# ROUGE_L: 0.108
# computing CIDEr score...
# CIDEr: 0.143
# computing SPICE score...
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.nustaq.serialization.FSTClazzInfo (file:/home/barzamini/PycharmProjects/pycocoevalcap/spice/lib/fst-2.47.jar) to field java.lang.String.value
# WARNING: Please consider reporting this to the maintainers of org.nustaq.serialization.FSTClazzInfo
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Parsing reference captions
# Parsing test captions
# Initiating Stanford parsing pipeline
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - TokenizerAnnotator: No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ...
# done [0.3 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [0.6 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [0.4 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.4 sec].
# Threads( StanfordCoreNLP ) [0.757 seconds]
# Warning: Nashorn engine is planned to be removed from a future JDK release
# SPICE evaluation took: 3.853 s
# SPICE: 0.039
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# tokenization...
# PTBTokenizer tokenized 295 tokens at 5890.71 tokens per second.
# PTBTokenizer tokenized 351 tokens at 7992.45 tokens per second.
# setting up scorers...
# computing Bleu score...
# {'testlen': 315, 'reflen': 259, 'guess': [315, 278, 241, 205], 'correct': [56, 17, 6, 0]}
# ratio: 1.2162162162115204
# Bleu_1: 0.178
# Bleu_2: 0.104
# Bleu_3: 0.065
# Bleu_4: 0.000
# computing METEOR score...
# METEOR: 0.108
# computing Rouge score...
# ROUGE_L: 0.152
# computing CIDEr score...
# CIDEr: 0.280
# computing SPICE score...
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.nustaq.serialization.FSTClazzInfo (file:/home/barzamini/PycharmProjects/pycocoevalcap/spice/lib/fst-2.47.jar) to field java.lang.String.value
# WARNING: Please consider reporting this to the maintainers of org.nustaq.serialization.FSTClazzInfo
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Parsing reference captions
# Parsing test captions
# Initiating Stanford parsing pipeline
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.TokenizerAnnotator - TokenizerAnnotator: No tokenizer type provided. Defaulting to PTBTokenizer.
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator parse
# [main] INFO edu.stanford.nlp.parser.common.ParserGrammar - Loading parser from serialized file edu/stanford/nlp/models/lexparser/englishPCFG.ser.gz ...
# done [0.3 sec].
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# Loading classifier from edu/stanford/nlp/models/ner/english.all.3class.distsim.crf.ser.gz ... done [0.6 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.muc.7class.distsim.crf.ser.gz ... done [0.4 sec].
# Loading classifier from edu/stanford/nlp/models/ner/english.conll.4class.distsim.crf.ser.gz ... done [0.4 sec].
# Threads( StanfordCoreNLP ) [0.747 seconds]
# Warning: Nashorn engine is planned to be removed from a future JDK release
# SPICE evaluation took: 3.959 s
# SPICE: 0.097

# %% [markdown]
# # Ped before

# %%
all_res = []
for el in gk.groups.keys():
    all_res.append(org_res_dict[el])
df_res = pd.DataFrame(all_res)
df_res.describe().round(4)
# Out:
#         Bleu_1   Bleu_2   Bleu_3   Bleu_4   METEOR  ROUGE_L    CIDEr    SPICE
# count  15.0000  15.0000  15.0000  15.0000  15.0000  15.0000  15.0000  15.0000
# mean    0.1141   0.0472   0.0187   0.0068   0.0526   0.1269   0.1947   0.0767
# std     0.0351   0.0231   0.0164   0.0114   0.0209   0.0384   0.0655   0.0443
# min     0.0417   0.0000   0.0000   0.0000   0.0071   0.0510   0.1125   0.0000
# 25%     0.0979   0.0333   0.0000   0.0000   0.0399   0.1072   0.1530   0.0466
# 50%     0.1158   0.0461   0.0206   0.0000   0.0469   0.1228   0.1943   0.0748
# 75%     0.1278   0.0597   0.0280   0.0120   0.0686   0.1402   0.2262   0.1031
# max     0.1890   0.0919   0.0534   0.0354   0.0859   0.2084   0.3293   0.1723

# %%
for el in gk.groups.keys():
    print(el)
#     print(split_res_dict[el])
    for metric, score in org_res_dict[el].items():
        print(f'{metric}: {score:.3f}')
    print()
# Out:
# a
# Bleu_1: 0.107
# Bleu_2: 0.046
# Bleu_3: 0.021
# Bleu_4: 0.000
# METEOR: 0.047
# ROUGE_L: 0.108
# CIDEr: 0.166
# SPICE: 0.079
#
# b
# Bleu_1: 0.117
# Bleu_2: 0.052
# Bleu_3: 0.025
# Bleu_4: 0.015
# METEOR: 0.059
# ROUGE_L: 0.125
# CIDEr: 0.251
# SPICE: 0.075
#
# c
# Bleu_1: 0.129
# Bleu_2: 0.064
# Bleu_3: 0.031
# Bleu_4: 0.000
# METEOR: 0.063
# ROUGE_L: 0.147
# CIDEr: 0.202
# SPICE: 0.127
#
# d
# Bleu_1: 0.137
# Bleu_2: 0.056
# Bleu_3: 0.022
# Bleu_4: 0.000
# METEOR: 0.078
# ROUGE_L: 0.173
# CIDEr: 0.199
# SPICE: 0.129
#
# e
# Bleu_1: 0.092
# Bleu_2: 0.031
# Bleu_3: 0.016
# Bleu_4: 0.009
# METEOR: 0.053
# ROUGE_L: 0.132
# CIDEr: 0.119
# SPICE: 0.081
#
# f
# Bleu_1: 0.127
# Bleu_2: 0.049
# Bleu_3: 0.000
# Bleu_4: 0.000
# METEOR: 0.038
# ROUGE_L: 0.110
# CIDEr: 0.194
# SPICE: 0.046
#
# g
# Bleu_1: 0.096
# Bleu_2: 0.036
# Bleu_3: 0.000
# Bleu_4: 0.000
# METEOR: 0.038
# ROUGE_L: 0.095
# CIDEr: 0.150
# SPICE: 0.057
#
# h
# Bleu_1: 0.099
# Bleu_2: 0.025
# Bleu_3: 0.000
# Bleu_4: 0.000
# METEOR: 0.045
# ROUGE_L: 0.103
# CIDEr: 0.113
# SPICE: 0.038
#
# i
# Bleu_1: 0.189
# Bleu_2: 0.092
# Bleu_3: 0.053
# Bleu_4: 0.035
# METEOR: 0.080
# ROUGE_L: 0.178
# CIDEr: 0.297
# SPICE: 0.098
#
# j
# Bleu_1: 0.042
# Bleu_2: 0.000
# Bleu_3: 0.000
# Bleu_4: 0.000
# METEOR: 0.007
# ROUGE_L: 0.051
# CIDEr: 0.117
# SPICE: 0.000
#
# k
# Bleu_1: 0.160
# Bleu_2: 0.083
# Bleu_3: 0.032
# Bleu_4: 0.000
# METEOR: 0.086
# ROUGE_L: 0.208
# CIDEr: 0.197
# SPICE: 0.172
#
# l
# Bleu_1: 0.067
# Bleu_2: 0.030
# Bleu_3: 0.021
# Bleu_4: 0.015
# METEOR: 0.040
# ROUGE_L: 0.133
# CIDEr: 0.329
# SPICE: 0.047
#
# m
# Bleu_1: 0.113
# Bleu_2: 0.040
# Bleu_3: 0.000
# Bleu_4: 0.000
# METEOR: 0.042
# ROUGE_L: 0.110
# CIDEr: 0.167
# SPICE: 0.040
#
# n
# Bleu_1: 0.116
# Bleu_2: 0.041
# Bleu_3: 0.019
# Bleu_4: 0.000
# METEOR: 0.039
# ROUGE_L: 0.107
# CIDEr: 0.156
# SPICE: 0.053
#
# o
# Bleu_1: 0.119
# Bleu_2: 0.065
# Bleu_3: 0.039
# Bleu_4: 0.027
# METEOR: 0.074
# ROUGE_L: 0.123
# CIDEr: 0.263
# SPICE: 0.108

# %% [markdown]
# # ped after wit

# %%
# org_res_dict
all_res = []
for el in gk.groups.keys():
    all_res.append(org_res_dict[el])
df_res = pd.DataFrame(all_res)
df_res.describe().round(4)
# Out:
#         Bleu_1   Bleu_2   Bleu_3   Bleu_4   METEOR  ROUGE_L    CIDEr    SPICE
# count  15.0000  15.0000  15.0000  15.0000  15.0000  15.0000  15.0000  15.0000
# mean    0.1317   0.0557   0.0233   0.0084   0.0599   0.1447   0.2218   0.0962
# std     0.0289   0.0201   0.0160   0.0127   0.0196   0.0403   0.1085   0.0489
# min     0.0878   0.0258   0.0000   0.0000   0.0263   0.0889   0.0792   0.0309
# 25%     0.1130   0.0456   0.0137   0.0000   0.0453   0.1195   0.1694   0.0578
# 50%     0.1325   0.0551   0.0245   0.0000   0.0580   0.1334   0.1957   0.0769
# 75%     0.1405   0.0657   0.0322   0.0194   0.0756   0.1655   0.2563   0.1400
# max     0.2017   0.1101   0.0559   0.0323   0.0950   0.2325   0.5258   0.1837

# %%
for el in gk.groups.keys():
    print(el)
#     print(split_res_dict[el])
    for metric, score in org_res_dict[el].items():
        print(f'{metric}: {score:.3f}')
    print()
# Out:
# a
# Bleu_1: 0.157
# Bleu_2: 0.067
# Bleu_3: 0.027
# Bleu_4: 0.000
# METEOR: 0.059
# ROUGE_L: 0.132
# CIDEr: 0.184
# SPICE: 0.074
#
# b
# Bleu_1: 0.130
# Bleu_2: 0.046
# Bleu_3: 0.017
# Bleu_4: 0.000
# METEOR: 0.058
# ROUGE_L: 0.132
# CIDEr: 0.178
# SPICE: 0.077
#
# c
# Bleu_1: 0.131
# Bleu_2: 0.067
# Bleu_3: 0.037
# Bleu_4: 0.018
# METEOR: 0.072
# ROUGE_L: 0.159
# CIDEr: 0.196
# SPICE: 0.127
#
# d
# Bleu_1: 0.133
# Bleu_2: 0.065
# Bleu_3: 0.028
# Bleu_4: 0.000
# METEOR: 0.087
# ROUGE_L: 0.233
# CIDEr: 0.287
# SPICE: 0.184
#
# e
# Bleu_1: 0.088
# Bleu_2: 0.029
# Bleu_3: 0.011
# Bleu_4: 0.000
# METEOR: 0.043
# ROUGE_L: 0.110
# CIDEr: 0.079
# SPICE: 0.052
#
# f
# Bleu_1: 0.161
# Bleu_2: 0.055
# Bleu_3: 0.000
# Bleu_4: 0.000
# METEOR: 0.068
# ROUGE_L: 0.156
# CIDEr: 0.224
# SPICE: 0.093
#
# g
# Bleu_1: 0.134
# Bleu_2: 0.049
# Bleu_3: 0.023
# Bleu_4: 0.000
# METEOR: 0.049
# ROUGE_L: 0.130
# CIDEr: 0.161
# SPICE: 0.062
#
# h
# Bleu_1: 0.111
# Bleu_2: 0.046
# Bleu_3: 0.025
# Bleu_4: 0.000
# METEOR: 0.045
# ROUGE_L: 0.101
# CIDEr: 0.118
# SPICE: 0.033
#
# i
# Bleu_1: 0.202
# Bleu_2: 0.110
# Bleu_3: 0.056
# Bleu_4: 0.032
# METEOR: 0.095
# ROUGE_L: 0.204
# CIDEr: 0.332
# SPICE: 0.142
#
# j
# Bleu_1: 0.106
# Bleu_2: 0.050
# Bleu_3: 0.000
# Bleu_4: 0.000
# METEOR: 0.026
# ROUGE_L: 0.098
# CIDEr: 0.303
# SPICE: 0.054
#
# k
# Bleu_1: 0.140
# Bleu_2: 0.071
# Bleu_3: 0.039
# Bleu_4: 0.027
# METEOR: 0.080
# ROUGE_L: 0.181
# CIDEr: 0.178
# SPICE: 0.162
#
# l
# Bleu_1: 0.089
# Bleu_2: 0.057
# Bleu_3: 0.038
# Bleu_4: 0.029
# METEOR: 0.046
# ROUGE_L: 0.172
# CIDEr: 0.526
# SPICE: 0.141
#
# m
# Bleu_1: 0.141
# Bleu_2: 0.026
# Bleu_3: 0.000
# Bleu_4: 0.000
# METEOR: 0.051
# ROUGE_L: 0.133
# CIDEr: 0.202
# SPICE: 0.072
#
# n
# Bleu_1: 0.115
# Bleu_2: 0.041
# Bleu_3: 0.027
# Bleu_4: 0.021
# METEOR: 0.040
# ROUGE_L: 0.089
# CIDEr: 0.132
# SPICE: 0.031
#
# o
# Bleu_1: 0.138
# Bleu_2: 0.059
# Bleu_3: 0.023
# Bleu_4: 0.000
# METEOR: 0.080
# ROUGE_L: 0.143
# CIDEr: 0.226
# SPICE: 0.139

# %% [markdown]
# # Ped after fat

# %%
all_res = []
for el in gk.groups.keys():
    all_res.append(org_res_dict[el])
df_res = pd.DataFrame(all_res)
df_res.describe().round(4)
# Out:
#         Bleu_1   Bleu_2   Bleu_3   Bleu_4   METEOR  ROUGE_L    CIDEr    SPICE
# count  15.0000  15.0000  15.0000  15.0000  15.0000  15.0000  15.0000  15.0000
# mean    0.2143   0.1361   0.0895   0.0669   0.1189   0.2579   0.7648   0.1477
# std     0.0743   0.0767   0.0814   0.0780   0.0543   0.1197   0.6772   0.1039
# min     0.1016   0.0478   0.0000   0.0000   0.0442   0.1075   0.1431   0.0000
# 25%     0.1612   0.0736   0.0308   0.0000   0.0719   0.1705   0.2688   0.0812
# 50%     0.2160   0.1269   0.0705   0.0410   0.1204   0.2365   0.4487   0.1094
# 75%     0.2686   0.1888   0.1366   0.1025   0.1501   0.3697   1.1256   0.2254
# max     0.3386   0.2756   0.2463   0.2383   0.2271   0.4921   2.1278   0.3225

# %%
for el in gk.groups.keys():
    print(el)
#     print(split_res_dict[el])
    for metric, score in org_res_dict[el].items():
        print(f'{metric}: {score:.3f}')
    print()
# Out:
# a
# Bleu_1: 0.175
# Bleu_2: 0.088
# Bleu_3: 0.050
# Bleu_4: 0.031
# METEOR: 0.083
# ROUGE_L: 0.139
# CIDEr: 0.204
# SPICE: 0.082
#
# b
# Bleu_1: 0.216
# Bleu_2: 0.135
# Bleu_3: 0.090
# Bleu_4: 0.066
# METEOR: 0.120
# ROUGE_L: 0.247
# CIDEr: 0.582
# SPICE: 0.129
#
# c
# Bleu_1: 0.219
# Bleu_2: 0.129
# Bleu_3: 0.074
# Bleu_4: 0.043
# METEOR: 0.122
# ROUGE_L: 0.236
# CIDEr: 0.414
# SPICE: 0.149
#
# d
# Bleu_1: 0.213
# Bleu_2: 0.156
# Bleu_3: 0.119
# Bleu_4: 0.095
# METEOR: 0.158
# ROUGE_L: 0.401
# CIDEr: 1.628
# SPICE: 0.322
#
# e
# Bleu_1: 0.296
# Bleu_2: 0.260
# Bleu_3: 0.246
# Bleu_4: 0.238
# METEOR: 0.227
# ROUGE_L: 0.492
# CIDEr: 2.008
# SPICE: 0.284
#
# f
# Bleu_1: 0.288
# Bleu_2: 0.223
# Bleu_3: 0.173
# Bleu_4: 0.137
# METEOR: 0.141
# ROUGE_L: 0.266
# CIDEr: 1.150
# SPICE: 0.097
#
# g
# Bleu_1: 0.117
# Bleu_2: 0.051
# Bleu_3: 0.000
# Bleu_4: 0.000
# METEOR: 0.048
# ROUGE_L: 0.118
# CIDEr: 0.199
# SPICE: 0.054
#
# h
# Bleu_1: 0.233
# Bleu_2: 0.127
# Bleu_3: 0.071
# Bleu_4: 0.041
# METEOR: 0.104
# ROUGE_L: 0.193
# CIDEr: 0.291
# SPICE: 0.109
#
# i
# Bleu_1: 0.339
# Bleu_2: 0.276
# Bleu_3: 0.239
# Bleu_4: 0.214
# METEOR: 0.180
# ROUGE_L: 0.380
# CIDEr: 2.128
# SPICE: 0.323
#
# j
# Bleu_1: 0.249
# Bleu_2: 0.113
# Bleu_3: 0.000
# Bleu_4: 0.000
# METEOR: 0.142
# ROUGE_L: 0.360
# CIDEr: 0.257
# SPICE: 0.000
#
# k
# Bleu_1: 0.318
# Bleu_2: 0.221
# Bleu_3: 0.155
# Bleu_4: 0.110
# METEOR: 0.184
# ROUGE_L: 0.395
# CIDEr: 1.101
# SPICE: 0.247
#
# l
# Bleu_1: 0.102
# Bleu_2: 0.051
# Bleu_3: 0.035
# Bleu_4: 0.027
# METEOR: 0.061
# ROUGE_L: 0.195
# CIDEr: 0.640
# SPICE: 0.203
#
# m
# Bleu_1: 0.148
# Bleu_2: 0.059
# Bleu_3: 0.000
# Bleu_4: 0.000
# METEOR: 0.061
# ROUGE_L: 0.189
# CIDEr: 0.449
# SPICE: 0.080
#
# n
# Bleu_1: 0.126
# Bleu_2: 0.048
# Bleu_3: 0.026
# Bleu_4: 0.000
# METEOR: 0.044
# ROUGE_L: 0.108
# CIDEr: 0.143
# SPICE: 0.039
#
# o
# Bleu_1: 0.178
# Bleu_2: 0.104
# Bleu_3: 0.065
# Bleu_4: 0.000
# METEOR: 0.108
# ROUGE_L: 0.152
# CIDEr: 0.280
# SPICE: 0.097
